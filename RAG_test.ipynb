# %%
# !pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.37 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.37)
# Requirement already satisfied: langchain<1.0.0,>=0.3.19 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.12)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.0.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.8.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.9)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<2,>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.37->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (2.27.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.18-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 77.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.8.0-py3-none-any.whl (30 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 6.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.18 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.8.0 python-dotenv-1.0.1 typing-inspect-0.9.0

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 30.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install -U bitsandbytes transformers

# %%
# !pip install faiss-gpu-cu12

# %%
import pandas as pd
import numpy as np
import torch
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFacePipeline
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# %%
data_path = "/content/drive/MyDrive/"

# %%
train = pd.read_csv(data_path+"train.csv" )
test = pd.read_csv(data_path+"test.csv" )
sample = pd.read_csv(data_path+"sample_submission.csv")

# %%
def preprocess(df):
    df.replace('-', np.nan, inplace=True)
    df['공사종류(대분류)'] = df['공사종류'].str.split(' / ').str[0]
    df['공사종류(중분류)'] = df['공사종류'].str.split(' / ').str[1]
    df['공종(대분류)'] = df['공종'].str.split(' > ').str[0]
    df['공종(중분류)'] = df['공종'].str.split(' > ').str[1]
    df['사고객체(대분류)'] = df['사고객체'].str.split(' > ').str[0]
    df['사고객체(중분류)'] = df['사고객체'].str.split(' > ').str[1]
    df['사고인지 시간'] = df['사고인지 시간'].str.split('-').str[0].str.strip()

    return df


train = preprocess(train)
test = preprocess(test)

# %%
# 훈련 데이터 통합 생성
combined_training_data = train.apply(
    lambda row: {
        "question": (
            f"'{row['공사종류(중분류)']}' 공사 중 "
            f"'{row['공종(중분류)']}' 작업에서 "
            f"사고객체 '{row['사고객체(대분류)']}'(중분류: '{row['사고객체(중분류)']}')와 관련된 사고가 발생했습니다. "
            f"작업 프로세스는 '{row['작업프로세스']}'이며, 사고 원인은 '{row['사고원인']}'입니다. "
            f"재발 방지 대책 및 향후 조치 계획은 무엇인가요?"
        ),
        "answer": row["재발방지대책 및 향후조치계획"]
    },
    axis=1
)

# DataFrame으로 변환
combined_training_data = pd.DataFrame(list(combined_training_data))

# %%
# 훈련 데이터 통합 생성
combined_test_data = test.apply(
    lambda row: {
        "question": (
            f"'{row['공사종류(중분류)']}' 공사 중 "
            f"'{row['공종(중분류)']}' 작업에서 "
            f"사고객체 '{row['사고객체(대분류)']}'(중분류: '{row['사고객체(중분류)']}')와 관련된 사고가 발생했습니다. "
            f"작업 프로세스는 '{row['작업프로세스']}'이며, 사고 원인은 '{row['사고원인']}'입니다. "
            f"재발 방지 대책 및 향후 조치 계획은 무엇인가요?"
        )
    },
    axis=1
)

# DataFrame으로 변환
combined_test_data = pd.DataFrame(list(combined_test_data))

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
#gpu 강제 버전
model_id = "NCSOFT/Llama-VARCO-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map={"": 0}  # GPU 0번에 모델 전체를 강제로 올림
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import torch
from langchain_community.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline
from tqdm import tqdm

# Train 데이터 준비
train_questions_prevention = combined_training_data['question'].tolist()
train_answers_prevention = combined_training_data['answer'].tolist()

train_documents = [
    f"Q: {q1}\nA: {a1}"
    for q1, a1 in zip(train_questions_prevention, train_answers_prevention)
]

# 임베딩 생성
embedding_model_name = "jhgan/ko-sbert-nli"
embedding = HuggingFaceEmbeddings(model_name=embedding_model_name)

# 벡터 스토어에 문서 추가
vector_store = FAISS.from_texts(train_documents, embedding)

# Retriever 정의
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 1})

text_generation_pipeline = pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    do_sample=True,
    temperature=0.1,
    return_full_text=False,
    max_new_tokens=64,
    batch_size=16  # 배치 크기 지정 (GPU 메모리에 맞게 조정)
)

prompt_template = """
### 지침: 당신은 건설 안전 전문가입니다.
질문에 대한 답변을 핵심 내용만 요약하여 간략하게 작성하세요.
- 서론, 배경 설명 또는 추가 설명을 절대 포함하지 마세요.
- 다음과 같은 조치를 취할 것을 제안합니다: 와 같은 내용을 포함하지 마세요.

{context}

### 질문:
{question}

[/INST]
"""

llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# 커스텀 프롬프트 생성
prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template,
)

# RAG 체인 생성
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt}
)
# Out:
# <ipython-input-9-0b3b05013cae>:21: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding = HuggingFaceEmbeddings(model_name=embedding_model_name)
# Device set to use cuda:0
# <ipython-input-9-0b3b05013cae>:54: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# %%
tokenizer.padding_side = 'left'

# %%
# 테스트 데이터 준비
test_questions = combined_test_data['question'].tolist()
batch_size = 32  # GPU 메모리에 맞게 조정

test_results = []
print("테스트 실행 시작... 총 테스트 샘플 수:", len(test_questions))

# 배치 단위로 처리
for i in tqdm(range(0, len(test_questions), batch_size), desc="처리 진행률"):
    batch_questions = test_questions[i:i + batch_size]

    # 배치로 문서 검색
    docs_batch = retriever.batch(batch_questions)  # 배치로 문서 검색

    # 검색된 문서에서 답변 추출
    for docs in docs_batch:
        # 문서 1개만 가져오므로 docs[0]의 답변 부분을 추출
        answer = docs[0].page_content.split("A: ")[1]  # "Q: 질문\nA: 답변" 형식 가정
        test_results.append(answer)

print("\n테스트 실행 완료! 총 결과 수:", len(test_results))
# Out:
# 테스트 실행 시작... 총 테스트 샘플 수: 964
# 처리 진행률: 100%|██████████| 31/31 [00:22<00:00,  1.40it/s]
# 테스트 실행 완료! 총 결과 수: 964

# %%
from sentence_transformers import SentenceTransformer

embedding_model_name = "jhgan/ko-sbert-sts"
embedding = SentenceTransformer(embedding_model_name)

# 문장 리스트를 입력하여 임베딩 생성
pred_embeddings = embedding.encode(test_results)
print(pred_embeddings.shape)  # (샘플 개수, 768)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.44k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# (964, 768)

# %%
submission = pd.read_csv(data_path+"sample_submission.csv", encoding = 'utf-8-sig')
# 최종 결과 저장
submission.iloc[:,1] = test_results
submission.iloc[:,2:] = pred_embeddings
submission.head()

# 최종 결과를 CSV로 저장
submission.to_csv('submissionv2.csv', index=False, encoding='utf-8-sig')

# %%
test_results
# Out:
# ['시공사 현장 정리 및 위험요소 점검 처리, 안전교육 철저, 공사장 부대 통로 연약지반 취환, 경상남도교육청 시설감리단 합동안전점검 및 공정회의 개최, 사고부위 재시공을 위한 구조기술사와 감독관 및 시공회사의 합동점검 실시.',
#  '근로자 안전 교육 및 방호덮개 확인과 현장 안전관리 감독을 통한 재발 방지 대책.',
#  '작업자가 계단으로 이동할 때 충분한 시야를 확보하고 이동하는 조치.',
#  '안전 및 현장 관리 철저.',
#  '작업자 안전 교육 및 자재 관리와 정리의 철저함.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '신호수 배치를 통한 작업 추진과 안전 교육 실시.',
#  '안전사고 요인 제거에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업발판 사용 시 수평상태 유지, 승하강 시 바닥상태 점검, 무리한 동작 및 불안전한 행동 방지를 위한 교육 실시와 재해 발생 방지를 위한 안전교육 실시.',
#  '안전교육 강화를 통한 재발 방지 대책과 시공자측의 산재처리 및 안전교육 강화 예정에 따른 향후 조치 계획.',
#  '근로자 안전 교육 철저 등.',
#  '사고원인에 따라 재발방지 대책 수립과 유사사고 발생 방지를 위한 공사현장 관리 철저.',
#  '고정바이스 사용, 톱날의 충분한 회전 확인 후 절단작업 실시, 절단방지용 장갑 착용 및 맨손 작업 금지, 해당 공종에 대한 수시 위험성 평가 및 위험성 평가 전파 교육 실시.',
#  '시공사 비계점검 및 작업자 안전관리 지도의 시행.',
#  '근로자 임의 작업금지 및 단순 작업에 대한 작업계획 수립과 위험작업구간 관리감독 패트롤 강화를 통한 재발 방지 대책과 사고사례 중심의 특별안전교육 실시, TBM 및 작업 전 5분 안전교육을 활용한 고위험작업 주의사항 및 안전수칙 교육 실시, 작업 전 작업내용, 작업수칙, 안전수칙 등의 숙지상태 확인 철저를 포함한 향후 조치 계획.',
#  '현장 안전점검 실시와 작업자 안전교육 강화.',
#  '재발 방지를 위한 작업자 안전교육 실시.',
#  '재발 방지 및 향후 조치 계획.',
#  '실족방지망 설치와 타설 작업 시 2인 1조 작업 실시.',
#  '재발 방지 계획 및 안전보건관리계획 이행 요청 확인',
#  'T.B.M 및 건설기계 하역 실시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '개인 보호구 착용 방법 교육 및 이동 시 위험 요소 제거 등의 재발 방지 대책과 향후 조치 계획.',
#  '위험 예지 상황 반복 교육과 사고자 산재처리 및 재발 방지를 위한 현장 교육 실시.',
#  '고소작업대 이동구간 지반 단차 부위 흙 되메우기 실시, T/L 내부 구조물 보양, 사고사례 교육 및 부딪힘 사고 예방 교육 실시.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '현장작업발판에 대한 대체와 안전교육, 관리감독 철저를 포함한 향후 조치 계획.',
#  '안전사고 방지를 위한 철저한 지시.',
#  '관련 공종 전 작업자 유해위험사항 재교육과 시공사 및 감리자 행정지도 실시',
#  '작업자 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전의식 강화와 안전관리 철저를 통한 재발 방지 대책.',
#  '안전교육 실시와 안전환경 조성을 위한 통행 공간 확보.',
#  '해당 구간과 동일한 작업에 대해 사전 계획에 따른 시공 여부 및 해체 방법의 올바른 진행 여부를 관리 감독자와 팀장이 사전 확인하고, 근로자에게 전파할 수 있도록 작업 전 T.B.M을 실시하여 운영하는 방안.',
#  '재발 방지 대책과 향후 조치 계획의 마련.',
#  '위험성 평가 회의를 통한 작업 방법 개선과 안전 수칙 및 작업 방법에 대한 지식, 기능, 태도 교육 실시와 산업 재해 처리 예정.',
#  '특별안전교육과 재발방지 교육 실시.',
#  '중량물 작업 시 2인 1조 작업 진행과 사고 사례 및 작업 방법 교육 실시.',
#  '철근 배근 구간 안전 발판 설치 및 인동선 구획 설정.',
#  '버팀 해체 구간 통로 확보 및 근로자 작업방법 안전교육 실시와 함께, 건설사업관리단을 통한 시공사 안전교육 철저 지시 및 작업통로 미확보 시 공사중단 조치.',
#  '해당 팀 사고사례 전파와 파이프 줄걸이 고정을 통한 작업 안전 관리 철저 및 안전 교육 실시.',
#  '건설 자재 이동 및 정리에 대한 향후 조치 계획.',
#  '작업자의 안전교육 강화와 현장 자재 정리정돈을 통한 안전관리 강화.',
#  '버팀 해체 구간 통로 확보 및 근로자 작업방법 안전교육 실시와 함께, 건설사업관리단을 통한 시공사 안전교육 철저 지시 및 작업통로 미확보 시 공사중단 조치.',
#  '안전통로 확보와 작업구간 위험요소 제거 및 안전교육 실시.',
#  '압송배관 사용 시 노후 여부 확인 및 커플러 체결 철저 확인, 콘크리트 타설 시 장비 및 자재 점검, 노후된 압송배관 폐기처리, 타설 전 이동통로 확보 및 안전교육 실시.',
#  '현장안전점검 및 안전교육 실시.',
#  '고소 작업 시 생명줄 설치 후 안전벨트 고리 체결 및 작업방법에 대한 근로자 안전교육 실시와 작업지휘자 배치, 시공사에 사고조치 입력 지시 및 근로자 안전사고 예방교육 지시.',
#  '갱폼 핀 해체 후 이동 시 안전고리 체결 및 기 체결한 안전고리 해체에 대한 재발 방지 대책 수립.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업방법 변경과 점검 및 교육을 통한 재발 방지 대책 마련.',
#  '안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 발판 고정 및 결속작업개시 전 이동 구간 내 서리 등 사고 위험 방지 방안.',
#  '지정통로 이동 교육 및 서포트 고정상태 수시점검 실시',
#  '휴식시간 내 임의로 작업장 출입금지 및 발판주변 식별조치 시행.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '안전교육 강화와 안전관리 철저를 통한 재발 방지 대책 마련.',
#  '안전관리 숙지 및 안정성 검토에 대한 재발 방지 대책과 향후 조치 계획.',
#  '사고사례 전파를 통한 재발 방지 대책 마련.',
#  '자재 야적공간 확보, 작업공간 확보, 작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전통로 확보와 통로 내 자재 적치 금지 조치.',
#  '윈치를 이용한 양중 작업 시 작업허가서 제출 승인 및 특별 안전교육 강화, 관리감독자 확인점검 실시, 위험성 평가 회의를 통한 웨지앙카 고정방법 설명 및 사전점검으로 재해예방대책 토론 실시, 도비 전문업체에서 플레이트판 2개소 이상 설치하여 작업 실시, 웨지앙카 고정 시 당초 4ea(m12*80l)에서 변경된 4ea 이상(m19*150l) 고정으로 충분한 근입깊이 확인 후 양중작업 실시.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '근로자 개인보호구 지급 및 착용 확인 철저, 불안전한 위치 자재 적치 금지 및 1m 높이 이하 자재 적치 실시로 전도 예방, 해당 공종 근로자 대상 재해사고 사례교육 실시, 사고원인 파악 후 재발방지 조치 행정지도 및 시공사에 재해자 피해보상 조치 여부 사후 확인.',
#  '작업 시 안전규칙 준수와 안전 준수에 대한 향후 조치 계획.',
#  '작업자 작업유의 계도의 재발 방지 대책 및 향후 조치 계획.',
#  '사고원인 파악 및 관련 안전교육 철저 시행.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '사고사례 전파와 작업구간 안전조치에 대한 향후 조치 계획.',
#  '현장 정리정돈 철저와 안전 교육 실시를 통한 재발 방지 대책.',
#  '모든 고소작업 및 상부작업은 고소작업대를 이용하여 진행하고, 공사 작업 시 안전수칙 준수를 요청하며, 공사 작업자를 대상으로 시공사 주재 하에 교육을 실시하는 조치.',
#  '안전교육 철저와 통원치료 예정에 따른 재발 방지 대책.',
#  '작업전 작업내용 및 방법에 대한 전파 및 교육 실시, 적절한 도구 사용 및 개인 보호구 착용 실시, 작업전 위험성에 대한 안전교육 실시.',
#  '통로 정비 및 이동 중 주의 교육을 포함한 산업재해조사표 제출.',
#  '근로자 안전의식 고취와 재해예방교육 시행, 이동식틀비계 현장 작업자 안전교육 실시를 통한 재발 방지 대책 마련.',
#  '작업자 불안전한 행동에 대한 안전교육 실시.',
#  '작업자에 대한 특별안전교육 실시와 현장 내 장비 재정비.',
#  '근로자 근무환경 유의에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업물 위치 조정과 자재 위치 변경 및 교육 실시를 통한 재발 방지 대책.',
#  '작업자 교육과 안전교육의 철저함.',
#  '근로자 안전교육 실시, 고소구간 작업 시 구조물 또는 생명줄 설치로 안전벨트 고리 체결, 전기 공도구 접지 상태 및 노출충전부 절연조치 상태 점검, 고소작업구간 걸이시설 확보 확인, 비계 설치 후 작업 실시.',
#  '거푸집 자재 해체 후 자재 정리와 이동 구간 통로 확보에 대한 조치 계획.',
#  '작업자 안전교육 및 주의 철저.',
#  '안전대책 강화를 통한 재발 방지 및 향후 조치 계획.',
#  '현장관리를 철저히 하는 재발 방지 대책과 향후 조치 계획.',
#  '데크플레이트 철근 상부 작업자 통로 확보에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '콘크리트 타설구간 하부 계단 천막 보양 시 조명 확보, 결빙구간 열풍기 및 고체연료 설치, 근로자 정기교육 및 작업 전 특별교육 실시를 통한 안전 확보.',
#  '안전교육 강화를 통한 재발 방지 대책 마련.',
#  '작업 시 안전교육 및 보호구 착용과 안전매트 설치를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '재발 방지를 위한 교육 독려와 안전교육 실시.',
#  '양중 시 자재 인양장비 변경(하카->샤크)과 현장관리 철저를 통한 관련사고 재발 방지.',
#  '현장대리인에게 구체적인 사고 경위와 사고 재발 방지대책 마련, 직원 안전교육 실시, 작업자 안전교육 철저, 시설점검 강화 등 안전사고 방지에 만전을 기하도록 행정지도 예정.',
#  '사고사례 위험성평가 적용 및 이행관리점검과 중량물 작업 시 작업자 안전보건교육 실시를 통한 동일사고 재발 방지 교육 및 안전관리 요청.',
#  '현장 안전 점검 및 관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '사고경위 상세 파악, 안전관리 미흡사항 확인 및 조치, 보완, 특별안전교육 실시.',
#  '건설공사 안전사고 사례전파 및 안전교육 철저 시행과 산재처리에 대한 조치 계획.',
#  '작업자 안전 및 보건교육을 통한 작업성 질병 예방.',
#  '거푸집해체 작업 시 안전교육 철저 및 관리자와 안전지킴이 배치와 병원 이송 후 당일 시술 완료를 통한 재발 방지 대책 마련.',
#  '굴착부 토사 안정상태 확인 후 작업 투입, 굴착부 붕괴 우려 시 작업 전 토사 제거 작업 시행, 현장 근로자 특별 전체 안전교육 실시 및 건설사업관리단과 시공사의 안전교육 실시.',
#  '전동 톱 사용 시 주의와 철제 노출 부분의 수작업 진행.',
#  '안전사고 재발 방지를 위한 작업자 안전교육 실시',
#  '작업자와 근로자 안전교육 강화를 통한 재발 방지 대책.',
#  '재발 방지 대책과 향후 조치 계획의 통합으로 집게를 이용한 인양 작업 금지, 신호수 및 장비 운전원에 대한 특별 안전교육 실시, 작업자 및 관리자의 위험성 평가에 사고 사례 반영, 정기 안전교육 및 초기 투입자 교육에서 사고 사례 공유, 관리 감독자 및 작업지휘자의 안전활동 강화, 시공사에 재발 방지 대책 수립 요청, 자재 운반 시 적합한 장비 및 방법 시행 지시, 신규 근로자 관리 및 교육 철저 지시가 포함된 안전 관리 방안.',
#  '2인1조 작업 시행과 목재틀 거푸집 바닥 자립 시공을 통한 재발 방지 대책 및 작업방법 개선 계획.',
#  '사고사례 전파 및 교육을 통한 재발 방지 대책과 향후 조치 계획.',
#  '수레에 레미탈 적재 수량을 6Box포 이하로 운반하고, 일일 TBM 진행 시 단독작업 여부를 확인하며 2인1조 작업을 관리하고, 운반경로 내 장애물을 제거하고 경로를 확인한 후 작업을 진행하며, 전체 BP 소장 사고사례를 전파하고 재발 방지 대책에 대한 특별 교육을 실시하고 작업 전 충분한 스트레칭 및 안전작업 주의사항 교육을 실시하는 조치.',
#  '작업자 안전교육을 통한 재발 방지 대책.',
#  '굴착기 위험반경 접근금지 안전방호장치 설치, 장비유도자 추가 배치 및 특별안전교육 시행.',
#  '배수로 바닥의 경사와 이끼류 서식으로 인한 고압 살수 및 미끄럼방지시설 설치 작업.',
#  '안전의식 강화와 안전관리 철저를 통한 재발 방지 대책.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '주요 공사장에 사소사례 전파 및 사고 예방 점검 실시',
#  '자재 정리에 대한 강조와 재발 방지 대책.',
#  '안전작업계획 수립 및 안전교육 실시 후 작업 진행.',
#  'TBM 시 작업방법 및 안전사항 관리감독 강화, 해당 작업의 위험성 및 몸 균형상실에 대한 안전교육 실시, 공정별 작업 시 안전지시 및 관리감독 강화, 불시점검 실시와 확인.',
#  '안전사고 유의를 위한 개인보호구 및 안전장구 배부.',
#  '현장 점검 및 근로자 안전교육 실시.',
#  '안전고리 부착시설 설치와 말비계 사용 안전수칙 교육을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '고소작업대 신호수 배치 및 동일구간 동시 작업 금지, 안전교육 및 장비 운전인원과 유도원 교육 실시, 장비 유도원 배치 시 자리 이탈 금지, 유사사고 발생 방지를 위한 공사현장 고소작업차 사용자 안전수칙 사항을 광주건축사협회에 발송하여 홍보 협조 요청.',
#  '철근 조립작업 시 숙력공 배치와 작업 전 안전교육을 통한 안전의식 고취 및 현장 수시점검을 통한 관리감독자의 안전관리 철저 지도가 필요함.',
#  '사고 원인 분석과 재발 방지 대책 수립, 근로자 안전 교육 실시.',
#  '작업자 안전교육 실시와 현장 감시 강화에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '비계 버팀대에 안전표지판 설치와 보행 중 동선 내 장애물 유무 확인.',
#  '해체작업 순서 준수와 작업구간 접근 금지, 사고사례 전파 및 근로자 교육 실시를 통한 재발 방지 대책.',
#  '해당 작업징 주변 정리정돈 실시 및 가설계단 설치를 통한 넘어질 위험 방지.',
#  '거푸집 자재 해체 후 자재 정리와 이동 구간 통로 확보에 대한 조치 계획.',
#  '안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자 특별안전교육 실시, 시공사의 재발 방지 대책 수립, 재해조사표 작성 후 노동부 신고 및 산업재해 처리 진행상태 확인, 재발 방지 대책 수립 내용 확인, 해댕공종 근로자 특별안전교육 실시 여부 확인, 작업장 불안전 상태의 시설물 보완조치 및 지속적 확인, 작업자의 불안전 행동 지속적 확인 등의 안전 점검 시행.',
#  '작업통로 안전확인 점검 및 작업자 안전작업 준수 지시',
#  '회전체에 손이 접촉되지 않도록 근원적 차단, 1장씩 낱개 절단 실시, 회전체 작업 시 적정 보호구 착용, 근로자 집합교육 및 사고사례 전파를 통한 재발 방지 대책 마련.',
#  '안전교육 및 주의 철저 등의 재발 방지 대책과 향후 조치 계획.',
#  '작업 전 주변 정리정돈 실시.',
#  'TBM활동 및 일일안전교육 철저, 위험성평가 반영 후 배포, 근로자 아침조회시 교육 실시.',
#  '작업자 안전교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '핸드그라인더 사용 시 주의 예방 교육 실시와 건설기계 사용 전 교육 요청을 통한 재발 방지 대책 마련.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '미끄러지지 않도록 난간 안전 조치 설치 완료.',
#  '작업구간 정리정돈 및 작업자 안전교육 실시.',
#  '관리감독자의 현장 내 수시 순찰 실시.',
#  '작업 시 무리하게 힘을 주지 않고, 작업 순서와 방법에 맞게 작업을 실시하는 방안.',
#  '작업 전 자재 사용 설명 숙지와 산재 처리에 대한 조치 계획.',
#  '작업자를 대상으로 한 안전교육 강화와 작업 시 안전관리 철저, 재해예방기술지도 업체의 현장 방문 및 위험요소 파악 제거 완료에 따른 안전사고 재발 방지를 위한 건축공사장 안전관리 철저 요청.',
#  '작업장의 자재 정리정돈 철저, 해체시 작업장 이동통로 확보, 작업근로자에 대한 안전 교육철저, 조치여부 확인 실시.',
#  '이동 시 안전한 보행통로 이동을 위한 교육 실시.',
#  '안전교육 및 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업근로자에 대한 안전 조치 여부 확인 및 안전교육, 안전관리 컨설팅 시행 검토.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '현장 작업자의 안전교육 강화와 근로자 건강검진 실시.',
#  '현장 안전활동 강화 및 시설물 점검을 통한 안전사고 예방 철저.',
#  '안전보행로 확보와 안전 난간 설치, 미끄럼 물건 제거를 포함한 재발 방지 대책과 향후 조치 계획.',
#  '현장책임자에게 관리 감독 철저 및 유사사고 재발 방지를 위한 TBM시간 활용 안전교육 실시.',
#  '근로자 안전 교육 철저 등.',
#  '작업 전후 안전교육 및 현장 정리정돈 철저, 부상자 산업재해 처리와 통원치료, 작업 전 안전사고 사례 전파 및 안전교육 실시.',
#  '시스템동바리 상부 발판 설치 시 2개소 이상 견고하게 고정하고 고소작업자의 안전고리 체결상태를 확인하며, 시스템비계 및 시스템동바리 상부에서 작업 시 작업발판 설치상태와 근로자의 개인보호구 착용상태를 점검하고 아침조회 및 TBM을 통해 근로자들에게 전달 및 교육하는 절차.',
#  '해체작업 시 이동통로 확보 및 주변 정리정돈 철저.',
#  '자재운반 시 인력운반 지양 및 소운반 시 리어카 이용과 근로자 이동동선 및 작업방법 사전확인.',
#  '작업전 주변 정리 철저 및 안전교육 실시와 일일단위 건강 확인.',
#  '안전교육 철저 등.',
#  '비계발판 보완, 안전난간 보완, 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업발판 사이 틈 제거와 단차부위 안전표지판 설치, 지상층 외부 비계 정리정돈, 단차부위 제거를 위한 작업발판 보강, 자재물 낙하 방지를 위한 쪽망 설치.',
#  '안전시설 추가 설치와 작업자 안전교육 실시를 통한 재발 방지 대책.',
#  '안전교육을 포함한 재발 방지 대책과 향후 조치 계획.',
#  '근로자 재발 방지 교육과 안전관리에 철저하도록 유선상 통보하는 조치 계획.',
#  '현장 안전관리 강화를 통한 조치 완료.',
#  '작업통로 정리정돈에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '근로자 안전교육 강화 및 작업 전, 중 근로자 개인보호구 착용상태 확인 후 작업실시.',
#  '재발 방지 및 향후 조치 계획에 대한 기타 사항.',
#  '상부 스트러트 위 작업 시 스트러트 하부에서 건설기계 작업 중지, 신호수 배치, 작업 개시 전 작업내용 숙지 및 안전교육 강화를 포함한 재발 방지 대책과 현장 지시, 수시 현장 방문 및 점검을 통한 향후 조치 계획.',
#  '자재적치 시 밴딩 강화 및 작업구간 안전확보, 작업간 안전거리 철저 준수.',
#  '작업자 안전교육 및 안전조치 교육 실시.',
#  '간이 흙막이 설치, 기존 구조물 사전조사, 작업자 대상 교육 실시를 통한 안전사고 재발 방지 대책.',
#  '교육 실시와 병원 진료를 통한 재발 방지 대책 마련.',
#  '작업 전 위험성 평가를 통한 위험 요인 사전 도출 및 저감, 배관 이동 시 전용 대차 제작 사용, 인양 이동 및 기타 설치 작업 시 숙련공을 통한 작업 진행, 그리고 건설 현장 부상 사고 발생에 따른 안전 관리 교육 철저 공문 발송.',
#  '작업자 안전교육 재실시.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '근로자 안전교육 실시, 천막 보양구간 내 통로부분 하단 로프 제거, 핸드자키 운반 시 라젯트 고정바 확보 및 설치 후 작업, 작업 전 이동 동선 확인 및 3미터 이상 빔 자재 이동 시 이동원 배치.',
#  '작업발판 위 작업 근로자에 대한 사고사례 전파교육 실시와 관리감독 철저, 동일 공종에 대한 안전교육 및 관리감독 확인 실시.',
#  '안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '현장 내 자재 정리와 안전 교육을 통한 재발 방지 대책 마련.',
#  '무리한 작업 강행금지, 자재 인양 시 유도로프 교체(웨빙띠 -> 안전로프), 안전교육 철저 시행.',
#  '보행로의 고른 다짐과 되메우기를 통한 재발 방지 대책.',
#  '불안전한 행동을 하지 않도록 교육 실시와 관리감독 강화를 통한 재발 방지 대책.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 전 작업구역 내 요철부 등의 지형, 지물 파악 및 정리정돈 실시와 작업 시작 전 작업에 대한 안전교육 실시 및 사고 사례 전파.',
#  '작업자 안전교육 실시와 현장 관리감독 강화를 통한 재발 방지 대책 마련.',
#  '후속공정 투입 전 관리감독자의 확인 및 개구부 표지 부착을 통한 시인성 확보와 개구부 발생 시 통제구획 및 시인성 확보를 위한 표지 부착 지도의 실행.',
#  '작업자 주의조치를 통한 안전사고 예방과 부상자의 산업재해보험 처리를 통한 약 2달간의 입원치료 계획.',
#  '사고 이후 비계 철거, 유사작업 시 위험성 파악 및 교육 실시, 작업자 안전관리 감독 강화와 유사사고 재발방지 대책 제출 통보.',
#  '가능한 장비를 활용한 이동 진행.',
#  '말비계 사용 금지, 틀비계 안전 난간대 및 안전 보호구 착용 후 작업 진행과 근로자의 퇴원 후 통원 치료, 현장에서의 위험물 제거 및 개선 조치, 근로자 안전 교육 실시를 포함한 재발 방지 대책.',
#  '토사 반입 시 평탄한 곳으로 반입하고, 사고 발생 사례를 타 현장에 전파하며 재발 방지 교육을 실시하는 방안.',
#  '작업 전 주변 위험요인 확인 및 작업 후 특이사항 공유.',
#  '결빙구간 제거와 결빙 시 보온재를 깔아 미끄럼 방지를 위한 조치 계획.',
#  '작업 시 안전교육 및 위험작업 관리자 배치 지도의 재발 방지 대책.',
#  '안전철저 지시와 안전관리 철저를 통한 재발 방지 대책.',
#  '자재운반 시 통행로 확보, 불안전한 작업 금지, 작업자 안전수칙 교육 실시.',
#  '안전고리 체결 및 안전난간대 설치를 통한 재발 방지 대책과 향후 조치 계획.',
#  '현장 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '말비계 사용 금지, 틀비계 안전 난간대 및 안전 보호구 착용 후 작업 진행과 근로자의 퇴원 후 통원 치료, 현장에서의 위험물 제거 및 개선 조치, 근로자 안전 교육 실시를 포함한 재발 방지 대책.',
#  '사고사례 전파 및 사전 개인보호구 착용상태 확인, 안전교육 시행 및 현장 관리 강화.',
#  '개인 안전보호구 착용 철저.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '안전사고 재발 방지를 위한 안전관리 계획 수립과 현장점검 강화를 통한 안전관리 강화 및 공사중지 사항에 대한 향후 관련 기관 조사 결과에 따른 행정조치 예정.',
#  '시스템 비계 내측 설치 및 안전 발판 설치에 따른 재발 방지 대책.',
#  '연결고리 추가 제공과 작업전 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 구역 내 정리 정돈 및 이동통로 확보와 작업에 대한 안전교육 및 사고사례 전파 실시.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '이동 구간 간섭시설물 미끄럼 방지 테이프 부착과 사고사례 전파를 통한 향후 조치 계획.',
#  '단독작업 금지와 공사현장에서의 안전교육 강화 예정.',
#  '작업장 정리정돈 및 작업자 안전교육 실시.',
#  '작업자 이동통로 잔여자재 정리정돈, 안전교육 실시 및 현장 일일위험성평가 등록과 관리 확인.',
#  '거푸집해체 작업 시 안전교육 철저 및 관리자와 안전지킴이 배치와 병원 이송 후 당일 시술 완료를 통한 재발 방지 대책 마련.',
#  '버팀 해체 구간 통로 확보 및 근로자 작업방법 안전교육 실시와 함께, 건설사업관리단을 통한 시공사 안전교육 철저 지시 및 작업통로 미확보 시 공사중단 조치.',
#  '작업반경 변경, 위험성 평가 및 이행 관리, 사전 위험 요소 제거 및 안전 교육 강화를 통한 재발 방지 대책과 산재 신청을 포함한 향후 조치 계획.',
#  '작업 인원 안전교육 강화와 2인 이상 작업 준수를 통한 재발 방지 대책 및 작업 관련사항 숙지와 안전관리자의 현장 상주, 관리 감독자의 수시 확인을 통한 향후 조치 계획.',
#  '작업자 진출입로의 부지정지 및 추가 장애물 요소 제거, 주변 정리, 작업자 안전교육 강화와 같은 재발 방지 대책과 작업로 부지정지, 안전교육 강화, 재발 방지 계획의 향후 조치 계획.',
#  '가시설 계획 변경, 전근로자 안전교육, 위험성 평가 등급 조정으로 인한 재발 방지 대책.',
#  '재발 방지를 위한 해당 재해 위험성 평가 실시 및 동종 근로자 사고 사례 안전 교육, 보행 구간 통로 확보 및 정리 정돈 실시와 재발 방지 대책 이행 여부 확인.',
#  '자재 정리 정돈과 이동통로 확보를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '전체 작업발판 흔들림 재점검 실시',
#  '주의 필요성과 향후 조치 계획의 수립.',
#  '불안정한 자재 작업 지양에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업장 정리정돈 및 정기교육 실시, 슬라브 위 절단작업 중지, 전원반 적소 배치로 작업선 유지 조치.',
#  '동일한 사고가 발생하지 않도록 행정지도 시행.',
#  '안전교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전작업방법 및 안전보호구 착용과 불티 비산 예방교육 실시, 불티 방지 보양시설 설치, 현장 관리감독 강화, 피해상황 추적관찰.',
#  '2인1조로 자재 인력운반 작업 시 신호체계를 준수하여 작업 이행.',
#  '작업 전 바닥 평탄작업 및 안전통로 확보를 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육 실시와 공도구 방호장치 점검, 현장점검 실시.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '동일한 사고가 발생하지 않도록 안전교육 실시.',
#  '공사현장 안전사고 재발 방지를 위한 근로자 안전교육 강화와 안전의식 고취.',
#  '작업 중 리프트카의 이동에 방해되는 ㅇ서 제거와 작업자 간 협조가 원활하게 이루어지도록 하는 교육 실시.',
#  '작업자 작업방법 및 안전교육 강화에 대한 재발 방지 대책과 향후 조치 계획.',
#  '융착기에 협착방지링 설치를 통한 협착 방지 조치.',
#  '밸브 연결부 개선 및 교체, 작업절차 준수, 근로자 특별 안전교육을 포함한 재발 방지 대책과 향후 조치 계획.',
#  '근로자 안전교육 강화 및 사고사례 전파 현황 추적 관리.',
#  '안전사고 방지를 위한 안전관리자 상주 및 안전교육 강화와 안전사고 재발방지 계획서 수립, 안전관리자 선임, 시설물 보완을 통한 조치 계획.',
#  '작업자 혈압 체크 후 현장 투입, 안전교육 및 TBM 실시 철저를 포함한 건설사고 재발 방지 대책 수립 및 제출 통보.',
#  '자재 운반 시 과적 금지를 위한 안전 교육 실시.',
#  '유리 보관 파레트의 철제 유리 전용 파레트로 교체와 결속 철저를 통한 향후 조치 계획.',
#  '건설사업관리단 대상 안전한 작업지도 요령 향상과 건설사업관리 지도 요령 강화.',
#  '현장 작업자의 안전교육 강화와 근로자 건강검진 실시.',
#  '작업전 작업자세의 중요성과 주의분산 방지에 대한 인식 제고, 산재보상보험 처리 및 작업중 주의분산 방지에 대한 교육 실시.',
#  '작업자 안전교육 및 안전관리 교육 실시.',
#  '관 하차 시 로프를 연결하기 전 관의 움직임 여부를 확인하는 주의 사항.',
#  '동일한 사고가 발생하지 않도록 안전교육 실시.',
#  '작업장 바닥 정리된 상태에서 작업 실시.',
#  '특별 교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전교육 철저 시행.',
#  '작업자에게 주의 요청을 포함한 재발 방지 대책.',
#  '근로자 이동간 적재자재 주의 안전교육 진행과 산업재해조사표 제출 완료.',
#  '작업자들 안전교육 실시를 통한 유사/동일 사고 재발 방지.',
#  '1인 작업 지양을 위한 팀 관리 작업 시행과 산업 조사 재해표 제출 및 사고자 일일 유선 관리의 필요성.',
#  '작업 시 관리 감독자의 상주 확인과 압송관 청소 시 주변 인원의 철저한 통제를 통한 재발 방지 대책과 제출된 서류 확인 및 안전교육 강화를 포함한 향후 조치 계획.',
#  '작업 전 작업 요령 숙지 및 주변 위험 요소 확인 후 작업 시행.',
#  '작업 시 주의 조치에 대한 재발 방지 대책.',
#  '안전교육 및 안전관리 철저 지시.',
#  '공사 완료로 인한 해결 완료.',
#  '재발 방지 대책과 향후 조치 계획으로 재발방지 특별안전교육 실시 및 작업환경 사전 숙지 후 작업 진행, 기 설치된 안전시설물 해체 금지 교육 실시.',
#  '굴착기를 이용한 굽힘 작업 실시.',
#  '안전관리철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업 전 서포트 고정상태 확인 및 점검, 해체구간 타근로자 접근금지 표지판 설치, 관리감독자 상주하여 위험요소 근절, 해체구간 정리정돈 및 근로자 안전교육 실시.',
#  '작업 전 이동통로 확보와 재발 방지 대책 수립 및 지도 점검으로 인한 향후 조치 계획.',
#  '각종 기기와 장비 작동 시 작업반경 내 접근 금지 및 작업자 정위치 확인, 이동통로 구간 장애물 제거 및 정리정돈 철저, 근로자 특별안전교육 실시와 현장 안전점검 강화.',
#  '타워크레인 좌대 위 작업발판 추가설치 및 고정 철저와 고위험작업 시 현장 상주관리 및 재발방지대책 수립.',
#  '주변 자재 정리 철저와 사고조사 내역 전달을 통한 재발 방지를 위한 대책 수립 및 안전조치 철저 시행.',
#  '근로자 안전한 이동통로 및 작업 공간 확보.',
#  '작업발판 재확인 및 보강 조치.',
#  '덕트 오픈구 보양조치 및 시공순서 개선과 지속적인 안전교육 실시를 통한 재발 방지 대책.',
#  '관련 작업자에 대한 안전교육 실시와 사고 내용 전파 및 안전벨트의 중요성 교육, 산재 처리.',
#  '철 구조물 조립 및 해체작업 시 신체 끼임점 사전 확인, 작업 전 tbm 활동 내실화, 안전점검활동 및 교육 증대를 통한 동종 및 유사재해 방지, 근로자 안전교육 이행 모니터링, 사고방지 안전종합 대책회의를 통한 재해원인 분석 및 안전대책 선정, 발주청 안전보건관계자와의 현장 안전점검활동 강화.',
#  '재발 방지를 위한 작업자 교육 실시.',
#  '안전교육 및 작업장 주변 정리정돈을 통한 재발 방지 대책과 향후 조치 계획.',
#  '현장 안전교육 및 지도 점검 강화를 통한 근로자 안전확보 조치와 사고자의 약 3주간 안전가료 조치.',
#  '근로자 안전교육 및 안전시설물 보완조치와 근로자 안전교육 철저의 실행.',
#  '현장 작업 전 각 공종별 소장에게 전달 후 근로자 재교육 실시, 작업구역 및 안전시설물 설치, 타작업으로 인한 해체 시 안전관리자 보고 및 현장 재점검 실시를 통한 종결처리.',
#  '가능한 장비를 활용한 이동 진행.',
#  '현장 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '적치물 제거와 안전 교육 및 안전 관리에 유념한 시공 계획.',
#  '2인1조 작업 실시와 관리자의 위험요인 확인 후 작업 개시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '위험요인 및 안전대책에 따른 현장관리 실시',
#  '운반도구 사용 시 적합한 운반도구 사용과 무리한 자재운반 금지 실시.',
#  '안전수칙 전달과 현장관리 철저를 통한 사고 재발 방지 대책.',
#  '고소작업대 내부 청소 및 난간 충격보호재 설치와 무리한 작업 금지, 동일공종 특별안전보건교육 실시, 관리감독자 배치.',
#  '안전사고 재발 방지를 위한 안전관리계획 재수립, 안전활동 강화, 고소작업 간 안전고리 미결속 시 작업중지 및 현장관리감독, 안전교육 및 안전대책계획 수립 및 승인 후 작업재개.',
#  '결빙구간 즉시 제거하여 안전통로 확보 및 재발방지대책 이행 여부 확인.',
#  '해당 작업 시 작업발판(말비계) 설치와 안전교육 실시를 통한 유사작업 발생 방지.',
#  '굴착작업 중 사면에 대한 철저한 관찰, 근로자 및 관리감독자 교육 시행, 지장물 간섭구간에 대한 임시 간이 흙막이 제작 및 설치, 건설사업관리단 및 시공사를 통한 특별교육 실시와 작업 중 관리감독 철저 지시.',
#  '미끄럼 방지용 논슬립 설치 및 교육과 말비계 사용교육 실시를 통한 재발 방지 대책 마련.',
#  '굴착기 작업 중 반경 내 접근 금지 조치.',
#  '시스템동바리 해체작업 구간 상부 생명줄 설치 및 안전고리 체결, 작업발판 설치, 특별안전교육 실시.',
#  '작업자 이동 시 안전 확보를 위한 향후 조치 계획.',
#  '불안전한 행동 금지요령 및 특별교육 실시.',
#  '작업 전 사전 작업계획 및 위험요인 교육 실시와 자재 운반 시 미끄럼 방지를 위한 기구 이용, 피재자의 진료상황 수시 점검 및 현장 안전관리 활동 점검이 포함된 재발 방지 대책과 향후 조치 계획.',
#  '전 직원 대상 특별안전교육 시행과 장비 관리 철저, 시공사 및 가밀사에 주의조치 예정, 교육결과 제출 및 장비 전도 방지계획서와 작업자 안전교육일지 제출.',
#  '충분한 높이의 비계 사용 및 안전난간대 설치.',
#  '관리적 대책으로 작업 전 특별 안전 교육 실시, 작업 시 안전대 착용 및 케이지 내 안전고리 체결 철저, 기술적 대책으로 크레인 운전원 교육을 통한 불안전한 속도 조작 금지 관리 철저, 작업자와 운전원의 신호 체계 철저(무전기 이용)와 사업장 전반에 대한 안전 점검 및 각종 시설물 재정비 실시를 통한 사고 원인 및 피해 수습 대책 마련.',
#  '지지대 결속 시 전용 클립 사용과 작업 시작 전 안전한 작업 방법 결정 후 작업 실시를 포함한 재발 방지 대책 교육 실시.',
#  '작업자 안전관리 철저 및 안전교육을 통한 재발 방지 대책과 향후 조치 계획.',
#  '자재 인력운반 시 올바른 자세 등의 적정한 취급방법 교육과 유도원 배치 후 작업 동선 내 장애물 유무 확인을 통한 안전 교육 철저.',
#  '공사관리자 및 신호수 배치와 안전교육 강화를 통한 집중 관리 방안.',
#  '이동간 안전교육 실시 및 현장상태 정리.',
#  '건설기계 장비 작업 전 사전안전교육 실시와 작업 시 위험요소 제거, 신호수 추가배치, 전 근로자에게 사고내용 전파 및 안전교육 실시, 근로자 안전관리 교육 여부 확인, 신호수 및 안전관리 이행실태 수시점검 실시.',
#  '안전교육 실시와 해당사고 전파 공유를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '중량물 운반 작업 시 관리감독자 상주하에 혼합적재 금지 관리 및 산업재해 처리 예정.',
#  '개구부 전면 폐합조치.',
#  '재발방지대책 수립과 안전보호조치 방안 강구',
#  '동종 재해사례 및 재발 가능성 전파 교육 실시, 현장 점검을 통한 부적절한 작업자세 및 위치 교정, 작업환경 변화 관리감독 실시, 적합한 개인보호구 착용 필요성에 대한 반복 교육 실시, 시설물 해체 시 사전 협의를 통한 안전대책 마련 후 작업 진행.',
#  '안전점검과 외부전문기관의 안전진단 실시를 통한 재발 방지 대책.',
#  '공도구 및 전동공구 사용 시 유의점에 대한 안전교육 실시와 동일 유형의 사고재해에 대한 안전교육 실시, 시공사 안전관리 교육 철저 통보.',
#  '작업 전 건강상태 및 관련 질병 유무 등의 사전 체크 강화.',
#  '작업자 안전관리 교육 철저와 행정지도 실시.',
#  '재발 방지 및 향후 조치 계획.',
#  '작업 전중후 안전교육 강화를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전발판 및 시스템비계 설치 완료 후 공사 재진행.',
#  '안전사고 요인 제거에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업자에게 주의 요청을 포함한 재발 방지 대책.',
#  '작업자 안전교육 및 안전관리 강화.',
#  '재발장지 교육을 통한 동일 및 유사 안전사고 재발 방지 방안.',
#  '작업자 안전교육 및 특별교육 실시.',
#  '해당 작업 시 작업발판(말비계) 설치와 안전교육 실시를 통한 유사작업 발생 방지.',
#  '작업 전 안전교육 실시 및 현장 안전관리 상태 점검을 통한 재발 방지 대책과 향후 조치 계획.',
#  '안전한 작업을 위한 건축공사장 안전관리 철저와 작업자 지도, 재발 방지 안내.',
#  '작업 전 공사구역 지반상태 확인 및 재발방지대책 이행 지시.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '유도로프 사용과 관리감독자 및 작업반장 지휘하에 운반 실시를 통한 재발 방지 대책과 현장 점검 실시를 포함한 향후 조치 계획.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '현장 내 안전수칙 및 재발 방지 교육과 작비 작업 계획 수립.',
#  '안전 수칙 교육 및 작업전 자재운반 안전교육 실시',
#  '건설공도구의 방호장치 임의 해체 금지, 작업장 작업 전 공도구 사전 점검 및 현장 정리정돈 실시, 근로자 불안전한 행동 및 위험요인 사전 차단을 위한 현장 안전순찰 강화, 근로자 단독작업 금지 및 2인 1조 작업 진행, 현장 안전점검 실시, 재발 방지대책 수립, 근로자 특별안전교육 실시.',
#  '작업자 안전관리 교육과 철저한 행정지도의 시행.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '근로자 작업 전 교육과 고소작업차 작업 시 사전 지지지반 조사의 철저함.',
#  '안전의식 재확인, 임의 작업 금지, 관리감독자의 상주 및 작업방법과 순서에 대한 지도 감독 실시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '작업자 교육과 작업장 정리정돈을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '단부구간 작업 시 안전로프와 추락방지망의 임의 해체 지양, 안전벨트 착용 및 안전고리 체결 철저.',
#  '타워크레인 신호수 및 작업자 전체 안전교육과 현장 자체점검을 통한 위험요소 저감과 안전사고 발생 방지를 위한 행정지도.',
#  '면처리 공구 작업간 숙련공 배치와 공구를 이용한 작업방법에 대한 지속 교육 실시',
#  '작업자 안전교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획으로 철근공 절곡기 사용 시 작업방법 교육, 사고사례 전파 및 재발방지 대책 교육 실시, 경고 및 안전수칙 간판 설치, 재발방지 의사소통 협의회 실시 및 위험성 평가 반영, 동종 작업 진행 시 안전교육 실시, 작업방법 교육 및 근로자 정기교육 시 사고사례 전파가 포함됨.',
#  '추후 작업 시 주의 필요와 사업 준공된 현장에서의 현장 정리 과정에서 발생된 사고에 대한 향후 조치 계획.',
#  '작업발판의 정리정돈 유지 및 관리 점검과 안전화 착용상태 확인.',
#  '사고 조사 완료 후 재발 방지 대책 수립 예정.',
#  '근로자 안전교육 강화를 통한 불안전한 행동에 대한 관리감독자 확인 및 조치와 근로자 특별안전보건교육 실시.',
#  '이동 시 주변 확인 철저.',
#  '임시 작업 발판 고정 시 겹침폭 20cm 이상 유지 및 2개소 이상 묶음 철저히 확인과 안전교육 철저 및 작업 전후 안전조치 이행 확인을 통한 재발 방지 대책.',
#  '작업 중 근로자 동선 확보 및 불안전한 행동 금지 교육 실시, 작업 전, 중, 후 주변 정리정돈 및 전 근로자 유사 재해 발생 방지 교육 실시, 무리한 동작 금지, 해당 공종 특별안전교육 실시.',
#  '근로자 안전교육을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획이 없는 상황.',
#  '현장 정리정돈을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자 안전교육 실시와 시공사에서 병원 치료를 통한 재발 방지 대책.',
#  '안전교육 철저 및 실시 홍보를 통한 재발 방지 대책.',
#  '안전난간 및 안전가드 설치와 안전교육 실시를 통한 재발 방지 대책.',
#  '재교육과 안전교육의 철저한 이행.',
#  '올바른 작업방법에 대한 관리감독과 사고사례를 기반으로 한 안전교육 실시를 통한 동종 재해 예방 및 시공사 통보에 따른 향후 조치 계획.',
#  '작업자 안전교육 및 특별교육 실시.',
#  '버팀보 해체 시 해체방법 및 순서에 따른 해체작업 진행, 설치 및 해체 중량물 고위험 작업 시 매일 사전 작업 허가서 작성, 설치 및 해체 등의 고위험 작업 시 사전 점검 및 작업지휘자 또는 안전팀 상주관리, 근로자 안전법규 준수 관리감독 철저 지시.',
#  '작업장 내 인력 운반 중 부상 위험 관련 안전교육 실시, 중량물 임의 이동 금지, 작업장 주변 정리 및 사고 예방 조치, 안전관리 담당자 수시 점검, 자재 운반 작업 중 위험요소 안전교육 재실시 및 예방조치 실시.',
#  '작업자 안전교육과 조치사항 확인을 통한 재발 방지 대책.',
#  '안전교육 및 작업자 안전수칙 준수를 통한 재발 방지 대책 마련.',
#  '작업자 특별안전교육 시행과 거푸집 설치 및 해체 작업시 작업순서 준수를 위한 감독 철저 지시.',
#  '작업자 재교육 및 동시 작업 금지 요청을 포함한 재발 방지 대책 수립.',
#  '작업 전 개인건강 이상여부 파악.',
#  '현장안전점검 및 작업자 안전교육 강화를 통한 재발 방지 대책.',
#  '사고 현장 재발 방지 발표 및 현장 자체 특별 교육 실시.',
#  '안전수칙 준수 및 부주의 관련 교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '불안전한 자세로 취급 행위 금지 및 작업관리감독 철저와 동일 공종 작업 완료.',
#  '안전교육 및 작업장 주변 정리정돈을 통한 재발 방지 대책과 향후 조치 계획.',
#  '계단참 및 통로에 필히 설치된 이동 안전장치와 관리감독 강화를 통한 재발 방지 교육 실시.',
#  '특별교육 실시와 생명줄 설치 후 안전고리 체결 작업의 진행.',
#  '작업자 안전교육 철저, 낙하물 방지를 위한 현장 점검, 꾸준한 교육을 통한 근로자 인식개선 및 현장 안전 조치와 주변 정리 지시 후 확인점검 예정.',
#  '안전장치 임의 해체 금지와 위험기계기구 사용에 대한 관리감독 강화.',
#  '안전교육 실시와 같은 재발 방지 대책 및 향후 조치 계획.',
#  '개인안전보호구 착용 철저 및 작업 전 스트레칭 실시와 유사사고 재발 방지 대책 제출 통보.',
#  '맨홀 뚜껑 작업 시 식별 표시 및 개구부 뚜껑 설치, 근로자 통행로 및 안전통로 확보, 위험성 평가 실시 및 전파 교육을 통해 추락 위험성을 인식하도록 하고, 직원 안전 및 재발 방지 교육을 실시하는 방안.',
#  '작업절차 준수와 재발방지를 위한 계획 수립.',
#  '위험성 평가 반영, 작업간 근로자 개인 안전 보호구 착용 상태 상시 확인, 해당 공종 근로자 특별 교육 실시 및 작업 순서 준수 여부 확인 강화.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 단순과실로 인한 재발 방지 대책 및 향후 조치 계획의 필요성.',
#  '주변 정리 정돈 및 안전한 공사 진행을 위한 조치 계획.',
#  '작업자 안전관리교육 실시와 산재보험처리.',
#  '안전교육과 안전관리 철저를 통한 재발 방지 대책.',
#  '시스템동바리 내부 승강로 개선과 계단식 통행로 설치, 협력회사 관리감독자 안전교육 실시 및 자재 운반용 경사로 통로 설치, 전 근로자 전파 교육 및 수시 교육 실시, 접점 관리 대상 선정 후 오전과 오후 접점 관리로 안전사고 예방.',
#  '작업자 안전교육 실시와 공도구 방호장치 점검, 현장점검 실시.',
#  '안전교육 강화를 통한 재발 방지 대책 마련.',
#  '작업 전 사전 교육과 보호구 착용의 철저함, 관리감독자 배치 후 작업 진행, 안전교육의 철저한 진행.',
#  '작업자 교육과 병원 치료를 통한 재발 방지 대책.',
#  '현장 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '재발 방지를 위한 현장 점검과 사고 원인 및 예방 조치 관련 조치 요청.',
#  '안전교육 실시와 안전관리 철저함을 통한 재발 방지 대책.',
#  '연결고리 추가 제공과 작업전 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '사고 주의 지시와 감리를 통한 현장 관리 철저 지시의 통합.',
#  '안전관리 교육 및 사고사례 전파를 통한 향후 유사 사례 방지.',
#  '안전수칙 준수를 통한 작업자 부주의 방지 대책.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '고소렌탈 장비 작업 시 과상승방지봉 사용, 작업특성에 맞는 작업대차 사전 계획, 작업 전 안전교육 실시 및 현장 정리 철거 후 작업 진행, 현장 안전관리자의 철저한 관리와 지속적인 현장 지도 실시.',
#  '안전난간 설치와 공사 위험요소 정비를 통한 재발 방지 대책.',
#  '작업발판의 안정성을 확보하기 위한 지지물 연결 및 고정 실시.',
#  '작업장 정리정돈 철저 및 청결 관리, 전 근로자들의 작업안전수칙 및 특별안전보건교육 실시, 개인안전장구 착용 철저 교육, 이동식틀비계 설치기준 준수 안전교육 실시.',
#  '작업발판 설치에 대한 재발 방지 대책과 향후 조치 계획.',
#  '철저한 안전교육 후 작업 실시를 통한 재발 방지 대책.',
#  '올바른 작업방법에 대한 관리감독과 사고사례를 기반으로 한 안전교육 실시를 통한 동종 재해 예방 및 시공사 통보에 따른 향후 조치 계획.',
#  '현장 재단작업을 공장가공으로 변경하고 공도구 작업자 안전교육을 실시하는 조치 계획.',
#  '작업자 안전교육 및 안전방지대책 마련.',
#  '현장 자재 정리 철저 지시.',
#  '수직 트레이 케이블 취급 작업 시 작업발판 설치와 향후 조치 계획으로 재발 방지 조치 요구.',
#  '신호수 지정 및 활동 철저, 근로자 특별교육 실시 및 위험요소 숙지, 작업내용에 대한 위험성 평가 실시, 작업 전 기상상태 확인 및 근로자 출입 전 작업 가능 상태 점검 실시, 전 근로자 대상 재해사례 교육, 사고 재발을 위한 안전교육 실시, 안전관리사항 이행 여부 점검 추진.',
#  '안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전사고 예방 교육 및 현장 점검 실시.',
#  '안전사고 예방을 위한 안전관리 및 안전교육 철저.',
#  '방호선반 설치 및 근로자 재발 방지 교육 실시.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '계단실구간 난간대 및 방지망 설치와 공사현장 안전관리 철저를 통한 재발 방지 대책.',
#  '가시설 근로자 전원 작업실시전 T.B.M 실시 철저, 특별안전보건교육 실시, 터파기 토사 법면경사를 낮추고 다짐하며 작업지휘자와 신호수를 배치하여 작업 실시하는 재발 방지 대책과 향후 조치 계획.',
#  '재발 방지를 위한 안전교육 실시와 작업자 안전교육의 세심한 진행.',
#  '현장 조사와 재발 방지 교육, 시설 점검을 통한 재발 방지 대책 마련.',
#  '작업 중 정리정돈 완료와 사고 재발 방지를 위한 향후 조치 계획.',
#  '근골격계 예방에 관한 안전교육 실시.',
#  '고소작업 시 사다리 이용 작업 금지 및 중량물 취급 시 이동식 틀비계를 활용한 고소작업 실시와 준공 후 잔손보기 공사 중 관리감독자의 사전 승인 및 작업계획서에 의한 시공확인.',
#  '작업 구간 안전통로 확보와 자체 점검 실시를 통한 재발 방지 대책.',
#  '해당 작업자에 대한 동일 재해 예방 교육과 특별 안전 교육 실시 및 원인 조사 후 현장 적용을 통한 재발 방지 대책 마련.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '현장 작업의 정밀 시공과 위험 요소 발견 시 즉시 조치, 개인 보호구 착용 및 안전 교육 실시, 철저한 안전 수칙 준수 교육, 미 고정된 자재물이나 시설물에 대한 고정 작업 및 즉각적인 안전 조치, 근로자에 대한 안전 교육 실시와 현장 관리 감독의 철저함.',
#  '사고 내용 근로자 전파 및 안전운전 수칙 홍보와 조수석 인원 하차 시 차량 정지에 대한 향후 조치 계획.',
#  '안전교육 강화와 안전의식 확충을 통한 재발 방지 대책.',
#  '안전사고 예방을 위한 작업전후 안전교육과 발주처 및 건설사업관리단의 주기적인 현장점검 실시.',
#  '작업 현장 정리정돈 및 유사사고 발생 방지를 위한 안전교육 실시 예정.',
#  '작업 재개 시 비계 재정비와 준공을 통한 재발 방지 대책.',
#  '작업 전 가설통로 확인 및 위험성 평가 철저와 재해자 부상상태 확인 후 산재처리 및 현장 가설통로 안전관리 철저.',
#  '안전관리 준수에 대한 재발 방지 대책과 향후 조치 계획.',
#  '해체 작업 실시 전 인근 타 작업자 일정 거리 유지 확보를 위한 안전교육 재실시와 부상 정도 확인 후 산재 처리 진행.',
#  '재발 방지 대책과 향후 조치 계획의 종결.',
#  '작업 근로자에게 특별안전교육을 실시하고 병원치료 및 산재처리를 통해 안전사고 발생 방지를 위한 철저한 조치 계획.',
#  '철근작업 실시 전 작업동선 관련 안전교육과 현장조사 및 관련자 면담, 작업장 내 위험요소 제거를 통한 재발 방지 대책 마련.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '화재방지를 위한 안전점검 수시진행과 건축물 철거를 포함한 조치 계획.',
#  '사고사례 전파와 작업자 교육, 자재적치 상태 점검 실시.',
#  '사고 사례 전파 및 자재 적재 방법 교육과 동종 유사 재해 방지를 위한 주기적 현장 점검 확인.',
#  '현장작업 전 안전사고 체크와 건설현장 안전조사 실시를 통한 재발 방지 대책.',
#  '안전교육 재실시를 통한 재발 방지 대책.',
#  '개구부 안전 덮개 조치와 산재처리 예정의 통합적 관리 방안.',
#  '이동 시 칼날을 칼집에 넣고 이동하며 안전관리를 철저히 하는 대책.',
#  '현장 안전점검 및 근로자 특별안전교육 실시와 안전점검 및 사례전파 등 사후대책 시행.',
#  '안전수칙 준수에 대한 재발 방지 대책과 향후 조치 계획.',
#  '철근캡 설치와 갱폼 단차구간 난간대 설치를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '보행 시 주의에 대한 재발 방지 대책과 향후 조치 계획.',
#  '추락 가능성이 있는 위치에서 작업 시 2인 1조로 작업하고 작업지도자를 배치하여 근로자의 불안정한 행동으로 인한 안전사고를 예방하며, 현장 근로자 안전교육 강화와 전직원 특별교육 실시를 통해 부주의로 인한 추락사고 발생 가능성을 인지하고 개인보호구 착용 상태 및 불안전한 행동을 지속적으로 확인하는 조치.',
#  '특별안전교육과 현장 작업발판 설치 및 정리정돈 실시',
#  '유사 사고에 관한 안전교육 실시.',
#  'TBM 작업 내용 숙지와 보호구 착용 철저, 안전교육 실시를 통한 안전 의식 강화 및 전체 근로자를 대상으로 한 사고 사례 전파와 교육 예정.',
#  '건축관계자 안전교육 실시 지시.',
#  '중량물 취급 시 무리한 작업 방지를 위한 근로자 안전교육 실시, 장비기사의 시야 확보 및 근로자와의 신호체계 정립, 띠장 보걸이 충분히 확보, 그리고 건설사업관리단을 통한 해당 공종 작업 전 안전교육 철저 지시.',
#  '작업내용 변경 시 근로자 대상 특별교육 실시와 안전사고 예방을 위한 안전교육 실시.',
#  '작업자 안전교육 및 가설계단 확인과 조치사항 확인을 통한 재발 방지 대책 마련.',
#  '현장 관리감독 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 혈압 체크 후 현장 투입, 안전교육 및 TBM 실시 철저를 포함한 건설사고 재발 방지 대책 수립 및 제출 통보.',
#  '안전관리교육철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '근로자 안전교육 강화 및 안전보호 장비 착용을 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육 및 현장 안전관리 철저를 통한 사고 재발 방지 대책.',
#  '작업 공간 확보 및 작업 순서 준수, 2인 2조 작업과 안전작업 기준에 대한 위험성 평가 실시.',
#  '안전사고 예방을 위한 작업공구 사용 시 안전장치 점검 및 안전한 작업방법 숙지, 회전 공구의 안전캡 확인, 작업자에 대한 안전교육 실시, 불필요한 물건 정리, 건설공구 관리 및 안전수칙 준수를 통한 철저한 안전관리 지시 예정.',
#  '작업자 안전교육 실시',
#  '건설현장 안전사고 방지와 작업자 안전 확인 및 조치, 부상자 치료 경과 및 피해 여부 지속적 확인.',
#  '현장 공구 안전장치 점검 및 절단 방지 장갑 현장 비치 지시 사항.',
#  '인력으로 불가한 작업은 공구를 이용하고, 근로자 임의판단보다는 담당직원과 협의 후 작업진행하며, 동일한 사고가 재발되지 않도록 시공사 안전관리 교육과 협력사 교육을 실시하는 방안.',
#  '작업 시 주의 조치에 대한 재발 방지 대책.',
#  '사고원인 조사 진행 중이며, 안전사고 예방 철저.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '연약지반 작업 시 임시가시설 설치에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '해당사례 전파 및 안전사고 예방교육 실시자료 제출 요청.',
#  '우마(말비계)에서 작업 중지 및 틀비계와 견고한 작업발판 설치 후 안전벨트 등 안전조치와 안전장비 착용을 통한 안전 확보.',
#  '해당 재해 관련 특별 안전 교육 실시와 위험 예지 활동을 통한 위험 감수성 향상, 적합한 보호구 선택 및 작업 중 철저한 안전 조치, 근로자 건강 상태 지속 확인 및 안전 교육과 안전 시설물 설치 강화.',
#  '작업공간 및 이동통로 확보, 근로자 자재 운반 시 시야 확보 관련 안전교육과 위험성 평가 실시, 작업장 정리정돈 상태 및 이동통로 확보 상태 수시 점검.',
#  '안전관리철저문서통보에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업 시작 전 물 제거 등 미끄럼 방지 조치 실시.',
#  '사고 내용 전파 및 안전 교육 실시와 재발 방지 대책 수립.',
#  '작업량 확인 및 현장 실 시공 현황 체크, 사소한 작업에 대한 주의 당부와 지속 관리, 작업환경의 청소 및 유지 관리.',
#  '안전관리 철저와 안전교육을 통한 재발 방지 대책.',
#  '재발 방지 대책 마련과 안전교육 실시.',
#  '차로 통제차와 라바콘을 이용한 작업구간 구획설정 및 신호수 통제와 배치구간 위치 확인을 통한 사고 재발 방지 조치 요청.',
#  '작업자 안전관리 교육 및 실시 계획.',
#  '작업통로 정리정돈에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '안전 관리 확보 후 공사 재개 명령.',
#  '작업자 안전교육 철저 실시를 통한 재발 방지 대책.',
#  '작업 전, 중, 후 이동 시 안전교육과 근로자 이동 시 주의조치를 통한 재발 방지.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '협착 방지 장갑 지급 및 착용, 작업자 손다침 사고 방지 교육 실시, 드릴에서 타카총으로의 작업 방법 개선, 강화된 재발 방지 대책 수립 및 전체 작업자 대상 사고 사례 전파 교육 실시.',
#  '안전관리자의 주도로 현장 작업 전 교육 추가 진행, 고사 작업 등 위험작업 시 안전작업허가서 발행, 위험 작업 시 안전관리자 입회, 안전관리자 현장 점검 강화와 시공사가 최초 발주처를 신탁사로 기재하고 인허가기관에 보고함에 따른 사고조사 입력 지연에 대한 재발 방지 대책 준수 요청.',
#  '작업장 주변에 근로자가 접근하기 쉽고 편안하게 통행할 수 있는 안전통로 설치, 동종 재해사례 반복 근절을 위한 전파교육 실시, 근로자 이동을 고려한 작업 배치로 과다한 이동 발생 방지.',
#  '사고 사례 전파 및 안전교육 실시, 위험요인 발생 가능성 파악 후 안전조치 시행, 현장 안전 순찰활동 강화.',
#  '근로자 안전교육을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전사고 발생 가능성을 줄이기 위한 자재 안전 관리 철저와 내부 인테리어 공사 완료를 통한 유사 사례 방지.',
#  '작업 전 위험 발생 주요 요인 전파 교육, 가시설 발판 간격 수정 및 확인, 개인 보호구 착용 교육, 사고 발생 방지를 위한 집중 관리.',
#  '작업장소 내 지장물 확인 및 제거.',
#  '적치물 제거와 안전 교육 및 안전 관리에 유념한 시공 계획.',
#  '향후 동종 작업 시 폐기물 틈 사이에 발이 빠지거나 폐기물에 걸려 넘어질 위험 요소를 작업 전에 주지하여 작업자가 주의하여 작업할 수 있도록 하는 현장 안전관리 강화 방안 수립.',
#  '현장 관리 철저에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '안전조치와 현장확인으로 이루어진 향후 조치 계획.',
#  '작업구간 위험사항 및 간섭사항의 사전 확인, 작업 상황별 불안전행동 및 위험사항에 대한 안전교육 실시, 작업 및 운반에 대한 계획 수립 및 현장이행 확인.',
#  '안전교육 실시를 통한 재발 방지 대책.',
#  '고소작업 안전벨트 고리 체결과 특별 안전교육 실시.',
#  '자재 정리에 대한 강조와 재발 방지 대책.',
#  '시설물 안전조치 강화와 공사현장 안전시설물 재점검 및 관리감독 강화.',
#  '부적절한 작업방법 예방과 수시 안전교육을 통한 재발 방지 대책 및 안전점검 실시 계획.',
#  '시설물 점검 및 작업자 교육 실시와 현장 시설 보완이 포함된 향후 조치 계획.',
#  '공사장 시설물 안전점검 실시와 안전관리 철저 통지의 재발 방지 대책.',
#  '사고 재발 방지를 위한 철저한 안전교육 및 수칙 교육과 작업자 교육 및 안전관리 강화.',
#  '현장 안전교육 실시와 현장 정리 철저 지시를 통한 관리 강화.',
#  '재발 방지 대책과 향후 조치 계획의 통합으로 근로자 특별안전교육 실시, 위험성 평가 재실시 및 교육, 유해위험기계기구 안전작업 표지판 부착, 공도구 비치 철저, 철근절단기 방호커버 대책 실치, 사고사례 전파 등이 포함된 안전 관리 체계 구축.',
#  '안전교육 및 안전관리 철저 지시.',
#  '사고사례 전파 및 안전교육 철저한 시행.',
#  '안전교육 및 올바른 작업방법 강화, 개인보호구 착용 및 관리 교육 실시, 관리감독자 배치를 통한 현장관리 철저, 안전점검 및 안전순찰 강화를 통한 사전 위험요인 제거.',
#  '재발 방지 안전관리 지도 마련.',
#  '작업자 교육 및 건설사업관리단과 시공사에 대한 조치계획과 재발방지대책 요청.',
#  '작업자 안전교육 재실시.',
#  '안전한 작업방법 및 재해사례 교육의 강화, TBM 활동을 통한 안전작업방법 및 안전의식의 강화, 작업장 불안전 요소의 점검 및 제거, 시공자와 안전관리담당자 및 책임건설사업관리기술인의 작업장 관리감독 활동의 강화, 그리고 건설현장 근로자 안전교육을 통한 현장관리의 강화.',
#  '고소작업 시 전 안전교육 실시 및 안전벨트 착용 후 작업 수행.',
#  '재해예방 안전관리 교육 지속 실시 및 산재관련 조치 철저 지시.',
#  '위험요인 및 안전대책에 따른 현장관리 실시',
#  '안전교육 실시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '근골격계 질환 방지를 위한 업무 강도 고려 작업 배치와 제출된 서류 확인을 통한 사실유무 확인.',
#  '안전교육을 포함한 재발 방지 대책과 향후 조치 계획.',
#  '사고 방지를 위한 2인 1조 자재 정리 및 작업 편성 계획.',
#  '현장 안전 관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업 후 현재 준공함에 따른 작업발판 설치.',
#  '바닥고르기, 가설계단 설치, 근로자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전교육 철저와 사고처리 경위관리를 통한 재발 방지 대책.',
#  '자재 관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '중량물 인양 시 2인1조 작업과 숙련된 작업자 배치에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '사고사례 전파와 안전교육 실시.',
#  '철근 가공장 내 이동통로 정비와 산재 처리 예정.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업방법 미숙으로 인한 기술적 요인에 대한 재발 방지 대책으로 02월 25일 작업근로자에게 작업방법 및 안전교육을 실시하고, 지속적인 안전 관리 교육과 안전관리 감독 강화를 통해 사고를 방지할 계획.',
#  '작업자 안전교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '건설공사 중 작업자 안전모 등의 안전보호장비 착용 준수 및 건설공사 안전사고 방지 사항 알림.',
#  '작업공구 필수사용에 대한 재발 방지 대책과 향후 조치 계획.',
#  '경찰조사 및 기타조사 후 정확한 사고원인 파악에 따른 재발 방지 대책 수립과 공사 진행 관련 계획 재수립.',
#  '안전관리 교육과 작업자 안전 교육을 통한 재발 방지 대책.',
#  '작업자 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '유로폼 핀 제거 시 류로폼 자재 탈락 주의, 작업 전 TBM 실시, 작업 발판 설치 후 작업, 개인 보호구 착용 확인, 협소 공간 작업 시 2인 1조 작업 실시.',
#  '지속적인 교육 실시와 사고 사례의 현장 공유를 통한 안전교육 및 지속적인 모니터링.',
#  '버팀 해체 구간 통로 확보 및 근로자 작업방법 안전교육 실시와 함께, 건설사업관리단을 통한 시공사 안전교육 철저 지시 및 작업통로 미확보 시 공사중단 조치.',
#  '호스 연결 직하부 이격거리 준수 작업 실시, 콘크리트 타설 전 연결호스 상태 확인, 현장 전 근로자 특별안전교육 및 안전수칙 이행 여부 관리감독 철저.',
#  '작업자 안전통행로 보수, 안전통행로 외 통행금지 교육 시행, 지속적인 안전교육 및 현장관리 강화.',
#  '무리한 작업 자제를 위한 종사자 안전 교육과 작업 위치 주변 정리정돈의 철저한 시행.',
#  '작업환경 수시 정리 실시.',
#  '철근 작업자 전원 작업중지 후 현장 특별안전보건교육 실시, 안전모 등 사고예방물품 착용 여부 점검, 작업 후 안전사고 주의 및 정리정돈 철저, 안전사고예방교육 실시 여부 확인.',
#  '안전교육 실시와 신호체계 점검을 포함한 조치 계획.',
#  '사고 내용 및 사례 전파와 교육 진행.',
#  '작업자 안전교육 및 현장 안전관리 철저를 통한 사고 재발 방지 대책.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '자재운반통로 및 넘어질 위험 확인에 대한 재발 방지 대책과 향후 조치 계획.',
#  '공사장 시설물 안전점검 실시와 안전관리 철저 통지의 재발 방지 대책.',
#  '양중 시 자재 인양장비 변경(하카->샤크)과 현장관리 철저를 통한 관련사고 재발 방지.',
#  '연약지반 작업 시 임시가시설 설치에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '해체작업 전 위험요인 및 해체범위 확인과 낙하물 제거 실시.',
#  '철근배근작업 시 기존 방식에서 철근작업대를 제작하여 지정된 위치에 철근을 배분하고, 안전통로를 마련하여 부상을 방지하며, 종합적인 사고 원인 판단 후 감리 수행 실태 점검 계획.',
#  '사후사례 전파 및 작업자 안전관리 교육을 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육 및 안전시설 점검, 개인보호장구 착용 철저.',
#  '작업전 안전교육 실시 철저와 사고 이후 병원진료 및 휴식 조치.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육 및 조치사항 확인을 통한 재발 방지 대책.',
#  '현장 안전점검 정기적 수행, 공구류 관리 철저 및 관리대장 준수, 공도구 점검을 통해 인증받은 기계기구에 한하여 작업 허용, 관리감독 체계 강화.',
#  '개인 안전보호구 착용 철저.',
#  '작업전 안전교육 시행, 작업지휘자 상시 확인, 무리한 작업 금지로 인한 재발 방지 대책 및 향후 조치 계획.',
#  '작업구간 통로 추가 확보 및 수배전반 설치 구간 이동 통로 추가 확보를 통한 관리 방안.',
#  '작업공간의 수시 정리정돈 실시와 안전관리 철저, 현장 정리정돈 및 근로자 안전교육 철저.',
#  '작업자의 위험행동에 대한 안전교육 강화와 안전의식 고취.',
#  '가설재 적정 적재 높이 준수, 2인1조 작업 시행, 안전교육 실시.',
#  '현장 내 위험요소 파악과 작업자 안전조치 및 안전교육 실시.',
#  '향후 안전관리와 안전교육을 철저히 하는 계획서를 고용노동부에 제출하여 작업재개 승인을 받는 조치.',
#  '결빙 구간 보행 수칙 준수 전파와 안전교육 실시를 통한 재발 방지 대책 마련.',
#  '작업 전 간섭 요소 판단 및 조치, 사고사례 근로자 교육, 주기적 안전점검 실시.',
#  '건설현장 안전 보호장비 착용 및 동절기 안전점검 실시.',
#  '작업 중 일어나는 불가피한 상황을 최대한 예방하여 안전관리를 강화하는 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육과 현장 관리 강화를 통한 재발 방지 대책 마련.',
#  '현장자재 정리와 안전관리 철저를 통한 재발 방지 대책 및 공문 발송을 통한 향후 조치 계획.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자 안전교육 실시와 현장 내부 정리정돈 철저를 통한 유사사고 재발 방지 대책 제출.',
#  '재발 방지 대책과 향후 조치 계획의 시공자 작성 및 통보.',
#  '무리한 작업자세와 서두름 등 불안전한 행동에 따른 위험요인 및 사례에 대한 주기적 교육 실시.',
#  '벌목 및 삭초 작업 등 공구사용 시 유의사항 교육과 안전보호구 착용 철저, 안전교육 강화 및 일일 사전 교육 실시.',
#  'A형 사다리 작업 방지, P/T 아시바 사용, 주기적인 안전교육 실시를 통한 안전의식 고취.',
#  '근로자 안전교육을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '자재 관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전교육 실시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '동바리 작업 투입 전 작업장소 확인 및 안전조치 시행.',
#  '추락방호망 등 안전조치 명령 및 정기점검 시 산업안전보건관리비 사용 실태 점검과 안전관리계획 별도 제출 지시, 구조전문가 안전점검 후 관련 행정조치 검토 예정.',
#  '자재 정리 및 현장 청소를 통한 재발 방지 대책과 향후 조치 계획.',
#  '근로자 인전교욕 실시 및 전도 방지시설 보강.',
#  '작업 시 무리하게 힘을 주지 않고, 작업 순서와 방법에 맞게 작업을 실시하는 방안.',
#  '부주의로 인한 사고 방지를 위한 구두 요구와 향후 조치 계획.',
#  '작업자에 대한 특별안전 교육 실시와 현장 안전관리 철저.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '작업 전 안전교육 실시, 자재 정리 및 작업순서 준수, 동바리 해체 후 정리정돈 실시, 안전점검 및 안전교육 실시, 개인 보호구 및 안전시설물 설치.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '안전발판의 고정 및 보강조치 진행.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '안전관리교육철저.',
#  '재발 방지와 향후 조치 계획에 대한 주의.',
#  '근로자의 무리한 동작 금지와 2인 1조 작업 관리, TBM 일일안전교육 전파 교육 실시, 상부 가시설 작업 시 근로자의 손목, 무릎, 팔꿈치 보호대 안전장비 착용 검토 지시.',
#  '유사 작업 시 마대 상태 확인 교육과 작업 전 안전교육 및 주변 환경 정리 계획, 피해자 산재 처리 예정.',
#  '신호체계 확립과 산업재해조사표 제출을 통한 재발 방지 대책 마련.',
#  '안전난간대 및 안전고리 설치 완료와 작업자 안전교육 강화에 따른 안전시설 보강 및 책임 있는 사고 후속 조치.',
#  '공구 조작 시 사고 대비와 현장 내 관리 철저를 통한 재발 방지 대책.',
#  '안전작업통로 보행 및 안전교육 실시와 재해자 부상상태 확인 후 산재처리 및 콘크리트타설공사 안전 관리 강화와 교육 실시.',
#  '재발 방지 대책과 향후 조치 계획으로 산업재해조사표 제출.',
#  '근로자 안전 교육 실시와 관리 감독자 배치, 시공사에 각 공종별 작업 사진 및 안전 교육 실태 조사 실시를 통한 현장 점검 예정.',
#  '근로자 안전교육 실시와 작업 중 관리감독 철저.',
#  '철근 작업장 정리 및 통보 확보와 안전 관리 및 교육 강화의 재발 방지 대책.',
#  '관련내용 인지 교육 및 안전장화 구비 지급',
#  '2인1조 작업 실시와 관리자의 위험요인 확인 후 작업 개시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자의 안전거리 유지 철저 지시와 향후 조치 계획에 따른 작업자 안전거리 유지 철저.',
#  '작업 전 사전 작업계획 및 위험요인 교육 실시와 자재 운반 시 미끄럼 방지를 위한 기구 이용, 피재자의 진료상황 수시 점검 및 현장 안전관리 활동 점검이 포함된 재발 방지 대책과 향후 조치 계획.',
#  '안전교육을 통한 사고 재발 방지 대책.',
#  '양중 작업시 통제 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '시스템서포트 설치 시 작업상태 관리감독과 위험요인 제거 후 근로자 배치, 근로자 작업투입 전 특별안전교육 실시 및 개인보호구 착용상태 관리 철저함.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '건설공사 안전사고 사례전파 및 안전교육 철저 시행과 산재처리에 대한 조치 계획.',
#  '합벽지지대 보강 및 해체 시 속대와 연결조인트가 하단까지 내려왔는지 확인 후 후속작업을 실시하는 재발 방지 대책과 이를 확인하는 향후 조치 계획.',
#  '안전수칙 전달과 현장관리 철저를 통한 사고 재발 방지 대책.',
#  '작업자 안전교육과 안전의식 고취를 통한 재발 방지 대책.',
#  '작업 전 안전교육 실시와 위험성 평가 등록 및 특별안전교육 강화에 대한 재발 방지 대책.',
#  '작업 종료 후 작업 공구 및 장비 청소 및 정리 시 안전에 대한 경각심을 높이기 위한 안전교육과 방수공사 등 습식공사 작업 시 교반 기계에 회전날 탈부착 시 유의사항에 대한 안전교육 실시.',
#  '사고원인 파악 및 관련 안전교육 철저 시행.',
#  '안전조치시설의 임의 해체 금지와 작업 시작 전후의 작업장 정리 및 정돈 실시.',
#  '안전보호대 착용 요청 및 사고 발생 방지를 위한 조치 계획.',
#  '사례 전파 및 작업 전 안전 교육 실시',
#  '사고현장 및 작업기계의 위험요인에 대한 안전점검 실시, 철근가공작업 표준절차 준수, 위험작업시 올바른 작업방법에 대한 근로자 안전교육 실시, 관련 공종 공사참여자에게 사례 전파 및 안전관리 의식 확립, 철근 가공 작업시 숙련공 투입으로 안전사고 예방 및 관리 강화.',
#  '안전로프 설치, 법면 재정비 및 법면 보호와 안전휀스 설치를 통한 재발 방지 대책.',
#  '재발 방지를 위한 안전교육 실시와 작업장 내 전치 비계 및 작업발판 점검 후 불안전 요소 제거.',
#  '시스템서포트 설치 시 작업상태 관리감독과 위험요인 제거 후 근로자 배치, 근로자 작업투입 전 특별안전교육 실시 및 개인보호구 착용상태 관리 철저함.',
#  '굴착기 회전반경 내 작업자 진입금지 교육과 병원 진료(MRI) 결과 후 조치계획 수립.',
#  '거푸집해체 작업 시 안전교육 철저 및 관리자와 안전지킴이 배치와 병원 이송 후 당일 시술 완료를 통한 재발 방지 대책 마련.',
#  '근로자 불안전 작업으로 인한 소부재의 안전성을 높이기 위한 일반톱 사용 및 좌상 관련 안전교육 추가 실시.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '재설작업 재실시 및 통로확보와 산재처리 예정에 따른 조치 계획.',
#  '무거운 자재 및 악천후 시 자재 운반 시 이동식 리프트 이용과 2인 1개조 작업 실시.',
#  '중량물 취급기준 및 작업자 부주의에 대한 안전점검과 교육 실시, 안전지도 업체(베스트안전)와의 현장감독 합동 조사 및 특별안전교육 실시.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '사전 공구를 이용한 작업 시 위험사례 안교육 및 안전작업방법 교육과 고 연령작업자에 대한 적절한 작업 배치, 시공전 작업자 안전교육 철저 및 작업자 배치 적정성 검토 지시.',
#  '현장 정리 철저와 공사현장 안전교육 강화를 통한 재발 방지 대책.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '자재 정리 및 현장 청소를 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업 시 주의 조치에 대한 재발 방지 대책.',
#  '작업자 현장 안전교육 강화와 개인 안전장구 점검 강화를 통한 재발 방지 대책 마련.',
#  '현장관리 강화 및 작업자 주의에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전교육 강화를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '모든 현장근로자 특별안전교육 및 해당공종 작업계획서와 위험성평가서 재작성 실시 예정.',
#  '안전수칙 준수에 대한 재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획의 통합: 동력을 이용한 공도구 사용 시 용도에 적합한 기계기구 사용, 공도구 점검 또는 설치․해체 시 전원 차단 후 취급, 거푸집 등의 가공작업은 형틀목공에 의한 작업 배치 후 실시, 동일한 공도구 사용 시 덮개 사용 및 해체 시 전원 차단 등의 안전교육 강화, 용도에 적합한 공도구 사용 여부 점검 및 지도 실시, 숙련된 근로자가 취급하도록 관리.',
#  '안전사고 재발 방지를 위한 협조 요청',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '근로자 대상 사고 발생 원인 및 주의사항 전파와 건설현장 현장책임자 대상 특별교육 실시를 통한 재발 방지 대책.',
#  '근로자 전원 재발방지 특별안전교육 실시와 재발방지대책 수립 및 조치 지시.',
#  '재발 방지 및 향후 조치 계획.',
#  '안전수칙 준수 및 강조를 통한 재발 방지 대책 마련.',
#  '작업자들 안전교육 재실시 및 건축관계자 관리감독 강화.',
#  '작업환경 수시 정리 실시.',
#  '작업 시 주의 조치에 대한 재발 방지 대책.',
#  '해당 근로자뿐만 아니라 업체 관리책임자와 관리감독자의 위험성 인식 및 관심 부족으로 인한 재해 예방을 위한 지속적인 교육 실시와 형틀 할석 작업 시 허가제 도입, 관리책임자 및 관리감독자의 직접 지도 하에 작업 진행 필요성.',
#  '융착기에 협착방지링 설치를 통한 협착 방지 조치.',
#  '안전관리 철저 및 건설자재 관리에 대한 재발 방지 대책과 향후 조치 계획.',
#  '무리한 양중 및 자재운반으로 인한 사고 발생 방지를 위한 계도.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '사고사례 전파 및 작업자 안전교육 실시.',
#  '공사중단, 재발방지 계획 수립 및 안전교육 철저.',
#  '거푸집 고정 작업 시 비계 위에서의 교육, 취약부분에 대한 교육, 작업발판의 견고한 설치 및 유지 관리, 작업자 유선조사 및 대응방안 강구, 추가 사고예방을 위한 면담.',
#  '작업자 안전관리교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전사고 예방을 위한 안전관리 및 안전교육 철저.',
#  '위험 예지 상황 반복 교육과 사고자 산재처리 및 재발 방지를 위한 현장 교육 실시.',
#  '자재 운반 시 단독 운반 작업 금지 및 2인 1조 작업 실시.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '경사 통행로의 완만한 설치와 가설계단 설치를 통한 관리 점검 실시.',
#  '안전교육 및 작업 기계 조작법 숙지, 안전장비 착용 지시와 함께 작업자 안전교육 철저, 현장 사고 발생 파악 및 사고 내용 통보의 신속함이 요구됨.',
#  '작업자 안전관리 철저와 산재처리 및 보험처리의 통합적 관리.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '고소작업 시 안전벨트 착용 및 고리 체결, 안전 발판 및 안전 난간대 설치.',
#  '안전조치강화에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '안전사고 요인 제거에 대한 재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '테이블쏘 작업 중 각재나 판재가 날에서 튀어 오를 경우 기계를 멈추고 재작업을 진행하도록 교육을 완료한 사항.',
#  '굴착기 작업 중 반경 내 접근 금지 조치.',
#  '근로자 교육 철저와 사고재발 방지 지시.',
#  '대형기계장비 사용 시 기계와 작업자의 간격을 10m로 유지하고, 현장 및 감리를 적극 감독하여 작업자 안전을 확보하는 조치.',
#  '작업자의 안전교육 강화와 현장 안전관리 교육 철저를 통한 재발 방지 대책 마련.',
#  '신규채용전 건감검진과 충분한 휴식의 시행.',
#  '안전발판의 고정 및 보강조치 진행.',
#  '작업 전 위험성 평가를 통한 위험 요인 사전 도출 및 저감, 배관 이동 시 전용 대차 제작 사용, 인양 이동 및 기타 설치 작업 시 숙련공을 통한 작업 진행, 그리고 건설 현장 부상 사고 발생에 따른 안전 관리 교육 철저 공문 발송.',
#  '거푸집 해체 작업 관련 안전교육 실시와 해체 관련 재발 사고 방지 교육 철저.',
#  '작업자 안전장구 착용 및 안전시설 설치 이상유무 수시 확인과 작업 전 안전교육 강화 등.',
#  '근로자에게 해체 작업순서 및 안전교육 실시.',
#  '덤프트럭 운전원 교육 및 관리감독 강화에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업전 교육 및 안전관리 철저와 현장 안전관리 철저를 통한 재발 방지 대책.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '작업장 지반 정리정돈 실시.',
#  '현장감독 철저와 작업중지명령 및 자체 조사를 통한 재발 방지 대책 마련.',
#  '근로자 안전의식 고취와 재해예방교육 시행, 이동식틀비계 현장 작업자 안전교육 실시를 통한 재발 방지 대책 마련.',
#  '가시설 작업 시 장비 유도신호수 상호 연락 체계 확립과 안전유도원 배치 및 관련 규정 준수 지도를 통한 안전성 확보.',
#  '작업 적정량 엄수 및 안전교육 강화를 통한 사고 재발 방지 대책.',
#  '사고위험 요소 확인 및 제거에 대한 재발 방지 대책과 향후 조치 계획.',
#  '버팀대 작업용 수평구명줄 및 부착설비 설치계획 수립과 설치 완료, 작업 전 안전교육 실시, 안전용품 점검 및 착용 강조를 포함한 현장 작업자 추락사고 재발 방지를 위한 조치계획 수립.',
#  '작업 전 작업장 상태 확인 후 작업투입 및 단독작업 금지 조치.',
#  '현장 위험성 평가 실시와 재발 방지 계획 수립, 병원 후송 후 입원 치료.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '사고원인 조사와 해당현장 안전점검, 예방교육 실시.',
#  '작업발판 고정 확인 등 안전조치 시행에 따른 재발 방지 대책 및 향후 조치 계획.',
#  '불안전한 행동으로 인한 사고와 회전톱 작업 시 면장갑 착용으로 인한 회전말림에 대한 근로자 특별 및 정기 안전교육 실시와 공구류 확인 점검의 필요성.',
#  '안전교육 실시와 재발 방지 대책 수립.',
#  '재발 방지 및 향후 조치 계획.',
#  '배관에 밴딩 결속하여 손잡이를 만들어 방향 조정하는 재발 방지 대책과 향후 조치 계획.',
#  '이동중 동선 파악 등 작업자 이동수칙 준수와 작업자 안전교육 실시를 통한 재발 방지 대책 마련.',
#  '산업재해 재발 방지를 위한 유해위험요소 제거 및 관리감독자의 상주.',
#  '슬라브설치 작업 시 생명줄 추가 설치 및 안전고리 체결, 장선에 작업 전 각재 검수 확인, 장선 위에 합판 깔고 이동 작업, 그리고 사고 재발 방지를 위한 철저한 관리 감독 실시.',
#  '작업방법 및 작업절차 개선을 통한 거푸집 설치 작업 시 전면부 시스템 비계 2단 수평재 해체 후 작업 실시 및 작업 종료 후 해체한 2단 수평재 재설치와 작업자들의 부주의로 인한 사고 방지를 위한 사내 교육 실시 여부 확인.',
#  '안전관리 숙지 및 안정성 검토에 대한 재발 방지 대책과 향후 조치 계획.',
#  '피해 발생 원인 상세 분석 및 전문가 컨설팅, 근로자 교육, 관계기관 안전점검 우선 대상 적용, 부상근로자 회복 및 상태 점검 확인 등.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '재해자의 불안전한 행동으로 인한 사고를 예방하기 위해 공사팀과 협의하여 기둥 폼 설치작업 시 하부에만 반도를 체결하고 상부에는 타이볼트로 체결하는 방법으로 위험요소를 사전에 제거하고, 동종 재해 방지를 위한 지도 계획을 수립함.',
#  '작업장소 내 지장물 확인 및 제거.',
#  '이동중 동선 파악 등 작업자 이동수칙 준수와 작업자 안전교육 실시를 통한 재발 방지 대책 마련.',
#  '현장정리정돈 및 통행로 확보 실시.',
#  '안전교육 실시와 현장 정리를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자 안전교육 실시 및 작업 이동 동선 안전조치 보강.',
#  '작업 전 주변 지장물 확인 및 작업공간 확보, 타워크레인 양중작업 시 줄걸이 등 2인 1조 작업 실시 여부 확인.',
#  '자재 결속부분 재정비를 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업대 설치를 통한 작업자 불안전한 행동 억제 및 안전한 작업 유도를 위한 조치 계획.',
#  '잠수 작업 중 측량부표 확인 등 접근 시 준설 버킷을 선박 내로 이동하고, 너울 및 조류 등 해상 기상 상황에 대한 교육 및 점검을 실시하는 재발 방지 대책과 향후 조치 계획.',
#  '고소작업 시 안전발판의 견고한 설치와 안전벨트 착용 후 안전걸이 걸기를 포함한 철저한 안전교육 및 자체점검을 통한 안전관리 강화.',
#  '재발 방지 대책과 향후 조치 계획으로 재발 방지 대책 수립 및 현장 내 안전 관리 교육 등 관리 철저.',
#  '당일 작업투입전 개인별 건강상태 확인 철저와 사후관리 철저.',
#  '안전대 착용, 안전로프 설치, 안전고리와 동바리 수평재 연결, 유해 위험요인 인지 교육 및 안전 수칙 마련, 안전관리 철저.',
#  '근로자 안전교육 실시와 부상자 치료를 통한 안전사고 재발 방지 대책 마련.',
#  '안전사고 방지를 위한 철저한 지시.',
#  '현장 안전시설 조치와 안전시설 설치 확인을 통한 재발 방지 대책.',
#  '가설 발판 및 안전난간 설치와 안전교육 강화를 통한 재발 방지 대책.',
#  '현장 관리와 안전 관리의 철저한 안내 및 지시 예정.',
#  '재해 원인 조사 및 분석을 통해 동종 작업 시 발생 요인을 사전에 인지하고 위험 요소를 제거하기 위한 사전 교육 실시, 근로자 보호구 착용 및 탈착 시 작업 진행 금지 교육 강화, 동종 작업 사고 사례 및 원인 교육을 통한 안전사고 재발 방지, 공종별 작업 시 사고 발생 요인 철저 분석 및 안전 보호구 착용 교육 이행 여부 확인 조치.',
#  '작업자 이동통로 확보와 안전교육 실시를 통한 재발 방지 대책.',
#  '자재 운반 시 기계 및 장비 사용 방법 고려와 현장 안전 점검 강화에 따른 재발 방지 대책.',
#  '작업자 안전관리 교육 철저와 행정지도 실시.',
#  '중량물 취급 방법 정립과 사전 안전관리 강화를 통한 재발 방지 대책 마련.',
#  '창호코킹 작업 등 단부 작업에 대한 추락방지 조치와 현장 점검 실시.',
#  '안전통로 확보와 통로 내 자재 적치 금지 조치.',
#  '자재 결속부분 재정비를 통한 재발 방지 대책과 향후 조치 계획.',
#  '임시 고정물 고정 상태 확인 철저와 산업재해처리 및 피해 근로자의 수술 후 1주일 가량 입원 후 퇴원 및 통원 치료 중인 상황.',
#  '비탈면 작업 시 안전대 걸이시설 사용과 2중 안전고리 지급 및 착용 확인을 통한 추락 방지와 사전작업계획 수립, 개인보호구 착용 및 안전작업 실시, 작업별 원인 도출 및 개선대책 공유, 근로자의 불안전한 행동 배제를 통한 안전 관리 강화.',
#  '재발 방지를 위한 건설장비 및 건설현장 안전점검 실시',
#  '거푸집 및 비계 해체작업 시 작업지휘자 배치와 안전작업방법에 대한 수시 교육 실시, 현장 안전관리 강화 요청 및 필요 시 현장 점검 예정.',
#  '안전사고 방지를 위한 안전관리 철저 지도',
#  '작성 과정에서 발생할 수 있는 안전사고에 대한 교육과 유사 안전사고 발생 방지를 위한 교육 실시.',
#  '재발 방지 대책 수립과 향후 조치 계획으로 자재에 쌓여있던 물길 제거 후 작업 재개 및 안전교육 실시 예정.',
#  '철골해체 작업 시 처짐 방지 대책 실시.',
#  '안전교육 및 자재점검을 통한 재발 방지 대책과 향후 조치 계획.',
#  '공구 정리정돈 및 상하 동시 작업금지 교육과 기계실 출입문 시건관리를 통한 안전 관리 방안.',
#  '안전교육 및 관리 철저를 통한 사고조사현황 제출.',
#  '자재 상하차 시 크레인 사용을 지양하고 지게차를 사용하여 작업하며, 묶음 자재는 반드시 지게차로 상하차하고 부득이하게 크레인을 사용할 경우 1개 부재씩 상하차하며, 자재가 트레일러 적재함에 안착되기 전에는 근로자가 트레일러 적재함에 오르지 않는 안전 수칙.',
#  '작업후 자재 정리정돈 및 승하강시 동선내 장애물 유무 확인.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '작업전 작업내용 및 방법에 대한 전파 및 교육 실시, 적절한 도구 사용 및 개인 보호구 착용 실시, 작업전 위험성에 대한 안전교육 실시.',
#  '사고 발생 원인 분석과 재발 방지 대책 수립, 작업자 안전 교육 실시.',
#  '현장 관리 및 작업자 안전 교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전과 리 강화 및 안전교육 강화와 부상자 치료 진행을 통한 재발 방지 대책.',
#  '작업 전 서포트 고정상태 확인 및 점검, 해체구간 타근로자 접근금지 표지판 설치, 관리감독자 상주하여 위험요소 근절, 해체구간 정리정돈 및 근로자 안전교육 실시.',
#  '재해 예방을 위한 재발 방지 대책 수립 및 이행 관리, 특별 안전보건 교육 실시, 위험성 평가 중점 관리 및 관리 감독 강화, 안전 담당자 부재 시 대체자 지정과 배치를 통한 현장 관리 감독 강화, 기 수립된 기술적, 교육적, 관리적 대책의 현장 적용.',
#  '거푸집 작업 시 아웃트리거 등 장애물에 의한 전도 예방 조치 시행.',
#  '현장 내 보행 시 전방 주시 및 휴대폰 사용 금지, 인동선 구간 장애물 제거와 사례 전파 요청을 통한 재발 방지 대책.',
#  '작업자 안전교육 철저와 현장정리정돈 철저.',
#  '안전교육 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '사고원인 파악 및 안전유의 통보를 통한 유사사고 재발생 방지 방안.',
#  '근로자 안전한 이동통로 및 작업 공간 확보.',
#  '작업자 안전교육 재실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자 안전교육 철저.',
#  '관리자 및 근로자 안전교육 실시와 중량부재 취급 시 무리한 행동 금지, 관리감독자 특별교육 후 회신 조치.',
#  '안전모 등 안전용품 착용 확인 및 돌풍 시 작업 중지 실시와 병원 치료를 포함한 조치 계획.',
#  '작업 전 안전교육 실시, 누전차단기를 통한 전원 인출 체계 확립, 절연 보호구 지급 및 착용, 신규 투입자 건강 문진 강화, 현장 내 가설 전원 일제 점검, 신규 채용자 작업 전 문진 강화.',
#  '재해 예방을 위한 안전 교육 실시와 재해 방지 대책 수립.',
#  '장비의 정기적인 안전점검 및 일일점검 강화, 아웃트리거 작동 및 누유 상태 점검, 근로자 특별안전교육 실시.',
#  '작업자 불안전한 행동에 대한 안전교육 실시.',
#  '터파기 경사면 붕괴 대비 안전조치와 되메우기 후 상부 콘크리트 구조물 철거 후 후속 공정 진행을 포함한 재발 방지 대책.',
#  '작업자 주변 공구통 등 각종 자재 5m 이상 이격과 동일사례 재발 방지를 위한 교육 및 현장 수시점검 실시.',
#  '작업장 정리정돈 및 보행자 통로 내 자재정리 구획 준수에 따른 작업관리 재해 위험성 평가 실시와 재발 방지 대책 내용 전 근로자 교육, 산업재해보상보험 처리 종결.',
#  '현장 정리와 작업 전 안전 계획 수립을 통한 재발 방지 대책.',
#  '안전교육 철저 시행.',
#  '장애물 파악 및 순차적 이동에 대한 재발 방지 대책과 향후 조치 계획.',
#  '말비계 끝 부분 낙상방지장치 설치 유무 재확인과 근로자 안전교육 실시.',
#  '안전관리 교육 철저와 작업장 안전준수 교육 실시를 통한 재발 방지 대책.',
#  '작업자 및 장비조정원 전원에 대한 안전교육 실시와 유사사고 사례 교육을 통한 위험작업 인식 고취 및 필요시 안전점검 실시.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자 일일단위 건강상태 확인을 통한 재발 방지 대책 및 향후 조치 계획.',
#  '기상예보 확인 후 구역별 담당구간 지정 및 제설 작업 진행, 지속적인 근로자 안전교육 및 현장 점검 실시와 지속적인 현장 안전점검 실시.',
#  '사고재발 방지를 위한 교육 실시',
#  'TBM 및 위험 작업 시 안전교육 강화를 통한 사고 재발 방지 대책과 작업자 안전교육 실시 여부 확인을 포함한 향후 조치 계획.',
#  '현장인부 안전교육 실시와 공사현장 전반에 대한 안전관리계획 재검토 지시 예정.',
#  '사고현장 및 작업기계의 위험요인에 대한 안전점검 실시, 철근가공작업 표준절차 준수, 위험작업시 올바른 작업방법에 대한 근로자 안전교육 실시, 관련 공종 공사참여자에게 사례 전파 및 안전관리 의식 확립, 철근 가공 작업시 숙련공 투입으로 안전사고 예방 및 관리 강화.',
#  '살수차와 작업 차량의 안전 관리 철저.',
#  '재발 방지와 향후 조치 계획에 대한 주의.',
#  '옹벽시공 간 하단부 낙하방지망 설치와 낙하방지망 설치 이후 작업 재개 및 사고자에 대한 치료와 산재처리.',
#  '작업 전 주변 시설 안전조치 철저와 준공 완료를 통한 재발 방지 대책.',
#  '해당 작업공정에 대한 위험성 평가 실시와 근로자 전파 교육을 통한 재발 방지 대책 이행 상태 점검.',
#  '안전교육 재실시와 사고자 병원 통원치료를 통한 재발 방지 대책.',
#  '재발 방지를 위한 향후 조치 계획.',
#  '현장정리정돈 및 통행로 확보 실시.',
#  '작업자 특별안전교육 실시와 재발방지 특별대책 수립, 재해자 경과 모니터링 및 해체작업 개선대책 수립, 산업재해 관련 규정 및 절차의 적법한 이행 감독.',
#  '작업공간 확보와 정리정돈, 중량물 2단 적재 지양, 관련 재해사례 전파교육 실시, 안전관리 철저 및 안전교육 시행.',
#  '작업공구 필수사용에 대한 재발 방지 대책과 향후 조치 계획.',
#  '회전형 공도구 사용 시 장갑 착용 금지 조치와 관련 교육 실시.',
#  '중량물 작업 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '해체 한 샤클 및 슬링벨트를 보 거푸집 내에 둔 상태에서 샤클해체 근로자 대피 후 빈 슬링벨트 상승 실시와 보 거푸집 설치 작업 중 안전대책 이행의 주기적 실태 점검 실시.',
#  '작업 전 안전교육 철저와 산재처리의 실행.',
#  '중량물 작업 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '자재 운반방법 재교육, 작업구간 정리정돈 실시, 전도 사고사례 교육 및 작업장 정리정돈에 대한 관리감독자 교육과 전파.',
#  '시스템동바리 해체 작업계획서에 따른 작업방법 교육 실시와 위험성평가표에 따른 중점관리 실시, 작업계획서 작성 및 이행 상태 확인.',
#  '안전교육 실시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '특별 교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전의식 강화를 위한 근로자 교육 실시',
#  '이동통로 이용 준수 및 보행 중 전방 주시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업자 안전교육과 작업 전 각종 장비 및 자재 점검, 정비 철저를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '근로자 안전한 이동통로 및 작업 공간 확보.',
#  '근로자의 무리한 동작 금지와 2인 1조 작업 관리, TBM 일일안전교육 전파 교육 실시, 상부 가시설 작업 시 근로자의 손목, 무릎, 팔꿈치 보호대 안전장비 착용 검토 지시.',
#  '말비계 사용 시 안전작업 수칙 준수, 말비계 상부에서 작업 시 위험성 사전 경보 기능 강화 및 스토퍼 설치, 말비계 사전 확인 점검 강화와 현장 점검 시 스토퍼 부착 기준에 맞게 사용 실태 집중 점검 강화.',
#  '재발 방지 안전관리 지도 마련.',
#  '향후 작업 시 숙련공을 배치하여 작업하도록 지시함.',
#  '불안전행동 관리와 관련하여 해당 작업(철근배근) 외 근로자 출입금지 및 불안전한 상태에서 무리한 이동 금지 교육 실시.',
#  '안전발판의 고정 및 보강조치 진행.',
#  '시스템동바리 설치 시 작업지휘자를 지정하여 횡대 및 발판 체결 상태를 확인하고, 관리감독자 안전 교육 실시 및 현장 안전점검 강화를 통한 재발 방지 대책 마련.',
#  '작업자 부주의로 발생한 사고에 대한 재발 방지를 위한 안전교육 및 기계실 안전통로 확보 조치.',
#  '해당 작업공정에 대한 위험성 평가 실시와 근로자 전파 교육을 통한 재발 방지 대책 이행 상태 점검.',
#  '작업 시 주의 조치에 대한 재발 방지 대책.',
#  '작업자 안전교육 실시와 관리감독 철저를 통한 재발 방지 대책.',
#  '자재 정리 정돈과 이동통로 확보를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '터파기 작업 시 주변 환경 면밀 확인 및 부석 제거, 근로자 작업 전 낙하물 확인 및 제거, 작업 전 관련 안전 교육 실시, 현장 안전 관리 철저, 현장 작업자 안전 관리 교육 철저, 현장 수시 점검.',
#  '재발방지교육 실시',
#  '안전시설물 설치 및 정비 점검과 비계 및 안전시설물 수정 정비, 현장책임자 및 안전관리자, 작업자를 대상으로 한 수시 안전지도 실시.',
#  '향후 작업 시 바닥 이동 시 신발 관리 조치 및 추후 진행 경과 협의에 따른 조치 예정.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획의 시공자 작성 및 통보.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '관리감독자 확인 관리 철저에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '절단작업 지양과 숙련공 배치, 합판 제거 후 스티로폴 부착으로 이루어진 재발 방지 대책.',
#  '작업발판 재확인 및 보강 조치.',
#  '추락방지망 설치상태에서 해체작업 진행, 추락방지망 간섭으로 인한 볼트 해체 어려운 구간의 일부 추락방지망 절제 후 해체, 노출된 이음철근 보호캡 보양을 통한 찔림사고 예방, 하부 노출철근캡 보양, 고위험 작업 시 추가교육 실시.',
#  '철근작업 실시 전 작업동선 관련 안전교육과 현장조사 및 관련자 면담, 작업장 내 위험요소 제거를 통한 재발 방지 대책 마련.',
#  '재발 방지 계획 수립과 안전보건관리계획 이행.',
#  '중량물 작업 시 현장 조도 확보 및 발걸림 위험 제거 후 작업 지시.',
#  '작업 전 작업장 주변 위험 요소 조치 및 기계 장비 상태 점검 후 안전 조치와 보후구 착용, 공종 벽 관리 감독자의 지도 점검을 포함한 고속 절단기 사용 주의사항과 안전 장치가 설치된 장비만 반입 및 사용 교육.',
#  '거푸집 작업 시 아웃트리거 등 장애물에 의한 전도 예방 조치 시행.',
#  '안전통로 확보와 작업구간 위험요소 제거 및 안전교육 실시.',
#  '자재 정리에 대한 강조와 재발 방지 대책.',
#  '안전사고 재발 방지를 위한 안전시설 추가 및 보강, 공사안내표지판 추가 및 보강, 근로자 안전교육 강화, 근로자 보호대책 강화 및 추가배치, 공사 안전시설 완비로 구성된 조치 계획.',
#  '안전수칙 철저 및 작업자 안전교육 실시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '근로자 특별안전교육 및 위험성평가 실시, 흙막이 배면부 토석붕괴 방지 조치 실시 및 안전한 작업환경 확보 후 작업 개시, 건설사업관리단 및 시공사 안전순찰 강화, 건설현장 산업재해 재발방지 이행조치 결과 집중 관리.',
#  '작업공구(그라인더)를 두 손으로 파지하고 안정적인 자세로 작업을 이행하는 방안.',
#  '이동통로 구획과 안전교육 실시를 통한 안전 확보.',
#  '안전 관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '현장 여건에 맞는 작업계획 수립과 작업공간 및 여건 마련 후 작업개시를 통한 부상 방지 대책과 손가락 끝부분을 스친 작업공구로 인한 통원 치료 예정.',
#  '작업장 바닥 정리정돈과 공사현장 관리철저 지도의 실행.',
#  '안전교육 철저와 지속적인 교육 실시를 통한 재발 방지 대책.',
#  '실족방지망 설치와 안전고리를 몸에 감아 체결하는 조치.',
#  '현장주변 관리 철저와 작업자 안전교육 실시.',
#  '작업 시 주의 및 안전교육 철저와 안전사고 예방교육 철저를 통한 재발 방지 대책.',
#  '보행 시 주의에 대한 재발 방지 대책과 향후 조치 계획.',
#  '배관에 밴딩 결속하여 손잡이를 만들어 방향 조정하는 재발 방지 대책과 향후 조치 계획.',
#  '사다리 탈락 원인 확인과 다른 사다리 설치 상태 점검, 현장 점검 및 이상 징후 발생 시 재시공 계획.',
#  '안전교육 강화, 작업 구간 정리 정돈 철저, 관리 감독 강화 및 동기 부여 실시를 통한 재발 방지 대책 마련.',
#  '공사완료에 대한 재발 방지 대책과 향후 조치 계획.',
#  '지하 매설물의 올바른 작업 절차와 예방조치에 대한 교육, 작업 단계별 관련 위험요소 고려, 필요한 지침과 예방조치의 지속적인 점검, 그리고 지하 매설물의 위치와 수량 등 적절하고 정확한 정보 확보를 통한 굴착 작업 개시 전 점검이 이루어질 것입니다.',
#  '작업 시 안전보호대 강화와 안전교육 실시, 무리한 일정 조율을 통한 안전장비 강화 및 업무 부주의 감독 강화.',
#  '무거운 자재 이동 시 무게에 맞게 인원 배치와 안전교육 실시.',
#  '안전관리 재발 방지 교육과 치료조치 시행.',
#  '작업 전 사전 작업계획 및 위험요인 교육 실시와 자재 운반 시 미끄럼 방지를 위한 기구 이용, 피재자의 진료상황 수시 점검 및 현장 안전관리 활동 점검이 포함된 재발 방지 대책과 향후 조치 계획.',
#  '재발 방지 대책과 향후 조치 계획의 마련.',
#  '작업자 안전교육 실시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업전선 관련 점검 진행.',
#  '사고현장 및 작업기계의 위험요인에 대한 안전점검 실시, 철근가공작업 표준절차 준수, 위험작업시 올바른 작업방법에 대한 근로자 안전교육 실시, 관련 공종 공사참여자에게 사례 전파 및 안전관리 의식 확립, 철근 가공 작업시 숙련공 투입으로 안전사고 예방 및 관리 강화.',
#  '막장면 안정성 확보 후 작업 시행과 막장 관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전수칙 준수에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전확보를 위한 재발 방지 대책 및 향후 조치 계획.',
#  '작업자 양중작업 시 신호사항 최종 확인과 작업교육 실시.',
#  '근로자의 건강상태 확인 및 작업전 준비운동 철저.',
#  '현장 마무리 요청 및 안전 게도의 향후 조치 계획.',
#  '자재운반 시 2인 1조 작업 실시와 근로자 안전관리수칙 관련 교육 철저.',
#  '안전사고 재발 방지를 위한 작업자 안전교육 실시 강화.',
#  '작업발판 점검 후 보강 교체 및 수리와 현장 점검을 통한 가설자재 및 안전시설물 보완 후 작업 실시 예정.',
#  '안전교육 및 현장관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '이동 작업시 추가 발판 설치에 대한 재발 방지 대책 및 향후 조치 계획.',
#  '안전관리계획 준수에 따른 작업 지도와 사고조사 실시 및 통보.',
#  '안전교육 실시와 안전관리 철저에 대한 재발 방지 대책.',
#  '안전관리교육 철저 시행.',
#  '산재처리에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전고리 체결 및 안전난간대 설치를 통한 재발 방지 대책과 향후 조치 계획.',
#  '설치 작업 간 자재 결속 확인.',
#  '작업장 내 돌출물 확인 및 제거, 유사재해 방지를 위한 안전교육 실시, 근로자 이동통로 확보 상태 확인.',
#  '재발 방지를 위한 작업자 교육 및 안전지도 실시',
#  '가설 방음벽 지주 절단 작업 전 크레인으로 지주를 고정하고 고정 상태를 확인한 후 절단 작업을 실시하며, 작업 책임자를 지정하여 작업 전 작업자 교육과 장비 점검을 철저히 시행하고 작업 책임자가 현장에 상주하여 시공 및 안전 관리를 철저히 하는 것과 작업 계획을 검토하여 보완 작성하고 작업 책임자를 지정하여 현장에 상주하여 관리 감독을 실시하며 작업 전 작업자 교육과 장비 이상 유무 점검을 철저히 하는 것.',
#  '이동통로 이용 준수 및 보행 중 전방 주시를 통한 재발 방지 대책과 향후 조치 계획.',
#  '작업 시 주의 조치에 대한 재발 방지 대책.',
#  '작업자 안전교육 실시와 사고조사 통보를 통한 재발 방지 대책 마련.',
#  '고소작업대 작업 시 안전대 고리 체결 철저, 불안전한 행동 및 자세 근절을 위한 작업 전 안전교육 실시, 작업지휘자 및 관리감독자의 철저한 관리감독, 부주의 발생에 따른 안전교육 강화, 근로복지공단 산재요양신청 조치, 고용노동부 산업재해조사표 30일 이내 작성 제출, 재해자 경과 관찰.',
#  '사고사례 전파 및 작업자 안전교육 실시.',
#  '가설 설치 안전확인 후 공사 진행과 사고 예방을 위한 노력이 포함된 재발 방지 대책.',
#  '근로자 교육 실시와 협착 방지 장갑 지급 및 착용.',
#  '철근 배근 구간 안전 발판 설치 및 인동선 구획 설정.',
#  '2인 이상 작업 지시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전수칙 준수에 대한 재발 방지 대책과 향후 조치 계획.',
#  '사고를 유발한 원인 제거를 위한 현장 작업자 통로 확보 및 작업 중 잔여 자재 통로 적치 금지와 관리 철저.',
#  '거푸집 보강을 통한 후면부 지주 연결 및 거푸집 간 체결용 타이를 이용한 긴결 체결, 공종별 안전계획 재검토와 보완조치, 안전사고 발생 예상부위 확인 후 사고 요인 사전 제거.',
#  '재발 방지를 위한 작업자 교육 및 안전지도 실시',
#  '현장작업 전 안전사고 체크와 건설현장 안전조사 실시를 통한 재발 방지 대책.',
#  '규정된 작업통로 이용과 고령근로자의 골절 사고에 대한 위험성 강조 및 주의당부가 포함된 재발 방지 대책과 향후 조치 계획.',
#  '작업 안전교육 실시를 통한 향후 조치 계획.',
#  '비계등 고소작업 시 공구내 이탈방지끈 설치 및 공구/자재 보관용 공도구함(달포대 등) 설치 여부 확인.',
#  '안전고리 체결 및 안전난간대 설치를 통한 재발 방지 대책과 향후 조치 계획.',
#  '자재 하역 시 주변 지장물 사전 확인 및 간섭부위 제거, 상하부 동시작업 금지 및 하부구간 접근금지, 인양용 자재의 고정상태 확인 후 인양작업 실시, 상하부 자재 하역구간 낙하물 반경 내 원천 접근금지 조치 이행여부 확인, 자재 이동 전 수평상태 및 고정상태 확인 조치 이행여부 확인.',
#  '안전교육 실시를 통한 재발 방지 대책 및 향후 조치 계획.',
#  '작업 전 자재 고정 및 체결 여부 확인, 안전교육 실시, 불안정한 조건 완전 조치 후 작업 진행.',
#  '안전관리 철저로 인한 사고 재발 방지 필요성.',
#  '작업반경 외 구간 생명줄 설치를 통한 작업 시 간섭 방지.',
#  '안전관리자 교체 요청과 재발 방지 대책 요구.',
#  '안전교육 철저지시.',
#  '작업발판의 안정성을 확보하기 위한 지지물 연결 및 고정 실시.',
#  '안전조치 철저와 사용승인 검사 완료를 통한 재발 방지 대책.',
#  '안전교육 실시',
#  '믹서기 미사용 점검 시 전원 차단조치, 믹서기 교반 작업 후 자동버튼 해제, 작업 전 공도구 점검 및 개인별 공도구 점검과 작업순서 준수 관리감독 강화.',
#  '사고 발생 방지를 위한 인양함틀 상단의 완충자재 덧대기와 시설 초지 및 안전교육 실시.',
#  '재발 방지 대책으로 실시되는 특별안전교육과 진단서 첨부 제출 예정 사항.',
#  '안전교육 실시와 정리정돈을 통한 유사재해 예방 조치.',
#  '안전관리교육 및 현장정리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '기계적 원인 및 대책 미비, 물질 및 환경적 원인으로 인한 현장 이동구간 Condition 미확인, 인적 원인으로 인한 전방주시 태만, 관리적 원인으로 인한 이동동선의 안전상태 확인 미흡에 대한 대책으로 컨테이너 앞 이동구간의 큰 잡석 제거 및 비계발판 설치, 이동간 주의 사항 교육, 근로자 이동동선 안전상태 확인이 필요함.',
#  '사고사례 전파와 안전교육 실시.',
#  '작업 전 주변 정리와 잔업 전 사전 점검 및 관리 감독 철저.',
#  '재발 방지를 위한 작업자 교육 및 안전지도 실시',
#  '지게차를 이용한 자재 운반 시 자재 결속 실시 및 장비 운행 시 반경 내 접근금지 교육과 재발 방지 철저 지시.',
#  '현장안전조치와 현장안전관리를 통한 재발 방지 대책 마련.',
#  '재발 방지 및 향후 조치 계획.',
#  '공사현장 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '안전점검 및 안전교육 실시',
#  '주의 깊은 시공과 사고 조사 후 처리 방안 마련.',
#  '부주의로 인한 사고 방지를 위한 구두 요구와 향후 조치 계획.',
#  'TBM 작업 내용 숙지와 보호구 착용 철저, 안전교육 실시를 통한 안전 의식 강화 및 전체 근로자를 대상으로 한 사고 사례 전파와 교육 예정.',
#  '공사 전 안전조치 철저.',
#  '안전통행로 주변 자재적치 금지 및 결빙구간 제거.',
#  '사고공종 위험성 평가 및 사고사례 전파를 통한 재발 방지 교육과 작업 통로 정비.',
#  '작업 시 작업공구의 안전장치 정상작동 유무 확인과 근로자 대상 안전교육 실시를 통한 안전사고 예방.',
#  '교육 및 관리 철저 실시를 통한 안전환경 개선과 위험 빈도 감소를 위한 조치 계획.',
#  '자재 운반 시 과적 금지를 위한 안전 교육 실시.',
#  '건설현장 안전사고 방지를 위한 특별안전 교육 강화, 장비 안전점검 강화, 작업 중 즉시 작업중지 조치, 안전점검 순찰활동 강화, 관리감독자 및 근로자 안전교육 강화, 안전장치 기능상태 확인, 비상사태 발생 시 긴급 상황전파, 사업장 안전활동 강화.',
#  '재발 방지 및 향후 조치 계획.',
#  '산업재해 판단 후 조치 예정 사항.',
#  '재발 방지 대책과 향후 조치 계획.',
#  '중량물 취급기준 및 작업자 부주의에 대한 안전점검과 교육 실시, 안전지도 업체(베스트안전)와의 현장감독 합동 조사 및 특별안전교육 실시.',
#  '공사현장 안전관리 철저에 대한 재발 방지 대책과 향후 조치 계획.',
#  '작업공간 및 이동통로 시인성 확보와 근로자 안전교육 강화.',
#  '근로자 안전교육 실시, 수시 및 일일 안전점검 강화, 작업 전 TBM 교육 강화, 안전점검 강화 및 특별안전교육 지시.',
#  '안전사고 예방을 위한 안전관리 및 안전교육 철저.',
#  '각도절단기 정비, 청소, 검사, 수리 작업 시 작동 정지 후 작업하도록 교육하고, 작업방법 준수 여부를 철저히 관리 감독하며, 작업자 안전교육 및 현장 관리를 통해 사고 재발 방지에 힘쓰는 방안.']
