# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.37 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.40)
# Requirement already satisfied: langchain<1.0.0,>=0.3.19 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.0.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.11)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<2,>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.37->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (2.27.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.18-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 79.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.18 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.8.1 python-dotenv-1.0.1 typing-inspect-0.9.0

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 25.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install -U bitsandbytes transformers
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Collecting transformers
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 114.7 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# Successfully installed transformers-4.49.0

# %%
# !pip install faiss-gpu-cu12
# Out:
# Collecting faiss-gpu-cu12
#   Downloading faiss_gpu_cu12-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (24.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (12.4.5.8)
# Downloading faiss_gpu_cu12-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 MB 15.5 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu-cu12
# Successfully installed faiss-gpu-cu12-1.10.0

# %%
# !pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (0.3.18)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.37 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.40)
# Requirement already satisfied: langchain<1.0.0,>=0.3.19 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.11)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<2,>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.37->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 24.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
import pandas as pd
import numpy as np
import torch
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFacePipeline
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# %%
data_path = "/content/drive/MyDrive/"

# %%
train = pd.read_csv(data_path+"train.csv" )
test = pd.read_csv(data_path+"test.csv" )
sample = pd.read_csv(data_path+"sample_submission.csv")

# %%
def preprocess(df):
    df.replace('-', np.nan, inplace=True)
    df['공사종류(대분류)'] = df['공사종류'].str.split(' / ').str[0]
    df['공사종류(중분류)'] = df['공사종류'].str.split(' / ').str[1]
    df['공종(대분류)'] = df['공종'].str.split(' > ').str[0]
    df['공종(중분류)'] = df['공종'].str.split(' > ').str[1]
    df['사고객체(대분류)'] = df['사고객체'].str.split(' > ').str[0]
    df['사고객체(중분류)'] = df['사고객체'].str.split(' > ').str[1]
    df['사고인지 시간'] = df['사고인지 시간'].str.split('-').str[0].str.strip()

    return df


train = preprocess(train)
test = preprocess(test)

# %%
# 훈련 데이터 통합 생성
combined_training_data = train.apply(
    lambda row: {
        "question": (
            f"작업 프로세스는 '{row['작업프로세스']}'이며 {row['인적사고']}발생, 사고 원인은 '{row['사고원인']}'입니다."
            f"재발 방지 대책 및 향후 조치 계획은 무엇인가요?"
        ),
        "answer": row["재발방지대책 및 향후조치계획"]
    },
    axis=1
)

# DataFrame으로 변환
combined_training_data = pd.DataFrame(list(combined_training_data))

# %%
# 훈련 데이터 통합 생성
combined_test_data = test.apply(
    lambda row: {
        "question": (
            f"작업 프로세스는 '{row['작업프로세스']}'이며 {row['인적사고']}발생, 사고 원인은 '{row['사고원인']}'입니다."
            f"재발 방지 대책 및 향후 조치 계획은 무엇인가요?"
        )
    },
    axis=1
)

# DataFrame으로 변환
combined_test_data = pd.DataFrame(list(combined_test_data))

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)

# %%
model_id = "NCSOFT/Llama-VARCO-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto"
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import torch
from langchain_community.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline
from tqdm import tqdm

# Train 데이터 준비
train_questions_prevention = combined_training_data['question'].tolist()
train_answers_prevention = combined_training_data['answer'].tolist()

train_documents = [
    f"Q: {q1}\nA: {a1}"
    for q1, a1 in zip(train_questions_prevention, train_answers_prevention)
]

# 임베딩 생성
embedding_model_name = "jhgan/ko-sbert-sts"
embedding = HuggingFaceEmbeddings(model_name=embedding_model_name)

# 벡터 스토어에 문서 추가
vector_store = FAISS.from_texts(train_documents, embedding)

# Retriever 정의
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 5})
# Out:
# <ipython-input-9-e7d180f13c86>:21: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding = HuggingFaceEmbeddings(model_name=embedding_model_name)

# %%
text_generation_pipeline = pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    do_sample=True,
    temperature=0.1, # 0~1 까지 0에 가까울 수록 보수적인 답변 즉 창의성이 떨어짐
    return_full_text=False,
    max_new_tokens=128, # 문장 최대 길이 조정
    batch_size=16  # 배치 크기 지정
)
# Out:
# Device set to use cuda:0

# %%
prompt_template = """
### 지침: 당신은 건설 안전 전문가입니다.
질문에 대한 **재발 방지 대책 및 향후 조치 계획**만 간결하게 답변하세요.
- 서론, 배경 설명, 추가 설명 없이 핵심 내용만 전달하세요.
- 불필요한 형식(목차, 강조 표시, 리스트 등)을 사용하지 마세요.
- 한 문장 또는 간결한 문단으로 자연스럽게 작성하세요.
- 특수문자를 포함하지 마세요.

{context}

### 질문:
{question}

### 답변:
"""

llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# 커스텀 프롬프트 생성
prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template,
)

# RAG 체인 생성
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt}
)
# Out:
# <ipython-input-11-8844173da8bf>:17: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# %%
tokenizer.padding_side = "left"

# %%
from torch.utils.data import DataLoader
from datasets import Dataset
import torch
from tqdm import tqdm
import psutil

max_num_workers = psutil.cpu_count() - 1  # CPU 코어 수 - 1 (시스템 안정성을 위해 1개 예약)
min_batch_size = 4  # 최소 배치 크기
max_batch_size = 64  # 최대 배치 크기 (GPU 메모리에 따라 조정 가능)

# Matmul 성능 최적화
torch.set_float32_matmul_precision('high')

# 최적의 num_workers 계산
def calculate_optimal_num_workers():
    cpu_usage = psutil.cpu_percent(interval=1)
    available_cores = max_num_workers
    # CPU 사용률이 80% 이상이면 num_workers 줄임
    if cpu_usage > 80:
        return max(1, available_cores // 2)
    return available_cores

# 테스트 데이터 준비
test_questions = combined_test_data['question'].tolist()
test_dataset = Dataset.from_dict({"question": test_questions})

# DataLoader 설정 (num_workers로 병렬 처리 활성화)
batch_size = 16
num_workers = calculate_optimal_num_workers()
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
test_results = []
print("테스트 실행 시작... 총 테스트 샘플 수:", len(test_questions))

# 배치 처리 함수
def process_batch(batch):
    contexts = [retriever.invoke(q)[0].page_content for q in batch["question"]]
    prompts = [prompt.format(context=c, question=q) for c, q in zip(contexts, batch["question"])]
    results = text_generation_pipeline(prompts, batch_size=batch_size)
    return [r[0]["generated_text"] for r in results]

# DataLoader로 병렬 처리
for batch in tqdm(test_dataloader, desc="처리 진행률"):
    batch_results = process_batch(batch)
    test_results.extend(batch_results)
print("\n테스트 실행 완료! 총 결과 수:", len(test_results))
# Out:
# 테스트 실행 시작... 총 테스트 샘플 수: 964
# 처리 진행률:   5%|▍         | 3/61 [04:29<1:24:54, 87.84s/it]

# %%
test_results
# Out:
# ['지반 안정성 강화를 위해 아웃트리거 설치 전 지반 조사 및 강화 조치 실시, 아웃트리거 길이 일치 조정 및 지반 고임목 추가 보강, 작업 위치 최적화 및 붐대 운용 범위 제한 설정, 정기적인 장비 안정성 점검 및 유지보수 강화, 펌프카 작업 교육 프로그램 강화로 무게중심 관리 및 비상상황 대처 훈련 포함, 사고 원인 분석 기반의 안전 지침 업데이트 및 준수 강제화 실시.',
#  '안전 교육 강화와 함께 숫돌 사용 지침 엄격히 준수하도록 교육 실시. 모든 작업자에게 적절한 보안면 착용 의무화 및 정기적인 안전장비 점검 실시.',
#  '안전교육 강화로 주의력 집중 및 주변 환경 인식 훈련 실시, 계단 안전 표시 설치 확대 및 정기적인 계단 유지보수 점검 실시.',
#  '작업 발판 주변 벽돌 잔재 정기적 제거 및 안전 표시 설치, 작업자 안전 교육 강화 실시.',
#  '작업자에게 점심시간 안전이동 지침 강화 및 정기적인 안전 교육 실시. 안전 경로 표시 확대와 함께 개인 보호 장비 착용 의무화 강화.',
#  '안전발판의 표준 설치 절차를 명확히 정립하고 정기적인 점검 실시, 모든 작업자 대상 강화된 안전 교육 및 절차 준수 인증 제도 도입.',
#  '안전 교육 강화 및 개인 보호 장비(PPE) 착용 강제화 실시, 정기적인 안전 점검 및 행동 기반 안전 프로그램 도입.',
#  '1. **안전 교육 강화**: TSC GIRDER 및 SPLICE PLATE 설치 관련 안전 절차에 대한 정기적 교육 실시.\n2. **작업 공간 개선**: 설치 작업 공간의 시야 확보 및 장애물 제거로 작업 환경 개선.\n3. **개인 보호 장비(PPE) 의무화**: 헬멧 및 안전 고글 착용 강제화.\n4. **작업 지침서 업데이트**: 부딪힘 위험을 최소화하는 구체적인 작업 지침 추가 및 배포.\n5. **정기적 안전 점검**: 설치 작업 현장에 대한 정기적 안전 점검 실시 및 문제점 즉시 개선.',
#  '작업장 내 명확한 안내 표시 설치 및 정기적인 안전 교육 강화를 통해 작업자의 주의를 높이고, 이동식틀비계 사용 시 안전 절차 준수를 강제하는 점검 시스템 도입.',
#  '안전장비 착용 강화와 함께 작업 영역 경계 설정 및 작업자 간 소통 시스템 구축. 정기적인 안전 점검과 해체 작업 시뮬레이션 훈련 실시.',
#  '고령자 대상 정기적 건강 및 체력 평가 실시, 적합한 작업 배치 및 안전 교육 강화. 현장 안전 점검 빈도 증가와 맞춤형 안전 장비 제공 계획 수립.',
#  '철판 궤도 정기 점검 및 유지보수 강화, 궤도 설치 및 이동 절차 표준화 실시, 감리자의 실시간 모니터링 시스템 도입.',
#  '안전장비 착용 의무화 및 작업 전 공간 확보 확인 절차 도입, 운반작업 교육 강화로 주의사항 강조, 실시간 모니터링 시스템 구축으로 작업 공간 위험 감지, 사고 발생 시 즉각적인 대응 훈련 실시 및 정기적 안전 점검 강화.',
#  '자재 사용 시 안전 지침 엄격히 준수하고, 관리 직원 대상 안전 교육 강화 및 실시간 감시 시스템 도입으로 불안전 행동 방지. 판넬설치공 보호 장비 착용 의무화 및 작업 공간 분리 조치 실시.',
#  '작업 경로 명확히 표시하고 안전 통로 확보, 정기적인 현장 안전 점검 실시, 근로자 대상 안전 교육 강화 및 동바리 설치 관련 특별 안전 지침 제공.',
#  '상부 개구부 안전 바리케이드 설치 및 정기 점검 실시. 합판 사용 시 안전 고정 장치 의무화.',
#  '작업자 대상 고정핀 제거 절차 엄격히 준수 교육 강화, 실시간 모니터링 시스템 도입 및 안전장비 사용 의무화 확대.',
#  '신호수 교대 절차 표준화 및 지속적인 감독 강화, 실시간 통신 장비 도입으로 공백 방지',
#  '안전 교육 강화 및 철근 배치 확인 절차 도입, 미끄럼 방지 매트 설치, 정기적인 현장 안전 점검 실시.',
#  '2인1조 작업 시 표준화된 신호체계 도입 및 정기적인 훈련 실시, 실시간 통신 장비 제공으로 의사소통 강화.',
#  '가이드빔 안정화 장치 설치, 작업자 안전 교육 강화, 정기적인 작업 환경 점검 및 개선 실시.',
#  '작업자 안전 교육 강화와 중각재 배치 개선, 명확한 작업 경로 표시 및 정기적인 작업장 안전 점검 실시 계획 수립.',
#  '작업 환경 온도 관리 강화 및 정기적 휴식 제공. 작업자에게 열 스트레스 대응 교육 실시. 미끄럼 방지 장비 사용 의무화.',
#  '고소작업대 운행 경로 명확히 표시하고 제한 구역 설정, 작업자 대상 고소작업대 안전 운전 교육 강화, 충돌 방지 센서 장착 장비 우선 사용, 정기적 안전 점검 및 위험 평가 실시.',
#  '현장 위험성 평가 강화 및 사전 안전 점검 의무화를 통해 재발 방지 대책을 마련하고, 정기적인 현장 안전 검토와 개선 사항 즉시 적용하는 계획을 수립한다.',
#  '1. 우천 시 작업 금지 정책 도입 및 준수 강화\n2. 모든 작업자에게 적절한 논슬립 보호 장비 필수 착용 규정화\n3. 기상 조건에 따른 작업 일정 조정 시스템 구축',
#  '안전 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 시행. 정기적인 안전 점검과 함께 작업 전 안전 검토 절차 도입.',
#  '타공 위치 일치 확인 절차 표준화 및 자동화 도입, 양손 사용 강제화를 위한 작업 지침 강화와 정기적인 안전 교육 실시, 작업 감독 강화 및 실시간 모니터링 시스템 구축.',
#  '임시 통로 해체 시 안전 경고 표시 설치 의무화 및 정기적 안전 점검 실시. 작업자 대상 안전 교육 강화로 임시 통로 사용 시 주의사항 명확히 전달.',
#  '작업자 안전 장비 강화 및 작업 공간 안전 구역 설정을 통해 재발 방지. 향후 조치로는 크레인 작업 시 생명줄 관리 교육 강화와 동바리 자재 주변의 안전 경계 설치를 실시한다.',
#  '자재 고정 강화 및 작업 공간 안전 경계 설정. 정기적인 안전 점검 실시.',
#  '안전장갑 착용 의무화 및 개인 보호 장비 점검 강화. 지지대 설치 작업 시 보조자 배치를 통한 지원 체계 구축. 정기적인 안전 훈련 강화에 초점을 맞춤.',
#  '정기적인 건강 검진 실시와 작업 중 안전 이동 교육 강화, 그리고 작업 공간의 위험 요소(벽체 이음철근 등) 제거 또는 보호 장치 설치를 포함한 조치 계획 수립.',
#  '작업자에게 올바른 자세와 안전 작업 방법에 대한 정기적 교육 실시 및 작업 중 자세 감독 강화.',
#  '작업 전 안전평가 의무화, 위험지역 통행로 확보 및 안전장비 설치, 감독자 대상 안전지시 절차 교육 강화, 정기적 안전점검 실시.',
#  '작업 공간 확장 및 안전 경계 설치, 정기적인 안전 교육 강화, 중량물 운반 시 보조 작업자 배치 의무화.',
#  '턱 제거 또는 안전 발판 설치와 함께 작업자에게 지형 인지 및 안전 이동 교육 실시. 정기적인 현장 안전 점검 강화.',
#  '철근 배치 구역에 안전 경계 설치 및 경고 표시 강화, 정기적인 현장 안전 점검 실시, 정리작업 전 안전 교육 의무화 실시.',
#  '작업자 간 실시간 통신 시스템 도입 및 명확한 작업 지침서 배포. 정기적인 안전 점검과 소통 훈련 강화 실시.',
#  '신호 체계 표준화 및 정기적 훈련 강화, 실시간 통신 장비 도입.',
#  '콘크리트 측구와 천막 위 안전 표시 설치 및 정기적인 안전 점검 강화, 작업자 대상 경로 안내 교육 실시.',
#  '안전 발판 강화 및 정기적인 안전 교육 실시, 근로자 체력 관리 프로그램 도입.',
#  '구간의 지형 평탄화 작업 및 정기적인 점검 실시, 차량 운행 경로 최적화 계획 수립 및 시행.',
#  '와이어 및 장비 고정 강화, 개인 보호 장비 착용 강제화 및 정기적 안전 교육 실시.',
#  '장갑 착용 강제화 및 전용 절단 도구 사용 의무화, 정기적인 안전 교육 강화 실시.',
#  '바닥 상태 정기 점검 및 위험 표시 설치 강화. 작업자들에게 안전 이동 교육 실시 및 이동 전 바닥 확인 절차 의무화.',
#  '작업자 간 명확한 신호 체계 구축 및 정기적인 통신 훈련 실시, 해체작업 전 신호 확인 절차 의무화.',
#  '1. **바닥 안전 강화**: 작업 구역 바닥에 미끄럼 방지 재질을 설치하고 정기적으로 점검하여 안전성 유지.\n2. **장비 개선**: 거푸집 자재 운반용 안정적인 카트나 롤러 시스템 도입.\n3. **교육 강화**: 운반 작업자 대상 미끄럼 방지 및 안전 운반 기술 교육 정기 실시.\n4. **안전 점검 리스트 도입**: 운반 전 안전 점검 항목을 명확히 하여 준수 여부 확인.\n5. **피드백 시스템 구축**: 작업자로부터 안전 관련 피드백 수집 및 신속한 개선 조치 실시.',
#  '계단 안전 표시 강화 및 정기적인 균형 훈련 실시, 청소 장비 경량화 및 안정성 개선',
#  '정기적인 건설기계 점검 및 유지보수 강화, 주야간 교대 근무 직원들의 휴식 시간 보장 및 피로 관리 프로그램 도입, 브레이크 시스템에 대한 특별 점검 프로토콜 마련 및 준수',
#  '안전화 적절한 사이즈 착용 강제화 및 정기적인 안전화 점검 실시. 안전 교육 강화로 개인 보호구 중요성 인식 제고.',
#  '정기적인 현장 온도 및 습기 상태 모니터링을 통해 위험 구간을 식별하고, 필요시 임시방수 처리 및 미끄럼 방지 매트 설치. 작업자들에게 안전한 이동 경로 교육 강화 및 개인 보호 장비 착용 의무화.',
#  '파이프 운반 시 양손 사용 지침 강화 및 정기적인 안전 교육 실시, 서포트 연결부 안전 취급 훈련 확대.',
#  '휴게시간 출입구 빙판 표시 강화 및 정기적 제설작업 실시, 미끄러짐 예방 교육 강화',
#  '정기적인 안전 교육 강화와 개인 책임 의식 향상 프로그램 도입, 작업 현장의 미끄럼 방지 시설 개선 및 정기적인 점검 실시.',
#  '신호 체계 표준화 및 정기 교육 실시, 작업 전 신호 확인 절차 강화, 실시간 통신 장비 도입 고려.',
#  '지장물 제거 우선순위 설정 및 안전한 간이흙막이 설치 가능한 공간 확보를 위한 현장 재설계 실시. 정기적인 안전 점검 및 위험 평가 강화.',
#  '이동통로 확보 및 실족방지망 설치, 모든 용접 작업 시 2인1조 원칙 준수 강화와 함께 장비 운반 방법 개선 교육 실시.',
#  '1. 안전 교육 강화: 유재폼 운반 및 취급 절차에 대한 정기적 교육 실시.\n2. 장비 개선: 유재폼 고정 장치 설치 및 사용 의무화.\n3. 점검 시스템 구축: 매일 작업 전 장비 및 안전 장치 점검 실시.\n4. 책임 제도 도입: 운반 담당자에게 안전 책임 부여 및 모니터링 강화.',
#  '안전거리 확보 가이드라인 강화 및 실시간 모니터링 시스템 도입, 정기적인 안전 교육 실시 및 작업 전 안전 점검 리스트 준수 강화.',
#  '고소작업대 안정성 검사 정기화 및 전산볼트 고정 강화, 작업자 간 안전거리 확보 지침 강화, 실시간 작업 모니터링 시스템 도입.',
#  '안전교육 강화와 함께 작업 전 안전점검 리스트 준수 의무화, 개인 보호장비 착용 확인 절차 도입.',
#  '무거운 자재의 단독 취급 금지 및 작업 구역 내 안전 경계 설정을 통해 접근 통제 강화. 정기적인 안전 교육 실시 및 작업 전 위험 평가 의무화.',
#  '안전망 설치 확대 및 작업 중 산물 낙하 예측 시스템 도입으로 위험 감소. 정기적인 안전 교육 강화 및 개인 보호 장비(PPE) 사용 의무화 실시.',
#  '안전 교육 강화 및 현장 내 명확한 안내 표지판 설치. 정기적인 안전 점검과 함께 부주의 방지 훈련 실시. 골절 치료 지원 및 재활 프로그램 제공.',
#  '정기적인 안전 교육 강화와 작업 전 안전 점검 의무화 실시.',
#  '작업자 교육 강화 및 정기적 안전 점검 실시. 이동 경로 명확히 표시하고, 개인 보호 장비 착용 의무화. 부주의 예방을 위한 심리적 지원 프로그램 도입 및 안전 행동 인센티브 제도 구축.',
#  '안전 통로 준수 의무 강화 교육 실시 및 통로 주변 미끄럼 방지 시설 설치 확대.',
#  '작업 전 배수로 깊이와 구조 안전성 점검 의무화, 위험 지역 표시 강화 및 안전 교육 실시, 발목 보호 장비 제공 고려.',
#  '정기적인 작업 공간 점검과 안전 표시 설치를 통해 위험 요소 제거하고, 작업자들에게 석고보드 및 하지틀 주변 주의사항 교육 강화.',
#  '작업 전 둥근톱 완전 정지 및 안전덮개 확인 절차 의무화, 정기적인 안전장비 점검 및 유지보수, 그리고 작업자 대상 안전 교육 강화 실시.',
#  '절단작업 시 배관 고정 강화 및 체인블록 필수 설치 절차 확립, 정기적 안전 점검 실시.',
#  '작업구간 명확히 구획 표시하고 정기적인 정리정돈 점검 실시.',
#  '틀비계 안전 점검 강화 및 작업자 개인 보호장비 적합성 검토 실시, 정기적인 안전 교육 프로그램 도입.',
#  '작업 전 상세한 안전 계획 준수 의무화 및 실시간 감독 강화를 통한 재발 방지 대책 수립. 정기적인 안전 교육 강화와 즉각적인 피드백 시스템 도입 계획.',
#  '작업 공간 개선 및 정기적 체력 관리 프로그램 도입, 안전한 작업 방법 교육 강화.',
#  '정기적인 안전 교육 강화와 작업 전 안전 점검 의무화를 통해 재발 방지. 또한, 미끄럼 방지용 바닥 처리 개선 및 개인 보호 장비 착용 강제화를 병행 실시.',
#  '페인트 건조 완료 확인 후 통행 허용, 정기적인 바닥 상태 점검 및 미끄럼 방지 처리 강화.',
#  '정기적인 안전 교육 강화와 실시간 작업 감독 도입, 안전 장비 사용 의무화 및 준수 여부 엄격 점검 실시.',
#  '2인1조 작업 의무화 및 실시간 모니터링 시스템 도입, 정기적인 사다리 안전장비 점검 및 유지보수 강화, 추가적인 안전수칙 교육 실시.',
#  '작업 구역 분리 및 안전 경계선 설치, 콘판넬 안정적 고정 방법 교육 강화, 실시간 작업 감독 체계 도입.',
#  'BT비계 안전 교육 강화 및 작업 절차 표준화 실시. 정기적인 안전 점검과 개인 보호 장비(PPE) 착용 강제화.',
#  '제설작업 완료 전 운반작업 금지 및 실시간 제설 상태 모니터링 시스템 도입. 정기적인 안전 점검과 함께 작업자에게 안전한 작업 구역 확인 절차 교육 강화.',
#  '슬링바 체결 강도 강화 및 정기적인 점검 시스템 구축으로 재발 방지.',
#  '정기적 통로 점검 및 유지보수 강화, 작업자 안전 교육 프로그램 확대 실시, 장애물 관리 시스템 도입.',
#  '계단 안전등반 시스템 설치 및 미끄럼 방지재 적용, 정기적인 안전 교육 실시.',
#  '자재 배치 최적화 및 경고 표시 설치, 정기적인 안전 교육 실시.',
#  '안전대 필수 설치 규정 강화 및 풍속 등 환경 요인 사전 평가 시스템 도입',
#  '상하작업 안전 교육 강화 및 숙련공 우선 배치, 정기적인 역량 평가 실시.',
#  '하카 안전장치 강화 및 정기 점검 의무화, 반출작업 전 안전장비 착용 확인 강화',
#  '타설 주변 구조물(잭서포트 등)의 안정성 점검 강화 및 고정 상태 확인 절차 의무화. 정기적 안전 점검과 함께, 근로자 대상으로 타설 작업 시 주변 장애물 안전 관리 교육 실시.',
#  '압송관 고정 절차 표준화 및 작업 전 위험구역 격리 강화, 정기적 안전점검 실시, 인접 작업자 이동 관리 시스템 구축.',
#  '정기적인 공구 점검 및 유지보수 강화, 부주의 방지 위한 심화 교육 프로그램 도입, 개인 보호 장비(PPE) 착용 의무화 및 준수 감독 강화.',
#  '안전 발판 및 손잡이 설치 확대, 정기적인 안전 교육 강화, 하차 전 안전 점검 절차 도입 및 준수 확인 시스템 구축.',
#  '안전 교육 강화와 함께 작업 구역 분리 및 명확한 이동 경로 지정을 실시하고, 개인 보호 장비(PPE) 착용 의무화를 강화하며 정기적인 안전 점검을 실시한다.',
#  '정기적인 건강 검진 실시 및 지병 관리 교육 강화, 작업 적합성 평가 도입으로 위험 요소 최소화.',
#  '작업 전 안전 점검 강화와 개인 보호 장비(PPE) 착용 의무화를 통해 재발 방지 대책을 마련하고, 미끄러짐 방지 매트 설치 및 균형 유지 훈련을 추가 조치로 계획합니다.',
#  '토사 안정화 작업 강화와 함께 가시설 설치 시 지반 강화 조치를 취하고, 정기적인 안전 점검 및 작업자 교육을 실시하여 재발 방지.',
#  '작업 전 자재 점검 강화 및 전동공구 안전사용 교육 확대 실시.',
#  '미끄러운 표면 방지를 위한 작업 환경 개선과 개인 보호 장비(안전화, 미끄럼 방지 신발)착용 의무화를 통해 재발 방지 대책을 마련하고, 정기적인 작업 현장 안전 점검 및 미끄러짐 위험 교육을 실시하는 계획을 수립합니다.',
#  '근로자 대상의 정기적인 안전 교육 강화와 작업 절차 표준화를 통해 부주의로 인한 사고를 방지하며, 실시간 모니터링 시스템 도입으로 작업 중 위험 상황을 즉시 감지하고 대응하는 체계 구축.',
#  '노견 경사도 표시 강화 및 정기적인 안전 교육 실시로 부주의 감소 목표 설정.',
#  '거푸집 안정성 검사 강화 및 작업 전 구조적 안전성 확인 절차 도입, 작업자들에게 다중 구조 해체 시 안전 절차 교육 강화 실시.',
#  '수신호 시스템 표준화 및 정기 훈련 실시, 실시간 통신 장비 도입으로 의사소통 강화.',
#  '정기적인 안전 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 시행.',
#  '화자 안전 교육 강화 및 TBM 전 개인 보호 장비 점검 의무화 실시, 작업 공간 내 발 걸림 위험 요소 제거 및 명확한 통행로 지정.',
#  '굴착기 작업 영역 명확히 구분 표시, 유도자 안전 교육 강화, 실시간 위치 추적 시스템 도입 및 작업 허가 절차 강화.',
#  '미끄럼 방지 매트 설치 및 정기적인 바닥 청소 강화, 작업자에게 안전화 착용 의무화 및 미끄러운 환경에서의 작업 절차 교육 강화 실시.',
#  '작업자에게 안전한 도구 사용 교육 강화 및 쇠지렛대 안정성 점검 의무화 실시. 또한, 해체 작업 시 최소 2인 협업 구조를 도입하고 정기적인 안전 훈련을 실시한다.',
#  '정기적인 밧줄 및 안전장비 점검 시스템 구축과 함께, 작업자에게 안전장비 올바른 사용법 교육 강화 실시.',
#  '전방 주시 교육 강화 및 정기적인 안전 훈련 실시,  지능형 감시 시스템 도입으로 실시간 안전 모니터링 강화.',
#  '1. 유로품 운반 경로의 미끄럼 방지 처리 강화.\n2. 작업자에게 안전 운반 교육 재실시 및 개인 보호 장비 착용 의무화.',
#  '작업 동시 진행 최소화 및 안전 통로 확보, 정기적인 작업 영역 안전 점검 실시.',
#  '작업 전 드릴 작동 원리 및 위험 인지 교육 강화, 안전장비(방호장갑, 드릴 고정장치) 의무 착용, 실시간 모니터링 시스템 도입 및 정기적 안전 점검 실시.',
#  '안전장비 표준화 정책 강화 및 정기적인 안전장비 착용 확인 실시.',
#  '정기적인 숙련도 평가와 자세 교정 훈련 강화, 안전 장비 사용 의무화 및 지속적인 모니터링 실시.',
#  '안전대 착용 의무화 강화 및 정기적인 안전장비 점검 실시, 조립작업 시 안전 교육 프로그램 재실시.',
#  '작업 전 명확한 통신 프로토콜 확립 및 실시간 위치 추적 시스템 도입으로 작업자 안전 강화. 정기적인 안전 훈련 강화 및 고속작업차 이동 전 확인 절차 의무화.',
#  '철근 주변 안전 경계 설정, 미끄럼 방지 매트 설치, 정기적 안전 교육 강화',
#  '갱폼 유닛 고정 절차 엄격히 준수하도록 교육 강화 및 실시간 모니터링 시스템 도입. 정기적 안전 점검과 유닛 이탈 방지 장치 설치를 병행한다.',
#  '안전망 설치 유지 의무화 및 관리자 출근 전 작업 금지. 정기적인 안전점검과 비상시 대응 훈련 강화 실시.',
#  '작업 공간 안전 경계 설정 강화와 개인 보호 장비(PPE) 점검 의무화 실시, 정기적인 작업 환경 위험성 평가 실시.',
#  '작업 전 각재 품질 검사 강화 및 안전장비 착용 의무화 실시. 앙카드릴 사용 시 안정적인 고정 방법 교육 확대 실시. 정기적인 작업 환경 안전 점검 및 개선 실시.',
#  '자재인양함 이동 시 안전한 가설계단 설치 의무화 및 정기적인 안전 교육 실시로 안전 이동 방법 강화.',
#  '거푸집 해체 전 철저한 안정성 확인 및 충격 흡수재 설치, 정기적 안전 교육 강화 실시.',
#  '하부 작업자 안전 확보를 위한 명확한 작업 구역 분리 및 신호수 배치 강화, 정기적인 안전 교육 강화 및 실시간 작업 감독 시스템 도입.',
#  '동바리 설치 시 안전 지지대 강화 및 작업자 교육 강화를 통해 안정성 확보하고, 작업 전 철저한 안전 점검 실시 및 개인 보호 장비 착용 의무화를 시행한다.',
#  '시야 확보 위한 직선 이동 강조 교육 실시 및 작업 공간 정기적인 점검과 정리로 장애물 제거 강화.',
#  '안전장갑 착용 의무화, 커터칼 사용 시 안정적인 작업대 및 클램프 사용 권장, 정기적인 안전 교육 실시 및 작업 전 안전 점검 강화.',
#  '안전통로 지정 및 표시 강화, 정기적인 안전 교육 프로그램 도입, 개인 보호 장비 착용 의무화 실시.',
#  '1. **안전망 설치**: 외부 비계에 안전망을 설치하여 낙하물로부터 작업자 보호.\n2. **작업 구역 분리**: 위에서 작업하는 구역과 아래에서 작업하는 구역을 명확히 구분하고 접근 제한.\n3. **정기적 안전 점검**: 비계 및 작업 환경 정기적으로 점검하여 위험 요소 사전 제거.\n4. **강화된 안전 교육**: 낙하물 위험성 및 개인 보호 장비 착용의 중요성 강조 교육 실시.',
#  '안전교육 강화 및 시간 압박에 따른 안전위협 인식 제고, 가설재 계단 사용 의무화 및 비정상적 접근 경로 차단, 정기적인 안전 점검 및 위반 시 즉각적인 제재 실시.',
#  '1. **강화된 안전 교육 프로그램**: 정기적인 안전 교육과 실습을 통해 근로자의 작업 기술 향상 및 안전 수칙 준수 강화.\n2. **작업 지침서 개선**: 명확하고 구체적인 작업 지침서 작성 및 배포, 모든 작업자에게 준수 의무 강조.\n3. **감독 및 모니터링 강화**: 현장 감독 강화와 실시간 모니터링 시스템 도입으로 안전 위반 즉시 시정.\n4. **피드백 및 인센티브 시스템**: 안전 준수 우수 사례에 대한 피드백 제공과 인센티브 제도 도입으로 안전 문화 확산.',
#  '정기적인 안전 교육 프로그램 강화와 함께, 핸드그라인더 사용 절차에 대한 표준 작업 지침서(SOP) 마련 및 준수 점검을 실시한다. 또한, 개인 보호 장비(PPE) 착용 강제화 및 주기적인 공구 점검 시스템 구축을 통해 재발 방지한다.',
#  '정기적인 발판 청소 및 방빙 시스템 도입, 작업자에게 미끄럼 방지 장비 착용 의무화 실시.',
#  '안전장비 착용 강제화 및 정기적인 점검 실시, 미끄럼 방지용 안전화 제공 및 작업 현장의 실트질점토 제거 프로토콜 강화.',
#  '작업 전 복개배수로 주변 안전 경계 설정 및 개인 보호 장비 착용 의무화 실시. 정기적 위험 평가와 함께 작업 중 지속적인 감독 강화 및 끼임 방지 교육 강화.',
#  '가설 사무실 입구에 안전 경사로 설치 및 정기적인 점검 실시, 바닥 미끄럼 방지 처리 강화, 작업자들에게 경사로 주의 교육 실시.',
#  '시스템 비계의 안정성 확보 및 작업자 보호장비 착용 의무화를 통해 재발 방지. 정기적인 비계 점검과 함께, 목재 취급 및 해체 절차를 표준화하여 안전성을 높이고, 사고 발생 시 즉각적인 대응 훈련을 실시한다.',
#  '작업자에게 회전체 접근 금지 교육 강화 및 이물질 제거 시 전용 도구 사용 의무화를 통한 재발 방지 대책 수립. 정기적 안전 점검과 드릴 작업 절차 표준화를 포함한 향후 조치 계획 실행.',
#  '안전교육 강화 및 작업 전 안전점검 의무화, 작업자 개인 보호장비 착용 확인 강화 실시.',
#  '작업자 간 원활한 소통 강화 및 안전 거리 확보 지침 마련, 정기적인 안전 교육 실시와 함께 작업 절차 표준화를 통해 무리한 행동 방지.',
#  '정기적인 작업공간 점검과 타설배관 관리 강화, 작업자 대상 안전 교육 및 개인 보호 장비 착용 의무화 실시.',
#  '안전교육 강화와 정기적인 안전장비 착용 확인 실시, 작업 전 안전점검 리스트 의무화 및 준수 강화.',
#  '안전 신호 체계 강화 및 정기적인 장비 운용 교육 실시, 작업 전 철저한 안전 점검 프로토콜 도입.',
#  '정기적인 위험 평가 실시 및 작업자에게 안전 인식 교육 강화. 또한, 설치작업 전 상세한 안전 점검 리스트 준수 의무화와 실시간 모니터링 시스템 도입을 통해 사고 예방.',
#  '정기적인 휴식 시간 확보와 주관절 보호 장비 사용 의무화, 그리고 30분마다 스트레칭을 포함한 신체 활동 권장.',
#  '안전교육 강화와 함께 손낌 방지 장치의 의무 설치 및 정기 점검 실시. 작업자들에게 개인 보호 장비 착용 의무화 및 실시간 모니터링 시스템 도입.',
#  '바닥 안정화 작업 실시 및 정기적인 안전 점검 강화, 작업자에게 미끄럼 방지 장비 착용 의무화.',
#  '이동식 사다리 사용 시 안정성 확보 절차 준수 강화 및 정기적인 안전 점검 실시. 작업자에게 고급 안전 교육 제공하여 안전한 작업 방법 교육.',
#  '작업 전 안전 교육 강화 및 실시간 모니터링 시스템 도입으로 작업자의 주변 인지 의무 강화. 후진 작업 금지 및 대체 안전한 작업 절차 표준화 실시. 정기적 안전 점검과 피드백 시스템 구축으로 지속적인 개선.',
#  '안전 발판 및 미끄럼 방지 매트 설치 확대, 정기적인 말비계 점검 및 유지보수 강화, 미끄럼 방지 교육 프로그램 도입 및 실시.',
#  '작업자에게 안전한 물체 취급 및 이동 방법 교육을 강화하고, 수직 승강로 내에서의 전용 도구 사용을 의무화한다. 정기적인 안전 점검과 시뮬레이션 훈련을 실시하여 위험 상황 인지와 대응 능력을 향상시킨다.',
#  '자재 운반 경로 명확히 표시하고 정기적인 현장 청소 실시, 작업자에게 시야 확보 및 안전 주의사항 교육 강화 실시.',
#  '중량물 운반 시 반드시 2인1조 작업 준수, 조적운반장비 사용 교육 강화, 정기적인 안전 점검 및 감독 강화 실시.',
#  '장기간 노출 최소화를 위한 정기적 건강 검진 강화, 개인 보호 장비(PPE) 의무 사용 확대, 작업 환경 내 먼지 및 화학물질 저감 시스템 도입, 그리고 형틀공 대상 정기적 안전 교육 프로그램 확대 실시.',
#  '정기적인 안전 교육 강화와 함께 미끄럼 방지 장비 의무 착용, 작업 전 안전 점검 리스트 준수 확인 시스템 도입.',
#  '해치발판 안전시설 의무 설치 및 정기 점검 실시, 작업 전 안전 점검 리스트 강화, 관련 작업자 대상 안전 교육 재실시 및 인증 제도 도입.',
#  '비계 및 작업 공간의 안전 경계 강화와 정기적인 안전 점검 실시, 작업자들에게 높은 고도 작업 시 안전 장비 사용 강제화 및 재교육 실시.',
#  '안전 교육 강화 및 사다리 사용 규정 준수 강조, 임시 가설 구조물 설치 의무화, 작업 전 안전 점검 리스트 도입 및 정기적 안전 훈련 실시.',
#  '정기적인 스트레칭 프로그램 도입 및 충분한 휴식시간 보장, 작업자 건강 모니터링 강화, 안전 교육 프로그램에 피로 관리 포함.',
#  '자재 배치 개선 및 작업 경로 명확히 표시, 정기적인 안전 교육 실시, 개인 보호 장비(안전모, 안전화) 착용 강제화, 작업 중 임시 보호 장벽 설치.',
#  '정기적인 안전 교육 강화 및 부주의 예방 프로그램 도입, 실시간 모니터링 시스템 구축으로 작업자 행동 감독 및 즉시 피드백 제공.',
#  '정기적인 건강 검진 실시와 작업 환경의 안정성 확보를 위한 바닥 미끄럼 방지 조치 강화.',
#  '1. **안전 교육 강화**: 모든 작업자에게 로라 작동 절차와 안전 거리 유지에 대한 교육을 정기적으로 실시.\n2. **작업 절차 표준화**: 로라 시동 및 해체 과정에 대한 명확한 표준 작업 절차를 마련하고 준수 강제화.\n3. **감시 시스템 도입**: 작업 현장에 CCTV 설치를 통해 실시간 모니터링 및 위험 상황 즉시 대응 체계 구축.',
#  '지정된 안전 이동 경로 명확히 표시하고 정기적인 안전 교육 실시하여 준수 강화.',
#  '작업 중 양손 사용 제한, 보조자 배치 의무화, 정기적인 안전 교육 강화 및 작업 절차 표준화 실시.',
#  '가시설 대좌 용접 품질 강화 및 정기적인 검사 실시, 인장 작업 전 구간의 안전 재평가 의무화, 작업자 대상 안전 인식 교육 강화 실시.',
#  '실시간 통신 시스템 도입 및 정기적인 팀 커뮤니케이션 훈련 강화',
#  '비개착통로암거 내부 그라우팅 완전 제거 절차 표준화 및 정기적 안전 점검 실시, 작업자 교육 강화를 통해 안전 의식 향상 도모.',
#  '장기간 노출 방지를 위한 정기적인 소음 수준 모니터링 및 개인 보호 장비(PPE) 강화. 정기적인 청력 검사 실시 및 직원 교육 강화.',
#  '바닥 단차 표시 강화 및 정기적인 안전 점검 실시, 작업자 대상 단차 인지 및 안전 이동 교육 강화 실시.',
#  '작업 구역 분리 및 고도별 작업 관리 강화, 실시간 통신 시스템 도입으로 작업자 간 충돌 위험 감소, 정기적인 안전 점검 및 위반 시 즉각적인 제재 조치 시행.',
#  '1. 정기적인 안전 교육 강화 및 미끄러짐 예방 교육 실시.\n2. 작업 현장 바닥의 마찰력 향상을 위한 정기적인 청소와 미끄럼 방지재 설치.\n3. 개인 보호 장비(안전화 등) 착용 의무화 및 준수 여부 점검 강화.\n4. 작업 전 안전 점검 리스트 도입으로 부주의 요인 사전 제거.\n5. 부주의 관련 사고 사례 공유 및 인식 제고 프로그램 운영.',
#  '1. **작업 경로 안전 표시 강화**: 운반 경로에 명확한 안전 표시 설치 및 정기적 점검 실시.\n2. **개인 보호 장비(PPE) 의무화**: 안전화 및 보호대 착용 강제화, 정기적 점검 실시.\n3. **정기적 안전 교육**: 운반작업 관련 안전 교육 주기적으로 실시, 넘어짐 예방 및 응급 처치 교육 포함.\n4. **작업 환경 개선**: 바닥 미끄러움 방지 처리, 불필요한 장애물 제거로 작업 공간 최적화.\n5. **사고 발생 시 신속 보고 시스템 구축**: 즉시 사고 보고 및 초기 대응 훈련 실시,',
#  '작업발판 안전사용 교육 강화 및 개인 보호장비(안전모, 발목 보호대) 착용 의무화 실시. 정기적인 안전 점검과 함께 부주의로 인한 사고 예방 프로그램 도입.',
#  '작업 공간 확보를 위한 장비 재배치 및 작업 공간 확장, 불안정한 자세 방지 위한 안전장비(지지대, 안전봉) 제공, 정기적인 안전 교육 강화 및 좁은 공간 작업 특화 훈련 실시, 실시간 모니터링 시스템 도입으로 작업자 안전 감독 강화.',
#  '바닥 정리정돈 강화, 정기적인 안전 점검 실시, 작업자에게 안전 교육 재실시 및 개인 보호 장비 착용 의무화.',
#  '인상작업 중단 절차 명확히 정립 및 준수 강화, 실시간 위치 추적 시스템 도입으로 장비 및 로프 위치 모니터링, 정기적인 안전 교육 실시 및 작업 전 안전 점검 의무화',
#  '자재 운반 경로 명확히 표시하고 안전 통로 확보, 정기적인 안전 교육 실시 및 개인 보호 장비 착용 강제화.',
#  '천막 고정 강화 및 풍압 모니터링 시스템 도입, 정기적인 점검과 근로자 안전 교육 실시.',
#  '작업공간 확장 및 정기적인 정리정돈 실시, 안전 교육 강화와 지속적인 재평가 실시.',
#  '안전 통로 확보 및 표시 강화, 신호수 이동 경로 정기 점검, 개인 보호 장비 착용 의무화 및 재교육 실시.',
#  '동절기 안전 교육 강화 및 미끄럼 방지 장비 제공, 작업 전 체온 유지 활동 실시.',
#  '철근 식별표시 강화 및 명확한 위험 정보 표시, 인근 공정 작업자 대상 안전 교육 실시, 작업 구역 분리 및 상호 작업 일정 조정, 실시간 작업 상황 공유 시스템 도입.',
#  '작업 및 휴식 공간의 안전성 확보와 함께, 미끄러짐 위험 요소 제거를 위한 정기적인 점검 실시. 또한, 근로자에게 안전한 휴식 및 이동 지침을 명확히 교육하고, 관리자의 현장 감독을 강화하여 부적절한 휴식 위치 사용을 방지.',
#  '자재 보관 구역을 명확히 구분하고 정기적인 정리정돈 점검 실시, 작업자 대상 정리정돈 교육 강화 및 안전 인식 향상 프로그램 도입, 위험 지역에 경고 표시 설치 및 안전 통로 확보.',
#  '단차부 안전 표시 설치 및 작업 전 경로 점검 강화, 작업자에게 단차부 주의 교육 실시.',
#  '고령 근로자 대상 맞춤형 안전 교육 실시 및 말비계 사용 전 상태 점검 의무화, 모든 작업자에게 개인별 안전 장비 할당 및 사용 지침 강화.',
#  '지면 안정화 및 정기적인 점검 실시, 신호수와 운전자 간의 명확한 소통 프로토콜 강화, 적재작업 관련 안전 교육 재실시 및 평가 도입.',
#  '1. **강화된 안전 교육 프로그램**: 레미콘 스토퍼 사용 및 취급에 대한 정기적인 교육 강화.\n2. **안전 장비 의무화**: 보호구 착용을 엄격히 규정하고 준수 여부를 점검.\n3. **작업 절차 표준화**: 방심을 방지하기 위한 세부 작업 지침 마련 및 준수 강조.\n4. **감독 및 모니터링**: 운반작업 중 지속적인 현장 감독과 실시간 안전 모니터링 시스템 도입.\n5. **인센티브 및 제재 시스템**: 안전 수칙 준수자에게 인센티브 제공, 위반자에게는 적절한 제재 적용.',
#  '1. **온도 관리 시스템 도입**: 작업 환경의 온도를 안정적으로 유지하기 위한 시스템 설치.\n2. **정기적인 점검 및 유지보수**: 타설 장비와 열풍기의 상태를 정기적으로 점검하여 이상 징후 조기 발견.\n3. **안전 경계 설정**: 얼음 낙하 위험 지역에 안전 경계 설치 및 경고 표지판 설치.\n4. **작업자 교육 강화**: 온도 변화와 관련된 안전 위험 인식 및 대응 방법에 대한 교육 실시.',
#  '정기적 위험성 평가 실시 및 위험 정보 공유 시스템 구축, 작업 전 위험요소 브리핑 의무화',
#  '작업장 내 임시 작업 구조물 안전 점검 강화 및 작업자에게 응급 상황 시 안전 대응 교육 실시.',
#  '안전통로 사용 의무화 교육 강화 및 정기적인 자재 정리 점검 실시, 미끄럼 방지 표면 처리 확대 적용.',
#  '작업 경로 명확히 표시하고 장애물 제거, 정기적인 작업 공간 점검 및 안전 교육 강화 실시.',
#  '작업장 내 조명 개선 및 계단 안전 표시 강화, 정기적인 계단 안전 점검 실시, 근로자들에게 개인 이동 시 안전 주의사항 교육 강화 및 비상구 및 안전한 이동 경로 안내 제공.',
#  "1. 말비계 사용 시 안전 벨트 및 안전 그물 설치 의무화.\n2. 정기적인 안전 장비 점검 및 유지보수 실시.\n3. '마감작업' 관련 떨어짐 위험 교육 강화 및 재교육 주기 단축.\n4. 작업 전 안전 점검 리스트 준수 강화 및 감독 체계 구축.",
#  '안전장비 착용 강제화 및 그라인더 사용 교육 강화 실시. 정기적인 안전 점검과 작업 전 위험 평가 실시.',
#  '보안경의 적절한 착용 교육 강화 및 정기적인 착용 상태 점검 실시.',
#  '마감작업 전 건식PD 내 위험 요소 정밀 점검 실시 및 작업자 대상 위험 인지 교육 강화. 정기적 안전 점검과 PPE 사용 의무화를 통해 안전성 향상.',
#  '외부 비계 설치 및 해체 시 전문 인력 배치 의무화, 크레인 작업 시 안전 감독 강화, 정기적인 안전 교육 실시 및 작업 전 안전 점검 리스트 준수 의무화.',
#  '통로용 발판에 대한 정기적인 점검 및 유지보수 강화, 모든 발판에 안전난간대 설치 의무화, 작업자들에게 안전 통로 이용 교육 실시 및 안전 규정 준수 강화.',
#  '지정된 안전 이동통로 사용 의무화 및 주기적인 통로 점검 강화 실시.',
#  '정해진 이동통로 준수 강화 교육 실시 및 통로 표시 개선.',
#  '정기적인 현장 점검과 불안전 요소 제거 시스템 구축, 작업 전 주변 환경 철저히 확인 및 기록 의무화.',
#  '정기적인 안전 교육 프로그램 강화와 실시간 작업 모니터링 시스템 도입으로 부주의 사고 감소 목표. 또한, 개인별 안전 성과 평가를 통한 인센티브 제공으로 안전 의식 향상 도모.',
#  '전방 주시 교육 강화 및 작업 공간 내 장애물 제거, 명확한 이동 경로 표시 설치.',
#  '작업 공간 확보 및 안전 통로 확보, 지게차 운행 경로와 자재 정리 구역 명확히 구분, 작업자에게 긴급 상황 시 안전한 대피 경로 교육 강화, 정기적인 안전 점검 및 위험 요소 식별 시스템 구축, 지게차 운전자와 정리 작업자 간의 실시간 통신 체계 도입.',
#  '낙하물 방지망 강화 설치 및 작업자에게 개인 보호 장비 필수 착용 규정 강화. 정기적 안전 교육 실시와 작업 전 안전 점검 절차 표준화.',
#  '잉여자재 정기적 정리 실시 및 운반자재 적재량 관리 강화, 작업구간 안전성 확보를 위한 정기 점검 실시.',
#  '합벽지지대 해체 시 안전 경계 설정 강화 및 작업자에게 개인 보호 장비 착용 의무화. 또한, 해체 전 구조물 안정성 검토 절차 도입 및 정기적 안전 교육 실시.',
#  '안전고리 해체 절차 준수 강화 교육 실시, 해체작업 전 안전점검 리스트 의무화 및 이행 확인, 굴착기 운용자와 작업자 간 실시간 통신 시스템 도입, 위반 시 작업 중지 및 재교육 실시.',
#  '작업구간 정기적인 안전점검 및 결빙 제거 시스템 구축, 이동식 틀비계 사용 시 안전절차 표준화 및 교육 강화, 작업 전 안전환경 확인 절차 도입, 조급한 작업 피하기 위한 작업시간 관리 및 휴식시간 확보.',
#  '지반 안정성 평가를 정기적으로 실시하고, 필요시 지반 강화 작업 수행. 사다리 설치 전 안정성 검사 의무화 및 적합한 고정 장치 사용 강제. 작업자 교육 강화로 지반 상태 확인 및 안전한 작업 환경 인식 제고.',
#  '정기적인 안전 교육 강화와 명확한 경로 표시 설치, 실시간 모니터링 시스템 도입을 통한 재발 방지 대책. 또한, 부주의 사고 감소를 위해 개인별 안전 책임 제도를 시행하고, 사고 발생 후 즉시 피드백 및 개선 조치를 취하는 사이클을 구축합니다.',
#  '안전 발판 및 미끄럼 방지 매트 설치 확대와 함께 측량 작업 시 안전 장비 착용 의무화를 통해 재발 방지하며, 정기적인 안전 교육 및 미끄러짐 사고 예방 훈련 실시 계획.',
#  '근로자 건강상태 사전 확인 시스템 구축 및 정기적 건강 검진 의무화, 관리자 대상 건강상태 모니터링 교육 강화, 이상 발견 시 즉시 작업 배제 및 의료 지원 연계 시스템 도입.',
#  '안전구역 경계 강화 및 명확한 표시 설치, 정기적인 안전 교육 강화, 부주의 방지를 위한 작업 절차 재검토 및 개선',
#  '1. 핀 체결 절차 표준화 및 교육 강화 실시.\n2. 작업 전 안전 점검 리스트 도입 및 준수 의무화.\n3. 무리한 동작 방지 위한 작업 자세 및 도구 사용 지침 마련 및 훈련 실시.',
#  '정기적인 안전 교육 강화와 행동 기반 안전 프로그램 도입, 실시간 모니터링 시스템 구축을 통한 즉각적인 위험 감지 및 개입 강화.',
#  '후크 해지 상태의 엄격한 확인 절차 도입 및 정기적인 안전 점검 실시로 재발 방지. 작업자 대상 후크 안전 절차 교육 강화 및 준수 감독 체계 구축.',
#  '1. **안전교육 강화**: 설치작업 전 철근 및 구조물 주변 작업 시 안전 수칙 교육을 강화합니다.\n2. **작업 보조 도구 사용**: 손가락 보호 장비 및 작업 보조 도구(예: 긴 막대로 철근 조작)를 제공합니다.\n3. **작업 인원 확보**: 복잡하거나 위험한 작업 시 최소 2인 이상의 작업 인원을 확보합니다.\n4. **안전 점검 리스트 도입**: 통로암거 및 동바리 설치 전 안전 점검 리스트를 통해 위험 요소를 사전에 확인합니다.',
#  '정기적인 안전 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 시행. 또한, 작업 전 안전 점검 리스트 도입으로 사전 위험 요소 제거 및 실시간 모니터링 시스템 구축을 통해 지속적인 안전 관리 강화.',
#  '안전장비 착용 의무화 및 정기적인 작업 기술 재교육 실시.',
#  '작업발판 간격 정기 점검 및 안전시설물 설치 기준 강화, 작업자 교육 강화 실시.',
#  '작업자 간 명확한 역할 분담 및 신호 체계 구축, 모든 작업자 대상 의사소통 및 협업 훈련 강화, 양중작업 전 철저한 안전 점검 및 준비 상태 확인 절차 도입, 최소 2인 이상의 감독 참여 의무화.',
#  '안전화 선택 기준 강화 및 우천 시 작업 중단 정책 도입',
#  '안전장갑 개선 및 착용 강제화, 작업 절차 표준화 교육 강화, 개인 보호 장비(PPE) 점검 시스템 도입.',
#  '정기적인 안전 점검 및 유지보수 강화, 작업자에게 균형 유지 및 안전 하강 절차 교육 실시.',
#  '정기적인 안전 교육 강화와 작업 절차 준수 감시 시스템 도입, 그리고 부주의로 인한 사고 예방을 위한 행동 기반 안전 프로그램 실행.',
#  '보행로 명확히 표시 및 확보, 토공 흙쌓기 법면부 안전 경계 설치, 정기적 안전 교육 실시, 비상시 안전한 이동 경로 안내 강화',
#  '작업 중 시야 확보를 위한 안전 장비 설치 및 펌프카 운전원 대상의 정밀한 조작 훈련 실시. 정기적인 작업 영역 안전 점검과 붐대 움직임 모니터링 시스템 도입.',
#  '작업자에게 적절한 힘 사용 및 안전한 작업 자세 교육 강화, 정기적인 안전 훈련 실시 및 작업 환경의 마찰력 향상 조치를 취합니다.',
#  '자재 이동 시 안전장비 착용 의무화 및 실시간 위치 추적 시스템 도입으로 작업자 안전 확보 강화. 정기적인 안전 점검과 함께 자재 관리 및 이동 절차 표준화 실시.',
#  '실시간 통신장비 도입 및 명확한 수신호 프로토콜 정립, 정기적인 안전 훈련 강화, 접속구간 작업 시 대체 안전장비 사용 의무화.',
#  '안전 교육 강화 및 실시간 통신 시스템 도입으로 작업자 간 소통 개선, 정기적인 장비 점검과 운전자 훈련 프로그램 확대 실시.',
#  '1. **작업 표면 안전 확보**: 모든 작업 플랫폼에 미끄럼 방지 매트 설치 및 정기적인 점검 실시.\n2. **안전 교육 강화**: 미끄러짐 위험 인식과 안전한 작업 방법에 대한 정기 교육 실시.\n3. **개인 보호 장비 의무화**: 안전화 및 안전벨트 착용을 강제화하며, 특히 미끄러운 환경에서는 추가적인 미끄럼 방지 기능이 있는 장비 사용 권장.\n4. **작업 절차 표준화**: 자재 이동 및 해체 작업 시 안전한 절차를 명확히 정의하고 준수를 감독.\n5. **정기적 안전 점검**: 해체 작업',
#  '정기적인 건강 검진 실시 및 개인 건강 상태 문서화 강화. 의사 소견 불일치 시 외부 전문가 자문을 통한 정확한 건강 평가 도입.',
#  '석재 운반 시 기계 지원 장비 사용 의무화 및 작업자에게 안전 운반 교육 강화 실시. 정기적인 안전 점검과 함께 작업 현장의 안전 통로 확보 및 경계석 위험 구역 표시 강화.',
#  '유리자재 취급 시 보호장비 의무 착용 및 작업환경 안전성 강화. 정기적인 자재 품질 점검 실시.',
#  '위험 요인 체계적 식별 및 평가 시스템 구축, 정기적 안전 점검 강화, 작업자에게 위험 인식 및 대응 교육 제공',
#  '정기적인 휴식 시간 확보와 주관절 보호 장비 사용 의무화, 그리고 30분마다 스트레칭을 포함한 신체 활동 권장.',
#  '자재 및 구조물 정리 강화, 작업 전 안전 점검 의무화, 동바리 해체 시 안전 지지대 사용 의무화 및 정기적 안전 교육 실시.',
#  '작업 전 안전장비 착용 확인 강화, 원형톱 사용 교육 재실시 및 안전절차 준수 강조, 작업 영역 내 위험구역 설정 및 비작업자 접근 제한, 정기적인 안전점검 및 피드백 시스템 구축.',
#  '관 자재의 안정적인 적재 및 인양 절차 표준화, 굴착기 버켓 사용 시 추가 지지 구조물 설치, 슬링벨트 체결 전 안전 확인 절차 강화 및 정기적인 안전 교육 실시.',
#  '정기적인 숙련도 평가 및 재교육 프로그램 도입, 작업 전 숙련 수준 확인 절차 강화.',
#  '정기적인 작업장 점검 및 장애물 제거 시스템 구축, 안전 교육 강화를 통한 작업자 주의력 향상.',
#  '신호체계 표준화 및 정기적인 훈련 강화 실시.',
#  '작업 전 상세한 안전 계획 수립 및 모든 작업자 대상의 철저한 교육 실시. 정기적 안전 점검 강화와 임의 행동에 대한 엄격한 관리 시스템 구축.',
#  '정기적인 비계 고정장치 점검 및 인증 시스템 도입, 작업자 대상 고정장치 확인 교육 강화 실시.',
#  '작업 전 철저한 건강상태 점검 도입, 정기적인 건강 모니터링 시스템 구축, 안전조회 시 건강상태 확인 절차 강화 및 관리감독자 교육 강화 실시.',
#  '사다리 안전사용 교육 강화 및 개인 보호 장비(헬멧) 필수 착용 규정 도입. 정기적인 안전 점검 및 작업 전 안전 확인 절차 확립.',
#  '1. **명확한 신호 체계 구축** 및 모든 작업자 대상 교육 강화.\n2. **인양 장비 작업 시 안전 감시자 배치**를 의무화.\n3. 정기적인 안전 점검 및 시뮬레이션 훈련 실시.',
#  '1. **안전 교육 강화**: 타설작업 후 배관 처리 절차에 대한 안전 교육을 강화하고, 동료 간의 안전 거리 유지 및 신호 체계 도입.\n2. **작업 지침 명확화**: 배관 잔여물 제거 시 안전한 방법과 절차를 명확히 정의한 작업 지침서 배포 및 준수 확인.\n3. **개인 보호 장비 사용 강제**: 안전 모자 및 보호 부츠 착용을 의무화하여 추가적인 부상 예방.',
#  '사각블럭 적재 표준화 절차 도입 및 정기적 점검 실시, 작업자 대상 적재물 안전 취급 교육 강화 실시.',
#  '작업자에게 안전 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 시행. 정기적인 안전 점검과 함께 작업 전 안전 절차 준수 확인 절차 도입.',
#  '정기적인 안전 교육 강화와 작업 전 미끄럼 방지 조치 확인 절차 도입.',
#  '안전 발판 설치 및 개인 보호 장비 강화, 정기적 안전 교육 실시, 대체 작업 플랫폼 도입 검토.',
#  '타업체와의 협업 프로세스 강화 및 현장 출입 관리 체계 구축. 정기적인 안전 점검과 미완료 작업 구역의 출입 통제 강화, 작업자 대상 안전 교육 강화 실시.',
#  '방호장치 유지보수 강화와 함께 합판 반발 방지를 위한 작업대 개선 및 안전 교육 강화 실시.',
#  '안전 가드 설치 강화 및 둥근톱 사용 교육 의무화로 재발 방지. 정기적인 안전 점검과 직원 대상의 절단 작업 안전 교육 프로그램 확대 실시.',
#  '동바리 설치 시 주변 구조물 간섭 최소화를 위한 공간 확보 강화, 개인 보호 장비(PPE) 착용 의무화 및 정기 점검 실시, 협착 위험 교육 프로그램 확대 및 시뮬레이션 훈련 도입.',
#  '정기적인 안전 교육 강화와 실시간 위치 추적 시스템 도입을 통해 작업자의 주변 환경 인식을 향상시키고, 작업 전 주변 확인 절차를 의무화합니다.',
#  '작업자 대상 안전 동작 훈련 강화 및 실시간 모니터링 시스템 도입으로 안전 의식 향상 및 즉시적 위험 감지 시스템 구축. 정기적인 안전 평가와 피드백 세션을 통해 지속적인 개선 실시.',
#  '기상 모니터링 강화와 작업 중단 기준 명확히 설정, 타워크레인 안정성 강화 조치 실시.',
#  '유압기계 운반 경로 철저한 안전점검 및 틈새 차단 설치, 작업자에게 긴급상황시 안전거리 유지 및 개인보호장비 착용 강화 교육 실시.',
#  '바닥 정기적인 제설 및 습기 제거 시스템 구축, 미끄럼 방지 매트 설치 확대, 근로자에게 결빙 조건 하의 안전운반 지침 교육 강화 실시.',
#  '안전 경계 설치 확대 및 작업 공간 위험 구역 표시 강화, 브레싱 작업 시 임시 보호 구조물 설치 의무화, 작업자 대상 개구부 및 높은 곳 작업 안전 교육 재실시.',
#  '안전 발판 및 보호장치의 정기 점검 강화와 함께, 말비계 사용 시 안전 절차 교육을 의무화하고, 정기적인 재교육 실시. 또한, 작업 전 안전 점검 리스트 준수를 강제화하여 사전 위험 요소 제거.',
#  '작업 공간 분리 및 안전 구역 설정, 동료 작업 간 상호 안전 확인 절차 도입, 고소작업 중 자재 취급 시 안전 지침 강화 교육, 정기적인 안전 시뮬레이션 훈련 실시.',
#  '1. **안전 교육 및 훈련 강화**: 근로자들에게 지지부재의 하중 한계와 안전한 적치 방법에 대한 교육을 정기적으로 실시합니다.\n2. **작업 절차 표준화**: 지지부재 사용 및 부재 적치에 대한 구체적인 안전 절차를 정립하고 모든 작업자에게 준수하도록 합니다.\n3. **장비 및 시설물 점검**: 지지부재와 관련 시설물의 정기적인 안전성 점검을 실시하고, 필요시 교체 또는 보강합니다.\n4. **위험 평가 및 관리**: 작업 전 위험성 평가를 의무화하여 잠재적 위험 요소를',
#  '1. **안전장비 점검 강화**: 정기적인 안전장비(추락방지대 포함) 점검 및 유지보수 실시, 불량 장비 즉시 교체.\n2. **온열질환 예방 프로그램**: 작업 중 수분 보충 및 휴식 시간 강제화, 체온 조절을 위한 냉각 시스템 도입.\n3. **안전교육 강화**: 도장작업 관련 추락 위험 및 온열질환 예방 교육을 정기적으로 실시, 실제 사례 공유를 통한 인식 제고.\n4. **작업 환경 개선**: 작업대 안정성 향상 및 안전 거리 확보, 필요시 작업 높이를 낮추거나 안전그물 설치.',
#  '정기적인 안전 교육 강화와 작업 전 바닥 상태 점검 의무화를 통해 재발 방지. 또한, 미끄러짐 방지 매트 설치 확대 및 실시간 안전 모니터링 시스템 도입 계획 수립.',
#  '굴착기 작업 시 안전거리 확보 강화 및 실시간 모니터링 시스템 도입. 정기적인 장비 점검과 작업자 대상 안전 교육 프로그램 확대 실시.',
#  '정기적인 안전 교육 강화와 작업 현장 미끄럼 방지 시설 개선을 통해 재발 방지. 또한, 부주의 행동에 대한 모니터링 시스템 도입 및 피드백 루프 구축 계획.',
#  '지하계단 내 조명 개선 및 작업 전 시야 확보 확인 절차 도입. 정기적인 안전 교육 강화로 시야 확보와 무게중심 관리 교육 실시.',
#  '자재 고정 강화 및 무게 중심 안정화 절차 도입, 정기적인 점검과 작업자 교육 실시.',
#  '작업장 내 기상 조건 모니터링 강화와 함께 임시 구조물 안정성 검토 및 고정 강화, 정기적 안전 교육 실시 및 위험 상황 대응 훈련 강화.',
#  '작업장 바닥 정리 강화 및 실시간 감시 시스템 도입, 정기적인 안전 교육 실시.',
#  '정기적인 작업 현장 점검 실시와 함께 핵석 주변 미끄럼 방지 매트 설치, 그리고 작업 전 안전 교육 의무화를 통해 재발 방지.',
#  '작업 동작 표준화 교육 실시, 정기적인 작업 현장 정리정돈 점검 강화, 개인 안전 의식 향상 프로그램 도입.',
#  '원형스리브 폐합 점검 강화 및 자동 경보 시스템 도입, 정기적인 안전 교육 실시, 작업 전 장비 상태 확인 절차 표준화',
#  '정기적인 안전 교육 강화 및 작업 경로 미끄럼 방지 시설 개선 실시.',
#  '리프트 사용 시 안전 벨트 착용 의무화 및 정기적인 안전 교육 실시. 작업 전 리프트 안정성 점검 강화, 발판 안전 표시 강화 및 작업자의 동선 제한 구역 설정.',
#  '안전시설 완비 전 공사 중지 준수 강화 및 원도급사와 하도급사 간의 안전지침 공유 및 감독 체계 구축. 정기적 안전점검 실시와 위반 시 즉각적인 제재 조치 도입.',
#  '결빙구간에 대한 정기적인 제설 및 미끄럼 방지 매트 설치, 작업자에게 안전 이동 교육 강화 실시.',
#  '안전교육 강화 및 작업 전 철저한 안전점검 실시, 복공판 및 구조물 간섭 확인 절차 표준화, 작업팀 간의 명확한 신호체계 확립 및 2인1조 작업 시 의사소통 훈련 실시. 사고 원인 분석을 바탕으로 작업 지침 업데이트 및 정기적 안전 감사 실시.',
#  '안전 경계 설정 강화와 개인 보호 장비 착용 의무화, 정기적 안전 교육 실시.',
#  '바닥 상태 사전 점검 의무화 및 말비계 설치 지침 강화. 정기적인 안전 점검과 교육 프로그램 확대 실시.',
#  '작업자 안전 구역 명확히 구분 설정 및 실시간 감시 시스템 도입, 굴삭기 운전자 대상 시야 사각지대 인지 및 대응 훈련 강화 실시.',
#  '안전벨트 및 워크밴드 연결 상태의 사전 점검 의무화와 정기적인 안전 교육 실시, 코핑폼 해체 작업 시 안전 감독 강화.',
#  '크람쉘 주변 바닥에 미끄럼 방지 재질 설치 및 정기적인 점검 실시. 작업자들에게 안전한 이동 경로와 신발 착용 지침 강화 교육 제공.',
#  '용접 토치와 호스 간 안전거리 확보 교육 강화 및 정기적인 장비 점검 실시, 작업 전 안전 점검 리스트 도입.',
#  '작업자에게 균형 유지 및 중량물 취급 안전 교육 강화, 오수관로 취급 시 보조 인력 배치 및 안정적인 지지대 사용 의무화, 정기적인 작업 환경 안전 점검 실시.',
#  '정기적인 안전 교육 강화와 행동 기반 안전 프로그램 도입, 실시간 모니터링 시스템 구축을 통한 즉각적인 위험 감지 및 개입 강화.',
#  '안전교육 강화 및 실시간 위치 추적 시스템 도입, 정기적인 안전 점검과 임시 방호장치의 일관성 유지 강화 실시.',
#  '상하부 작업 분리 및 순차적 진행, 크레인 이동 경로 사전 확보 및 표시, 작업자 보호장비 강화, 정기적인 작업 계획 검토 및 안전 교육 실시.',
#  '작업 중 강풍 예측 시 작업 중단 명령 시행, 이동식 비계 안정성 점검 강화 및 고정장치 사용 의무화, 형틀 및 철근 작업 간의 동시 작업 제한 및 명확한 작업 구역 분리 실시, 정기적인 안전 교육 강화로 위험 인지 및 대응 능력 향상.',
#  '정기적인 안전 교육 프로그램 도입 및 현장 인식 향상 활동 실시. 또한, 개인 보호 장비 착용 의무화와 함께 실시간 모니터링 시스템을 구축하여 작업자의 주의력 저하를 조기에 감지하고 개입한다.',
#  '지면 정리 강화 및 작업 경로 안전 표시 설치, 정기적인 안전 교육 실시.',
#  '정기적인 소통 훈련 강화와 실시간 통신 장비 도입을 통해 운전원과 신호수 간의 협업을 개선하고, 명확한 신호 체계 표준화 및 점검 절차를 마련한다.',
#  '작업 구역 내 미끄럼 방지 매트 설치 및 정기적인 바닥 점검 강화. 작업자들에게 안전한 이동 경로 교육 실시 및 개인 보호 장비(안전화, 미끄럼 방지 신발)착용 의무화. 가설계단에 미끄럼 방지 처리 및 안전 난간 설치 보완. 정기적인 안전 교육 프로그램을 통해 미끄러짐 사고 예방 의식 강화.',
#  '작업 구역 내 이동 제한 구역 설정 및 명확한 표시 강화, 미니굴착기 작업 시 저속 운행 및 주변 감시 의무화, 정기적인 안전 교육 강화 및 안전장비 착용 확인 절차 도입.',
#  '작업 중 불필요한 신체 노출 제한, 바이브로 햄머 사용 시 안전 가이드라인 준수 강화, 정기적인 안전 교육 실시 및 개인 보호 장비 착용 의무화.',
#  '안전장비 필수 사용, 끼임방지블럭 사용 의무화, 정기적 안전 교육 강화 및 경험에 의존하지 않고 표준 작업 절차 준수 강조.',
#  '작업발판 완전 연결 및 안정성 확인 의무화, 정기적인 비계 및 발판 안전점검 실시, 작업자 대상 안전 교육 강화 및 개인 보호 장비 착용 강제화.',
#  '바닥 미끄럼 방지 처리 강화 및 정기적인 안전 점검 실시, 작업자 대상 미끄럼 위험 인지 교육 강화.',
#  '안전 교육 강화 및 명확한 신호 체계 구축, 정기적인 작업 절차 검토 및 훈련 실시.',
#  '정기적인 안전 교육 강화 및 개인 책임 의식 제고 프로그램 도입, 작업 전 안전 점검 리스트 의무화 실시.',
#  '전원 차단 절차 엄격히 준수하도록 교육 강화하고, 전기톱 사용 전 안전 점검 리스트 도입 및 정기적인 안전 훈련 실시.',
#  '정기적인 수분 보충 및 휴식 시간 강제화, 작업 환경 온도 관리 시스템 도입, 개인 보호 장비(냉각 조끼 등) 제공, 그리고 열 스트레스 예방 교육 강화 실시.',
#  '로프 및 도르레 정기 점검과 강화된 유지보수 프로그램 도입, 작업 공간 안전 경계 설정 및 개인 보호 장비 착용 의무화를 통해 재발 방지. 또한, 모든 설치 작업자에게 고급 안전 교육 실시 및 실시간 안전 모니터링 시스템 구축 계획.',
#  '정기적인 비계 점검 및 유지보수 강화, 작업자 교육 강화를 통해 비계 안정성 확보 및 안전 의식 제고.',
#  '정기적인 운전원 기술 훈련 강화와 실시간 작업 모니터링 시스템 도입을 통한 재발 방지 대책 및 향후 조치 계획 수립.',
#  '1. **미끄럼 방지 매트 설치** 및 작업 구역 바닥 정기적인 청소 강화.\n2. **백호 하차 절차 표준화** 및 안전 교육 실시.\n3. **개인 보호 장비(안전화) 점검** 의무화 및 적절한 신발 착용 강제.',
#  '작업 중 철근 다발 취급 절차 세분화 및 안전 교육 강화, 무릎 보호 장비 의무 착용 도입',
#  '작업자에게 그라인더 조작 및 안전 교육 강화 실시, 정기적인 기술 평가와 재교육 프로그램 도입, 작업 전 안전 점검 리스트 의무화 및 준수 강화',
#  '해체작업 전 철저한 안전 교육 및 해체 순서 준수 강조. 정기적인 안전 점검과 함께 작업 계획에 대한 사전 승인 절차 도입.',
#  '정기적인 계단 안전 점검 실시 및 근로자 대상 안전 교육 강화. 미끄럼 방지 바닥재 설치 고려.',
#  '정기적인 건강 검진 실시와 작업 중 동반자의 주기적인 상태 확인 의무화, 안전구역 내 응급 처치 키트 비치 및 응급 대응 훈련 강화.',
#  '토사 구간에 미끄럼 방지 매트 설치 및 안전 통로 확보, 정기적인 안전 교육 강화, 개인 보호 장비(안전화, 안전모) 필수 착용 규정 준수 점검 실시.',
#  '1. **안전 교육 강화**: 정기적인 안전 교육 프로그램을 도입하여 작업자의 주의력 향상과 안전 의식 강화.\n2. **작업 환경 개선**: 작업 공간 내 장애물 제거 및 명확한 통로 표시로 안전한 이동 경로 확보.\n3. **개인 보호 장비 의무화**: 안전화 및 반사 조끼 착용 의무화로 시야 확보 및 넘어짐 방지.\n4. **감독 및 점검 체계 구축**: 작업 중 지속적인 감독과 주기적인 안전 점검 실시.\n5. **사고 보고 및 분석 시스템**: 발생한 사고에 대한 체계적인 보고와 원인 분석',
#  '2인 1조 작업 시 안전 지침 강화 및 공구 운반 절차 표준화. 정기적인 안전 훈련과 행동 관찰 시스템 도입으로 불안전 행동 감소.',
#  '성토구간 바닥의 경사지형 개선 및 안전경로 표시 설치를 통한 재발 방지 대책과 정기적인 지형 안전성 점검 계획 수립.',
#  '비규격 및 임의 설치 사다리 사용 금지, 안전인증 받은 고정식 발판 및 통로 설치 의무화, 정기적인 안전 교육 강화 및 현장 감독 강화 실시.',
#  '작업장 내 차량 통행 관리 강화 및 명확한 통행로 지정, 정기적인 교통 안전 교육 실시.',
#  '안전 감시 시스템 도입 및 정기적인 안전 교육 강화로 작업자의 주변 인지 능력 향상 도모.',
#  '동시 작업 제한 및 명확한 작업 스케줄링 도입, 정기적 안전 교육 강화 실시.',
#  '고소작업 시 필수 안전장비(안전난간대, 안전로프, 개인용 보호장비)의 강제적 사용 규정 강화 및 정기적 안전점검 실시. 모든 작업자 대상 강화된 안전 교육 프로그램 도입 및 준수 여부 엄격히 관리.',
#  '안전교육 강화 및 비계 안정성 점검 정기화, 개인 보호장비(PPE) 착용 의무화 시행.',
#  '공구 고정장치 사용 의무화 및 정기적인 점검 실시, 작업자에게 개인 보호 장비(특히 안면 보호구) 착용 강화 교육 실시, 작업 공간 정리정돈을 통해 공구 탈락 위험 최소화.',
#  '작업 전 둥근톱 완전히 정지 확인 절차 의무화 및 개인보호장구(장갑) 개선. 정기적 안전 교육 강화.',
#  '작업 경로 명확히 표시하고, 장애물(모르타르통 등) 정기적 이동 및 보관 관리 강화. 작업자에게 주변 환경 인지 훈련 실시.',
#  '절토면 위험성 평가 강화 및 작업 전 상세한 안전 정보 제공 시스템 구축, 정기적인 안전 교육 실시.',
#  '작업순서 표준화 교육 강화 및 실시간 감독 시스템 도입으로 작업 준수 감독 강화, 정기적 안전 점검 및 절차 위반 시 즉각적인 작업 중지 및 재교육 실시.',
#  '사다리 안전 사용 교육 강화와 함께 미끄럼 방지 패드 설치 의무화 및 정기적인 사다리 점검 실시.',
#  '안전 장비 착용 의무화 및 정기적인 인력운반 안전 교육 실시, 작업 구역 내 안전 통로 확보 및 자재 고정 장치 사용 강화.',
#  '크레인 조작자의 자격 및 경험 기준 강화, 실시간 통신 시스템 도입으로 신호 명확성 향상, 연결작업 시 안전 확인 절차 의무화 및 정기적인 크레인 조작 훈련 실시.',
#  '실시간 통신 시스템 도입 및 정기적인 소통 훈련 강화로 소통 오류 방지.',
#  '작업대 안정성 확보 및 정기 점검 실시, 그라인더 사용 시 안전장비 착용 강제화, 작업자 안전 교육 강화를 통한 재발 방지 및 안전 절차 준수 모니터링 시스템 도입 계획.',
#  '작업 전 위험성 평가 강화 및 작업자에게 안전거리 확보 교육 실시. 정기적인 안전 점검과 부주의 방지 위한 인지 훈련 프로그램 도입.',
#  '정기적인 유압호스 압력 확인 절차 도입 및 커플러 해체 전 안전 확인 프로토콜 강화.',
#  '경사면 작업 시 안전장비 착용 의무화 및 정기적인 안전 교육 강화 실시. 또한, 양생용 천막 제거 또는 안전 고정 장치 설치를 통해 미끄러짐 위험 감소 계획 수립.',
#  '계단 안전 표시 강화 및 정기적인 계단 청소와 점검 실시, 근로자 대상 계단 안전 교육 강화.',
#  '심혈관 건강 관리 프로그램 도입, 정기적인 건강 검진 실시, 작업 중 휴식 시간 보장 및 접근성 좋은 화장실 설치, 스트레스 관리 교육 강화',
#  '작업 중 틀비계 안전 확보를 위한 정기적 점검 강화와 함께, 근로자들에게 비계 사용 및 안전한 하강 방법에 대한 재교육 실시. 또한, 개인 보호 장비(PPE) 착용 의무화 및 작업 공간 내 물체 배치 재검토를 통해 부딪힘 위험 최소화.',
#  '경사로 상부 정기적인 청소 및 유지 관리 강화, 안전 교육 프로그램을 통한 주의력 집중 및 안전 의식 향상 실시.',
#  '이동식 비계 설치 전 철저한 안전 점검 의무화 및 정기적인 점검 일정 도입. 작업자들에게 비계 설치 및 점검 절차에 대한 재교육 실시.',
#  '안전장비 착용 의무화 및 작업 절차 엄격 준수 강조, 정기적인 건강 검진 실시, 호이스트 작업 관련 세분화된 안전 교육 실시.',
#  '공조기 설치 전 도장 작업 우선 진행 보장, 안전 부착 설비 확보 및 임시 설치 방안 마련, 작업자에게 명확한 작업 공간 인식 교육 실시, 정기적인 안전 점검 및 비계 설치 가능성 평가 실시.',
#  '작업 속도 조절 교육 강화와 이동 전 안전 확인 절차 의무화를 통한 재발 방지. 정기적 안전 훈련 및 이동 경로 점검 리스트 도입으로 지속적인 안전 관리 강화.',
#  '바닥 안정화 작업 및 미끄럼 방지재 설치, 정기적인 작업장 점검 강화, 근로자에게 안전 이동 교육 실시 및 개인 보호 장비 착용 의무화.',
#  '작업자에게 지속적인 시야 확보 교육을 실시하고, 작업 중 감시 시스템 도입을 통해 실시간 모니터링 강화.',
#  '바닥 장애물 제거 및 정기적인 안전 점검 실시, 작업자 대상 안전 교육 강화 및 위험 인식 훈련 실시.',
#  '기계 설치 구역 내 앙카플레이트 주변 안전 경계 설정 및 정기적인 장애물 제거 작업 실시.',
#  '안전장비 착용 의무화 강화 및 유로폼 이동 경로 안전 표시 설치, 정기적인 안전 교육 실시.',
#  '안전 발판 및 미끄럼 방지 장치 설치 확대, 정기적인 비계 안전 점검 실시, 작업자에게 개인 보호 장비 착용 강제화, 미끄러운 표면 처리 방지 교육 강화.',
#  '안전 발판 및 손잡이 설치 확대, 정기적인 작업 환경 안전 점검 실시, 비닐보양재 설치 시 보조자 배치 강화',
#  '작업 구역 내 미끄럼 방지 매트 설치 및 정기적인 바닥 청소 강화, 안전 교육 강화를 통한 안전 의식 향상, 작업 전 안전 점검 리스트 준수 의무화 및 감독 체계 구축.',
#  '철판 구조 안전성 점검 및 강화, 개인 보호 장비(안전 벨트 및 안전망)필수 착용 규정 도입, 정기적인 작업 공간 안전 점검 실시 및 훈련 강화.',
#  '안전교육 강화와 함께 작업 파트너 지정 의무화 실시, 적합한 안전장비 및 작업발판 제공 확대, 정기적인 작업환경 안전점검 실시.',
#  '정기적인 안전 교육 강화 및 절차 준수 확인 시스템 도입, 자동화된 체결 도구 활용 검토.',
#  '작업 중 톱날 접근 방지 위해 안전 커버 항상 착용 의무화 및 정기적인 안전 교육 실시.',
#  '1. **안전장비 강화**: 모든 작업자에게 고급 보호장갑 및 안전경 착용 의무화.\n2. **작업 절차 개선**: 시스템 동바리 설치 시 안전간격 확보 및 정밀한 위치 확인 절차 도입.\n3. **정기 교육 및 훈련**: 분기별 안전 교육 프로그램 강화, 특히 물체 부딪힘 사고 예방에 초점을 맞춤.\n4. **위험성 평가**: 설치작업 전 위험성 평가 실시 및 결과 기반 안전 대책 마련.\n5. **감독 강화**: 현장 감독자의 정기적인 안전 점검 및 실시간 피드백 제공 시스템 구축.',
#  '개인 건강 모니터링 프로그램 도입 및 정기적 건강 검진 의무화, 작업 환경 스트레스 관리 교육 강화, 개인 건강 상태에 따른 작업 조정 가이드라인 마련 및 시행.',
#  '정기적인 절곡기 점검과 유지보수 실시, 작업자 대상 안전 교육 강화 및 안전 절차 준수 감독 강화를 통해 재발 방지.',
#  '작업자에게 적절한 힘 사용 교육 강화, 개인 보호 장비(PPE) 착용 의무화, 정기적인 기술 훈련 실시 및 안전 점검 리스트 도입.',
#  '정기적인 안전 교육 강화와 명확한 작업 지시서 배포, 실시간 모니터링 시스템 도입을 통해 재발 방지.',
#  '시스템 비계 정기 점검 및 유지보수 강화, 안전장비 착용 의무화 및 준수 감독 강화, 고소작업 안전 교육 재실시 및 인증제 도입.',
#  '정기적인 안전 교육 강화와 작업 전 안전 점검 의무화를 통해 재발 방지. 또한, 부주의 사례 분석을 바탕으로 개인별 맞춤형 안전 훈련 프로그램 도입 계획.',
#  '작업 이동통로와 계단에 미끄럼 방지 매트 설치, 정기적인 안전 교육 강화, 난간대 사용 의무화 규정 도입 및 준수 점검 실시.',
#  '작업 전 안전 점검 리스트 의무화 및 작업자에게 작업 공간 높이 인지 교육 실시. 또한, 안전 발판 및 보호 장비 제공을 확대하여 재발 방지. 정기적인 안전 훈련과 현장 위험 평가를 통해 지속적인 안전 개선을 추진.',
#  '1. **강화된 안전 교육**: 정기적인 안전 교육 프로그램을 통해 거푸집 해체 절차와 안전 수칙을 엄격히 교육.\n2. **감독 및 점검 강화**: 해체 작업 시 전문가의 현장 감독을 의무화하고, 작업 전후 철저한 안전 점검 실시.\n3. **장비 및 보호장구 개선**: 안전성이 검증된 해체 장비 사용을 의무화하고, 작업자에게 고급 보호장구 제공.\n4. **절차 표준화**: 거푸집 해체에 대한 표준 작업 절차를 정립하고 모든 작업자에게 준수 의무 부과.\n5. **사고 보고 및 분석',
#  '고속절단기 운반 시 전원 차단 강제화 시스템 도입 및 정기적 안전 교육 실시.',
#  '작업 중 망치 사용 시 정확한 타격점 확인 교육 강화 및 보호장갑 착용 의무화 실시. 항타기 SHEAVE 교체 작업 시 보조 작업자 배치하여 안전 감시 체계 구축.',
#  '안전 발판 및 보호망 설치 확대, 정기적인 안전 장비 점검 및 유지보수 강화, 높이 작업 관련 특별 안전 교육 실시.',
#  '안전장비 착용 의무화와 함께 맨홀 작업 시 보조자 배치를 통한 안전 확인 절차 도입. 정기적인 맨홀 작업 안전 교육 강화.',
#  '자재 하역 시 수동 로프 사용 금지하고, 크레인 또는 자동화 하역 장비 도입. 정기적인 안전 교육 강화 및 개인 보호 장비(PPE) 착용 강제화 실시.',
#  '고소작업차 작업 시 안전 경계 설정 강화 및 고정장치 안전성 점검 의무화, 배관 작업 시 진동 영향 평가 실시, 작업자에게 안전장비 착용 및 위험 상황 인지 교육 강화, 정기적인 고정장치 점검 및 유지보수 계획 수립.',
#  '정기적인 시설물 안전 점검 및 유지보수 강화, 노후화된 구조물 즉시 교체, 작업자에게 안전한 작업 환경 인식 교육 제공.',
#  '안전 발판 및 미끄럼 방지 매트 설치 확대, 정기적인 통로 안전 점검 실시, 작업자들에게 안전 이동 교육 강화 및 개인 보호 장비 착용 의무화 시행.',
#  '컷팅기 사용 시 안전한 보관 및 작업 공간 분리 확보, 작업자에게 개인 보호 장비 착용 강제화 및 정기적인 안전 교육 실시.',
#  '연장근무 시간 단축 및 주기적인 휴식 보장, 탈수 예방을 위한 수분 보충 교육 강화, 건강 상태 모니터링 시스템 도입.',
#  '1. **안전 교육 강화**: 모든 작업자에게 정기적인 안전 교육 실시, 특히 높은 곳에서의 작업 안전 절차와 개인 보호 장비(PPE)의 중요성 강조.\n2. **작업 감독 강화**: 마감작업 시 전담 안전 감독관 배치하여 작업 진행 상황 실시간 모니터링 및 즉시 개입 가능하도록 함.\n3. **작업 계획 명확화**: 각 작업자의 역할과 작업 구역 명확히 정의하고 문서화하여 혼란을 방지하고 책임 소재 명확히 함.\n4. **PPE 사용 강제화**: 안전모, 안전화, 안전벨트 등 필수 개인 보호 장비 착용 의무',
#  '안전 발판 및 미끄럼 방지 매트 설치 확대, 정기적인 안전 장비 점검 및 작업자의 안전 교육 프로그램 강화 실시.',
#  '안전장비 착용 의무화 강화 및 실시간 작업 모니터링 시스템 도입으로 작업자 행동 감독. 정기적인 안전 훈련 프로그램을 통해 망치 사용 시 주의사항 집중 교육 실시.',
#  '미끄러운 표면 방지를 위한 정기적인 바닥 청소와 미끄럼 방지 매트 설치. 작업자들에게 안전 부츠 착용 의무화 및 미끄러짐 방지 교육 강화 실시.',
#  '도로절단기 사용 시 이동 전 반드시 시동 끄기를 강제하는 절차 도입 및 정기적인 안전수칙 준수 교육 실시.',
#  '마대자루 주변 명확히 표시 및 경고 표지판 설치, 정기적인 작업 공간 안전 점검 실시, 근로자 대상 안전 교육 강화 실시.',
#  '개인보호구 착용 강제화 및 정기적 안전 교육 실시, 해체 작업 시 안전거리 확보 지침 강화, 실시간 모니터링 시스템 도입으로 위험 상황 즉시 감지 및 대응 체계 구축.',
#  '정기적인 시스템비계 점검 및 유지보수 강화, 파손 부품 즉시 교체 시스템 구축, 작업자 안전 교육 강화 실시.',
#  '2인1조 작업 원칙 준수 강화 교육 실시 및 실시간 모니터링 시스템 도입으로 감독 강화. 정기적 안전 점검과 위반 시 즉각적인 제재 조치 시행.',
#  '안전벨트 및 안전 로프 착용 강제화 교육 강화, 정기적인 착용 확인 절차 도입, 철골 이동 경로 안전 장벽 설치 및 개선.',
#  '말비계 설치 위치의 안전성 검토 강화 및 정기적인 안전 점검 실시, 작업자 대상 안전 교육 강화 및 안전 장비 사용 의무화',
#  '1. 개인 보호 장비(PPE) 착용 강제화 및 점검 강화\n2. 정기적인 안전 교육 프로그램 실시, 특히 앉아 작업 시 주의사항 강조\n3. 작업 전 안전 점검 리스트 도입 및 준수 의무화',
#  '정기적인 현장 청소 및 장애물 제거 절차 도입, 나일론 실 등 위험물질 관리 강화 및 보관 지침 명확히 함.',
#  '정기적인 건강 검진 실시 및 작업 강도 조절, 지병 관리 교육 강화.',
#  '고소작업차 사용 시 아웃트리거 최대 인출 및 하중 조건 준수 교육 강화, 정기적인 장비 점검 및 작업 전 안전 점검 리스트 도입.',
#  '동바리 안전 점검 강화 및 보호장치 설치, 정기적인 안전장비 사용 교육 실시, 인력운반 대체 자동화 시스템 도입 검토.',
#  '해체 전 철저한 강재 안정성 점검 실시 및 안전 확인 절차 표준화, 정기적인 안전 교육 강화, 보호장비 착용 의무화 시행',
#  '안전벨트 착용 의무화 강화 및 모든 작업 구역에 안전난간 설치 확대 실시. 정기적 안전 점검과 교육 프로그램 강화를 병행한다.',
#  '정기적인 현장 안전 점검 실시 및 위험 정보 명확한 표시 설치. 작업자에게 위험 구역 인식 교육 강화.',
#  '인력 증원 및 중량 장비 이동을 위한 보조 인력 배치, 정기적인 안전 교육 강화 실시.',
#  '바람 영향 최소화를 위한 작업 일정 조정 및 작업 공간의 안전 경계 설치, 정기적인 안전 교육 실시.',
#  '작업공구 취급 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 실시. 정기적 안전 점검과 부주의 예방 프로그램 도입.',
#  '사다리 설치지점의 안정성 점검 의무화 및 정기적인 안전점검 실시, 근로자 대상 사다리 안전사용 교육 강화, 미끄럼 방지 바닥 처리 및 안전장비 사용 강제화.',
#  '체크플레이트 해체 전 안전 확인 절차 의무화 및 임시 안전 방호장치 설치 강화. 정기적인 안전 점검과 작업자 교육 강화 실시.',
#  '2인1조 작업 원칙 강화 및 정기적인 안전 점검 실시, 사다리 사용 안전 교육 강화 실시.',
#  '신호체계 표준화 및 정기적 교육 실시, 거푸집 작업 시 안전간격 확보 지침 강화, 사전 안전점검 의무화 및 실시간 통신 장비 도입.',
#  '정기적인 안전 교육 강화와 함께 굴삭기 운전원의 실무 훈련 및 감시 시스템 도입을 통해 재발 방지 대책을 마련하고, 위험 요소 평가를 정기적으로 실시하여 작업 환경 개선 계획을 실행합니다.',
#  '안전장비 착용 의무화 및 함마드릴 작업 시 올바른 자세와 손잡이 사용에 대한 정기적 교육 실시.',
#  '작업 전 위험물질 제거 절차 의무화 및 정기적인 안전 교육 강화 실시.',
#  '천정부 숏크리트 안정성 강화를 위한 사전 검사 강화와 실시간 모니터링 시스템 도입, 작업자 보호 장비 의무 착용 및 정기적 안전 교육 실시.',
#  '작업 환경 개선 및 개인 보호 장비 강화를 통해 작업자 건강 보호 강화. 정기적인 건강 검진 실시 및 작업 관련 질병 예방 교육 프로그램 확대. 작업 스케줄 최적화와 휴식 시간 확보로 피로 누적 방지. 전문가 자문을 통한 작업 절차 안전성 검토 및 개선 지속 실시.',
#  '계단 표면 미끄럼 방지 처리 강화, 정기적인 계단 안전 점검 실시, 그리고 미끄럼 방지 교육 프로그램 확대 적용.',
#  '안전 통로 확보 및 경계 표시 강화, 터파기 구간에 안전 난간 설치, 안전 교육 강화를 통한 위험 인지 향상.',
#  '위험성 평가 강화 및 안전장비(보호장갑, 보호안경) 의무 착용, 정기적인 안전 교육 실시, 작업 전 안전 점검 리스트 도입 및 준수, 작업 공간의 위험 요소 표시 강화.',
#  '미끄러운 곳 방지 패드의 체계적인 설치 및 정기적인 점검 강화 실시.',
#  '서포트 안정성 점검 강화 및 정기적인 안전 교육 실시.',
#  '계단 및 이동 경로 안전 표시 강화와 정기적인 안전 교육 실시를 통해 재발 방지. 향후에는 모든 이동 구간에 미끄럼 방지 매트 설치 및 주기적인 현장 안전 점검을 실시할 계획입니다.',
#  '안전한 사다리 사용 지침 준수 강화, 정기적인 사다리 안전 점검 및 유지보수 실시, 모든 작업자에게 개인보호구 착용 의무화 및 고소작업 안전 교육 재실시.',
#  '자재 통로 명확히 표시하고 정기적인 점검 실시, 작업자에게 안전 이동 교육 강화.',
#  '안전 교육 강화 및 기계 장비 사용 전 전원 차단 절차 의무화 실시. 정기적인 안전 점검과 준수 여부 확인 시스템 구축.',
#  '작업장 바닥 미끄럼 방지 조치 강화 및 개인 보호 장비(장갑, 안전화) 착용 의무화 실시. 정기적인 안전 훈련 강화.',
#  '비계 발판 안정성 강화 및 개인 보호 장비 강제 착용, 정기적인 안전 점검 실시, 고소작업 관련 재교육 강화.',
#  '안전벨트 착용 의무화 강화 및 작업차량 이동 시 모든 탑승자의 착석 상태 확인 절차 도입. 정기적 안전 교육 실시로 위험 인지 향상.',
#  '계단 표면 미끄럼 방지 처리 강화 및 작업자에게 안전 이동 교육 실시. 정기적인 계단 안전 점검 실시.',
#  '안전 발판 및 미끄럼 방지 매트 설치 확대, 롤러 장비 이동 및 하차 절차 표준화 교육 실시, 작업 현장의 지면 안정성 개선 작업 수행.',
#  '안전 발판 설치 및 개인 보호 장비 강화. 햄머 드릴 사용 시 안정적인 작업 플랫폼 확보 지침 마련. 정기적인 장비 안정성 점검 실시.',
#  '가설 발판 설치 의무화 및 지정된 안전 통로 사용 강제화 교육 강화 실시.',
#  '신호체계 개선 및 정기적인 훈련 실시.',
#  '해체작업 시 단계별 순차적 해체 절차 준수 강제화 및 실시간 감독 강화, 작업자 대상 안전 교육 프로그램 정기 실시, 가설재 안전 고정 장치 사용 의무화',
#  '위험물 전도 작업 시 기계 장비 사용 의무화 및 인력 전도 금지 규정 강화. 정기적인 안전 교육 실시와 개인 보호 장비(PPE) 착용 강제화.',
#  '1. 모든 작업자에게 안전대의 필수 착용 및 정기적인 점검 교육 실시.\n2. 작업발판의 사전 안전 검사 및 고정 절차 강화.\n3. 안전 장비 사용 준수를 위한 현장 감독 강화 및 위반 시 즉각적인 제재.\n4. 정기적인 안전 훈련 프로그램 도입으로 안전 의식 향상.\n5. 해체작업 전 안전 점검 리스트 준수 의무화 및 미준수 시 작업 중단.',
#  '안전 발판 및 보호망 설치 확대, 이동 경로 안전 표시 강화, 정기적인 안전 교육 실시 및 위험성 평가를 통한 작업 절차 개선.',
#  '계단실 및 통로 바닥의 미끄럼 방지 처리 강화와 정기적인 청소 및 점검 실시.',
#  '개인 건강 관리 프로그램 도입 및 정기적인 건강 검진 실시로 예방 강화. 작업 환경에서의 스트레스 관리 교육 제공 및 직원 지원 시스템 구축. 개인질병 관련 데이터 분석을 통해 위험 요인 식별 및 맞춤형 건강 관리 조언 제공.',
#  '담뱃불 사용 금지 구역 설정 및 정기적인 화재 예방 교육 실시. 화재 감지 및 소화 시스템의 업그레이드와 함께, 정기적인 안전 점검 및 위반 시 엄격한 제재를 통해 안전 문화를 강화합니다.',
#  '고압선 주변 작업 시 철저한 지하 시설물 탐사 실시, 정기적인 위치 확인 교육 강화 및 안전 매뉴얼 업데이트, 실시간 위치 추적 시스템 도입으로 위험 지역 인지 향상.',
#  '작업자들에게 안전 장비 착용 의무화 및 시스템 동바리 주변 이동 경로 명확히 표시. 정기적인 안전 교육 실시와 함께, 좁은 공간 작업 시 보조 인력 배치를 강화한다.',
#  '공구 정기 점검 및 교체 시스템 구축, 작업자 안전 교육 강화, 개인 보호 장비(PPE) 사용 의무화 실시.',
#  '정기적 안전점검 강화 및 안전수칙 준수 교육 재실시.',
#  '작업 공간 정리 강화, 개인 보호 장비 착용 의무화, 정기적 안전 교육 실시 및 위험 지역 접근 제한 조치 강화.',
#  '커터칼 안전 보관 및 사용 지침 강화, 정기적인 안전 교육 실시, 작업 시 보호장구 착용 의무화',
#  '작업자 안전 교육 강화 및 하차 절차 표준화를 통해 재발 방지. 정기적인 안전 점검과 훈련 실시 계획 수립.',
#  '바닥 철선 표시 강화 및 정기적인 청소 일정 도입, 작업자에게 안전 이동 교육 실시.',
#  '결빙구간 사전 제거 및 정기적인 현장 안전 점검 실시, 작업자에게 미끄럼 방지 장비 착용 의무화 강화.',
#  '램프 구간의 단차를 평탄화하고, 경고 표시 설치 및 정기적인 안전 점검 실시.',
#  '안전 발판 설치 의무화 및 정기적인 안전 교육 실시로 재발 방지.',
#  '덕트 고정 상태 사전 점검 의무화 및 정기적 안전 점검 실시, 작업자에게 안전 교육 강화, 개인 보호 장비(안전대) 착용 강제화',
#  '1. **안전 교육 강화**: 정기적인 안전 교육 프로그램을 도입하여 작업자의 안전 의식을 향상시키고, 부주의로 인한 사고 예방 교육을 포함한다.\n2. **작업 절차 표준화**: 명확한 작업 절차와 안전 지침을 정립하고, 이를 모든 작업자가 준수하도록 모니터링 시스템을 구축한다.\n3. **환경 개선**: 작업 공간의 바닥을 미끄럼 방지 처리하고, 불필요한 장애물을 제거하여 안전한 작업 환경을 조성한다.\n4. **개인 보호 장비(PPE) 의무화**: 안전화와 같은 적절한 개인 보호 장비',
#  '안전망 설치 확대 및 작업 구역 격리, 유로폼 안정화 고정 장치 사용 의무화, 정기적인 안전 점검 및 교육 실시 강화.',
#  '2층 접근 제한 구역 설정 및 정기적인 안전 교육 강화를 통해 재발 방지. 또한, 접근 금지 구역 준수 감시 시스템 도입 계획.',
#  '지반 안정성 평가 강화 및 실시간 모니터링 시스템 도입, 작업 중 이동 제한 구역 설정 및 개인 보호 장비(PPE) 착용 강제화, 정기적인 지반 강화 작업 및 작업자 안전 교육 강화 실시.',
#  '말비계 안정성 강화(정기적 점검 및 고정 장치 개선), 작업자에게 올바른 사용 방법 교육 및 개인 보호 장비 착용 의무화 실시.',
#  '정해진 이동통로 준수 의무 강화 교육 실시 및 시간 압박 해소를 위한 작업 스케줄 재검토.',
#  '안전 교육 강화 및 말비계 사용 절차 표준화 실시. 정기적인 안전 점검과 개인 보호 장비(PPE) 착용 강제화를 포함한 안전 관리 시스템 개선.',
#  '정기적인 건강 검진 실시와 작업 환경 내 호흡기 자극물질 관리 강화, 직원 대상 응급 처치 교육 및 스트레스 관리 프로그램 도입.',
#  '크레인 작업 시 근로자 위치 고려한 회전 금지 프로토콜 강화, 크레인 운전자 대상 실시간 위치 인식 시스템 도입, 해체 작업 시 안전 거리 확보 지침 명확히 하고 정기적 안전 교육 실시, 사고 발생 구역에 안전 장벽 설치 및 재해자의 치료 및 회복 지원 강화.',
#  '그라인더 사용 시 주변 인화물질 제거 강화, 불꽃 차단 장치 설치, 정기적 안전 교육 실시 및 화재 대응 훈련 강화.',
#  '작업자들에게 정기적인 안전 교육을 실시하고, 개인 보호 장비(PPE) 착용을 강제화하며, 작업 절차를 명확히 문서화하여 준수를 강화합니다. 또한, 부주의 사고를 줄이기 위한 모니터링 시스템을 도입합니다.',
#  '정기적 안전 교육 강화와 실시간 위험 평가 시스템 도입을 통해 재발 방지. 또한, 개인별 안전 수칙 준수 점검 리스트를 활용한 지속적인 모니터링 실시.',
#  '안전장비 착용 의무화 및 절단 도구 사용 시 양손 조작 지침 강화. 작업 절차 표준화 및 정기적인 안전 교육 실시.',
#  '정기적인 안전 교육 강화 및 실시간 작업 감독 시스템 도입, 안전 수칙 준수 점검 리스트를 통한 주기적 평가 실시.',
#  '작업 전 안전 교육 강화 및 개인 보호 장비 착용 의무화 실시. 정기적인 안전 점검과 부주의 사례 분석을 통한 개선 방안 마련 및 피드백 시스템 구축.',
#  '전동공구 사용 전 철저한 점검 절차 도입 및 전원 차단 의무화. 정기적인 안전 교육 강화와 위반 시 엄격한 제재 적용.',
#  '작업 공간 넓이 확보를 위한 설계 검토 및 유연한 작업 공간 확보 가이드라인 도입. 정기적인 안전 교육 강화로 작업자의 공간 인식 및 위험 평가 능력 향상.',
#  '작업 전 안전 점검 강화와 철선 절단 후 즉시 후속 고정 조치 의무화, 정기적 안전 교육 실시.',
#  '장비 점검 주기 단축 및 실시간 모니터링 시스템 도입으로 스파크 발생 원인 분석 및 예방. 정기적인 안전 교육 실시하여 작업자의 이상 징후 인지 능력 향상.',
#  '폐기물 정리를 위한 정기적인 현장 청소 일정 도입, 작업자에게 안전 교육 강화 및 장애물 회피 기술 훈련 실시, 작업 영역 내 통행로 명확히 구분 표시 및 유지 관리 강화.',
#  '가스 라인 주변 안정화 작업 강화와 정기적인 안전 점검 실시를 통해 토사 무너짐 재발 방지.',
#  '작업 중 안전장비 착용 의무화 및 정기적인 안전 교육 실시. 거푸집 작업 시 보조자 배치를 통해 공간 확인 절차 강화.',
#  '말비계 정확한 위치 설치 지침 강화 및 알폼 해체 장비 사용 의무화, 정기적 안전 교육 실시.',
#  '유로폼 안정화 강화 및 작업 절차 표준화를 통해 재발 방지. 목재 대체재 사용 확대와 실시간 안전 모니터링 시스템 도입 계획 수립.',
#  '작업 구역 내 안전 경계 설정 및 작업자에게 개인 보호 장비 착용 강제화. 정기적인 안전 교육 강화 및 자재 관리 시스템 개선을 통해 재발 방지.',
#  '1. **안전장비 의무 착용**: 모든 작업자에게 고강도 보호장갑과 안전글러브 착용 의무화.\n2. **작업 절차 개선**: 수장 벽체 보드 설치 시 보조 작업자 배치 및 작업 공간 확보 지침 강화.\n3. **정기 안전 교육**: 분기별 안전 교육 프로그램 실시, 특히 끼임 사고 예방 및 응급 처치 교육 강화.\n4. **위험 평가 및 점검**: 설치 작업 전 위험성 평가 실시 및 정기적인 작업 환경 안전 점검 실시.\n5. **피드백 시스템 구축**: 작업자로부터 안전 관련 피드백 수집 및 즉시 개선 조치 적용.',
#  '1. 미끄럼 방지 매트 설치 및 작업 현장 바닥 정기적인 건조 유지 관리 강화\n2. 물통 운반용 휠카트 도입으로 수동 운반 최소화\n3. 정기적인 안전 교육 실시, 특히 미끄러짐 위험 인식 및 예방 방법 강조',
#  '자재 관리 강화 및 안전 통로 확보, 정기적인 안전 교육 실시',
#  '1. 틀비계 안전 점검 강화 및 정기적인 유지보수 실시.\n2. 근로자 대상 안전 교육 강화, 특히 비계 이동 및 주의사항 집중 교육.\n3. 개인 보호 장비(안전모, 안전화, 안전 벨트 등) 착용 의무화 및 준수 확인 강화.',
#  '고소작업 중 장비 조작과 주변 환경 인지 강화 교육 실시. 작업 중 불필요한 물체 접촉 금지 지침 강화 및 정기적인 안전 점검 실시.',
#  '1. 그라인더 사용 시 손잡이 필수 사용 규정 강화 및 준수 모니터링 실시.\n2. 정기적 안전 교육과 작업 휴식 시간 도입으로 안전 의식 제고.',
#  '신호 시스템 표준화 및 실시간 통신 장비 도입으로 작업자 간 의사소통 강화. 정기적인 신호수 및 운전자 훈련 프로그램 운영.',
#  '갱폼 발판 해치 덮개 개구부 안전 차단막 설치 및 작업자 교육 강화 실시.',
#  '폐자재 관리 시스템 개선과 근로자 안전 교육 강화를 통해 재발 방지. 정기적인 안전 점검 및 개인 보호 장비 착용 의무화 실시.',
#  '작업절차 표준화 및 정기 교육 실시, 실시간 모니터링 시스템 도입, 안전 점검 리스트 강화 및 준수 확인 절차 마련',
#  '1. **정기적 안전 교육 강화**: 고속절단기 사용 시 안전 절차 준수를 위한 정기 교육 실시.\n2. **안전 장비 의무 착용**: 절단 작업 시 반드시 보호 장갑과 안전 안경 착용 의무화.\n3. **작업 절차 표준화**: 절단 작업 전 전원 차단 절차를 명확히 정의하고 준수 확인 시스템 구축.\n4. **감독 및 점검 강화**: 작업 현장에서의 실시간 감독과 주기적인 안전 장비 및 장비 상태 점검 실시.\n5. **사고 보고 및 분석 시스템 도입**: 모든 사고를 체계적으로 보고하고 원인 분석을 통해 지속적인 개선 방안',
#  '작업자 교육 강화 및 작업 환경 개선을 통해 재발 방지. 정기적인 안전 훈련 실시와 미끄럼 방지 바닥 처리 및 명확한 안전 표시 설치를 포함한 환경 개선 실행.',
#  '음주운전 방지를 위한 엄격한 직원 교육 프로그램 도입 및 정기적인 알코올 검사 실시. 야간 작업 시 추가 조명 설치와 안전지대 확대, 교통 관리 인력 증원으로 현장 안전성 강화.',
#  '작업 중 개인 보호 장비(PPE) 필수 착용 강화 및 드릴 작업 안전 절차 교육 재실시. 천공작업 시 보조 작업자 배치를 통한 안전 감시 체계 구축.',
#  '운반 장비 활용 및 경량화된 자재 사용을 확대하고, 위험 지역(배수로 등)에는 경고 표시 및 안전 통로 설치를 강화한다. 또한, 모든 운반 작업자에게 안전 교육을 정기적으로 실시하여 장애물 회피 기술을 향상시킨다.',
#  '1. 골재 더미 주변에 안전 통로 확보 및 미끄럼 방지 매트 설치.\n2. 정기적인 현장 안전 점검 실시 및 위험 요소 제거.\n3. 근로자 대상 미끄럼 방지 및 안전 보행 교육 강화.\n4. 개인 보호 장비(안전화, 미끄럼 방지 밑창 포함) 착용 의무화.',
#  '법면 안정성 점검 강화 및 정기적인 토사 상태 모니터링 시스템 도입, 굴착부 내부 대피공간 확보 및 명확한 대피 경로 표시, 작업자 대상 안전 교육 강화 실시.',
#  '안전 교육 강화 및 행동 기반 안전 프로그램 도입, 정기적인 안전 점검과 피드백 시스템 구축.',
#  '작업 공간 명확히 구분하고 안전 통로 확보, 정기적인 안전 교육 실시 및 실시간 모니터링 강화.',
#  '작업자에게 안정적인 작업대 사용 의무화, 중심잡기 및 균형 유지 교육 강화, 정기적인 작업 환경 안전 점검 실시, 넘어짐 예방 장비(예: 안전 손잡이 설치) 도입 고려.',
#  '정기적인 안전 교육 강화와 표준 이동 절차 정립 및 준수 점검 실시.',
#  '안전장비 착용 의무화 강화 및 철근 처리 시 안전절차 표준화 실시.',
#  '폐기물 정리를 위한 정기적인 작업 중단 및 청소 시간 도입, 작업자들에게 미끄러운 표면 인지 및 안전 신발 착용 의무화 강화, 현장 안전 교육 프로그램을 주기적으로 실시하여 위험 인식 향상 및 예방 수칙 준수 강화.',
#  '상호 전달체계 표준화 및 정기적 훈련 실시, 실시간 통신 장비 도입으로 정보 공유 강화.',
#  '안전 교육 강화 및 작업 전 안전 점검 의무화를 통해 재발 방지. 정기적인 안전 행동 평가 실시.',
#  '기술적 측면에서는 모든 중량 운반 작업에 2인 이상의 동반 작업을 의무화하고, 관리적 측면에서는 작업자의 건강 상태를 매일 점검하여 이상 징후 시 즉시 작업 중단 및 관리자에게 보고하는 시스템 구축. 정기적인 안전 교육 강화 및 건강 모니터링 앱 도입을 통해 지속적인 관리 강화.',
#  '작업 공간 내 장애물 제거 및 안전 경계 설정 강화, 도장작업 시 양손 사용 지침 명확히 하며, 정기적인 작업 환경 안전 점검 실시.',
#  '안전장비 착용 강제화 및 정기적 점검 시스템 구축,  정기적인 안전 교육 강화 실시.',
#  '자재 취급 절차 표준화 및 교육 강화, 안전장비 착용 의무화, 작업 전 위험성 평가 실시, 정기적인 안전 점검 및 감독 강화, 무리한 조작 금지 지침 명확히 공지',
#  '정기적인 비계 및 바닥 안전 점검 실시, 미끄럼 방지 재질 적용, 작업자 대상 안전 교육 강화 및 개인 보호 장비 착용 의무화',
#  '1. **강화된 안전 교육 프로그램**: 정기적인 안전 교육을 실시하여 작업자의 안전 의식을 향상시키고 부주의로 인한 위험을 인지시킵니다.\n2. **작업 전 안전 점검**: 설치작업 전에 반드시 안전 점검을 실시하여 작업 환경과 장비 상태를 확인합니다.\n3. **개인 책임 제도 도입**: 각 작업자에게 안전 책임을 부여하고, 부주의로 인한 사고 발생 시 책임을 명확히 합니다.\n4. **실시간 모니터링 시스템**: CCTV 및 센서를 활용한 실시간 모니터링 시스템 구축으로 위험 상황을 즉시 감지하고 대응합니다.\n5. **',
#  '작업공간 확장 및 최적화 설계 도입, 정기적인 기술 훈련과 집중력 향상 프로그램 실시, 작업 시 안전 자세 가이드라인 강화 및 준수 점검 강화.',
#  '정기적인 안전 교육 실시와 함께 작업 구역의 미끄럼 방지 시설 개선 및 명확한 안전 경로 표시를 통해 재발 방지.',
#  '비계 해체 시 임시 고정 장치 사용 의무화 및 정기적인 안전 점검 실시. 작업자에게 안전 장비 착용 강제화 및 재교육 실시.',
#  '기상 예보 모니터링 강화 및 악천후 시 작업 중단 정책 도입, 안전난간 강화 및 개인 보호장비 착용 의무화 실시.',
#  '조기대 잠김레버 정기 점검 및 유지보수 강화, 자동 잠금 시스템 도입 고려.',
#  '안전 교육 프로그램 확대 및 정기적 현장 안전 점검 실시, 작업 플랫폼과 안전 장비의 표준화 및 유지보수 강화.',
#  '망치 사용 시 보호장치 착용 의무화 및 정기적인 장비 점검 실시.',
#  '작업 전 안전 절차 준수 강화, 압륜 설치작업 시 보조자 배치 의무화, 정기적인 안전 교육 및 실습 실시, 그리고 작업 중 개인 보호 장비 착용 강제화.',
#  '펌프카 안정성 확보를 위한 정기적인 점검 및 유지보수 강화, 작업 전 안전 경로와 지지 구조물 확인 절차 도입, 작업자 대상 펌프카 주변 작업 안전 교육 실시.',
#  '안전장비 착용 강제화 및 점검 강화, 정기적 안전 교육 실시, 추락방지망 임의 해체 금지 규정 엄격히 적용 및 모니터링 강화.',
#  '화물차 운전원 대상 안전 행동 훈련 강화 및 정기적인 행동 관찰 시스템 도입.',
#  '말비계 사용 시 안전 잠금 장치 설치 의무화 및 정기적인 점검 실시. 작업자 대상 말비계 조작 및 안전 절차 재교육 실시.',
#  '이동식틀비계 사용 시 아웃트리거와 바퀴고정장치 필수 설치 규정 강화 및 준수 감독, 정기적 안전 교육 실시, 작업 전 안전 점검 리스트 도입 및 준수.',
#  '거푸집 안정성 확보를 위한 사전 점검 강화와 작업자들에게 안전한 핸들링 기법 교육 실시. 정기적인 안전 점검 및 불안정 요소 제거 시스템 구축.',
#  '임시승강통로 설치 의무화 및 정기적인 안전 점검 실시, 부주의 예방을 위한 안전 교육 프로그램 확대 실시.',
#  '안전난간 완전 설치 유지 의무화 및 정기 점검 실시, 유로폼 해체 시 반생 제거 절차 표준화 교육 강화.',
#  '반복 동작 최소화, 작업 도구 및 자세 개선, 정기적인 근골격계 건강 검진 실시, 작업 부하 분산 및 휴식 시간 확보를 통한 작업 환경 개선 및 직원 교육 강화.',
#  '정기적인 스트레칭 프로그램 도입 및 작업자 교육 강화 실시.',
#  '1. **강화된 안전 교육**: 운반작업 중 중심 유지 및 긴급 상황 대처 교육 강화.\n2. **작업 환경 개선**: 벽면에 안전 가드 설치 및 작업 공간의 혼잡도 최소화.\n3. **정기적인 안전 점검**: 운반 장비의 상태 점검 및 작업자의 안전 의식 평가를 위한 정기적인 점검 실시.\n4. **개인 보호 장비(PPE) 의무화**: 헬멧 및 보호대 착용 강제화로 부상 위험 감소.',
#  '전원 차단 후 작업 도구 안전 보관, 말비계 작업 시 주의 강화 교육, 개인 보호 장비 착용 의무화 및 정기적 안전 점검 실시.',
#  '케이블드럼 이동 시 2인1조 작업 의무화 및 정기적인 근력 강화 훈련 제공. 작업 전 위험성 평가와 안전장비 착용 확인 강화.',
#  '정기적 안전 교육 강화 및 작업 전 안전 점검 의무화 실시.',
#  '정기적인 안전 교육 실시와 함께 작업 전 철저한 안전 점검 및 개인 보호 장비 착용 의무화를 강화한다. 또한, 자재 정리 절차를 표준화하고, 부주의로 인한 사고를 예방하기 위한 실시간 모니터링 시스템 도입을 계획한다.',
#  '자재 수평 이동 강제화 및 작은 대차 사용 시 안전 가이드라인 강화. 정기적 안전 교육 실시와 현장 감독 강화를 통해 안전 의식 향상.',
#  '정기적인 중량물 취급 기술 훈련 강화 및 실시간 작업 감독 시스템 도입.',
#  '시인성 강화를 위한 안전 표시 설치 확대 및 정기적인 안전 교육 실시로 부주의 요인 최소화.',
#  '작업 공간 내 이동 가능한 안전 통로 확보 의무화 및 정기적인 통로 점검 실시.',
#  '강관비계 조인트 핀 강화 및 정기 점검 시스템 구축, 가설휀스 설치 절차 표준화 및 교육 강화, 개인 보호 장비(PPE) 사용 의무화 및 준수 감독 강화.',
#  '작업 전 자세 교정 교육 강화 및 실시간 작업 모니터링 시스템 도입으로 안전한 작업 자세 지속 확인. 정기적인 피드백 세션을 통해 개선 사항 적용 및 평가 실시.',
#  '자재 운반 시 엄격한 안전 절차 준수 의무화 및 정기적인 개인 안전 교육 강화 실시.',
#  '지지대 안정성 강화 및 정기 점검 의무화, 작업 전 안전 점검 리스트 준수 강화, 추가적인 지지 구조물 사용 검토.',
#  '안전보호구 착용 의무화 강화 및 정기적인 점검 실시, 신규 입사자 대상 강화된 안전 교육 프로그램 도입.',
#  '크레인 작업 영역 명확히 구분 표시 및 접근 제한 시스템 구축. 정기적 안전 교육 강화와 실시간 위치 추적 시스템 도입을 통해 작업자 위치 관리 강화.',
#  '정기적인 안전 교육 강화 및 작업 전 철저한 안전 점검 실시. 작업자들에게 개인 보호 장비 착용 의무화 및 실시간 모니터링 시스템 도입.',
#  '정기적인 안전 교육 강화와 작업 영역 내 명확한 안내 표지판 설치, 그리고 실시간 모니터링 시스템 도입을 통한 사고 예방 및 빠른 대응 체계 구축.',
#  '안전한 유로폼 적재 및 작업발판 관리 강화, 정기적인 안전 점검 실시 및 작업자에게 적재물 관리 교육 강화 실시.',
#  '안전한 표준 작업대 사용 의무화 및 정기적인 작업환경 안전 점검 실시, 작업자 대상 불안전 행동 예방 교육 강화 실시',
#  '철근 적재 공간의 명확한 통로 확보 및 경고 표시 설치, 정기적인 안전 교육 강화, 개인 보호 장비 착용 의무화 실시.',
#  'CPB 배관과 자바라 호스 연결부에 이탈방지 장치(로프 또는 와이어) 설치 의무화 및 정기적인 점검 시스템 구축. 작업자에게 연결클립 상태 확인 절차 강화 교육 실시.',
#  '가설구조물의 안전성 강화를 위해 정기적인 점검 및 유지보수 실시, 작업자에게 고급 안전장비(예: 안전그물, 강화된 안전발판) 제공, 추락 위험 작업 시 추가적인 안전 교육 실시 및 안전규정 준수 강화를 위한 내부 감사 시스템 구축.',
#  '안전교육 강화와 함께 지정된 안전통로 확보 및 비상시 사용 가능한 임시 발판 설치를 통해 재발 방지. 정기적인 통로 안전점검 실시.',
#  '2인1조 작업 원칙 준수 강화와 정기적인 안전 교육 실시를 통해 재발 방지. 또한, 작업 현장의 미끄럼 방지 시설 개선 및 실시간 모니터링 시스템 도입 계획.',
#  '보호장치 설치 및 기계 설계 개선, 정기적 안전 점검 실시, 작업자 대상 안전 교육 강화',
#  '안전 손잡이 설치 확대 및 정기적인 안전 교육 실시를 통해 재발 방지. 모든 작업자에게 굴착기 하차 시 안전 절차 준수 의무화 및 모니터링 강화.',
#  '작업 구역 내 장애물 제거 및 정기적인 안전 점검 실시, 방화문 하부 프레임 주변에 안전 경계 설치, 작업자 대상 안전 교육 강화 및 개인 보호 장비 착용 의무화 시행.',
#  '정기적 안전 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 시행, 작업 전 안전 점검 리스트 도입으로 사전 위험 요소 제거',
#  '작업 표준 절차 엄격히 준수 교육 강화 및 정기 건강 검진 실시로 작업자 상태 모니터링 강화.',
#  '작업장 이동 경로 안전 표시 강화 및 정기적인 건강 검진 실시, 의식 상실 원인 분석을 통한 개인 맞춤형 지원 계획 수립.',
#  '천막 아래에 미끄럼 방지 매트 설치 및 정기적인 점검 실시, 자재 보양 작업 시 안전 교육 강화 및 개인 보호 장비 착용 의무화.',
#  '방호장치 안전거리 확보 및 작업 전 철저한 점검 실시, 샤클 및 슬링 사용 절차 표준화 강화.',
#  '지반 안정성 평가를 위한 사전 조사 강화 및 강우 후 작업 지연 정책 도입. 정기적인 지반 모니터링 시스템 구축 및 작업자 교육 강화 실시.',
#  '자재 제거 절차 표준화 및 준수 강화, 작업 전 안전 점검 의무화, 실시간 모니터링 시스템 도입',
#  '이슬 제거 작업을 포함한 정기적인 작업 공간 청소와 미끄럼 방지 매트 설치, 작업자에게 방수 장갑 및 신발 제공, 그리고 이슬 발생 시간대 작업 최소화 또는 보호 장비 강화를 통한 재발 방지.',
#  '자재 운반 경로 명확히 표시하고 안전장비 착용 의무화하며 정기적인 안전 교육 실시.',
#  '작업자 대상 안전의식 강화 교육 실시 및 엄격한 안전규정 준수 감독 강화.',
#  '바람 예보 실시간 모니터링 시스템 도입 및 작업 중단 기준 강화, 작업자에게 기상 변화 대응 훈련 제공.',
# ...
#  '정기적인 안전 교육 강화와 작업장 바닥의 미끄럼 방지 처리 개선을 병행 실시.',
#  '거푸집 안정성 점검 강화 및 미끄럼 방지 장비 착용 의무화, 정기적인 안전 교육 실시.',
#  '자재 운반 시 주변 환경 철저히 확인 교육 강화, 뒷걸음질 운반 금지 및 안전한 대체 운반법 도입, 정기적인 안전 점검 및 위반자에 대한 재교육 실시.',
#  '지정된 이동통로 준수 강화 교육 실시 및 철근 위 이동 금지 구역 설정 및 표시 강화.',
#  '작업 중 전자기기 사용 금지 규정 강화 및 정기적인 안전 교육 실시로 작업자의 주의 분산 방지.',
#  '안전보호구 착용 의무화 강화 및 정기적인 점검 실시,  교육 프로그램 확대 실시, 위반 시 즉각적인 제재 조치 도입.',
#  '자동화 지지 장치 도입 및 작업 절차 표준화 강화를 통해 재발 방지. 정기적인 안전 점검과 작업자 교육 강화 실시.',
#  '천막 설치 강화 및 강풍 대비 안전 조치 도입, 정기적인 기상 모니터링 시스템 구축 및 작업자 강풍 대응 훈련 강화',
#  '1. **즉각적인 안전 점검**: 철근벤딩기계 및 주변 전기 시스템에 대한 철저한 안전 점검 실시.\n2. **개인 보호 장비 강화**: 작업자들에게 추가적인 개인 보호 장비(예: 절연장갑, 안전모) 착용 의무화.\n3. **작업 환경 개선**: 작업 공간의 환기 상태 개선 및 전기 장비의 정기적인 점검 및 유지보수 강화.\n4. **교육 및 훈련 강화**: 작업자들에게 전기 안전 및 응급 상황 대처 교육을 정기적으로 실시.\n5. **감시 및 모니터링 시스템 도입**: 작업자의',
#  '작업 공간 분리 강화 및 실시간 통신 시스템 도입으로 작업자 간의 충돌 위험 감소, 정기적인 안전 교육 강화 특히 차량 및 중장비 주변 작업 안전 지침 강조, 거푸집 설치 시 임시 방호벽 설치 및 작업 영역 명확히 표시.',
#  '환경적 요인에 대한 보호 코팅 적용 및 정기적인 부식 점검 강화. 노후 장비 교체 일정을 가속화하고, 모든 장비에 대한 정기적인 유지보수 및 안전 점검을 매월 실시.',
#  '안전 통행로 확보 및 정기적 안전 교육 강화, 궤도 패널 주변 미끄럼 방지 재질 설치',
#  '터파기 작업 후 임시 지지 구조물 설치 의무화 및 정기적 안전점검 실시. 이동 경로 안전통로 확보 및 안전 교육 강화.',
#  '안전 발판 및 작업 플랫폼 안정성 강화, 정기적인 안전 교육 실시, 협소 공간 작업 시 대체 장비 사용 검토',
#  '정기적인 의사소통 훈련 실시 및 크레인 작업 영역 내 위험 구간 명확히 표시, 실시간 통신 장비 도입, 사전 정보 공유 프로토콜 강화.',
#  '작업발판 단부에 명확한 안전 표시 설치 및 정기적인 점검 강화. 작업자들에게 안전한 작업 공간 인식 교육 실시.',
#  '정기적인 말비계 점검 및 유지보수 실시, 점검 기록 관리 강화, 작업자 대상 안전 교육 프로그램 확대 실시.',
#  '이동식 틀비계 사용 시 안전 벨트 착용 의무화 및 계단 이동 경로에 미끄럼 방지 매트 설치. 정기적인 안전 교육 강화와 작업 전 안전 점검 리스트 도입.',
#  '안전 발판 및 미끄럼 방지 장치 설치 강화와 정기적인 안전 교육 실시를 통해 재발 방지. 또한, 작업 전 안전 점검 리스트 준수 의무화 및 부상 예방 훈련 강화 계획 수립.',
#  '1. 모든 근로자에게 정기적인 안전 교육 강화 및 안전 의식 향상 프로그램 도입.\n2. 해체작업 전 필수적으로 안전장비(안전모, 안전대) 착용 확인 절차 확립.\n3. 사다리와 적절한 작업발판 설치 기준 준수를 위한 현장 점검 및 유지보수 강화.\n4. 안전수칙 위반 시 즉각적인 제재와 함께 개선 계획 수립 및 추적 관리 시스템 구축.',
#  '전문 업체 위탁 정비 의무화, 작업자 대상 안전 교육 강화, 장비 결함 시 절차 준수 강조, 실시간 모니터링 시스템 도입.',
#  '근로자 정기 안전 교육 강화와 가설계단 미끄럼 방지 장치 설치 및 정기 점검 실시.',
#  '정기적인 건강 검진 실시와 함께 아침조회 전 모든 작업자의 건강 상태를 철저히 점검하고, 초기 증상자는 즉시 의료기관으로 이송하며, 관련 교육을 강화하여 조기 발견 능력 향상시킨다.',
#  '기상 예보 모니터링 강화 및 제설 작업 우선순위 설정, 작업 전 현장 온도 및 얼음 상태 실시간 점검 실시, 정기적인 안전 교육과 미끄럼 방지 장비 제공 확대 실시.',
#  '작업자에게 개인 보호 장비 착용 의무화 및 정밀한 작업 지시서 배포로 안전 절차 준수 강화. 정기적인 안전 훈련 프로그램 도입으로 실무 중 발생 가능한 위험 인지 향상.',
#  '정기적인 안전 교육 강화와 이동식 틀비계 사용 시 안전 절차 준수 강조, 부주의 행동 감지를 위한 현장 모니터링 시스템 도입 계획.',
#  '굴착기 작업 시 안전 신호자 배치 의무화 및 실시간 감독 강화, 작업자 대상 굴착기 조작 및 긴급 상황 대응 교육 강화, 흙막이 구조물 안정성 사전 점검 프로토콜 도입.',
#  '작업자에게 철근 가공 장비 안전 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 실시. 정기적인 안전 점검과 함께 부주의 원인 분석을 통한 작업 절차 개선 및 경고 시스템 도입.',
#  '호스 고정 장치 설치 강화, 작업 전 안전 점검 절차 확립, 교통신호수와 작업자 간 실시간 통신 시스템 도입.',
#  '정기적인 스트레칭 프로그램 도입과 모든 작업자의 스트레칭 참여 의무화, 그리고 스트레칭 미준수 시 작업 허가 제한 조치를 시행합니다.',
#  '1. 기 설치된 구조물 주변 안전 경계 설정 및 경고 표시 강화\n2. 작업자에게 와이어 및 장애물 인식 훈련 강화\n3. 작업 전 현장 안전 점검 의무화 및 점검 리스트 표준화\n4. 개인 보호 장비(안전화, 안전모) 착용 강제화 및 정기 점검 실시',
#  '작업대 정기 점검 및 유지보수 강화, 오작동 감지 시스템 도입, 작업자 안전 교육 강화 실시.',
#  '안전지지대 설치 의무화 및 정기 점검 실시, 해체작업 전 안전 교육 강화, 개인 보호장비(PPE) 착용 강제화 및 준수 여부 지속 모니터링.',
#  '안전 교육 프로그램 정기화 및 행동 기반 안전 시스템 도입으로 작업자의 안전 의식 향상.',
#  '소음 저감 장비 도입 및 정기적인 청력 검사 실시, 작업자에게 청력 보호 장비 착용 의무화 및 안전 교육 강화.',
#  '정기적인 안전 점검 및 해체 자재의 체계적인 관리 시스템 구축. 작업자들에게 실시간 장애물 인식 교육 강화 및 명확한 작업 영역 표시 도입.',
#  '작업 지시 시 실시간 감독 강화 및 안전장비 사용 의무화, 정기적인 안전 교육 실시와 함께 개구부 주변 안전 장벽 설치 및 위험 구역 접근 관리 시스템 도입.',
#  '작업 전 적재 방향 및 인원 배치 사전 협의 의무화, 실시간 통신 장비 제공을 통한 원활한 의사소통 강화, 정기적인 팀 협업 훈련 실시, 안전 교육에 협업 및 의사소통 강화 내용 포함, 사고 발생 시 즉시 팀 협업 프로세스 검토 및 개선 방안 마련.',
#  '중량자재 이동 전 엄격한 승인 절차 도입 및 무단 작업 금지 강화 교육 실시',
#  '1. **안전장치 강화**: 홈 가공기의 안전 커버 및 긴급 정지 장치를 업그레이드하여 작업자의 신체 부위가 기계 내부로 들어가는 것을 방지합니다.\n2. **작업 지침 엄격화**: 홈 가공 작업 시 반드시 보호장구 착용과 기계 작동 중 접근 금지를 명시한 작업 지침을 강화하고, 정기적인 준수 확인 실시.\n3. **교육 프로그램 확대**: 관련 작업자 대상으로 홈 가공기 안전 운용 교육을 정기적으로 실시하며, 실제 사고 사례를 포함한 시뮬레이션 훈련을 도입.\n4. **감독 강화**: 지하 기계실 작업 시 안전 감독관',
#  '안전한 이동 경로 표시 강화 및 개인 보호 장비(PPE) 착용 강제화, 정기적인 안전 교육 실시.',
#  '신호체계 표준화 및 실시간 통신 장비 도입, 정기적인 신호수 훈련 강화 실시.',
#  '실시간 감시 시스템 도입과 기중기 운전자 대상의 인식 향상 교육 강화, 명확한 작업 영역 구분 표시 및 정기적인 안전 훈련 실시.',
#  '정기적 안전 점검 실시와 개인 보호장비 착용 의무화 강화.',
#  '작업 중 전화 사용 제한 및 안전한 통신 수단 제공, 전방 시야 확보 교육 강화, 양손 자유롭게 유지하는 작업 방법 지침 마련 및 준수 감독 강화.',
#  '작업구역 분리 및 작업시간 조정으로 동시작업 방지하고, 안전 교육 강화 및 명확한 작업 지침서 마련을 통해 안전 확보.',
#  '정기적인 기술 훈련과 공구 사용 시뮬레이션 도입, 그리고 일일 안전 점검 리스트를 통한 지속적인 관리 강화.',
#  '장비 이동 시 표준화된 신호어와 절차 도입, 정기적인 신호체계 교육 및 훈련 실시, 실시간 통신 장비 활용 강화.',
#  '안전 발판 및 보호망 설치 확대, 정기적인 안전 점검 실시, 부주의 방지를 위한 개인별 안전 교육 프로그램 도입 및 강화.',
#  '바닥 상태 정기 점검 및 명확한 안전 표시 설치, 이동 전 환경 확인 교육 강화 실시.',
#  '와이어로프 정기적인 점검 및 교체 시스템 구축, 굴착작업 시 보호장비 강화 및 안전 구역 설정, 작업자 대상 와이어로프 이상 징후 인지 교육 실시.',
#  '데크플레이트 및 철근 위 안전 메쉬 발판 설치 의무화와 정기적인 안전 통로 점검 실시 계획 수립.',
#  '작업 전 안전 점검 강화 및 개인 보호 장비 착용 의무화 실시. 해체 순서 표준화 및 실시간 모니터링 시스템 도입.',
#  '말비계 안정성 강화를 위해 정기적인 점검과 유지보수 실시, 드레인커버 등 지지 구조물의 내구성 강화 및 교체 기준 명확히 설정.',
#  '정기적인 장비 점검과 함께 작업자에게 정밀 조작 훈련 강화 및 개인 보호 장비 착용 의무화를 통해 재발 방지. 향후에는 안전 교육 프로그램을 확대하고, 작업 전 장비 상태 확인 절차를 엄격히 시행한다.',
#  '기계 반출 절차 표준화 및 개인 보호 장비 착용 강제화, 정기적인 안전 교육 실시.',
#  '계단 안전 표시 강화 및 정기적인 점검 실시, 작업자에게 미끄러짐 예방 교육 의무화.',
#  '1. **안전 통로 확보**: 타설작업 영역 내 안전한 통로를 명확히 표시하고 확보합니다.\n2. **개인 보호 장비 착용 강제**: 작업자들에게 안전화 및 보호대 착용을 의무화합니다.\n3. **정기적 안전 교육**: 넘어짐 예방 및 응급 처치 교육을 정기적으로 실시합니다.\n4. **작업 환경 점검**: 주기적인 작업 현장 안전 점검을 통해 위험 요소를 사전에 제거합니다.',
#  '유공발판의 안정성 점검 강화 및 즉시 교체 시스템 도입, 이동식 비계와 시스템 동바리 간 안전 이동 절차 표준화 교육 실시.',
#  '개구부 안전덮개 정기 점검 및 즉시 교체 시스템 구축, 작업자 안전 교육 강화 실시.',
#  '해체작업 전 철저한 절차 교육 실시, 실시간 감독 강화 및 준수 여부 점검 시스템 도입.',
#  '정기적인 안전 교육 강화와 개인 보호 장비(PPE) 착용 의무화를 통해 부주의로 인한 사고를 방지하고, 작업 절차 표준화 및 실시간 모니터링 시스템 도입으로 안전성을 향상시킵니다.',
#  '안전 의식 강화 교육 실시 및 작업 전 안전 점검 의무화, 부주의 방지를 위한 지속적인 모니터링 시스템 구축.',
#  '알폼 자재의 안전한 보관 및 작업 구역 경계 설정을 통해 재발 방지. 정기적인 현장 점검과 작업자 안전 교육 강화 실시.',
#  '작업 전 안전 점검 강화와 개인 보호 장비 착용 의무화 실시, 또한 2단 띠장 및 버팀대 설치 절차에 대한 상세 교육 프로그램 도입 및 정기적인 재교육 실시.',
#  '안전장비 착용 강제화 및 작업 전 위험성 평가 실시를 통한 재발 방지 대책 수립. 정기적 안전 교육 강화와 뾰족한 물체 노출 최소화를 위한 작업 방법 개선 계획 실행.',
#  '바퀴형 이동식 비계 사용 전 안전 교육 강화 및 안정성 검사 의무화, 작업 공간 확보 및 고정 장치 사용 의무화 실시.',
#  '정기적인 작업현장 점검과 바닥 장애물 제거 시스템 구축, 그리고 운반작업 전 바닥 상태 확인 절차 도입을 통해 재발 방지.',
#  '고소작업대 안정성 점검 및 유지보수 정기화, 근로자에게 안전한 하차 절차 교육 실시 및 개인 보호 장비 착용 강제화.',
#  '1. **안전 교육 강화**: 정기적인 안전 교육 프로그램을 도입하여 작업자들의 안전 의식을 향상시키고, 물체 주변 작업 시 주의사항을 강조한다.\n2. **작업 환경 개선**: 작업 공간을 정리정돈하여 장애물을 최소화하고, 필요한 경우 안전 통로와 경고 표시를 설치한다.\n3. **개인 보호 장비 의무화**: 안전화와 같은 개인 보호 장비 착용을 강제화하고, 장비의 적절한 사용을 점검한다.\n4. **감독 및 점검 체계 구축**: 작업 중 지속적인 현장 감독을 실시하고, 일일',
#  '작업 구역 내 차량 통행 제한 시간 설정 및 경고 시스템 구축, 정기적인 교통 관리 인력 교육 실시, 작업자 보호를 위한 가시성 높은 복장 의무화 시행.',
#  '정기적인 휴식 시간 도입과 작업 순환 제도를 통해 집중력 유지, 또한 작업 환경의 물체 배치 개선으로 안전성 향상.',
#  '정기적인 안전 교육 강화 및 작업 전 철저한 안전 점검 실시, 부주의 방지를 위한 행동 기반 안전 프로그램 도입, 실시간 모니터링 시스템 구축으로 작업자 위치 및 장비 상태 실시간 확인.',
#  '안전발판 높이를 점진적으로 조정하고, 미끄럼 방지 매트 설치, 정기적인 안전 교육 강화 및 개인 보호 장비(PPE) 착용 강제화 실시.',
#  '안전장비 착용 강화 및 난간대 제거 시 전문 도구 사용 의무화. 또한, 신호 및 타격 작업 시 안전거리 확보 지침 마련 및 정기적인 안전 교육 실시.',
#  '피아노선 관리 강화 및 계단 안전 표시 설치, 정기적 안전 교육 실시.',
#  '안전벨트 사용 지침 엄격히 준수 교육 강화, D링 전용 사용 의무화 및 정기적인 장비 점검 실시, 실시간 모니터링 시스템 도입으로 안전 위반 즉시 감지 및 개입.',
#  '철선 및 장애물 표시 강화와 정기적인 작업 영역 점검을 통해 재발 방지 대책을 마련하고, 작업자들에게 안전 교육을 강화하며, 위험 지역에 안전 경계선 설치를 포함한 향후 조치 계획을 실행한다.',
#  '1. **안전장비 표준화**: 절단 작업 시 전용 절단 장갑 사용 의무화 및 목장갑 사용 금지 규정 강화.\n2. **교육 강화**: 정기적인 안전 교육 프로그램 실시, 특히 개인 보호 장비(PPE) 올바른 사용법 강조.\n3. **감독 및 점검**: 작업 전 PPE 점검 절차 도입, 안전 관리자의 현장 감독 강화.\n4. **사고 보고 및 분석**: 모든 사고 상세 보고 시스템 구축, 원인 분석을 통한 지속적인 안전 개선 방안 마련.',
#  '자재 운반 경로 명확히 구분하고 아웃트리거 주변 안전 구역 설정, 정기적인 안전 교육 실시 및 작업 전 위험성 평가 강화.',
#  '지반 안정화 작업 실시 및 작업 영역 경계 설정 강화. 정기적인 지반 상태 점검과 안전 교육 강화 실시.',
#  '자동화 장비 도입 및 정기적인 안전 훈련 실시로 작업자 기술 향상 도모.',
#  '부직포 상태 정기 점검 및 즉시 보수 시스템 구축, 작업 구역 명확한 표시와 경고등 설치 확대, 작업자 안전 교육 강화 및 통행 차량 속도 제한 구역 설정 실시.',
#  '1. 마대걸이 및 작업 장비 정기 점검 실시.\n2. 작업자에게 안전 장비 착용 강제화 및 마대걸이 사용 교육 강화.\n3. 작업 전 안전 점검 리스트 준수 의무화 및 감독 강화.',
#  '사다리 발판 미끄럼 방지 처리 도입 및 작업장 습도 관리 강화, 정기적인 안전 교육 실시로 습기 조건 하의 작업 안전 강화.',
#  '작업 절차 재검토 및 안전장비 개선(강화된 보호장갑 착용 의무화), 정기적인 안전 훈련 강화 실시.',
#  '짐 운반 시 안전장비 착용 의무화 및 작업 경로 내 장애물 제거 및 정기적 점검 실시.',
#  '정기적인 크레인 점검 및 유지보수 강화, 운전원과 감리감독자에게 케이블 상태 확인 의무화 및 교육 실시.',
#  '작업구역 명확히 구분 표시, 모든 굴착작업 시 신호수 필수 배치 의무화, 작업 계획서 작성 및 승인 절차 강화 실시. 정기적 안전 교육 강화 및 접근 통제 시스템 도입 고려.',
#  '1. **안전 교육 강화**: 해체작업 전 안전 교육을 의무화하고, 비계 및 발판과의 안전거리 유지에 대한 교육을 집중적으로 실시합니다.\n2. **작업 절차 표준화**: 비계 해체 시 구체적인 안전 절차를 정립하고 모든 작업자에게 배포합니다.\n3. **개인 보호 장비(PPE) 강제 착용**: 작업 중 손가락 보호용 장갑 착용을 필수화합니다.\n4. **정기적 안전 점검**: 해체 작업 전후로 정기적인 안전 점검을 실시하여 위험 요소를 사전에 제거합니다.',
#  '정기적인 안전 교육 강화와 작업 전 필수 교육 확인 절차 도입, 부주의 방지를 위한 안전 의식 향상 프로그램 실시.',
#  '정기적인 안전장비 점검과 함께 작업자들에게 안전대 사용의 중요성 강조 교육 실시, 안전규정 준수 모니터링 강화 및 위반 시 즉각적인 제재 조치 도입.',
#  '1. 뒷걸음 이동 금지 교육 강화 및 대체 이동 방법 훈련 제공.\n2. 작업 현장 바닥 상태 정기 점검 및 위험 지역 표시 설치.\n3. 개인 보호 장비(안전화, 미끄럼 방지 신발) 착용 의무화 강화.',
#  '안전망 설치 및 작업 영역 격리 강화, 정기적인 안전 교육 실시.',
#  '계단실 조명 개선 및 미끄럼 방지 매트 설치, 정기적인 계단 안전 점검 실시.',
#  '작업 중 TPC(Tightening Positioning Component) 고정 강화 및 양손 사용 금지 지침 도입. 정기적인 안전 점검과 함께 작업자에게 개인 보호 장비 착용 강제화.',
#  '사다리 사용 교육 강화 및 안전 그립 장치 설치, 정기적인 사다리 안전성 점검 실시.',
#  '안전고리 재체결 절차 강화 교육 실시 및 실시간 모니터링 시스템 도입, 이동 전 안전 확인 체크리스트 의무화, 정기적인 안전 훈련 및 시뮬레이션 실시.',
#  '계단 미끄럼 방지재 설치 및 정기적인 점검, 미끄럼 방지 교육 강화와 개인 보호 장비 착용 의무화 실시.',
#  '지하 매설물 위치 확인 시스템 도입 및 사전 조사 의무화, 모든 설치작업 전 철저한 지하 조사 실시, 관련 작업자들에게 지하 매설물 확인 절차 교육 강화, 그리고 위반 시 엄격한 관리 및 감독 체계 구축을 통해 재발 방지를 도모합니다.',
#  '작업 속도 조절 및 한가닥씩 철근 절곡 원칙 준수 강화, 작업자에게 안전 장갑 및 보호 장비 필수 착용 지시, 정기적 안전 교육 실시로 위험 인식 제고, 작업 중 손 위치 엄격히 관리하는 안전 지침 마련 및 준수 확인 점검 실시.',
#  '철근 운반 중량 제한 설정 및 준수 강화 교육 실시. 정기적인 중량 운반 능력 평가와 안전 교육 프로그램 도입.',
#  '1. 주형보 주변에 명확한 안전 경계선 설치 및 경고 표시 강화.\n2. 작업자에게 주형보 위치 인지 및 주변 환경 주시 교육 강화.\n3. 정기적인 현장 안전 점검 실시 및 위험 요소 사전 제거.\n4. 개인 보호 장비(PPE) 착용 의무화 및 준수 여부 엄격히 관리.',
#  '1. 상수관 주변 안전 경계 설정 및 경고 표시 설치.\n2. 착공 전 노면 상태 점검 강화 및 필요시 임시 방수 처리 실시.\n3. 작업자 안전 교육 강화, 특히 미끄러운 표면 대처 방법 포함.',
#  '작업발판 미끄럼 방지 재질 적용 및 정기적인 점검 강화, 작업자에게 균형 유지 및 안전한 작업 자세 교육 실시.',
#  '보호장구 표준화 및 정기적인 점검 강화, 그라인더 작업 시 적합한 장갑 착용 의무화 실시.',
#  '트랜치 주변 안전 경계 설치 및 바닥 표시 강화로 인식 개선, 정기적인 안전 점검 실시.',
#  '정기적인 안전 교육 강화 및 실시간 작업 모니터링 시스템 도입, 철근 가공 장비에 자동 정지 기능 설치.',
#  '숏크리트 품질 강화 및 정기적인 막장면 점검 실시, 용출수 관리 시스템 개선.',
#  '정기적인 작업 공간 점검과 장애물 표시 강화, 그리고 운반자 대상의 시야 확보 교육 실시.',
#  '안전 의식 향상 교육 정기 실시 및 행동 기반 안전 프로그램 도입.',
#  '신호체계 표준화 및 정기적인 훈련 강화, 작업 전 신호 확인 절차 도입, 장비운전원과 작업원 간 실시간 통신 장비 제공.',
#  '적재함 내 및 주변 장애물 제거 철저히 하고, 안전 통로 확보 및 작업자 안전교육 강화 실시.',
#  '그라인더 사용 지침 엄격히 준수 교육 강화 및 작업 전 방향 확인 절차 도입.',
#  '작업 시 2인 1조 간 명확한 신호 체계 구축 및 안전 거리 유지 교육 강화. 또한, 석고보드 운반 장비 도입을 검토하고 정기적인 안전 훈련 실시.',
#  '장약 및 발파작업 시 덤프트럭 운행자에게 전문적인 운전 교육을 강화하고, 작업 영역 내 안전 거리 확보 및 통신 시스템 개선을 통해 실시간 상황 인지를 돕는다. 정기적인 재교육과 안전 점검을 실시한다.',
#  '마그네틱 코어드릴 고정 강화 및 안전 잠금 장치 설치, 작업 전 장비 상태 점검 의무화, 끼임 사고 예방을 위한 장비 조작 교육 강화 및 정기적 안전 훈련 실시.',
#  '안전교육 강화 및 안전장비 착용 강제화 실시, 정기적인 안전점검과 모니터링 시스템 도입.',
#  '작업장 바닥 미끄럼 방지 처리 강화 및 정기적인 안전 교육 실시를 통해 재발 방지. 덕트 주변 안전 경계 설치 및 위험 구역 표시를 확대하여 사고 위험 감소.',
#  '고임목 설치 자동화 시스템 도입 및 작업자에게 정밀한 고임목 조작 교육 실시. 정기적인 안전 점검과 지게차 운행 및 하역 작업 절차 표준화 강화.',
#  '정기적 위험성평가 실시, 작업 공간 확보 기준 강화, 반복적인 안전 훈련 및 평가를 통한 기술 향상, 그리고 감독 강화를 통해 재발 방지 대책을 마련하고, 위험성평가 의무화 및 공간 안전 점검 리스트 도입으로 향후 조치 계획을 실행합니다.',
#  '단차 제거 또는 안전 경계 설치, 정기적인 작업장 점검 및 안전 교육 강화 실시.',
#  '안전 발판 및 안전 그물 설치 확대, 정기적인 작업 환경 안전 점검 실시, 그리고 작업자 대상으로 고층 작업 안전 교육 프로그램 도입.',
#  '전원 차단 확인 절차 의무화 및 활선감지기, 절연보호구 사용 강제화. 정기적 안전 교육 강화와 작업 전 안전 점검 리스트 준수 감독 실시.',
#  '자재 안정화 시스템 도입 및 정기적인 점검 실시. 작업자 교육 강화로 불안정한 자재 배치 방지.',
#  '작업발판 안정성 강화 및 정기 점검 시스템 구축, 작업자 대상 안전 교육 강화와 함께 불안전 행동 예방 프로그램 도입.',
#  '계단 주변 조명 강화 및 안전 경고 표지판 설치, 정기적인 안전 교육 실시로 작업자 주의력 향상 도모.',
#  '빔 체결 강화 및 안정성 검사 절차 도입, 정기적인 장비 점검 및 근로자 안전 교육 강화 실시.',
#  '바닥면 평탄화 작업 실시와 함께 보행 중 지속적인 전방 주시 교육 강화 및 통행로 관리 체계 구축을 통한 재발 방지 대책 마련. 정기적인 안전 점검과 통행로 상태 개선 유지 계획 실행.',
#  '정기적인 안전 교육 강화 및 기계 조작 훈련 프로그램 도입. 철근 밴딩기 사용 전 점검 절차 표준화 및 준수 강화.',
#  '정기적인 안전 교육 강화와 개인 보호 장비(PPE) 착용 의무화를 통해 재발 방지. 또한, 작업 절차 표준화 및 실시간 안전 모니터링 시스템 도입을 계획합니다.',
#  '고소작업대 정기 점검 및 유지보수 강화, 안전 발판 및 안정장치 설치 의무화, 작업자 대상 안정성 확보 및 긴급상황 대처 훈련 실시.',
#  '고소작업대 발판 정기적인 안전 점검 및 유지보수 강화, 근로자 대상 안전 승하강 교육 의무화 및 준수도 평가 실시',
#  '난간대 시공 품질 강화를 위한 엄격한 사전 검사 도입 및 정기적 안전 점검 실시. 시공업체에 대한 품질 관리 교육 강화 및 부적합 사례에 대한 즉각적인 보수 계획 실행.',
#  '자상방지용 장갑 필수 착용 규정 강화 및 정기적 안전장비 점검 실시, 운반작업 관련 안전 교육 재실시.',
#  '안전 발판 설치 및 작업자에게 개인 보호 장비 착용 의무화 강화. 정기적인 안전 훈련 실시로 주의력 향상 도모.',
#  '소통 강화 훈련 실시 및 작업 전 명확한 역할 분담 설정, 실시간 통신 장비 사용 의무화를 통해 재발 방지. 정기적 안전 점검과 피드백 세션을 통해 지속적인 개선 도모.',
#  '전도 방지 장비의 표준화된 사용 의무화 및 정기적인 안전 교육 실시를 통해 재발 방지 대책을 마련하고, 작업 전 전도 위험 평가를 포함한 안전 점검 절차를 강화한다.',
#  '작업자에게 통로 안전 및 주의력 강화 교육 실시, 정기적인 통로 점검 및 장애물 제거 시스템 구축, 개인 보호 장비 착용 의무화 강화.',
#  '실족방지발판 설치 확대 및 작업자 안전교육 강화 실시. 정기적인 안전점검과 함께 작업 경로 안전 표시 강화.',
#  '작업자에게 상부 구조물 인식 교육 강화 및 현장 내 시각적 안전 표시 설치 확대 실시. 정기적 안전 점검과 함께, 위험 지역 접근 시 안내 시스템 도입.',
#  '갱폼 인양장비 정기적인 점검 및 유지보수 강화, 인양고리 품질 관리 엄격히 실시, 작업자 안전거리 확보 지침 강화 및 교육 실시.',
#  '정기적인 작업공간 점검과 부지정리 강화, 안전 교육 프로그램 확대 실시로 불안정한 작업 자세 개선.',
#  '정기적인 현장 점검 및 정리정돈 실시, 안전 교육 강화, 장애물 표시 및 제거 시스템 구축.',
#  '단부 안전난간대 설치 의무화 및 정기 점검 실시, 시스템비계 작업 시 안전벨트 착용 강제화와 함께 안전 교육 강화 실시.',
#  '작업 공간 정리정돈 의무화 및 정기적인 안전 점검 실시, 공구 보관 시스템 구축.',
#  '지붕 구조물 안정성 강화 및 정기적인 점검 실시, 작업자에게 지붕 작업 안전장비 사용 의무화 및 재교육 실시.',
#  '와이어로프 및 작업 영역 시각적 표시 강화, 정기적인 안전 교육 실시, 크레인 작업 전 철저한 점검 절차 도입.',
#  '정기적인 함마드릴 사용 교육 실시 및 실습 평가 강화, 안전 매뉴얼 배포 및 준수 감독 강화.',
#  '작업 중 불필요한 신체 접촉 금지 교육 강화 및 실시간 모니터링 시스템 도입으로 작업자 행동 감독.',
#  '작업구역 경계 설정 강화 및 되메우기 완료 확인 절차 도입, 정기적 안전점검 실시, 작업자에게 부주의 방지 교육 실시.',
#  '안전교육 강화와 함께 작업 절차 표준화 실시, 개인 보호장구 착용 의무화 및 정기적인 안전 점검 실시.',
#  '가공용 목재 고정 선반의 표준 사용 의무화 및 정기적인 점검 실시. 안전 교육 강화로 장비 올바른 사용법 숙지시키기.',
#  '1. 정기적인 안전 교육 강화 및 실습 포함.\n2. 작업 전 안전 점검 리스트 의무화.\n3. 개인 보호 장비(PPE) 착용 강제화 및 점검.\n4. 작업 영역 내 장애물 제거 및 통로 확보.\n5. 부주의 관련 사고 사례 공유 및 인식 제고 프로그램 운영.',
#  '해체 자재 즉시 정리 및 안전 구역 설정 강화. 정기적인 현장 점검 실시.',
#  '안전 교육 강화 및 라바콘 운반 경로의 안전한 경로 지정과 보호 장벽 설치를 통해 재발 방지 대책을 마련하고, 정기적인 안전 점검과 작업 전 경로 확인 절차를 도입합니다.',
#  '정기적인 휴식 시간 보장과 피로 관리 프로그램 도입으로 근로자 건강 유지 강화. 또한, 작업 주기별 집중력 향상 교육 실시.',
#  '믹서기 사용 후 반드시 전원 차단, 조적줄눈 작업자 대상 안전 교육 강화, 작업 전 안전 점검 리스트 도입, 믹서기 방호장치 설치, 현장 안전 감독관 지정 및 감독 강화',
#  '바닥에 비닐 사용을 제한하고, 정기적인 청소와 미끄럼 방지 매트 설치를 통해 안전한 작업 환경을 조성한다. 또한, 작업자들에게 미끄러운 표면을 인지하고 피하는 방법에 대한 교육을 강화한다.',
#  '자재 운반 경로 명확히 표시하고, 동바리 하부 구조물 주변에 안전 경계 설치. 정기적인 안전 교육 강화 및 현장 점검을 통한 위험 요소 사전 제거.',
#  '안전교육 강화 및 동출입구 주변의 바닥 미끄럼 방지 처리 개선 실시. 정기적인 안전 점검과 2단 핸드카 사용 지침 명확히 정립.',
#  '지반 안정화 작업 실시 및 정기적인 점검을 통해 미끄러짐 방지. 미끄럼 방지 매트 설치 확대 및 작업 구역 내 안전 통로 명확히 표시.',
#  '바닥면 평탄화 작업 우선 실시, 아스콘 작업 후 즉시 단차 점검 및 보수, 안전 부츠 착용 의무화 강화',
#  '작업 표준화 강화 및 정기적인 위험성 평가 실시, 작업자에게 지속적인 안전 교육 제공 및 작업 중 휴식 시간 보장.',
#  '물기 제거 및 미끄럼 방지 매트 설치, 정기적인 작업 현장 안전 점검 실시, 작업자에게 우천 후 안전 수칙 교육 강화.',
#  '안전 발판 및 미끄럼 방지 장비 제공 확대, 정기적인 작업 환경 안전 점검 실시, 미끄러짐 방지 교육 강화.',
#  '작업 중 의사소통 강화를 위해 명확한 신호 체계 도입 및 정기적인 커뮤니케이션 훈련 실시, 지게차 운전자와 작업자 간의 안전 확인 절차 표준화 및 준수 강화, 작업 전 모든 관련자에게 안전 점검 및 승인 절차 의무화.',
#  '가조립물 사용 강제화 및 정기적 안전 점검 실시, 철골 설치 절차 표준화 강화',
#  '원인 분석 팀 구성 및 상세 조사 실시, 표준 작업 절차(SOP) 재검토 및 개선, 정기적 안전 점검 강화 실시.',
#  '안전장비 착용 의무화와 함께 작업 전 간격 조정 절차 표준화 및 정기적인 안전 교육 실시.',
#  '작업 전 모든 변경사항에 대한 승인 절차 강화 및 정형 재단 장비 도입, 정기적인 안전 교육 실시.',
#  '원인 분석 완료 후 용접 작업 표준 절차 강화 및 정기적 안전 교육 실시, 개인 보호 장비(PPE) 사용 강제화, 작업 전 안전 점검 리스트 도입.',
#  '정기적인 안전 교육 강화와 함께 작업 전 위험 평가 실시, 부주의 방지를 위한 체크리스트 도입 및 준수 모니터링 시스템 구축.',
#  '거푸집 해체 전 안전 검토 절차 의무화, 작업자에게 높이별 낙하물 위험 인지 교육 강화, 보호구 착용 강제화 및 정기 점검 실시, 작업 구역에 안전 경계 설치 및 감독 강화.',
#  '정기적인 안전 교육 강화와 실시간 모니터링 시스템 도입을 통해 작업자의 주의력 향상 및 즉각적인 위험 감지를 실현합니다.',
#  '가설계단 사용 규정 준수 강화 및 정기적인 가설재 정리 및 점검 실시.',
#  '정기적인 안전 교육 강화와 현장 교통 관리 시스템 도입, 그리고 외부 교통 흐름과의 상호작용 최소화를 위한 작업 시간 조정 실시.',
#  '전원 차단 절차 엄격히 준수 및 작업 후 장비 안전 확인 교육 강화. 정기적 안전 점검 실시.',
#  '작업장 바닥의 미끄럼 방지 처리 강화 및 안전 통로 확보. 정기적인 안전 점검과 작업자 안전 교육 강화 실시.',
#  '1. **안전 장비 강화**: 모든 작업자에게 안전 부츠 및 보호대 착용 의무화.\n2. **작업 절차 개선**: 2인1조 작업 시 석재 고정 방법 표준화 및 정기적인 점검 실시.\n3. **교육 프로그램 확대**: 석재 운반 및 양중 안전 교육 강화, 실제 사례 공유를 통한 인식 제고.\n4. **정기적 안전 점검**: 운반 장비와 작업 환경에 대한 정기적 안전 점검 실시 및 개선 사항 즉시 적용.',
#  '장비 작업 반경 내 하중 관리 강화 및 최대 하중의 60% 이하로 제한, 크레인 운전자 대상 안전 교육 강화 및 실시간 모니터링 시스템 도입.',
#  '안전 발판 및 안전망 설치 강화, 정기적인 안전 교육 실시, 작업 전 안전 점검 리스트 의무화 및 준수 강화.',
#  'SRC 외부에서 석재절단작업을 수행하도록 절차 변경 및 안전장비 강화. 정기적인 안전점검 실시.',
#  '정기적인 안전 교육 실시와 함께 계단실 바닥의 미끄럼 방지 처리 강화, 작업 전후 철저한 청소 및 점검 실시.',
#  '안전발판의 정기적 점검 및 즉시 보수 시스템 구축, 작업자 대상 안전환경 인식 강화 교육 실시 및 개인 보호장비 착용 의무화 강화.',
#  '석재 품질 사전 검사 강화, 안전장비 착용 의무화, 파단 위험 석재 사용 제한 및 대체재 확보, 정기적인 안전 교육 실시.',
#  '작업 통로 명확히 표시하고 정기적인 안전 점검 실시. 근로자 대상 통로 안전 사용 교육 강화 및 통로 확보 준수 감독 강화.',
#  '안전 교육 강화 및 개인 보호 장비(PPE) 착용 의무화 실시. 믹서트럭 작업 영역을 명확히 구분하고 접근 제한 조치를 취함. 정기적인 안전 점검과 위험 평가 실시.',
#  '안전장갑 착용 의무화 및 깨진 자재 처리 전용 보호 장비 제공, 정기적인 안전 교육 실시.',
#  '방호덮개의 신속한 작동 확인 및 자동화 시스템 도입, 정기적인 장비 점검과 유지보수 강화, 절단작업자 대상 안전 교육 강화 실시.']

# %%
test_results[0]
# Out:
# '지반 안정성 강화를 위해 아웃트리거 설치 전 지반 조사 및 강화 조치 실시, 아웃트리거 길이 일치 조정 및 지반 고임목 추가 보강, 작업 위치 최적화 및 붐대 운용 범위 제한 설정, 정기적인 장비 안정성 점검 및 유지보수 강화, 펌프카 작업 교육 프로그램 강화로 무게중심 관리 및 비상상황 대처 훈련 포함, 사고 원인 분석 기반의 안전 지침 업데이트 및 준수 강제화 실시.'

# %%
from sentence_transformers import SentenceTransformer

embedding_model_name = "jhgan/ko-sbert-sts"
embedding = SentenceTransformer(embedding_model_name)

# 문장 리스트를 입력하여 임베딩 생성
pred_embeddings = embedding.encode(test_results)
print(pred_embeddings.shape)  # (샘플 개수, 768)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.44k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# (964, 768)

# %%
submission = pd.read_csv(data_path+"sample_submission.csv", encoding = 'utf-8-sig')
# 최종 결과 저장
submission.iloc[:,1] = test_results
submission.iloc[:,2:] = pred_embeddings
submission.head()
# 최종 결과를 CSV로 저장
submission.to_csv('submission-EXAONE-3.5-32B-Instruct.csv', index=False, encoding='utf-8-sig')
