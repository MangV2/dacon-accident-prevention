# %%
import pandas as pd

# %%
folder_path = r"C:\Users\minkyu\Desktop\test"

# %%
df = pd.read_csv(folder_path + "\\merged.csv")
test = pd.read_csv(folder_path + "\\test.csv")

# %%
df.columns
# Out:
# Index(['사고명', '발생일시', '사고인지 시간', '공공/민간 구분', '기상상태 - 날씨', '기상상태 - 기온',
#        '기상상태 - 습도', '시설물 종류 - 대분류', '시설물 종류 - 중분류', '시설물 종류 - 소분류', '인적사고',
#        '안전방호', '개인보호', '물적사고', '공종 - 대분류', '공종 - 중분류', '사고객체 - 대분류',
#        '사고객체 - 중분류', '작업프로세스', '사고 장소', '사고 부위', '사고경위', '사고원인', '구체적 사고원인',
#        '사망자수 : 내국인', '사망자수 : 외국인', '부상자수 : 내국인', '부상자수 : 외국인', '피해금액', '피해내용',
#        '사고신고사유', '사고발생후 조치사항', '재발방지대책', '시도', '군구', '공사종류 - 대분류',
#        '공사종류 - 중분류', '공사종류 - 소분류', '공사비', '낙찰률', '공사시작일', '공사종료일', '공정률',
#        '작업자수', '안전관리계획', '설계안전성검토', '해체계획서', '사고조사방법', '위원회조사필요성', '위원회구성(안)',
#        '향후조치계획'],
#       dtype='object')

# %%
df['구체적 사고원인']
# Out:
# 0                        장비 운전원 시야 미확보, 야간 작업으로 인한 조도 미확보
# 1                                  근로자 이동간 배근된 철근에 걸려 넘어짐
# 2       지층에서 2층으로 호이스트 이동 후 핸드카트를 들고 내부에서 내리던 중 발을 접지르...
# 3       철골 부재 산소 절단 작업 시 절단 방향(신체 외측 방향) 미 준수 및 적절한 개인...
# 4                                      내부 시설물 임의 훼손 및 부주의
#                               ...
# 6061    형틀목공(ㅇㅇㅇ)이 3층 벽체거푸집 해체작업을 하다가 거푸집이 떨어지면서 손가락을 ...
# 6062    철근 절곡기(가공기)를 사용 하여 철근 가공중 철근과 철근 사이에 왼손약지 손가락이...
# 6063                 작업 준비를 위하여 작업 전 자재 운반 중 손가락 끼임 사고 발생
# 6064    금속공사 작업 중 AL시트 마감재 설치를 위해 일부 절단 작업 과정에서 목장갑이 핸...
# 6065    노후 또는 자주 사용하지 기계기구(공도구/교반기) 사용 전 점검 미흡, 해당 근로자...
# Name: 구체적 사고원인, Length: 6066, dtype: object

# %%
test['사고원인']
# Out:
# 0      펌프카 아웃트리거 바닥 고임목을 3단으로 보강 했음에도, 지반 침하(아웃트리거 우측...
# 1                      작업자의 불안전한 행동(숫돌 측면 사용) 및 보안면 미 착용
# 2        작업자가 작업을 위해 이동 중 전방을 주시하지 않아 발을 헛디뎌 계단에서 굴러 넘어짐
# 3                                  작업 발판 위 벽돌 잔재를 밟고 넘어짐
# 4                       점심식사를 위한 이동시 작업자 부주의로 인한 추락사고 발생
#                              ...
# 959                               약한 석재가 자연 파단하여 늑골 골절 됨
# 960                             근로자가 작업 중 이동가능한 통로 확보 미흡
# 961        작업자가 믹서트럭 슈트아래로 불안전하게 이동하면서 콘크리트 통사이에 손가락이 끼임
# 962                  깨진타일을 손으로 주워 마대자루에 넣을려고 하던 중 파편이 박힘
# 963    2024년 11월 6일 9시경 재해자가 혼자 세대 천정 작업 중 각도 절단기를 이용...
# Name: 사고원인, Length: 964, dtype: object

# %%
for i in range(len(test)):
    # test의 '사고원인'과 일치하는 df의 행을 찾습니다.
    matched = df[df['구체적 사고원인'] == test.loc[i, '사고원인']]
    if not matched.empty:
        # 여러 행이 있을 경우 첫 번째 값을 사용합니다.
        test.loc[i, '재발방지대책'] = matched.iloc[0]['재발방지대책']
        test.loc[i, '향후조치계획'] = matched.iloc[0]['향후조치계획']

print(test)
# Out:
#            ID                 발생일시 사고인지 시간  날씨   기온   습도  \
# 0    TEST_000  2024-06-03 오전 09:39  정규작업 -  맑음  27℃  53%
# 1    TEST_001  2024-02-15 오전 09:00  정규작업 -  맑음   5℃  71%
# 2    TEST_002  2024-02-01 오전 09:30  작업 전 -  흐림   5℃  58%
# 3    TEST_003  2024-02-06 오후 05:00  정규작업 -  맑음   1℃  87%
# 4    TEST_004  2024-06-03 오전 11:35    기타 -  흐림  22℃  60%
# ..        ...                  ...     ...  ..  ...  ...
# 959  TEST_959  2024-01-31 오후 01:23  정규작업 -  맑음  10℃  50%
# 960  TEST_960  2024-08-23 오후 04:40  정규작업 -  맑음  33℃  50%
# 961  TEST_961  2024-12-27 오후 03:30  정규작업 -  맑음   1℃  26%
# 962  TEST_962  2024-08-20 오전 10:00    기타 -  맑음  33℃  65%
# 963  TEST_963  2024-11-06 오전 09:00  정규작업 -  맑음  17℃  70%
#
#                      공사종류          연면적           층 정보         인적사고 물적사고  \
# 0    건축 / 건축물 / 교정 및 군사시설    1,990.32㎡   지상 1층, 지하 0층          부딪힘   전도
# 1         건축 / 건축물 / 운수시설     349,895㎡   지상 5층, 지하 2층       절단, 베임   없음
# 2         건축 / 건축물 / 공동주택     171,198㎡  지상 27층, 지하 2층  떨어짐(2미터 미만)   없음
# 3         건축 / 건축물 / 공동주택  123,540.98㎡  지상 2층, 지하 35층  넘어짐(물체에 걸림)   없음
# 4          토목 / 교량 / 도로교량            -              -  떨어짐(2미터 미만)   없음
# ..                    ...          ...            ...          ...  ...
# 959     건축 / 건축물 / 근린생활시설   27,369.70㎡  지상 13층, 지하 4층          부딪힘   없음
# 960   토목 / 철도 / 일반 및 고속철도            -              -      넘어짐(기타)   없음
# 961       토목 / 상하수도 / 하수도            -              -           끼임   없음
# 962       건축 / 건축물 / 공동주택     654,878㎡  지상 49층, 지하 4층           기타   없음
# 963       건축 / 건축물 / 공동주택      21,765㎡  지상 23층, 지하 4층       절단, 베임   없음
#
#                 공종             사고객체 작업프로세스                      장소  \
# 0    건축 > 철근콘크리트공사    건설기계 > 콘크리트펌프   타설작업          교정 및 군사시설 / 외부
# 1        건축 > 수장공사       건설공구 > 공구류   절단작업               운수시설 / 내부
# 2        건축 > 미장공사          기타 > 기타     이동               공동주택 / 내부
# 3        건축 > 조적공사        건설자재 > 자재     기타  공동주택 / 102동 801호 세대 내부
# 4        토목 > 교량공사          기타 > 기타   해체작업               도로교량 / 외부
# ..             ...              ...    ...                     ...
# 959      건축 > 조적공사         시설물 > 건물   마감작업             근린생활시설 / 외부
# 960  토목 > 철근콘크리트공사        건설자재 > 철망   조립작업          일반 및 고속철도 / 내부
# 961       토목 > 관공사  건설기계 > 콘크리트믹서트럭   타설작업              하수도 / 인접주변
# 962  건축 > 타일 및 돌공사        건설자재 > 자재   청소작업               공동주택 / 내부
# 963      건축 > 수장공사       건설공구 > 공구류   절단작업               공동주택 / 내부
#
#                     부위                                               사고원인  \
# 0          콘크리트펌프 / 바닥  펌프카 아웃트리거 바닥 고임목을 3단으로 보강 했음에도, 지반 침하(아웃트리거 우측...
# 1         공구류 / 핸드그라인더                  작업자의 불안전한 행동(숫돌 측면 사용) 및 보안면 미 착용
# 2              기타 / 바닥    작업자가 작업을 위해 이동 중 전방을 주시하지 않아 발을 헛디뎌 계단에서 굴러 넘어짐
# 3    자재 / 말비계(H:720mm)                              작업 발판 위 벽돌 잔재를 밟고 넘어짐
# 4              기타 / 바닥                   점심식사를 위한 이동시 작업자 부주의로 인한 추락사고 발생
# ..                 ...                                                ...
# 959             건물 / 앞                             약한 석재가 자연 파단하여 늑골 골절 됨
# 960         철망 / 상부(위)                           근로자가 작업 중 이동가능한 통로 확보 미흡
# 961       콘크리트믹서트럭 / 뒤      작업자가 믹서트럭 슈트아래로 불안전하게 이동하면서 콘크리트 통사이에 손가락이 끼임
# 962            자재 / 바닥                깨진타일을 손으로 주워 마대자루에 넣을려고 하던 중 파편이 박힘
# 963           공구류 / 바닥  2024년 11월 6일 9시경 재해자가 혼자 세대 천정 작업 중 각도 절단기를 이용...
#
#                                                 재발방지대책  \
# 0    건설사고 발생 원인 분석 및 재발 방지대책 강구 지시 공문 하달 예정 : 건설사업관...
# 1                그라인더 작업시 숫돌 측면 사용 금지 및 작업 전 보안경 착용 철저
# 2          현장 내 이동 시 유의사항 주지 및 안전교육 실시와 계단실 내 조도 추가 확보
# 3                     해당 작업 관련 안전작업 절차 교육 및 관리 방안 수립 등
# 4                           근로자 교육 및 TBM활동 강화, 관리감독 철저
# ..                                                 ...
# 959  근로자 작업전 스트레칭/석재 운반시 석재 크랙유무 확인조치/안전보호구 착용철거/작업...
# 960  근로자가 작업 중 이동이 가능한 구간을 사전 확보하여 이동용 통로를 설치, 근로자 ...
# 961                            근로자 전체 안전교육 및 관리자 추가 배치
# 962  1) 폐기물을 빗자루 또는 헤라 등을 이용하여 찔림사고 방지\r\n2) 근로자 재발...
# 963               작업 전 전기기계, 기구 작동 상태 및 방호장치 등 일일점검 실시
#
#                                               향후조치계획
# 0    건설사고 발생 원인 및 재발 방지대책 강구 지시 공문 하달 : 건설사업관리단, 시공사
# 1                                   불안전한 행동에 대한 안전교육
# 2                       재발방지 교육실시 및 현장 내 안전시설물 점검 철저
# 3                                      현장 정리 및 직원 교육
# 4                   근로자 안전교육 철저 및 TBM 활동 강화, 관리감독 철저
# ..                                               ...
# 959                                  재발방지대책 이행 여부 확인
# 960                           산업재해조사표 작성 제출등 적법처리 실시
# 961                    근로자 및 건설기계 운전자 교육 및 관리자 추가 배치
# 962                  해당 공종 재발방지 대책 수립\r\n관련 사항 교육 실시
# 963                    내장 작업자 톱날 공도구 사용에 관한 안전 교육 실시
#
# [964 rows x 19 columns]

# %%
test

# %%
# test DataFrame을 CSV 파일로 저장 (한글이 깨지지 않도록 utf-8-sig 인코딩 사용)
test.to_csv('output.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd
df = pd.read_csv("C:/Users/minkyu/Desktop/test/output.csv")

# %%
df.head(3)
# Out:
#          ID                 발생일시 사고인지 시간  날씨   기온   습도                  공사종류  \
# 0  TEST_000  2024-06-03 오전 09:39  정규작업 -  맑음  27℃  53%  건축 / 건축물 / 교정 및 군사시설
# 1  TEST_001  2024-02-15 오전 09:00  정규작업 -  맑음   5℃  71%       건축 / 건축물 / 운수시설
# 2  TEST_002  2024-02-01 오전 09:30  작업 전 -  흐림   5℃  58%       건축 / 건축물 / 공동주택
#
#          연면적           층 정보         인적사고 물적사고             공종           사고객체  \
# 0  1,990.32㎡   지상 1층, 지하 0층          부딪힘   전도  건축 > 철근콘크리트공사  건설기계 > 콘크리트펌프
# 1   349,895㎡   지상 5층, 지하 2층       절단, 베임   없음      건축 > 수장공사     건설공구 > 공구류
# 2   171,198㎡  지상 27층, 지하 2층  떨어짐(2미터 미만)   없음      건축 > 미장공사        기타 > 기타
#
#   작업프로세스              장소            부위  \
# 0   타설작업  교정 및 군사시설 / 외부   콘크리트펌프 / 바닥
# 1   절단작업       운수시설 / 내부  공구류 / 핸드그라인더
# 2     이동       공동주택 / 내부       기타 / 바닥
#
#                                                 사고원인  \
# 0  펌프카 아웃트리거 바닥 고임목을 3단으로 보강 했음에도, 지반 침하(아웃트리거 우측...
# 1                  작업자의 불안전한 행동(숫돌 측면 사용) 및 보안면 미 착용
# 2    작업자가 작업을 위해 이동 중 전방을 주시하지 않아 발을 헛디뎌 계단에서 굴러 넘어짐
#
#                                               재발방지대책  \
# 0  건설사고 발생 원인 분석 및 재발 방지대책 강구 지시 공문 하달 예정 : 건설사업관...
# 1              그라인더 작업시 숫돌 측면 사용 금지 및 작업 전 보안경 착용 철저
# 2        현장 내 이동 시 유의사항 주지 및 안전교육 실시와 계단실 내 조도 추가 확보
#
#                                             향후조치계획
# 0  건설사고 발생 원인 및 재발 방지대책 강구 지시 공문 하달 : 건설사업관리단, 시공사
# 1                                 불안전한 행동에 대한 안전교육
# 2                     재발방지 교육실시 및 현장 내 안전시설물 점검 철저
