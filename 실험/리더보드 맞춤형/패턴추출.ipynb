# %%
import pandas as pd
import re
from prefixspan import PrefixSpan

# 1. 데이터 로딩
df = pd.read_csv("train.csv")
texts = df["재발방지대책 및 향후조치계획"].dropna().tolist()

# 2. 텍스트 전처리 및 토큰화 함수
def preprocess_text(text):
    # 특수문자 제거 (한글에 맞게 필요 시 추가 전처리)
    text = re.sub(r'[^\w\s]', '', text)
    # 공백 기준 토큰화
    tokens = text.split()
    return tokens

# 모든 텍스트를 토큰 리스트(시퀀스)로 변환
sequences = [preprocess_text(text) for text in texts]

# 3. PrefixSpan을 사용한 순차 패턴 추출
ps = PrefixSpan(sequences)

# 최소 지지도를 5번 이상 등장하는 패턴으로 설정 (데이터에 맞게 조정)
patterns = ps.frequent(minsup=230)

# 지지도 기준 내림차순 정렬 후 출력
for sup, pattern in sorted(patterns, key=lambda x: -x[0]):
    print(f"지지도: {sup}, 패턴: {pattern}")
# Out:
# 지지도: 15388, 패턴: ['및']
# 지지도: 8373, 패턴: ['안전교육']
# 지지도: 8342, 패턴: ['재발']
# 지지도: 8273, 패턴: ['방지']
# 지지도: 7950, 패턴: ['통한']
# 지지도: 7700, 패턴: ['실시']
# 지지도: 7493, 패턴: ['재발', '방지']
# 지지도: 7308, 패턴: ['작업']
# 지지도: 6624, 패턴: ['교육']
# 지지도: 5916, 패턴: ['시']
# 지지도: 5623, 패턴: ['조치']
# 지지도: 5339, 패턴: ['대책']
# 지지도: 5026, 패턴: ['방지', '대책']
# 지지도: 4954, 패턴: ['재발', '대책']
# 지지도: 4911, 패턴: ['재발', '방지', '대책']
# 지지도: 4896, 패턴: ['통한', '방지']
# 지지도: 4563, 패턴: ['작업', '및']
# 지지도: 4561, 패턴: ['통한', '재발']
# 지지도: 4484, 패턴: ['통한', '재발', '방지']
# 지지도: 4376, 패턴: ['근로자']
# 지지도: 4332, 패턴: ['계획']
# 지지도: 4223, 패턴: ['및', '실시']
# 지지도: 4179, 패턴: ['및', '및']
# 지지도: 4150, 패턴: ['안전교육', '및']
# 지지도: 4111, 패턴: ['철저']
# 지지도: 4027, 패턴: ['작업자']
# 지지도: 3962, 패턴: ['실시와']
# 지지도: 3958, 패턴: ['현장']
# 지지도: 3787, 패턴: ['전']
# 지지도: 3774, 패턴: ['대한']
# 지지도: 3721, 패턴: ['및', '방지']
# 지지도: 3664, 패턴: ['및', '통한']
# 지지도: 3637, 패턴: ['및', '조치']
# 지지도: 3605, 패턴: ['향후']
# 지지도: 3598, 패턴: ['통한', '대책']
# 지지도: 3573, 패턴: ['및', '재발']
# 지지도: 3561, 패턴: ['조치', '계획']
# 지지도: 3544, 패턴: ['통한', '방지', '대책']
# 지지도: 3491, 패턴: ['시', '및']
# 지지도: 3470, 패턴: ['통한', '재발', '대책']
# 지지도: 3466, 패턴: ['통한', '재발', '방지', '대책']
# 지지도: 3317, 패턴: ['및', '재발', '방지']
# 지지도: 3315, 패턴: ['및', '교육']
# 지지도: 3270, 패턴: ['향후', '조치']
# 지지도: 3265, 패턴: ['위한']
# 지지도: 3180, 패턴: ['교육', '및']
# 지지도: 3102, 패턴: ['실시', '및']
# 지지도: 3051, 패턴: ['안전교육', '통한']
# 지지도: 3040, 패턴: ['방지', '조치']
# 지지도: 3033, 패턴: ['작업', '전']
# 지지도: 3032, 패턴: ['안전교육', '실시']
# 지지도: 3021, 패턴: ['교육', '실시']
# 지지도: 3008, 패턴: ['향후', '계획']
# 지지도: 2992, 패턴: ['재발', '조치']
# 지지도: 2983, 패턴: ['안전교육', '방지']
# 지지도: 2940, 패턴: ['향후', '조치', '계획']
# 지지도: 2937, 패턴: ['및', '계획']
# 지지도: 2901, 패턴: ['확인']
# 지지도: 2877, 패턴: ['재발', '방지', '조치']
# 지지도: 2864, 패턴: ['및', '작업']
# 지지도: 2856, 패턴: ['안전교육', '재발']
# 지지도: 2843, 패턴: ['안전']
# 지지도: 2805, 패턴: ['재발', '계획']
# 지지도: 2783, 패턴: ['재발', '향후']
# 지지도: 2779, 패턴: ['방지', '향후']
# 지지도: 2767, 패턴: ['안전교육', '재발', '방지']
# 지지도: 2765, 패턴: ['방지', '계획']
# 지지도: 2746, 패턴: ['재발', '방지', '향후']
# 지지도: 2725, 패턴: ['재발', '향후', '조치']
# 지지도: 2722, 패턴: ['및', '안전교육']
# 지지도: 2720, 패턴: ['방지', '향후', '조치']
# 지지도: 2705, 패턴: ['재발', '방지', '계획']
# 지지도: 2698, 패턴: ['재발', '방지', '향후', '조치']
# 지지도: 2698, 패턴: ['작업', '실시']
# 지지도: 2608, 패턴: ['후']
# 지지도: 2601, 패턴: ['재발', '조치', '계획']
# 지지도: 2600, 패턴: ['작업', '시']
# 지지도: 2583, 패턴: ['방지', '조치', '계획']
# 지지도: 2562, 패턴: ['전', '및']
# 지지도: 2545, 패턴: ['재발', '방지', '조치', '계획']
# 지지도: 2545, 패턴: ['방지', '향후', '계획']
# 지지도: 2541, 패턴: ['재발', '향후', '계획']
# 지지도: 2529, 패턴: ['사고']
# 지지도: 2523, 패턴: ['재발', '방지', '향후', '계획']
# 지지도: 2523, 패턴: ['방지', '향후', '조치', '계획']
# 지지도: 2519, 패턴: ['재발', '향후', '조치', '계획']
# 지지도: 2503, 패턴: ['재발', '방지', '향후', '조치', '계획']
# 지지도: 2454, 패턴: ['근로자', '및']
# 지지도: 2453, 패턴: ['통한', '및']
# 지지도: 2449, 패턴: ['및', '조치', '계획']
# 지지도: 2434, 패턴: ['및', '향후']
# 지지도: 2342, 패턴: ['재발', '및']
# 지지도: 2340, 패턴: ['관리']
# 지지도: 2335, 패턴: ['및', '철저']
# 지지도: 2329, 패턴: ['및', '대책']
# 지지도: 2230, 패턴: ['및', '향후', '조치']
# 지지도: 2196, 패턴: ['방지', '및']
# 지지도: 2166, 패턴: ['안전교육', '통한', '방지']
# 지지도: 2155, 패턴: ['안전교육', '대책']
# 지지도: 2154, 패턴: ['작업', '작업']
# 지지도: 2121, 패턴: ['및', '향후', '계획']
# 지지도: 2102, 패턴: ['안전교육', '방지', '대책']
# 지지도: 2090, 패턴: ['및', '방지', '대책']
# 지지도: 2081, 패턴: ['작업자', '및']
# 지지도: 2079, 패턴: ['및', '향후', '조치', '계획']
# 지지도: 2079, 패턴: ['및', '시']
# 지지도: 2062, 패턴: ['및', '재발', '대책']
# 지지도: 2059, 패턴: ['안전교육', '재발', '대책']
# 지지도: 2056, 패턴: ['안전교육', '재발', '방지', '대책']
# 지지도: 2048, 패턴: ['작업', '교육']
# 지지도: 2042, 패턴: ['안전교육', '통한', '재발']
# 지지도: 2037, 패턴: ['및', '재발', '방지', '대책']
# 지지도: 2034, 패턴: ['통한', '조치']
# 지지도: 2034, 패턴: ['작업', '전', '및']
# 지지도: 2032, 패턴: ['및', '통한', '방지']
# 지지도: 2020, 패턴: ['안전교육', '통한', '재발', '방지']
# 지지도: 2001, 패턴: ['강화']
# 지지도: 1977, 패턴: ['시', '실시']
# 지지도: 1949, 패턴: ['작업', '통한']
# 지지도: 1939, 패턴: ['재발', '방지', '및']
# 지지도: 1931, 패턴: ['현장', '및']
# 지지도: 1904, 패턴: ['및', '현장']
# 지지도: 1870, 패턴: ['및', '통한', '재발']
# 지지도: 1862, 패턴: ['작업', '방지']
# 지지도: 1855, 패턴: ['점검']
# 지지도: 1831, 패턴: ['및', '통한', '재발', '방지']
# 지지도: 1819, 패턴: ['작업자', '안전교육']
# 지지도: 1810, 패턴: ['통한', '계획']
# 지지도: 1809, 패턴: ['안전관리']
# 지지도: 1798, 패턴: ['안전교육', '조치']
# 지지도: 1791, 패턴: ['시', '작업']
# 지지도: 1772, 패턴: ['작업', '재발']
# 지지도: 1733, 패턴: ['및', '대한']
# 지지도: 1730, 패턴: ['작업', '안전교육']
# 지지도: 1725, 패턴: ['설치']
# 지지도: 1724, 패턴: ['시', '교육']
# 지지도: 1719, 패턴: ['실시를']
# 지지도: 1706, 패턴: ['실시와', '및']
# 지지도: 1695, 패턴: ['교육', '방지']
# 지지도: 1689, 패턴: ['근로자', '실시']
# 지지도: 1681, 패턴: ['안전교육', '통한', '대책']
# 지지도: 1677, 패턴: ['및', '교육', '실시']
# 지지도: 1677, 패턴: ['및', '확인']
# 지지도: 1671, 패턴: ['안전교육', '통한', '방지', '대책']
# 지지도: 1659, 패턴: ['교육', '통한']
# 지지도: 1652, 패턴: ['안전교육', '실시와']
# 지지도: 1650, 패턴: ['통한', '향후']
# 지지도: 1649, 패턴: ['대책과']
# 지지도: 1645, 패턴: ['및', '근로자']
# 지지도: 1637, 패턴: ['안전교육', '통한', '재발', '대책']
# 지지도: 1636, 패턴: ['안전교육', '통한', '재발', '방지', '대책']
# 지지도: 1634, 패턴: ['안전교육', '철저']
# 지지도: 1634, 패턴: ['위한', '및']
# 지지도: 1629, 패턴: ['작업', '재발', '방지']
# 지지도: 1625, 패턴: ['방지를']
# 지지도: 1623, 패턴: ['방지', '대책과']
# 지지도: 1623, 패턴: ['통한', '조치', '계획']
# 지지도: 1618, 패턴: ['교육', '재발']
# 지지도: 1616, 패턴: ['재발', '방지', '대책과']
# 지지도: 1616, 패턴: ['재발', '대책과']
# 지지도: 1599, 패턴: ['방지를', '위한']
# 지지도: 1590, 패턴: ['실시를', '통한']
# 지지도: 1573, 패턴: ['대책과', '조치']
# 지지도: 1572, 패턴: ['통한', '향후', '조치']
# 지지도: 1565, 패턴: ['전', '실시']
# 지지도: 1564, 패턴: ['대책과', '향후']
# 지지도: 1557, 패턴: ['확인', '및']
# 지지도: 1553, 패턴: ['방지', '대책과', '향후']
# 지지도: 1553, 패턴: ['통한', '향후', '계획']
# 지지도: 1551, 패턴: ['안전교육', '계획']
# 지지도: 1549, 패턴: ['재발', '방지', '대책과', '향후']
# 지지도: 1549, 패턴: ['재발', '대책과', '향후']
# 지지도: 1548, 패턴: ['방지', '대책과', '조치']
# 지지도: 1546, 패턴: ['대책과', '향후', '조치']
# 지지도: 1545, 패턴: ['재발', '방지', '대책과', '조치']
# 지지도: 1545, 패턴: ['재발', '대책과', '조치']
# 지지도: 1541, 패턴: ['작업', '시', '및']
# 지지도: 1536, 패턴: ['방지', '대책과', '향후', '조치']
# 지지도: 1533, 패턴: ['재발', '방지', '대책과', '향후', '조치']
# 지지도: 1533, 패턴: ['재발', '대책과', '향후', '조치']
# 지지도: 1533, 패턴: ['근로자', '안전교육']
# 지지도: 1530, 패턴: ['교육', '재발', '방지']
# 지지도: 1528, 패턴: ['통한', '향후', '조치', '계획']
# 지지도: 1522, 패턴: ['대책', '및']
# 지지도: 1521, 패턴: ['및', '안전']
# 지지도: 1521, 패턴: ['대한', '및']
# 지지도: 1520, 패턴: ['착용']
# 지지도: 1509, 패턴: ['실시와', '통한']
# 지지도: 1507, 패턴: ['및', '관리']
# 지지도: 1501, 패턴: ['전파']
# 지지도: 1489, 패턴: ['철저', '및']
# 지지도: 1482, 패턴: ['작업자', '방지']
# 지지도: 1473, 패턴: ['통한', '방지', '조치']
# 지지도: 1459, 패턴: ['실시와', '방지']
# 지지도: 1459, 패턴: ['대책과', '계획']
# 지지도: 1448, 패턴: ['작업', '조치']
# 지지도: 1446, 패턴: ['안전', '교육']
# 지지도: 1445, 패턴: ['시', '방지']
# 지지도: 1439, 패턴: ['통한', '방지', '계획']
# 지지도: 1436, 패턴: ['안전사고']
# 지지도: 1434, 패턴: ['방지', '대책과', '계획']
# 지지도: 1431, 패턴: ['재발', '방지', '대책과', '계획']
# 지지도: 1431, 패턴: ['재발', '대책과', '계획']
# 지지도: 1431, 패턴: ['작업자', '재발']
# 지지도: 1428, 패턴: ['대책과', '조치', '계획']
# 지지도: 1426, 패턴: ['근로자', '교육']
# 지지도: 1421, 패턴: ['통한', '재발', '조치']
# 지지도: 1419, 패턴: ['대책과', '향후', '계획']
# 지지도: 1418, 패턴: ['통한', '재발', '계획']
# 지지도: 1413, 패턴: ['방지', '대책', '및']
# 지지도: 1412, 패턴: ['재발', '대책', '및']
# 지지도: 1411, 패턴: ['실시와', '재발']
# 지지도: 1411, 패턴: ['마련']
# 지지도: 1409, 패턴: ['방지', '대책과', '향후', '계획']
# 지지도: 1409, 패턴: ['통한', '재발', '방지', '조치']
# 지지도: 1408, 패턴: ['통한', '재발', '방지', '계획']
# 지지도: 1407, 패턴: ['대책과', '향후', '조치', '계획']
# 지지도: 1406, 패턴: ['재발', '방지', '대책과', '향후', '계획']
# 지지도: 1406, 패턴: ['재발', '대책과', '향후', '계획']
# 지지도: 1404, 패턴: ['방지', '대책과', '조치', '계획']
# 지지도: 1401, 패턴: ['재발', '방지', '대책과', '조치', '계획']
# 지지도: 1401, 패턴: ['재발', '대책과', '조치', '계획']
# 지지도: 1398, 패턴: ['방지', '대책과', '향후', '조치', '계획']
# 지지도: 1395, 패턴: ['재발', '방지', '대책과', '향후', '조치', '계획']
# 지지도: 1395, 패턴: ['재발', '대책과', '향후', '조치', '계획']
# 지지도: 1393, 패턴: ['재발', '방지', '대책', '및']
# 지지도: 1383, 패턴: ['통한', '방지', '향후']
# 지지도: 1382, 패턴: ['작업자', '통한']
# 지지도: 1376, 패턴: ['재발', '및', '조치']
# 지지도: 1376, 패턴: ['통한', '재발', '향후']
# 지지도: 1375, 패턴: ['작업자', '재발', '방지']
# 지지도: 1374, 패턴: ['작업', '및', '실시']
# 지지도: 1372, 패턴: ['통한', '재발', '방지', '향후']
# 지지도: 1369, 패턴: ['방지', '및', '조치']
# 지지도: 1362, 패턴: ['작업', '철저']
# 지지도: 1354, 패턴: ['통한', '방지', '향후', '조치']
# 지지도: 1353, 패턴: ['시', '통한']
# 지지도: 1352, 패턴: ['통한', '방지', '조치', '계획']
# 지지도: 1349, 패턴: ['및', '후']
# 지지도: 1348, 패턴: ['시', '재발']
# 지지도: 1347, 패턴: ['통한', '재발', '향후', '조치']
# 지지도: 1346, 패턴: ['통한', '방지', '향후', '계획']
# 지지도: 1346, 패턴: ['실시와', '재발', '방지']
# 지지도: 1345, 패턴: ['통한', '재발', '방지', '향후', '조치']
# 지지도: 1343, 패턴: ['통한', '재발', '조치', '계획']
# 지지도: 1343, 패턴: ['작업', '및', '및']
# 지지도: 1338, 패턴: ['통한', '재발', '향후', '계획']
# 지지도: 1336, 패턴: ['통한', '재발', '방지', '향후', '계획']
# 지지도: 1335, 패턴: ['통한', '재발', '방지', '조치', '계획']
# 지지도: 1334, 패턴: ['재발', '및', '계획']
# 지지도: 1330, 패턴: ['통한', '방지', '향후', '조치', '계획']
# 지지도: 1329, 패턴: ['방지', '및', '계획']
# 지지도: 1325, 패턴: ['재발', '방지', '및', '조치']
# 지지도: 1324, 패턴: ['안전교육', '조치', '계획']
# 지지도: 1323, 패턴: ['및', '통한', '대책']
# 지지도: 1322, 패턴: ['통한', '재발', '향후', '조치', '계획']
# 지지도: 1321, 패턴: ['통한', '재발', '방지', '향후', '조치', '계획']
# 지지도: 1312, 패턴: ['방지', '및', '향후']
# 지지도: 1308, 패턴: ['재발', '및', '향후']
# 지지도: 1305, 패턴: ['근로자', '통한']
# 지지도: 1296, 패턴: ['자재']
# 지지도: 1294, 패턴: ['재발', '방지', '및', '계획']
# 지지도: 1293, 패턴: ['안전교육', '향후']
# 지지도: 1292, 패턴: ['위한', '실시']
# 지지도: 1289, 패턴: ['및', '통한', '방지', '대책']
# 지지도: 1287, 패턴: ['재발', '방지', '및', '향후']
# 지지도: 1277, 패턴: ['대책', '마련']
# 지지도: 1275, 패턴: ['재발', '및', '향후', '조치']
# 지지도: 1275, 패턴: ['방지', '및', '향후', '조치']
# 지지도: 1274, 패턴: ['실시를', '방지']
# 지지도: 1272, 패턴: ['및', '작업', '및']
# 지지도: 1260, 패턴: ['및', '통한', '재발', '대책']
# 지지도: 1259, 패턴: ['재발', '방지', '및', '향후', '조치']
# 지지도: 1258, 패턴: ['및', '통한', '재발', '방지', '대책']
# 지지도: 1253, 패턴: ['및', '실시와']
# 지지도: 1251, 패턴: ['방지', '마련']
# 지지도: 1246, 패턴: ['재발', '및', '조치', '계획']
# 지지도: 1246, 패턴: ['방지', '및', '조치', '계획']
# 지지도: 1244, 패턴: ['재발', '마련']
# 지지도: 1240, 패턴: ['시', '재발', '방지']
# 지지도: 1239, 패턴: ['근로자', '방지']
# 지지도: 1238, 패턴: ['방지', '대책', '마련']
# 지지도: 1236, 패턴: ['작업', '확인']
# 지지도: 1233, 패턴: ['방지', '및', '향후', '계획']
# 지지도: 1233, 패턴: ['작업', '전', '실시']
# 지지도: 1232, 패턴: ['및', '사고']
# 지지도: 1231, 패턴: ['시', '조치']
# 지지도: 1228, 패턴: ['재발', '방지', '마련']
# 지지도: 1226, 패턴: ['재발', '대책', '마련']
# 지지도: 1226, 패턴: ['재발', '및', '향후', '계획']
# 지지도: 1226, 패턴: ['대한', '재발']
# 지지도: 1225, 패턴: ['재발', '방지', '및', '조치', '계획']
# 지지도: 1223, 패턴: ['대한', '방지']
# 지지도: 1223, 패턴: ['실시를', '통한', '방지']
# 지지도: 1222, 패턴: ['방지', '및', '향후', '조치', '계획']
# 지지도: 1217, 패턴: ['재발', '방지', '대책', '마련']
# 지지도: 1217, 패턴: ['안전교육', '향후', '조치']
# 지지도: 1217, 패턴: ['및', '안전교육', '실시']
# 지지도: 1216, 패턴: ['재발', '방지', '및', '향후', '계획']
# 지지도: 1216, 패턴: ['재발', '및', '향후', '조치', '계획']
# 지지도: 1214, 패턴: ['사용']
# 지지도: 1211, 패턴: ['실시를', '재발']
# 지지도: 1207, 패턴: ['재발', '방지', '및', '향후', '조치', '계획']
# 지지도: 1207, 패턴: ['실시와', '대책']
# 지지도: 1203, 패턴: ['통한', '방지', '및']
# 지지도: 1203, 패턴: ['대한', '실시']
# 지지도: 1203, 패턴: ['실시를', '재발', '방지']
# 지지도: 1202, 패턴: ['실시', '실시']
# 지지도: 1202, 패턴: ['내']
# 지지도: 1196, 패턴: ['안전교육', '실시', '및']
# 지지도: 1194, 패턴: ['작업', '대책']
# 지지도: 1191, 패턴: ['발생']
# 지지도: 1189, 패턴: ['작업', '작업', '및']
# 지지도: 1188, 패턴: ['근로자', '재발']
# 지지도: 1183, 패턴: ['TBM']
# 지지도: 1180, 패턴: ['안전', '및']
# 지지도: 1177, 패턴: ['안전교육', '향후', '계획']
# 지지도: 1177, 패턴: ['및', '위한']
# 지지도: 1173, 패턴: ['통한', '재발', '및']
# 지지도: 1168, 패턴: ['교육', '대책']
# 지지도: 1166, 패턴: ['사고사례']
# 지지도: 1163, 패턴: ['통한', '마련']
# 지지도: 1160, 패턴: ['실시를', '통한', '재발']
# 지지도: 1158, 패턴: ['대한', '재발', '방지']
# 지지도: 1157, 패턴: ['안전교육', '향후', '조치', '계획']
# 지지도: 1157, 패턴: ['및', '강화']
# 지지도: 1157, 패턴: ['전', '교육']
# 지지도: 1156, 패턴: ['대책', '조치']
# 지지도: 1154, 패턴: ['실시와', '방지', '대책']
# 지지도: 1154, 패턴: ['사고', '및']
# 지지도: 1153, 패턴: ['실시를', '통한', '재발', '방지']
# 지지도: 1152, 패턴: ['전', '안전교육']
# 지지도: 1151, 패턴: ['대한', '조치']
# 지지도: 1151, 패턴: ['실시와', '재발', '대책']
# 지지도: 1150, 패턴: ['안전교육', '및', '조치']
# 지지도: 1150, 패턴: ['및', '및', '실시']
# 지지도: 1145, 패턴: ['통한', '재발', '방지', '및']
# 지지도: 1144, 패턴: ['작업자', '실시']
# 지지도: 1142, 패턴: ['실시와', '재발', '방지', '대책']
# 지지도: 1140, 패턴: ['대책', '계획']
# 지지도: 1139, 패턴: ['방지', '대책', '조치']
# 지지도: 1139, 패턴: ['및', '및', '및']
# 지지도: 1139, 패턴: ['작업', '및', '작업']
# 지지도: 1136, 패턴: ['통한', '대책', '마련']
# 지지도: 1135, 패턴: ['전', '통한']
# 지지도: 1132, 패턴: ['재발', '대책', '조치']
# 지지도: 1132, 패턴: ['및', '교육', '및']
# 지지도: 1130, 패턴: ['재발', '방지', '대책', '조치']
# 지지도: 1129, 패턴: ['교육', '실시와']
# 지지도: 1128, 패턴: ['철저와']
# 지지도: 1126, 패턴: ['및', '점검']
# 지지도: 1125, 패턴: ['대책', '향후']
# 지지도: 1125, 패턴: ['통한', '방지', '마련']
# 지지도: 1124, 패턴: ['통한', '방지', '대책', '마련']
# 지지도: 1122, 패턴: ['설치', '및']
# 지지도: 1121, 패턴: ['시행']
# 지지도: 1120, 패턴: ['방지', '대책', '계획']
# 지지도: 1120, 패턴: ['근로자', '재발', '방지']
# 지지도: 1119, 패턴: ['실시', '작업']
# 지지도: 1116, 패턴: ['및', '실시', '및']
# 지지도: 1116, 패턴: ['작업', '및', '교육']
# 지지도: 1115, 패턴: ['작업', '실시', '및']
# 지지도: 1114, 패턴: ['재발', '대책', '계획']
# 지지도: 1111, 패턴: ['재발', '방지', '대책', '계획']
# 지지도: 1111, 패턴: ['방지', '대책', '향후']
# 지지도: 1110, 패턴: ['통한', '재발', '마련']
# 지지도: 1108, 패턴: ['대책', '및', '조치']
# 지지도: 1108, 패턴: ['통한', '재발', '방지', '마련']
# 지지도: 1108, 패턴: ['통한', '재발', '대책', '마련']
# 지지도: 1108, 패턴: ['교육', '철저']
# 지지도: 1108, 패턴: ['작업자', '교육']
# 지지도: 1107, 패턴: ['통한', '재발', '방지', '대책', '마련']
# 지지도: 1106, 패턴: ['작업', '방지', '대책']
# 지지도: 1104, 패턴: ['재발', '방지', '대책', '향후']
# 지지도: 1104, 패턴: ['재발', '대책', '향후']
# 지지도: 1103, 패턴: ['통한', '및', '조치']
# 지지도: 1103, 패턴: ['후', '및']
# 지지도: 1103, 패턴: ['작업자', '대책']
# 지지도: 1102, 패턴: ['대책', '향후', '조치']
# 지지도: 1097, 패턴: ['대책', '및', '향후']
# 지지도: 1096, 패턴: ['방지', '대책', '및', '조치']
# 지지도: 1096, 패턴: ['전파', '및']
# 지지도: 1093, 패턴: ['재발', '대책', '및', '조치']
# 지지도: 1093, 패턴: ['방지', '대책', '향후', '조치']
# 지지도: 1093, 패턴: ['대책', '및', '계획']
# 지지도: 1091, 패턴: ['재발', '방지', '대책', '및', '조치']
# 지지도: 1090, 패턴: ['시', '안전교육']
# 지지도: 1087, 패턴: ['방지', '대책', '및', '향후']
# 지지도: 1086, 패턴: ['재발', '방지', '대책', '향후', '조치']
# 지지도: 1086, 패턴: ['재발', '대책', '향후', '조치']
# 지지도: 1086, 패턴: ['및', '전']
# 지지도: 1083, 패턴: ['재발', '방지', '대책', '및', '향후']
# 지지도: 1083, 패턴: ['재발', '대책', '및', '향후']
# 지지도: 1083, 패턴: ['통한', '및', '계획']
# 지지도: 1083, 패턴: ['작업', '재발', '대책']
# 지지도: 1083, 패턴: ['교육', '방지', '대책']
# 지지도: 1082, 패턴: ['방지', '대책', '및', '계획']
# 지지도: 1079, 패턴: ['재발', '대책', '및', '계획']
# 지지도: 1078, 패턴: ['대책', '조치', '계획']
# 지지도: 1077, 패턴: ['재발', '방지', '대책', '및', '계획']
# 지지도: 1076, 패턴: ['대책', '및', '향후', '조치']
# 지지도: 1076, 패턴: ['현장', '통한']
# 지지도: 1073, 패턴: ['작업', '교육', '실시']
# 지지도: 1072, 패턴: ['대책', '향후', '계획']
# 지지도: 1072, 패턴: ['안전교육', '방지', '조치']
# 지지도: 1071, 패턴: ['교육', '재발', '대책']
# 지지도: 1070, 패턴: ['방지', '대책', '및', '향후', '조치']
# 지지도: 1070, 패턴: ['작업', '재발', '방지', '대책']
# 지지도: 1067, 패턴: ['방지', '대책', '조치', '계획']
# 지지도: 1066, 패턴: ['재발', '방지', '대책', '및', '향후', '조치']
# 지지도: 1066, 패턴: ['재발', '대책', '및', '향후', '조치']
# 지지도: 1064, 패턴: ['대책', '향후', '조치', '계획']
# 지지도: 1064, 패턴: ['교육', '조치']
# 지지도: 1063, 패턴: ['방지', '대책', '향후', '계획']
# 지지도: 1063, 패턴: ['작업', '계획']
# 지지도: 1061, 패턴: ['교육', '재발', '방지', '대책']
# 지지도: 1061, 패턴: ['작업자', '방지', '대책']
# 지지도: 1060, 패턴: ['재발', '대책', '조치', '계획']
# 지지도: 1059, 패턴: ['재발', '방지', '대책', '조치', '계획']
# 지지도: 1058, 패턴: ['특별안전교육']
# 지지도: 1056, 패턴: ['재발', '방지', '대책', '향후', '계획']
# 지지도: 1056, 패턴: ['재발', '대책', '향후', '계획']
# 지지도: 1056, 패턴: ['방지', '대책', '향후', '조치', '계획']
# 지지도: 1056, 패턴: ['작업', '안전']
# 지지도: 1056, 패턴: ['교육', '교육']
# 지지도: 1054, 패턴: ['시', '및', '및']
# 지지도: 1054, 패턴: ['전', '작업']
# 지지도: 1051, 패턴: ['대책', '및', '조치', '계획']
# 지지도: 1050, 패턴: ['안전교육', '재발', '조치']
# 지지도: 1050, 패턴: ['및', '작업자']
# 지지도: 1049, 패턴: ['재발', '방지', '대책', '향후', '조치', '계획']
# 지지도: 1049, 패턴: ['재발', '대책', '향후', '조치', '계획']
# 지지도: 1048, 패턴: ['대책', '및', '향후', '계획']
# 지지도: 1044, 패턴: ['방지', '대책', '및', '조치', '계획']
# 지지도: 1044, 패턴: ['작업', '현장']
# 지지도: 1044, 패턴: ['작업', '근로자']
# 지지도: 1043, 패턴: ['작업자', '재발', '대책']
# 지지도: 1042, 패턴: ['방지', '대책', '및', '향후', '계획']
# 지지도: 1041, 패턴: ['대책', '및', '향후', '조치', '계획']
# 지지도: 1040, 패턴: ['재발', '대책', '및', '조치', '계획']
# 지지도: 1039, 패턴: ['재발', '방지', '대책', '및', '조치', '계획']
# 지지도: 1039, 패턴: ['작업자', '재발', '방지', '대책']
# 지지도: 1038, 패턴: ['시', '및', '실시']
# 지지도: 1038, 패턴: ['재발', '방지', '대책', '및', '향후', '계획']
# 지지도: 1038, 패턴: ['재발', '대책', '및', '향후', '계획']
# 지지도: 1038, 패턴: ['안전교육', '재발', '방지', '조치']
# 지지도: 1036, 패턴: ['방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 1035, 패턴: ['안전교육', '방지', '계획']
# 지지도: 1035, 패턴: ['및', '작업', '실시']
# 지지도: 1032, 패턴: ['재발', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 1032, 패턴: ['재발', '대책', '및', '향후', '조치', '계획']
# 지지도: 1032, 패턴: ['안전교육', '재발', '계획']
# 지지도: 1032, 패턴: ['현장', '방지']
# 지지도: 1028, 패턴: ['수립']
# 지지도: 1026, 패턴: ['예방']
# 지지도: 1024, 패턴: ['대한', '계획']
# 지지도: 1023, 패턴: ['안전교육', '재발', '방지', '계획']
# 지지도: 1020, 패턴: ['교육', '통한', '방지']
# 지지도: 1019, 패턴: ['시', '철저']
# 지지도: 1019, 패턴: ['실시', '방지']
# 지지도: 1019, 패턴: ['금지']
# 지지도: 1014, 패턴: ['점검', '및']
# 지지도: 1013, 패턴: ['작업', '통한', '방지']
# 지지도: 1012, 패턴: ['안전교육', '재발', '향후']
# 지지도: 1012, 패턴: ['안전교육', '방지', '향후']
# 지지도: 1012, 패턴: ['포함한']
# 지지도: 1009, 패턴: ['통한', '및', '향후']
# 지지도: 1008, 패턴: ['안전교육', '재발', '방지', '향후']
# 지지도: 1006, 패턴: ['현장', '실시']
# 지지도: 1004, 패턴: ['시', '시']
# 지지도: 1000, 패턴: ['통한', '및', '조치', '계획']
# 지지도: 1000, 패턴: ['실시와', '통한', '방지']
# 지지도: 997, 패턴: ['교육', '작업']
# 지지도: 997, 패턴: ['전', '방지']
# 지지도: 996, 패턴: ['안전교육', '방지', '향후', '조치']
# 지지도: 996, 패턴: ['위한', '안전교육']
# 지지도: 995, 패턴: ['및', '방지', '조치']
# 지지도: 994, 패턴: ['안전교육', '재발', '향후', '조치']
# 지지도: 994, 패턴: ['따른']
# 지지도: 992, 패턴: ['안전교육', '재발', '방지', '향후', '조치']
# 지지도: 992, 패턴: ['안전교육', '방지', '조치', '계획']
# 지지도: 991, 패턴: ['작업', '및', '방지']
# 지지도: 989, 패턴: ['안전교육', '재발', '조치', '계획']
# 지지도: 989, 패턴: ['이동']
# 지지도: 988, 패턴: ['안전교육', '작업']
# 지지도: 987, 패턴: ['안전교육', '재발', '향후', '계획']
# 지지도: 987, 패턴: ['안전교육', '방지', '향후', '계획']
# 지지도: 987, 패턴: ['작업', '대한']
# 지지도: 986, 패턴: ['대한', '교육']
# 지지도: 985, 패턴: ['현장', '재발']
# 지지도: 984, 패턴: ['안전교육', '재발', '방지', '향후', '계획']
# 지지도: 984, 패턴: ['안전교육', '재발', '방지', '조치', '계획']
# 지지도: 984, 패턴: ['안전교육', '및', '계획']
# 지지도: 980, 패턴: ['시', '작업', '및']
# 지지도: 980, 패턴: ['위한', '교육']
# 지지도: 977, 패턴: ['안전교육', '방지', '향후', '조치', '계획']
# 지지도: 977, 패턴: ['작업', '교육', '및']
# 지지도: 976, 패턴: ['안전교육', '재발', '향후', '조치', '계획']
# 지지도: 976, 패턴: ['통한', '및', '향후', '조치']
# 지지도: 974, 패턴: ['안전교육', '재발', '방지', '향후', '조치', '계획']
# 지지도: 974, 패턴: ['수시']
# 지지도: 971, 패턴: ['작업', '및', '통한']
# 지지도: 969, 패턴: ['및', '시', '및']
# 지지도: 969, 패턴: ['후', '작업']
# 지지도: 969, 패턴: ['작업자', '통한', '방지']
# 지지도: 967, 패턴: ['통한', '및', '향후', '계획']
# 지지도: 964, 패턴: ['통한', '방지', '및', '계획']
# 지지도: 964, 패턴: ['교육', '실시', '및']
# 지지도: 964, 패턴: ['실시를', '대책']
# 지지도: 963, 패턴: ['실시', '재발']
# 지지도: 958, 패턴: ['실시를', '방지', '대책']
# 지지도: 957, 패턴: ['통한', '및', '향후', '조치', '계획']
# 지지도: 956, 패턴: ['통한', '재발', '및', '계획']
# 지지도: 955, 패턴: ['안전교육', '및', '방지']
# 지지도: 955, 패턴: ['및', '재발', '조치']
# 지지도: 955, 패턴: ['작업', '및', '재발']
# 지지도: 955, 패턴: ['전', '재발']
# 지지도: 955, 패턴: ['등']
# 지지도: 953, 패턴: ['통한', '방지', '및', '조치']
# 지지도: 952, 패턴: ['통한', '재발', '방지', '및', '계획']
# 지지도: 943, 패턴: ['시', '확인']
# 지지도: 943, 패턴: ['안전교육', '현장']
# 지지도: 943, 패턴: ['및', '재발', '계획']
# 지지도: 942, 패턴: ['통한', '대책', '및']
# 지지도: 940, 패턴: ['실시와', '통한', '재발']
# 지지도: 940, 패턴: ['실시를', '재발', '방지', '대책']
# 지지도: 940, 패턴: ['실시를', '재발', '대책']
# 지지도: 939, 패턴: ['통한', '재발', '및', '조치']
# 지지도: 938, 패턴: ['통한', '방지', '및', '향후']
# 지지도: 938, 패턴: ['작업', '후']
# 지지도: 937, 패턴: ['안전교육', '실시를']
# 지지도: 936, 패턴: ['및', '방지', '계획']
# 지지도: 936, 패턴: ['실시와', '통한', '재발', '방지']
# 지지도: 935, 패턴: ['통한', '재발', '방지', '및', '조치']
# 지지도: 935, 패턴: ['교육', '통한', '재발']
# 지지도: 934, 패턴: ['작업', '전', '안전교육']
# 지지도: 932, 패턴: ['주변']
# 지지도: 931, 패턴: ['안전교육', '강화']
# 지지도: 930, 패턴: ['통한', '재발', '방지', '및', '향후']
# 지지도: 930, 패턴: ['통한', '재발', '및', '향후']
# 지지도: 929, 패턴: ['사전']
# 지지도: 929, 패턴: ['현장', '재발', '방지']
# 지지도: 929, 패턴: ['실시를', '통한', '대책']
# 지지도: 926, 패턴: ['교육', '통한', '재발', '방지']
# 지지도: 924, 패턴: ['실시를', '통한', '방지', '대책']
# 지지도: 923, 패턴: ['통한', '방지', '및', '향후', '조치']
# 지지도: 921, 패턴: ['통한', '방지', '대책', '및']
# 지지도: 921, 패턴: ['통한', '방지', '및', '조치', '계획']
# 지지도: 921, 패턴: ['작업', '전', '통한']
# 지지도: 921, 패턴: ['작업자', '조치']
# 지지도: 918, 패턴: ['통한', '방지', '및', '향후', '계획']
# 지지도: 918, 패턴: ['및', '재발', '방지', '조치']
# 지지도: 917, 패턴: ['통한', '재발', '대책', '및']
# 지지도: 917, 패턴: ['작업', '통한', '재발']
# 지지도: 917, 패턴: ['작업자', '통한', '재발']
# 지지도: 916, 패턴: ['통한', '재발', '방지', '대책', '및']
# 지지도: 916, 패턴: ['통한', '재발', '방지', '및', '향후', '조치']
# 지지도: 916, 패턴: ['통한', '재발', '및', '향후', '조치']
# 지지도: 913, 패턴: ['안전교육', '및', '재발']
# 지지도: 913, 패턴: ['통한', '재발', '및', '조치', '계획']
# 지지도: 913, 패턴: ['사고', '방지']
# 지지도: 912, 패턴: ['작업', '전', '교육']
# 지지도: 911, 패턴: ['안전교육', '및', '통한']
# 지지도: 911, 패턴: ['통한', '재발', '방지', '및', '조치', '계획']
# 지지도: 911, 패턴: ['통한', '방지', '및', '향후', '조치', '계획']
# 지지도: 911, 패턴: ['강화', '및']
# 지지도: 910, 패턴: ['통한', '재발', '방지', '및', '향후', '계획']
# 지지도: 910, 패턴: ['통한', '재발', '및', '향후', '계획']
# 지지도: 909, 패턴: ['및', '재발', '방지', '계획']
# 지지도: 907, 패턴: ['관련']
# 지지도: 907, 패턴: ['착용', '및']
# 지지도: 906, 패턴: ['시', '교육', '실시']
# 지지도: 906, 패턴: ['작업자', '통한', '재발', '방지']
# 지지도: 906, 패턴: ['실시를', '통한', '재발', '방지', '대책']
# 지지도: 906, 패턴: ['실시를', '통한', '재발', '대책']
# 지지도: 904, 패턴: ['통한', '재발', '방지', '및', '향후', '조치', '계획']
# 지지도: 904, 패턴: ['통한', '재발', '및', '향후', '조치', '계획']
# 지지도: 901, 패턴: ['안전교육', '통한', '조치']
# 지지도: 901, 패턴: ['대한', '조치', '계획']
# 지지도: 898, 패턴: ['및', '안전관리']
# 지지도: 897, 패턴: ['강화를']
# 지지도: 896, 패턴: ['시', '대책']
# 지지도: 896, 패턴: ['작업', '및', '조치']
# 지지도: 894, 패턴: ['작업', '통한', '재발', '방지']
# 지지도: 893, 패턴: ['작업', '관리']
# 지지도: 889, 패턴: ['작업', '전', '작업']
# 지지도: 887, 패턴: ['안전교육', '실시를', '통한']
# 지지도: 887, 패턴: ['실시', '재발', '방지']
# 지지도: 883, 패턴: ['작업자', '안전교육', '및']
# 지지도: 877, 패턴: ['작업', '안전교육', '및']
# 지지도: 872, 패턴: ['전', '재발', '방지']
# 지지도: 870, 패턴: ['재발', '위한']
# 지지도: 869, 패턴: ['안전교육', '및', '조치', '계획']
# 지지도: 868, 패턴: ['안전교육', '및', '향후']
# 지지도: 868, 패턴: ['작업', '시', '작업']
# 지지도: 868, 패턴: ['작업', '실시와']
# 지지도: 867, 패턴: ['실시', '통한']
# 지지도: 863, 패턴: ['및', '및', '교육']
# 지지도: 863, 패턴: ['작업', '및', '재발', '방지']
# 지지도: 862, 패턴: ['상태']
# 지지도: 859, 패턴: ['안전교육', '및', '재발', '방지']
# 지지도: 857, 패턴: ['및', '방지', '향후']
# 지지도: 854, 패턴: ['사고', '재발']
# 지지도: 853, 패턴: ['및', '및', '방지']
# 지지도: 852, 패턴: ['및', '재발', '향후']
# 지지도: 851, 패턴: ['철저한']
# 지지도: 850, 패턴: ['교육', '현장']
# 지지도: 849, 패턴: ['시', '및', '교육']
# 지지도: 847, 패턴: ['교육', '계획']
# 지지도: 846, 패턴: ['실시와', '통한', '대책']
# 지지도: 845, 패턴: ['대한', '안전교육']
# 지지도: 845, 패턴: ['확보']
# 지지도: 844, 패턴: ['및', '재발', '방지', '향후']
# 지지도: 844, 패턴: ['및', '재발', '조치', '계획']
# 지지도: 844, 패턴: ['관리', '및']
# 지지도: 843, 패턴: ['근로자', '작업']
# 지지도: 842, 패턴: ['및', '작업', '전']
# 지지도: 841, 패턴: ['정리정돈']
# 지지도: 840, 패턴: ['및', '방지', '조치', '계획']
# 지지도: 838, 패턴: ['및', '안전교육', '및']
# 지지도: 838, 패턴: ['실시와', '통한', '방지', '대책']
# 지지도: 838, 패턴: ['TBM', '및']
# 지지도: 837, 패턴: ['및', '방지', '향후', '조치']
# 지지도: 836, 패턴: ['재발', '실시']
# 지지도: 836, 패턴: ['근로자', '대책']
# 지지도: 834, 패턴: ['근로자', '조치']
# 지지도: 833, 패턴: ['안전교육', '안전교육']
# 지지도: 833, 패턴: ['실시와', '통한', '재발', '대책']
# 지지도: 832, 패턴: ['및', '재발', '향후', '조치']
# 지지도: 832, 패턴: ['실시와', '통한', '재발', '방지', '대책']
# 지지도: 831, 패턴: ['안전', '실시']
# 지지도: 829, 패턴: ['안전교육', '통한', '및']
# 지지도: 828, 패턴: ['및', '재발', '방지', '향후', '조치']
# 지지도: 826, 패턴: ['및', '방지', '향후', '계획']
# 지지도: 826, 패턴: ['위험성']
# 지지도: 825, 패턴: ['안전교육', '통한', '계획']
# 지지도: 825, 패턴: ['전', '확인']
# 지지도: 824, 패턴: ['안전교육', '및', '향후', '조치']
# 지지도: 824, 패턴: ['및', '재발', '방지', '조치', '계획']
# 지지도: 823, 패턴: ['및', '재발', '향후', '계획']
# 지지도: 823, 패턴: ['준수']
# 지지도: 822, 패턴: ['통한', '방지', '대책', '계획']
# 지지도: 822, 패턴: ['통한', '대책', '계획']
# 지지도: 821, 패턴: ['및', '작업', '시']
# 지지도: 819, 패턴: ['및', '재발', '방지', '향후', '계획']
# 지지도: 819, 패턴: ['현장', '철저']
# 지지도: 818, 패턴: ['통한', '재발', '방지', '대책', '계획']
# 지지도: 818, 패턴: ['통한', '재발', '대책', '계획']
# 지지도: 818, 패턴: ['대한', '향후']
# 지지도: 815, 패턴: ['및', '방지', '향후', '조치', '계획']
# 지지도: 815, 패턴: ['해당']
# 지지도: 814, 패턴: ['통한', '방지', '대책', '및', '계획']
# 지지도: 814, 패턴: ['통한', '대책', '및', '계획']
# 지지도: 813, 패턴: ['시', '방지', '대책']
# 지지도: 813, 패턴: ['교육을']
# 지지도: 811, 패턴: ['통한', '재발', '방지', '대책', '및', '계획']
# 지지도: 811, 패턴: ['통한', '재발', '대책', '및', '계획']
# 지지도: 811, 패턴: ['통한', '대책', '향후']
# 지지도: 811, 패턴: ['및', '재발', '향후', '조치', '계획']
# 지지도: 810, 패턴: ['통한', '방지', '대책', '향후']
# 지지도: 810, 패턴: ['통한', '대책', '조치']
# 지지도: 810, 패턴: ['작업', '안전교육', '실시']
# 지지도: 809, 패턴: ['통한', '방지', '대책', '조치']
# 지지도: 808, 패턴: ['및', '재발', '방지', '향후', '조치', '계획']
# 지지도: 807, 패턴: ['통한', '재발', '방지', '대책', '향후']
# 지지도: 807, 패턴: ['통한', '재발', '대책', '향후']
# 지지도: 807, 패턴: ['통한', '대책', '및', '향후']
# 지지도: 807, 패턴: ['자재', '및']
# 지지도: 807, 패턴: ['작업', '시', '실시']
# 지지도: 806, 패턴: ['통한', '재발', '방지', '대책', '조치']
# 지지도: 806, 패턴: ['통한', '재발', '대책', '조치']
# 지지도: 806, 패턴: ['통한', '방지', '대책', '및', '향후']
# 지지도: 806, 패턴: ['작업', '조치', '계획']
# 지지도: 805, 패턴: ['및', '및', '재발']
# 지지도: 803, 패턴: ['통한', '재발', '방지', '대책', '및', '향후']
# 지지도: 803, 패턴: ['통한', '재발', '대책', '및', '향후']
# 지지도: 802, 패턴: ['재발', '방지를']
# 지지도: 801, 패턴: ['통한', '대책', '및', '조치']
# 지지도: 800, 패턴: ['통한', '방지', '대책', '및', '조치']
# 지지도: 799, 패턴: ['통한', '대책', '향후', '조치']
# 지지도: 798, 패턴: ['통한', '방지', '대책', '향후', '조치']
# 지지도: 797, 패턴: ['시', '재발', '대책']
# 지지도: 797, 패턴: ['통한', '재발', '방지', '대책', '및', '조치']
# 지지도: 797, 패턴: ['통한', '재발', '대책', '및', '조치']
# 지지도: 797, 패턴: ['작업', '사고']
# 지지도: 797, 패턴: ['전', '및', '실시']
# 지지도: 796, 패턴: ['안전교육', '및', '향후', '계획']
# 지지도: 795, 패턴: ['통한', '재발', '방지', '대책', '향후', '조치']
# 지지도: 795, 패턴: ['통한', '재발', '대책', '향후', '조치']
# 지지도: 795, 패턴: ['통한', '대책', '및', '향후', '조치']
# 지지도: 794, 패턴: ['시', '근로자']
# 지지도: 794, 패턴: ['통한', '방지', '대책', '및', '향후', '조치']
# 지지도: 793, 패턴: ['전', '및', '및']
# 지지도: 792, 패턴: ['통한', '방지', '대책', '향후', '계획']
# 지지도: 792, 패턴: ['통한', '대책', '향후', '계획']
# 지지도: 792, 패턴: ['작업', '작업', '실시']
# 지지도: 791, 패턴: ['통한', '재발', '방지', '대책', '및', '향후', '조치']
# 지지도: 791, 패턴: ['통한', '재발', '대책', '및', '향후', '조치']
# 지지도: 791, 패턴: ['통한', '방지', '대책', '조치', '계획']
# 지지도: 791, 패턴: ['통한', '대책', '조치', '계획']
# 지지도: 791, 패턴: ['작업', '전', '방지']
# 지지도: 790, 패턴: ['실시', '및', '실시']
# 지지도: 790, 패턴: ['실시', '철저']
# 지지도: 789, 패턴: ['시', '계획']
# 지지도: 789, 패턴: ['안전교육', '및', '향후', '조치', '계획']
# 지지도: 789, 패턴: ['통한', '재발', '방지', '대책', '향후', '계획']
# 지지도: 789, 패턴: ['통한', '재발', '대책', '향후', '계획']
# 지지도: 789, 패턴: ['및', '대책과']
# 지지도: 789, 패턴: ['방지를', '및']
# 지지도: 788, 패턴: ['통한', '재발', '방지', '대책', '조치', '계획']
# 지지도: 788, 패턴: ['통한', '재발', '대책', '조치', '계획']
# 지지도: 788, 패턴: ['통한', '방지', '대책', '및', '향후', '계획']
# 지지도: 788, 패턴: ['통한', '대책', '및', '향후', '계획']
# 지지도: 788, 패턴: ['근로자', '통한', '방지']
# 지지도: 787, 패턴: ['안전교육', '통한', '향후']
# 지지도: 787, 패턴: ['실시', '시']
# 지지도: 787, 패턴: ['통한', '방지', '대책', '향후', '조치', '계획']
# 지지도: 787, 패턴: ['통한', '대책', '향후', '조치', '계획']
# 지지도: 786, 패턴: ['시', '재발', '방지', '대책']
# 지지도: 786, 패턴: ['재발', '방지를', '위한']
# 지지도: 786, 패턴: ['실시', '조치']
# 지지도: 786, 패턴: ['통한', '방지', '대책', '및', '조치', '계획']
# 지지도: 786, 패턴: ['통한', '대책', '및', '조치', '계획']
# 지지도: 786, 패턴: ['교육과']
# 지지도: 785, 패턴: ['통한', '재발', '방지', '대책', '및', '향후', '계획']
# 지지도: 785, 패턴: ['통한', '재발', '대책', '및', '향후', '계획']
# 지지도: 784, 패턴: ['철저를']
# 지지도: 784, 패턴: ['통한', '재발', '방지', '대책', '향후', '조치', '계획']
# 지지도: 784, 패턴: ['통한', '재발', '대책', '향후', '조치', '계획']
# 지지도: 783, 패턴: ['통한', '재발', '방지', '대책', '및', '조치', '계획']
# 지지도: 783, 패턴: ['통한', '재발', '대책', '및', '조치', '계획']
# 지지도: 783, 패턴: ['통한', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 783, 패턴: ['통한', '대책', '및', '향후', '조치', '계획']
# 지지도: 782, 패턴: ['및', '방지', '대책과']
# 지지도: 781, 패턴: ['방지를', '위한', '및']
# 지지도: 780, 패턴: ['통한', '재발', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 780, 패턴: ['통한', '재발', '대책', '및', '향후', '조치', '계획']
# 지지도: 779, 패턴: ['대한', '향후', '조치']
# 지지도: 777, 패턴: ['및', '재발', '방지', '대책과']
# 지지도: 777, 패턴: ['및', '재발', '대책과']
# 지지도: 776, 패턴: ['근로자', '방지', '대책']
# 지지도: 775, 패턴: ['시', '교육', '및']
# 지지도: 775, 패턴: ['지시']
# 지지도: 774, 패턴: ['시', '및', '작업']
# 지지도: 773, 패턴: ['작업자', '통한', '대책']
# 지지도: 772, 패턴: ['시', '대한']
# 지지도: 769, 패턴: ['시', '현장']
# 지지도: 769, 패턴: ['근로자', '재발', '대책']
# 지지도: 769, 패턴: ['작업자', '통한', '방지', '대책']
# 지지도: 769, 패턴: ['현장', '안전교육']
# 지지도: 769, 패턴: ['관리감독']
# 지지도: 767, 패턴: ['근로자', '철저']
# 지지도: 765, 패턴: ['대한', '향후', '계획']
# 지지도: 765, 패턴: ['확인', '실시']
# 지지도: 764, 패턴: ['근로자', '재발', '방지', '대책']
# 지지도: 764, 패턴: ['교육', '시']
# 지지도: 763, 패턴: ['실시', '현장']
# 지지도: 763, 패턴: ['실시', '교육']
# 지지도: 763, 패턴: ['현장', '조치']
# 지지도: 762, 패턴: ['근로자', '안전교육', '및']
# 지지도: 762, 패턴: ['작업', '및', '철저']
# 지지도: 761, 패턴: ['예방을']
# 지지도: 760, 패턴: ['대한', '향후', '조치', '계획']
# 지지도: 758, 패턴: ['안전교육', '통한', '조치', '계획']
# 지지도: 758, 패턴: ['및', '및', '조치']
# 지지도: 756, 패턴: ['시', '안전']
# 지지도: 756, 패턴: ['안전교육', '통한', '향후', '조치']
# 지지도: 756, 패턴: ['전', '철저']
# 지지도: 756, 패턴: ['사용', '및']
# 지지도: 755, 패턴: ['작업', '전', '재발']
# 지지도: 754, 패턴: ['사고사례', '및']
# 지지도: 754, 패턴: ['강화를', '통한']
# 지지도: 752, 패턴: ['및', '통한', '조치']
# 지지도: 751, 패턴: ['작업자', '통한', '재발', '방지', '대책']
# 지지도: 751, 패턴: ['작업자', '통한', '재발', '대책']
# 지지도: 750, 패턴: ['통한', '실시']
# 지지도: 750, 패턴: ['및', '대책과', '향후']
# 지지도: 749, 패턴: ['안전교육', '통한', '향후', '계획']
# 지지도: 749, 패턴: ['및', '및', '통한']
# 지지도: 749, 패턴: ['내', '및']
# 지지도: 749, 패턴: ['교육', '통한', '대책']
# 지지도: 749, 패턴: ['작업자', '철저']
# 지지도: 749, 패턴: ['중']
# 지지도: 747, 패턴: ['및', '방지', '대책과', '향후']
# 지지도: 747, 패턴: ['및', '대책과', '계획']
# 지지도: 745, 패턴: ['안전교육', '실시를', '방지']
# 지지도: 745, 패턴: ['및', '대책과', '조치']
# 지지도: 744, 패턴: ['및', '재발', '방지', '대책과', '향후']
# 지지도: 744, 패턴: ['및', '재발', '대책과', '향후']
# 지지도: 744, 패턴: ['전', '실시', '및']
# 지지도: 743, 패턴: ['안전', '방지']
# 지지도: 742, 패턴: ['작업', '위한']
# 지지도: 742, 패턴: ['배치']
# 지지도: 741, 패턴: ['예방을', '위한']
# 지지도: 740, 패턴: ['및', '방지', '대책과', '계획']
# 지지도: 739, 패턴: ['및', '방지', '대책과', '조치']
# 지지도: 739, 패턴: ['및', '및', '재발', '방지']
# 지지도: 739, 패턴: ['교육', '통한', '방지', '대책']
# 지지도: 738, 패턴: ['및', '재발', '방지', '대책과', '계획']
# 지지도: 738, 패턴: ['및', '재발', '대책과', '계획']
# 지지도: 738, 패턴: ['작업자', '계획']
# 지지도: 737, 패턴: ['및', '재발', '방지', '대책과', '조치']
# 지지도: 737, 패턴: ['및', '재발', '대책과', '조치']
# 지지도: 737, 패턴: ['및', '착용']
# 지지도: 737, 패턴: ['전', '시']
# 지지도: 736, 패턴: ['및', '대책과', '향후', '조치']
# 지지도: 735, 패턴: ['안전교육', '통한', '향후', '조치', '계획']
# 지지도: 735, 패턴: ['안전점검']
# 지지도: 734, 패턴: ['통한', '사고']
# 지지도: 734, 패턴: ['근로자', '통한', '재발']
# 지지도: 733, 패턴: ['및', '방지', '대책과', '향후', '조치']
# 지지도: 732, 패턴: ['현장', '교육']
# 지지도: 731, 패턴: ['및', '재발', '방지', '대책과', '향후', '조치']
# 지지도: 731, 패턴: ['및', '재발', '대책과', '향후', '조치']
# 지지도: 731, 패턴: ['및', '전파']
# 지지도: 730, 패턴: ['안전교육', '실시를', '통한', '방지']
# 지지도: 729, 패턴: ['및', '대책과', '향후', '계획']
# 지지도: 729, 패턴: ['교육', '및', '방지']
# 지지도: 728, 패턴: ['및', '마련']
# 지지도: 728, 패턴: ['전', '근로자']
# 지지도: 726, 패턴: ['및', '방지', '대책과', '향후', '계획']
# 지지도: 725, 패턴: ['및', '대책과', '조치', '계획']
# 지지도: 725, 패턴: ['교육', '및', '실시']
# 지지도: 724, 패턴: ['및', '재발', '방지', '대책과', '향후', '계획']
# 지지도: 724, 패턴: ['및', '재발', '대책과', '향후', '계획']
# 지지도: 723, 패턴: ['교육', '통한', '재발', '방지', '대책']
# 지지도: 723, 패턴: ['교육', '통한', '재발', '대책']
# 지지도: 723, 패턴: ['후', '실시']
# 지지도: 722, 패턴: ['재발', '교육']
# 지지도: 722, 패턴: ['안전교육', '방지', '및']
# 지지도: 721, 패턴: ['근로자', '통한', '재발', '방지']
# 지지도: 721, 패턴: ['작업', '향후']
# 지지도: 721, 패턴: ['교육', '관리']
# 지지도: 720, 패턴: ['및', '대책과', '향후', '조치', '계획']
# 지지도: 719, 패턴: ['및', '방지', '대책과', '조치', '계획']
# 지지도: 719, 패턴: ['전', '조치']
# 지지도: 717, 패턴: ['안전교육', '시']
# 지지도: 717, 패턴: ['및', '재발', '방지', '대책과', '조치', '계획']
# 지지도: 717, 패턴: ['및', '재발', '대책과', '조치', '계획']
# 지지도: 717, 패턴: ['및', '방지', '대책과', '향후', '조치', '계획']
# 지지도: 715, 패턴: ['및', '재발', '방지', '대책과', '향후', '조치', '계획']
# 지지도: 715, 패턴: ['및', '재발', '대책과', '향후', '조치', '계획']
# 지지도: 714, 패턴: ['시', '및', '방지']
# 지지도: 714, 패턴: ['안전교육', '실시와', '방지']
# 지지도: 713, 패턴: ['교육', '안전']
# 지지도: 711, 패턴: ['시', '후']
# 지지도: 711, 패턴: ['안전교육', '실시를', '재발']
# 지지도: 711, 패턴: ['안전', '재발']
# 지지도: 711, 패턴: ['2인']
# 지지도: 710, 패턴: ['안전교육', '실시와', '통한']
# 지지도: 710, 패턴: ['실시', '및', '및']
# 지지도: 710, 패턴: ['작업', '시', '교육']
# 지지도: 710, 패턴: ['작업', '및', '안전교육']
# 지지도: 709, 패턴: ['안전교육', '재발', '및']
# 지지도: 709, 패턴: ['실시', '확인']
# 지지도: 708, 패턴: ['안전교육', '통한', '방지', '조치']
# 지지도: 707, 패턴: ['안전교육', '실시를', '재발', '방지']
# 지지도: 707, 패턴: ['현장', '대책']
# 지지도: 704, 패턴: ['시', '통한', '방지']
# 지지도: 704, 패턴: ['교육', '및', '재발']
# 지지도: 704, 패턴: ['제거']
# 지지도: 704, 패턴: ['작업방법']
# 지지도: 704, 패턴: ['특별']
# 지지도: 702, 패턴: ['사례']
# 지지도: 701, 패턴: ['현장', '관리']
# 지지도: 700, 패턴: ['작업', '통한', '대책']
# 지지도: 697, 패턴: ['시', '실시', '및']
# 지지도: 697, 패턴: ['안전교육', '실시를', '통한', '재발']
# 지지도: 697, 패턴: ['실시와', '조치']
# 지지도: 693, 패턴: ['안전교육', '통한', '재발', '조치']
# 지지도: 693, 패턴: ['안전교육', '통한', '방지', '계획']
# 지지도: 693, 패턴: ['안전교육', '실시를', '통한', '재발', '방지']
# 지지도: 693, 패턴: ['관리', '철저']
# 지지도: 691, 패턴: ['안전교육', '통한', '재발', '방지', '조치']
# 지지도: 691, 패턴: ['안전관리', '철저']
# 지지도: 691, 패턴: ['작업', '전', '재발', '방지']
# 지지도: 691, 패턴: ['대한', '재발', '조치']
# 지지도: 691, 패턴: ['대한', '방지', '조치']
# 지지도: 690, 패턴: ['안전교육', '실시와', '재발']
# 지지도: 690, 패턴: ['및', '설치']
# 지지도: 689, 패턴: ['및', '작업', '교육']
# 지지도: 689, 패턴: ['교육', '및', '및']
# 지지도: 689, 패턴: ['이행']
# 지지도: 689, 패턴: ['여부']
# 지지도: 687, 패턴: ['안전교육', '및', '실시']
# 지지도: 687, 패턴: ['안전교육', '통한', '재발', '계획']
# 지지도: 687, 패턴: ['작업자', '안전교육', '방지']
# 지지도: 687, 패턴: ['철저', '방지']
# 지지도: 686, 패턴: ['시', '관리']
# 지지도: 686, 패턴: ['작업', '통한', '방지', '대책']
# 지지도: 686, 패턴: ['대한', '재발', '계획']
# 지지도: 685, 패턴: ['안전교육', '재발', '방지', '및']
# 지지도: 685, 패턴: ['안전교육', '통한', '재발', '방지', '계획']
# 지지도: 685, 패턴: ['작업', '점검']
# 지지도: 685, 패턴: ['사고', '교육']
# 지지도: 685, 패턴: ['작업자', '안전교육', '통한']
# 지지도: 684, 패턴: ['작업장']
# 지지도: 683, 패턴: ['및', '및', '작업']
# 지지도: 683, 패턴: ['대한', '방지', '계획']
# 지지도: 681, 패턴: ['안전교육', '통한', '방지', '향후']
# 지지도: 681, 패턴: ['안전', '통한']
# 지지도: 680, 패턴: ['안전교육', '통한', '재발', '향후']
# 지지도: 680, 패턴: ['대한', '재발', '방지', '조치']
# 지지도: 680, 패턴: ['대한', '재발', '방지', '계획']
# 지지도: 679, 패턴: ['및', '통한', '및']
# 지지도: 678, 패턴: ['안전교육', '통한', '재발', '방지', '향후']
# 지지도: 678, 패턴: ['및', '안전', '교육']
# 지지도: 676, 패턴: ['위험']
# 지지도: 675, 패턴: ['사고', '재발', '방지']
# 지지도: 674, 패턴: ['시', '및', '재발']
# 지지도: 674, 패턴: ['실시', '및', '방지']
# 지지도: 673, 패턴: ['작업', '전', '확인']
# 지지도: 673, 패턴: ['작업', '확인', '및']
# 지지도: 672, 패턴: ['및', '작업', '작업']
# 지지도: 671, 패턴: ['안전교육', '실시와', '재발', '방지']
# 지지도: 671, 패턴: ['및', '시행']
# 지지도: 670, 패턴: ['작업', '및', '시']
# 지지도: 670, 패턴: ['교육', '및', '교육']
# 지지도: 669, 패턴: ['관리감독자']
# 지지도: 668, 패턴: ['철저를', '통한']
# 지지도: 667, 패턴: ['근로자', '및', '실시']
# 지지도: 667, 패턴: ['대한', '방지', '향후']
# 지지도: 666, 패턴: ['안전교육', '통한', '방지', '향후', '조치']
# 지지도: 666, 패턴: ['정리']
# 지지도: 666, 패턴: ['대한', '재발', '향후']
# 지지도: 666, 패턴: ['대한', '재발', '조치', '계획']
# 지지도: 665, 패턴: ['안전교육', '및', '및']
# 지지도: 665, 패턴: ['대한', '재발', '방지', '향후']
# 지지도: 665, 패턴: ['현장', '방지', '대책']
# 지지도: 665, 패턴: ['안전', '재발', '방지']
# 지지도: 664, 패턴: ['안전교육', '통한', '재발', '향후', '조치']
# 지지도: 664, 패턴: ['작업', '통한', '재발', '방지', '대책']
# 지지도: 664, 패턴: ['작업', '통한', '재발', '대책']
# 지지도: 664, 패턴: ['대한', '방지', '향후', '조치']
# 지지도: 663, 패턴: ['안전교육', '통한', '재발', '방지', '향후', '조치']
# 지지도: 663, 패턴: ['작업', '및', '계획']
# 지지도: 663, 패턴: ['대한', '재발', '방지', '향후', '조치']
# 지지도: 663, 패턴: ['대한', '재발', '향후', '조치']
# 지지도: 663, 패턴: ['대한', '방지', '조치', '계획']
# 지지도: 662, 패턴: ['안전교육', '통한', '방지', '향후', '계획']
# 지지도: 662, 패턴: ['대한', '재발', '방지', '조치', '계획']
# 지지도: 662, 패턴: ['실시와', '작업']
# 지지도: 662, 패턴: ['작업자', '안전교육', '재발']
# 지지도: 661, 패턴: ['시', '및', '통한']
# 지지도: 661, 패턴: ['안전교육', '통한', '재발', '향후', '계획']
# 지지도: 661, 패턴: ['근로자', '교육', '및']
# 지지도: 660, 패턴: ['대한', '방지', '향후', '조치', '계획']
# 지지도: 660, 패턴: ['대한', '방지', '향후', '계획']
# 지지도: 660, 패턴: ['교육', '및', '재발', '방지']
# 지지도: 660, 패턴: ['예정']
# 지지도: 659, 패턴: ['안전교육', '통한', '재발', '방지', '향후', '계획']
# 지지도: 659, 패턴: ['안전교육', '통한', '방지', '조치', '계획']
# 지지도: 659, 패턴: ['작업', '강화']
# 지지도: 659, 패턴: ['대한', '재발', '방지', '향후', '조치', '계획']
# 지지도: 659, 패턴: ['대한', '재발', '방지', '향후', '계획']
# 지지도: 659, 패턴: ['대한', '재발', '향후', '조치', '계획']
# 지지도: 659, 패턴: ['대한', '재발', '향후', '계획']
# 지지도: 659, 패턴: ['안전', '교육', '실시']
# 지지도: 658, 패턴: ['현장', '내']
# 지지도: 658, 패턴: ['현장', '재발', '대책']
# 지지도: 657, 패턴: ['철저', '재발']
# 지지도: 656, 패턴: ['안전교육', '통한', '재발', '조치', '계획']
# 지지도: 656, 패턴: ['및', '실시를']
# 지지도: 656, 패턴: ['교육', '및', '통한']
# 지지도: 656, 패턴: ['전', '대책']
# 지지도: 655, 패턴: ['시', '작업', '실시']
# 지지도: 655, 패턴: ['안전교육', '통한', '재발', '방지', '조치', '계획']
# 지지도: 655, 패턴: ['및', '근로자', '및']
# 지지도: 654, 패턴: ['근로자', '안전교육', '실시']
# 지지도: 654, 패턴: ['근로자', '교육', '실시']
# 지지도: 652, 패턴: ['안전교육', '통한', '방지', '향후', '조치', '계획']
# 지지도: 652, 패턴: ['방지를', '실시']
# 지지도: 652, 패턴: ['교육', '조치', '계획']
# 지지도: 652, 패턴: ['현장', '재발', '방지', '대책']
# 지지도: 652, 패턴: ['확인', '작업']
# 지지도: 651, 패턴: ['시', '위한']
# 지지도: 651, 패턴: ['및', '교육', '방지']
# 지지도: 651, 패턴: ['방지를', '위한', '실시']
# 지지도: 651, 패턴: ['불안전한']
# 지지도: 651, 패턴: ['안전수칙']
# 지지도: 650, 패턴: ['안전교육', '대한']
# 지지도: 650, 패턴: ['안전교육', '통한', '재발', '향후', '조치', '계획']
# 지지도: 650, 패턴: ['및', '대책', '마련']
# 지지도: 649, 패턴: ['안전교육', '통한', '재발', '방지', '향후', '조치', '계획']
# 지지도: 649, 패턴: ['근로자', '실시', '및']
# 지지도: 648, 패턴: ['현장', '안전']
# 지지도: 648, 패턴: ['진행']
# 지지도: 647, 패턴: ['근로자', '시']
# 지지도: 647, 패턴: ['작업자', '안전교육', '재발', '방지']
# 지지도: 646, 패턴: ['실시를', '조치']
# 지지도: 645, 패턴: ['시', '및', '조치']
# 지지도: 645, 패턴: ['금지', '및']
# 지지도: 644, 패턴: ['실시', '대책']
# 지지도: 644, 패턴: ['및', '시', '실시']
# 지지도: 644, 패턴: ['강화와']
# 지지도: 643, 패턴: ['실시와', '실시']
# 지지도: 642, 패턴: ['실시', '및', '재발']
# 지지도: 642, 패턴: ['및', '안전교육', '통한']
# 지지도: 642, 패턴: ['사고', '실시']
# 지지도: 642, 패턴: ['작업자', '향후']
# 지지도: 640, 패턴: ['및', '안전사고']
# 지지도: 639, 패턴: ['방지', '실시']
# 지지도: 639, 패턴: ['교육', '및', '조치']
# 지지도: 638, 패턴: ['교육', '향후']
# 지지도: 638, 패턴: ['안전', '관리']
# 지지도: 637, 패턴: ['시', '전']
# 지지도: 637, 패턴: ['시', '사고']
# 지지도: 637, 패턴: ['전', '현장']
# 지지도: 637, 패턴: ['안전', '교육', '및']
# 지지도: 636, 패턴: ['및', '포함한']
# 지지도: 636, 패턴: ['실시와', '철저']
# 지지도: 635, 패턴: ['작업', '전', '철저']
# 지지도: 635, 패턴: ['전', '안전교육', '및']
# 지지도: 634, 패턴: ['및', '및', '철저']
# 지지도: 634, 패턴: ['현장', '통한', '방지']
# 지지도: 634, 패턴: ['TBM', '시']
# 지지도: 633, 패턴: ['철저', '실시']
# 지지도: 632, 패턴: ['방지', '교육']
# 지지도: 632, 패턴: ['안전교육', '및', '철저']
# 지지도: 632, 패턴: ['점검', '실시']
# 지지도: 631, 패턴: ['및', '근로자', '실시']
# 지지도: 631, 패턴: ['작업자', '조치', '계획']
# 지지도: 630, 패턴: ['작업', '향후', '조치']
# 지지도: 630, 패턴: ['사고', '위한']
# 지지도: 628, 패턴: ['및', '방지', '마련']
# 지지도: 627, 패턴: ['안전교육', '실시와', '및']
# 지지도: 627, 패턴: ['작업', '및', '확인']
# 지지도: 626, 패턴: ['및', '확인', '및']
# 지지도: 625, 패턴: ['및', '통한', '계획']
# 지지도: 625, 패턴: ['및', '방지', '대책', '마련']
# 지지도: 625, 패턴: ['및', '교육', '통한']
# 지지도: 625, 패턴: ['및', '수립']
# 지지도: 625, 패턴: ['근로자', '실시와']
# 지지도: 625, 패턴: ['작업', '전', '및', '및']
# 지지도: 622, 패턴: ['전', '및', '교육']
# 지지도: 621, 패턴: ['시', '통한', '재발']
# 지지도: 621, 패턴: ['실시', '계획']
# 지지도: 620, 패턴: ['작업', '및', '대책']
# 지지도: 619, 패턴: ['및', '재발', '마련']
# 지지도: 619, 패턴: ['및', '교육', '재발']
# 지지도: 618, 패턴: ['전', '및', '작업']
# 지지도: 618, 패턴: ['전', '교육', '실시']
# 지지도: 618, 패턴: ['추가']
# 지지도: 617, 패턴: ['안전교육', '및', '대책']
# 지지도: 615, 패턴: ['및', '재발', '방지', '마련']
# 지지도: 615, 패턴: ['및', '재발', '대책', '마련']
# 지지도: 614, 패턴: ['시', '및', '재발', '방지']
# 지지도: 614, 패턴: ['철저', '재발', '방지']
# 지지도: 613, 패턴: ['및', '재발', '방지', '대책', '마련']
# 지지도: 612, 패턴: ['작업', '및', '안전']
# 지지도: 611, 패턴: ['시', '조치', '계획']
# 지지도: 611, 패턴: ['및', '안전교육', '방지']
# 지지도: 611, 패턴: ['장비']
# 지지도: 610, 패턴: ['시', '통한', '재발', '방지']
# 지지도: 610, 패턴: ['및', '현장', '및']
# 지지도: 609, 패턴: ['안전교육', '확인']
# 지지도: 609, 패턴: ['안전교육', '실시와', '대책']
# 지지도: 608, 패턴: ['작업', '전', '및', '실시']
# 지지도: 608, 패턴: ['전', '방지', '대책']
# 지지도: 607, 패턴: ['특별안전교육', '실시']
# 지지도: 605, 패턴: ['안전교육', '교육']
# 지지도: 605, 패턴: ['안전', '안전']
# 지지도: 603, 패턴: ['실시를', '계획']
# 지지도: 602, 패턴: ['위한', '철저']
# 지지도: 601, 패턴: ['실시', '및', '작업']
# 지지도: 601, 패턴: ['작업', '향후', '계획']
# 지지도: 600, 패턴: ['실시', '작업', '및']
# 지지도: 600, 패턴: ['작업', '시', '방지']
# 지지도: 599, 패턴: ['작업자', '안전교육', '실시']
# 지지도: 598, 패턴: ['안전교육', '대책', '및']
# 지지도: 598, 패턴: ['작업', '통한', '및']
# 지지도: 598, 패턴: ['전', '재발', '대책']
# 지지도: 596, 패턴: ['작업', '및', '교육', '실시']
# 지지도: 596, 패턴: ['대한', '대책']
# 지지도: 595, 패턴: ['통한', '예방']
# 지지도: 595, 패턴: ['작업', '및', '현장']
# 지지도: 595, 패턴: ['감독']
# 지지도: 594, 패턴: ['실시', '및', '통한']
# 지지도: 594, 패턴: ['근로자', '계획']
# 지지도: 594, 패턴: ['작업', '전', '실시', '및']
# 지지도: 594, 패턴: ['철저', '통한']
# 지지도: 593, 패턴: ['안전교육', '실시와', '방지', '대책']
# 지지도: 593, 패턴: ['통한', '대책과']
# 지지도: 592, 패턴: ['통한', '방지', '대책과']
# 지지도: 592, 패턴: ['전', '교육', '및']
# 지지도: 592, 패턴: ['안전', '조치']
# 지지도: 591, 패턴: ['작업자', '향후', '조치']
# 지지도: 591, 패턴: ['특별교육']
# 지지도: 590, 패턴: ['및', '대한', '실시']
# 지지도: 590, 패턴: ['근로자', '현장']
# 지지도: 590, 패턴: ['작업', '작업', '시']
# 지지도: 590, 패턴: ['전', '재발', '방지', '대책']
# 지지도: 590, 패턴: ['전파', '교육']
# 지지도: 589, 패턴: ['안전교육', '실시와', '재발', '대책']
# 지지도: 589, 패턴: ['안전관리', '방지']
# 지지도: 589, 패턴: ['작업', '작업', '교육']
# 지지도: 588, 패턴: ['안전교육', '실시와', '재발', '방지', '대책']
# 지지도: 588, 패턴: ['실시', '및', '재발', '방지']
# 지지도: 588, 패턴: ['근로자', '및', '및']
# 지지도: 588, 패턴: ['작업', '작업자']
# 지지도: 588, 패턴: ['전', '및', '통한']
# 지지도: 587, 패턴: ['작업', '향후', '조치', '계획']
# 지지도: 587, 패턴: ['실시를', '향후']
# 지지도: 586, 패턴: ['통한', '재발', '방지', '대책과']
# 지지도: 586, 패턴: ['통한', '재발', '대책과']
# 지지도: 586, 패턴: ['및', '교육', '재발', '방지']
# 지지도: 586, 패턴: ['전파', '실시']
# 지지도: 585, 패턴: ['안전교육', '방지', '대책', '및']
# 지지도: 585, 패턴: ['작업', '전', '시']
# 지지도: 584, 패턴: ['실시와', '안전교육']
# 지지도: 584, 패턴: ['특별안전교육', '및']
# 지지도: 583, 패턴: ['및', '대한', '및']
# 지지도: 582, 패턴: ['및', '및', '대책']
# 지지도: 582, 패턴: ['및', '수시']
# 지지도: 582, 패턴: ['작업자', '및', '조치']
# 지지도: 582, 패턴: ['현장', '계획']
# 지지도: 582, 패턴: ['재해']
# 지지도: 581, 패턴: ['안전교육', '방지', '및', '조치']
# 지지도: 580, 패턴: ['시', '및', '철저']
# 지지도: 580, 패턴: ['안전교육', '및', '방지', '대책']
# 지지도: 579, 패턴: ['안전교육', '재발', '대책', '및']
# 지지도: 579, 패턴: ['후', '조치']
# 지지도: 578, 패턴: ['안전교육', '재발', '방지', '대책', '및']
# 지지도: 578, 패턴: ['안전교육', '재발', '및', '조치']
# 지지도: 578, 패턴: ['안전교육', '방지', '및', '계획']
# 지지도: 578, 패턴: ['안전관리', '및']
# 지지도: 578, 패턴: ['작업', '작업', '작업']
# 지지도: 576, 패턴: ['안전교육', '재발', '및', '계획']
# 지지도: 576, 패턴: ['실시와', '교육']
# 지지도: 576, 패턴: ['전', '작업', '및']
# 지지도: 575, 패턴: ['안전교육', '재발', '방지', '및', '조치']
# 지지도: 575, 패턴: ['안전교육', '재발', '방지', '및', '계획']
# 지지도: 575, 패턴: ['및', '실시를', '통한']
# 지지도: 575, 패턴: ['실시를', '조치', '계획']
# 지지도: 574, 패턴: ['안전교육', '방지', '및', '향후']
# 지지도: 574, 패턴: ['작업', '시', '통한']
# 지지도: 573, 패턴: ['안전교육', '통한', '방지', '및']
# 지지도: 573, 패턴: ['통한', '작업']
# 지지도: 573, 패턴: ['실시를', '통한', '조치']
# 지지도: 572, 패턴: ['및', '예방']
# 지지도: 572, 패턴: ['실시와', '현장']
# 지지도: 572, 패턴: ['현장', '통한', '재발']
# 지지도: 571, 패턴: ['안전교육', '재발', '방지', '및', '향후']
# 지지도: 571, 패턴: ['안전교육', '재발', '및', '향후']
# 지지도: 571, 패턴: ['전', '및', '방지']
# 지지도: 571, 패턴: ['실시를', '향후', '조치']
# 지지도: 571, 패턴: ['실시를', '향후', '계획']
# 지지도: 570, 패턴: ['실시와', '계획']
# 지지도: 570, 패턴: ['현장', '작업']
# 지지도: 569, 패턴: ['교육', '확인']
# 지지도: 569, 패턴: ['포함한', '조치']
# 지지도: 569, 패턴: ['전', '안전']
# 지지도: 567, 패턴: ['안전교육', '실시를', '방지', '대책']
# 지지도: 567, 패턴: ['안전교육', '실시를', '대책']
# 지지도: 567, 패턴: ['통한', '안전교육']
# 지지도: 567, 패턴: ['교육', '향후', '조치']
# 지지도: 567, 패턴: ['전', '통한', '방지']
# 지지도: 566, 패턴: ['안전교육', '방지', '및', '향후', '조치']
# 지지도: 566, 패턴: ['작업', '시', '재발']
# 지지도: 566, 패턴: ['교육', '강화']
# 지지도: 566, 패턴: ['실시를', '향후', '조치', '계획']
# 지지도: 565, 패턴: ['및', '안전교육', '재발']
# 지지도: 565, 패턴: ['자재', '시']
# 지지도: 565, 패턴: ['포함한', '계획']
# 지지도: 565, 패턴: ['확인', '방지']
# 지지도: 564, 패턴: ['안전교육', '및', '재발', '대책']
# 지지도: 563, 패턴: ['재발', '안전교육']
# 지지도: 563, 패턴: ['안전교육', '재발', '방지', '및', '향후', '조치']
# 지지도: 563, 패턴: ['안전교육', '재발', '및', '향후', '조치']
# 지지도: 563, 패턴: ['안전교육', '및', '재발', '방지', '대책']
# 지지도: 562, 패턴: ['안전교육', '통한', '재발', '및']
# 지지도: 562, 패턴: ['실시', '방지', '대책']
# 지지도: 562, 패턴: ['조치', '및']
# 지지도: 562, 패턴: ['작업자', '향후', '계획']
# 지지도: 562, 패턴: ['현장', '통한', '재발', '방지']
# 지지도: 561, 패턴: ['안전교육', '마련']
# 지지도: 561, 패턴: ['실시', '안전교육']
# 지지도: 561, 패턴: ['안전관리', '재발']
# 지지도: 561, 패턴: ['안전교육을']
# 지지도: 560, 패턴: ['안전교육', '방지', '및', '조치', '계획']
# 지지도: 560, 패턴: ['안전교육', '통한', '재발', '방지', '및']
# 지지도: 560, 패턴: ['평가']
# 지지도: 560, 패턴: ['주변', '및']
# 지지도: 559, 패턴: ['안전교육', '안전관리']
# 지지도: 559, 패턴: ['안전교육', '실시를', '통한', '방지', '대책']
# 지지도: 559, 패턴: ['안전교육', '실시를', '통한', '대책']
# 지지도: 559, 패턴: ['작업', '전', '조치']
# 지지도: 558, 패턴: ['안전교육', '재발', '방지', '및', '조치', '계획']
# 지지도: 558, 패턴: ['안전교육', '재발', '및', '조치', '계획']
# 지지도: 558, 패턴: ['통한', '교육']
# 지지도: 558, 패턴: ['1조']
# 지지도: 557, 패턴: ['안전교육', '방지', '및', '향후', '계획']
# 지지도: 557, 패턴: ['안전교육', '실시를', '재발', '방지', '대책']
# 지지도: 557, 패턴: ['안전교육', '실시를', '재발', '대책']
# 지지도: 557, 패턴: ['확인', '재발']
# 지지도: 556, 패턴: ['및', '시', '작업']
# 지지도: 556, 패턴: ['작업', '작업', '전']
# 지지도: 555, 패턴: ['안전교육', '재발', '방지', '및', '향후', '계획']
# 지지도: 555, 패턴: ['안전교육', '재발', '및', '향후', '계획']
# 지지도: 555, 패턴: ['안전교육', '방지', '및', '향후', '조치', '계획']
# 지지도: 555, 패턴: ['및', '통한', '마련']
# 지지도: 555, 패턴: ['및', '발생']
# 지지도: 555, 패턴: ['이동', '및']
# 지지도: 554, 패턴: ['실시', '재발', '대책']
# 지지도: 554, 패턴: ['안전관리', '재발', '방지']
# 지지도: 554, 패턴: ['및', '및', '계획']
# 지지도: 553, 패턴: ['안전교육', '재발', '방지', '및', '향후', '조치', '계획']
# 지지도: 553, 패턴: ['안전교육', '재발', '및', '향후', '조치', '계획']
# 지지도: 553, 패턴: ['근로자', '확인']
# 지지도: 553, 패턴: ['이동', '시']
# 지지도: 553, 패턴: ['전', '안전교육', '실시']
# 지지도: 553, 패턴: ['작업전']
# 지지도: 552, 패턴: ['및', '전', '및']
# 지지도: 552, 패턴: ['작업', '및', '방지', '대책']
# 지지도: 552, 패턴: ['사고사례', '전파']
# 지지도: 551, 패턴: ['및', '작업', '통한']
# 지지도: 551, 패턴: ['근로자', '통한', '대책']
# 지지도: 550, 패턴: ['시', '및', '안전교육']
# 지지도: 550, 패턴: ['및', '실시', '실시']
# 지지도: 550, 패턴: ['2인', '1조']
# 지지도: 549, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책']
# 지지도: 549, 패턴: ['안전교육', '실시를', '통한', '재발', '대책']
# 지지도: 549, 패턴: ['철저를', '방지']
# 지지도: 549, 패턴: ['위험성', '및']
# 지지도: 549, 패턴: ['작업자', '향후', '조치', '계획']
# 지지도: 549, 패턴: ['TBM', '실시']
# 지지도: 548, 패턴: ['및', '통한', '향후']
# 지지도: 548, 패턴: ['작업', '착용']
# 지지도: 548, 패턴: ['작업', '근로자', '및']
# 지지도: 548, 패턴: ['작업자', '안전교육', '대책']
# 지지도: 548, 패턴: ['안전', '대책']
# 지지도: 547, 패턴: ['시', '및', '시']
# 지지도: 547, 패턴: ['통한', '대책과', '계획']
# 지지도: 547, 패턴: ['작업', '방지', '조치']
# 지지도: 547, 패턴: ['현장', '점검']
# 지지도: 546, 패턴: ['통한', '방지', '대책과', '계획']
# 지지도: 546, 패턴: ['통한', '대책과', '향후']
# 지지도: 546, 패턴: ['작업', '및', '재발', '대책']
# 지지도: 545, 패턴: ['설치', '작업']
# 지지도: 545, 패턴: ['통한', '방지', '대책과', '향후']
# 지지도: 545, 패턴: ['및', '및', '확인']
# 지지도: 545, 패턴: ['확인', '후']
# 지지도: 544, 패턴: ['및', '통한', '대책', '마련']
# 지지도: 544, 패턴: ['전', '및', '재발']
# 지지도: 543, 패턴: ['실시', '후']
# 지지도: 543, 패턴: ['통한', '재발', '방지', '대책과', '계획']
# 지지도: 543, 패턴: ['통한', '재발', '대책과', '계획']
# 지지도: 543, 패턴: ['위험성', '평가']
# 지지도: 543, 패턴: ['후', '방지']
# 지지도: 543, 패턴: ['포함한', '조치', '계획']
# 지지도: 542, 패턴: ['안전교육', '사고']
# 지지도: 542, 패턴: ['및', '및', '안전교육']
# 지지도: 542, 패턴: ['방지를', '안전교육']
# 지지도: 542, 패턴: ['해체']
# 지지도: 541, 패턴: ['통한', '재발', '방지', '대책과', '향후']
# 지지도: 541, 패턴: ['통한', '재발', '대책과', '향후']
# 지지도: 541, 패턴: ['방지를', '위한', '안전교육']
# 지지도: 541, 패턴: ['작업', '시', '조치']
# 지지도: 541, 패턴: ['작업', '및', '관리']
# 지지도: 540, 패턴: ['및', '통한', '조치', '계획']
# 지지도: 540, 패턴: ['대한', '통한']
# 지지도: 540, 패턴: ['전', '실시와']
# 지지도: 540, 패턴: ['실시를', '통한', '계획']
# 지지도: 539, 패턴: ['실시', '재발', '방지', '대책']
# 지지도: 539, 패턴: ['통한', '대책과', '조치']
# 지지도: 539, 패턴: ['작업', '안전', '교육']
# 지지도: 539, 패턴: ['작업자', '실시와']
# 지지도: 538, 패턴: ['통한', '방지', '대책과', '조치']
# 지지도: 538, 패턴: ['및', '안전교육', '재발', '방지']
# 지지도: 537, 패턴: ['설치', '실시']
# 지지도: 537, 패턴: ['및', '작업', '방지']
# 지지도: 537, 패턴: ['교육', '향후', '계획']
# 지지도: 537, 패턴: ['관리', '방지']
# 지지도: 536, 패턴: ['대책', '수립']
# 지지도: 536, 패턴: ['근로자', '통한', '방지', '대책']
# 지지도: 535, 패턴: ['안전교육', '대책', '마련']
# 지지도: 535, 패턴: ['안전교육', '및', '통한', '방지']
# 지지도: 535, 패턴: ['안전교육', '통한', '및', '조치']
# 지지도: 535, 패턴: ['통한', '재발', '방지', '대책과', '조치']
# 지지도: 535, 패턴: ['통한', '재발', '대책과', '조치']
# 지지도: 535, 패턴: ['및', '통한', '방지', '대책', '마련']
# 지지도: 535, 패턴: ['및', '통한', '방지', '마련']
# 지지도: 535, 패턴: ['위한', '작업']
# 지지도: 535, 패턴: ['작업', '및', '재발', '방지', '대책']
# 지지도: 535, 패턴: ['대한', '대책과']
# 지지도: 535, 패턴: ['대한', '대책과', '조치']
# 지지도: 534, 패턴: ['대한', '재발', '방지', '대책과']
# 지지도: 534, 패턴: ['대한', '재발', '방지', '대책과', '조치']
# 지지도: 534, 패턴: ['대한', '재발', '대책과']
# 지지도: 534, 패턴: ['대한', '재발', '대책과', '조치']
# 지지도: 534, 패턴: ['대한', '방지', '대책과']
# 지지도: 534, 패턴: ['대한', '방지', '대책과', '조치']
# 지지도: 534, 패턴: ['대한', '대책과', '향후']
# 지지도: 534, 패턴: ['대한', '대책과', '향후', '조치']
# 지지도: 533, 패턴: ['대한', '재발', '방지', '대책과', '향후']
# 지지도: 533, 패턴: ['대한', '재발', '방지', '대책과', '향후', '조치']
# 지지도: 533, 패턴: ['대한', '재발', '대책과', '향후']
# 지지도: 533, 패턴: ['대한', '재발', '대책과', '향후', '조치']
# 지지도: 533, 패턴: ['대한', '방지', '대책과', '향후']
# 지지도: 533, 패턴: ['대한', '방지', '대책과', '향후', '조치']
# 지지도: 533, 패턴: ['대한', '대책과', '조치', '계획']
# 지지도: 533, 패턴: ['대한', '대책과', '계획']
# 지지도: 532, 패턴: ['안전교육', '관리']
# 지지도: 532, 패턴: ['실시', '관리']
# 지지도: 532, 패턴: ['작업', '및', '조치', '계획']
# 지지도: 532, 패턴: ['대한', '재발', '방지', '대책과', '조치', '계획']
# 지지도: 532, 패턴: ['대한', '재발', '방지', '대책과', '계획']
# 지지도: 532, 패턴: ['대한', '재발', '대책과', '조치', '계획']
# 지지도: 532, 패턴: ['대한', '재발', '대책과', '계획']
# 지지도: 532, 패턴: ['대한', '방지', '대책과', '조치', '계획']
# 지지도: 532, 패턴: ['대한', '방지', '대책과', '계획']
# 지지도: 532, 패턴: ['대한', '대책과', '향후', '조치', '계획']
# 지지도: 532, 패턴: ['대한', '대책과', '향후', '계획']
# 지지도: 532, 패턴: ['사전', '및']
# 지지도: 531, 패턴: ['통한', '방지', '대책과', '향후', '조치']
# 지지도: 531, 패턴: ['통한', '대책과', '향후', '조치']
# 지지도: 531, 패턴: ['및', '통한', '재발', '방지', '대책', '마련']
# 지지도: 531, 패턴: ['및', '통한', '재발', '방지', '마련']
# 지지도: 531, 패턴: ['및', '통한', '재발', '대책', '마련']
# 지지도: 531, 패턴: ['및', '통한', '재발', '마련']
# 지지도: 531, 패턴: ['및', '후', '작업']
# 지지도: 531, 패턴: ['대한', '재발', '방지', '대책과', '향후', '조치', '계획']
# 지지도: 531, 패턴: ['대한', '재발', '방지', '대책과', '향후', '계획']
# 지지도: 531, 패턴: ['대한', '재발', '대책과', '향후', '조치', '계획']
# 지지도: 531, 패턴: ['대한', '재발', '대책과', '향후', '계획']
# 지지도: 531, 패턴: ['대한', '방지', '대책과', '향후', '조치', '계획']
# 지지도: 531, 패턴: ['대한', '방지', '대책과', '향후', '계획']
# 지지도: 531, 패턴: ['전', '계획']
# 지지도: 531, 패턴: ['전', '대한']
# 지지도: 531, 패턴: ['작업자', '안전교육', '방지', '대책']
# 지지도: 531, 패턴: ['확인', '교육']
# 지지도: 530, 패턴: ['안전교육', '방지', '대책', '마련']
# 지지도: 530, 패턴: ['안전교육', '방지', '마련']
# 지지도: 530, 패턴: ['및', '근로자', '교육']
# 지지도: 530, 패턴: ['근로자', '및', '방지']
# 지지도: 530, 패턴: ['대한', '재발', '대책']
# 지지도: 530, 패턴: ['교육', '사고']
# 지지도: 530, 패턴: ['안전사고', '및']
# 지지도: 529, 패턴: ['실시', '및', '철저']
# 지지도: 529, 패턴: ['작업', '전', '및', '작업']
# 지지도: 529, 패턴: ['후', '재발']
# 지지도: 529, 패턴: ['정리정돈', '및']
# 지지도: 528, 패턴: ['재발', '수립']
# 지지도: 528, 패턴: ['통한', '재발', '방지', '대책과', '향후', '조치']
# 지지도: 528, 패턴: ['통한', '재발', '대책과', '향후', '조치']
# 지지도: 528, 패턴: ['통한', '대책과', '향후', '계획']
# 지지도: 528, 패턴: ['및', '및', '현장']
# 지지도: 528, 패턴: ['작업', '재발', '조치']
# 지지도: 528, 패턴: ['대한', '방지', '대책']
# 지지도: 527, 패턴: ['통한', '방지', '대책과', '향후', '계획']
# 지지도: 527, 패턴: ['근로자', '통한', '재발', '방지', '대책']
# 지지도: 527, 패턴: ['근로자', '통한', '재발', '대책']
# 지지도: 527, 패턴: ['위한', '교육', '실시']
# 지지도: 527, 패턴: ['강화를', '방지']
# 지지도: 526, 패턴: ['안전교육', '재발', '마련']
# 지지도: 526, 패턴: ['사고', '조치']
# 지지도: 525, 패턴: ['시', '작업', '전']
# 지지도: 525, 패턴: ['시', '시', '및']
# 지지도: 525, 패턴: ['안전교육', '재발', '대책', '마련']
# 지지도: 525, 패턴: ['및', '철저', '및']
# 지지도: 525, 패턴: ['위한', '안전교육', '실시']
# 지지도: 525, 패턴: ['교육', '향후', '조치', '계획']
# 지지도: 525, 패턴: ['실시를', '통한', '향후']
# 지지도: 524, 패턴: ['안전교육', '재발', '방지', '대책', '마련']
# 지지도: 524, 패턴: ['안전교육', '재발', '방지', '마련']
# 지지도: 524, 패턴: ['통한', '재발', '방지', '대책과', '향후', '계획']
# 지지도: 524, 패턴: ['통한', '재발', '대책과', '향후', '계획']
# 지지도: 524, 패턴: ['및', '작업', '조치']
# 지지도: 524, 패턴: ['및', '시', '교육']
# 지지도: 524, 패턴: ['사고', '발생']
# 지지도: 523, 패턴: ['안전교육', '통한', '및', '계획']
# 지지도: 523, 패턴: ['작업', '전', '안전교육', '및']
# 지지도: 522, 패턴: ['시', '향후']
# 지지도: 522, 패턴: ['통한', '대책과', '조치', '계획']
# 지지도: 522, 패턴: ['교육을', '통한']
# 지지도: 522, 패턴: ['대한', '교육', '실시']
# 지지도: 522, 패턴: ['관리', '재발']
# 지지도: 521, 패턴: ['시', '안전교육', '실시']
# 지지도: 521, 패턴: ['통한', '방지', '대책과', '조치', '계획']
# 지지도: 521, 패턴: ['대한', '재발', '방지', '대책']
# 지지도: 521, 패턴: ['설치와']
# 지지도: 521, 패턴: ['행동']
# 지지도: 520, 패턴: ['통한', '철저']
# 지지도: 520, 패턴: ['및', '지시']
# 지지도: 519, 패턴: ['작업', '재발', '계획']
# 지지도: 519, 패턴: ['작업', '및', '작업', '및']
# 지지도: 518, 패턴: ['통한', '재발', '방지', '대책과', '조치', '계획']
# 지지도: 518, 패턴: ['통한', '재발', '대책과', '조치', '계획']
# 지지도: 518, 패턴: ['통한', '방지', '대책과', '향후', '조치', '계획']
# 지지도: 518, 패턴: ['통한', '대책과', '향후', '조치', '계획']
# 지지도: 518, 패턴: ['및', '통한', '향후', '조치']
# 지지도: 518, 패턴: ['교육', '및', '철저']
# 지지도: 518, 패턴: ['작업자', '안전교육', '재발', '방지', '대책']
# 지지도: 518, 패턴: ['작업자', '안전교육', '재발', '대책']
# 지지도: 517, 패턴: ['작업', '실시', '작업']
# 지지도: 517, 패턴: ['작업', '전', '대책']
# 지지도: 516, 패턴: ['및', '방지를']
# 지지도: 516, 패턴: ['교육', '작업', '및']
# 지지도: 516, 패턴: ['교육', '및', '계획']
# 지지도: 516, 패턴: ['실시를', '및']
# 지지도: 515, 패턴: ['안전교육', '대책', '향후']
# 지지도: 515, 패턴: ['안전교육', '대책', '조치']
# 지지도: 515, 패턴: ['철저를', '재발']
# ...
# 지지도: 241, 패턴: ['안전사고', '조치']
# 지지도: 240, 패턴: ['시', '및', '작업', '시']
# 지지도: 240, 패턴: ['안전교육', '작업', '통한']
# 지지도: 240, 패턴: ['안전교육', '및', '재발', '조치']
# 지지도: 240, 패턴: ['안전교육', '사고', '방지']
# 지지도: 240, 패턴: ['안전교육', '실시와', '현장']
# 지지도: 240, 패턴: ['안전교육', '실시와', '작업']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '및', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '및', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '및', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '대책', '및', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '통한', '대책', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '방지', '대책', '및', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '방지', '대책', '및', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '방지', '대책', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '방지', '대책', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '방지', '대책', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '대책', '및', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '대책', '및', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '대책', '및', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '대책', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '대책', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '재발', '대책', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '방지', '대책', '및', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '방지', '대책', '및', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '방지', '대책', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '방지', '대책', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '방지', '대책', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '대책', '및', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '대책', '및', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '대책', '및', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '대책', '향후', '조치', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '대책', '향후', '계획']
# 지지도: 240, 패턴: ['안전교육', '실시를', '대책', '조치', '계획']
# 지지도: 240, 패턴: ['실시', '및', '향후', '조치']
# 지지도: 240, 패턴: ['통한', '위한']
# 지지도: 240, 패턴: ['및', '관리', '통한']
# 지지도: 240, 패턴: ['작업', '시', '작업', '작업']
# 지지도: 240, 패턴: ['작업', '점검', '실시']
# 지지도: 240, 패턴: ['작업', 'TBM', '실시']
# 지지도: 240, 패턴: ['작업', '실시를', '재발']
# 지지도: 240, 패턴: ['작업', '교육을']
# 지지도: 240, 패턴: ['교육', '예방']
# 지지도: 240, 패턴: ['실시와', '재발', '방지', '조치', '계획']
# 지지도: 240, 패턴: ['실시와', '재발', '향후']
# 지지도: 240, 패턴: ['전', '확인', '실시']
# 지지도: 240, 패턴: ['전', '재발', '조치', '계획']
# 지지도: 240, 패턴: ['전', '방지', '향후']
# 지지도: 240, 패턴: ['현장', '및', '조치', '계획']
# 지지도: 240, 패턴: ['안전', '교육', '교육']
# 지지도: 240, 패턴: ['주변', '통한']
# 지지도: 240, 패턴: ['특별안전교육', '재발', '방지']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '및', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '및', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '방지', '대책', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '및', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '및', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '및', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '재발', '대책', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '및', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '및', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '방지', '대책', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '대책', '및', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '대책', '및', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '대책', '및', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '대책', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '대책', '향후', '계획']
# 지지도: 239, 패턴: ['안전교육', '실시를', '통한', '대책', '조치', '계획']
# 지지도: 239, 패턴: ['안전교육', '철저를', '방지', '대책']
# 지지도: 239, 패턴: ['안전교육', '철저를', '대책']
# 지지도: 239, 패턴: ['실시', '재발', '방지', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['실시', '재발', '향후', '조치', '계획']
# 지지도: 239, 패턴: ['및', '포함한', '재발', '방지']
# 지지도: 239, 패턴: ['및', '및', '및', '교육']
# 지지도: 239, 패턴: ['및', '관리', '실시']
# 지지도: 239, 패턴: ['및', '신호수']
# 지지도: 239, 패턴: ['및', '확인을']
# 지지도: 239, 패턴: ['작업', '작업', '재발', '대책']
# 지지도: 239, 패턴: ['작업', '방지', '및', '계획']
# 지지도: 239, 패턴: ['작업', '통한', '사고']
# 지지도: 239, 패턴: ['작업', '안전', '재발']
# 지지도: 239, 패턴: ['대한', '및', '통한']
# 지지도: 239, 패턴: ['교육', '실시와', '통한', '방지']
# 지지도: 239, 패턴: ['교육', '강화', '및']
# 지지도: 239, 패턴: ['교육', '안전관리']
# 지지도: 239, 패턴: ['실시와', '및', '교육']
# 지지도: 239, 패턴: ['점검', '및', '및']
# 지지도: 239, 패턴: ['전', '및', '사고']
# 지지도: 239, 패턴: ['전', '작업', '전']
# 지지도: 239, 패턴: ['전', '작업', '방지']
# 지지도: 239, 패턴: ['작업자', '교육', '대책']
# 지지도: 239, 패턴: ['작업자', '대책', '향후', '계획']
# 지지도: 239, 패턴: ['전파', '작업']
# 지지도: 239, 패턴: ['안전', '작업', '및']
# 지지도: 239, 패턴: ['안전', '교육', '조치']
# 지지도: 239, 패턴: ['안전', '향후', '계획']
# 지지도: 239, 패턴: ['사례', '방지']
# 지지도: 239, 패턴: ['올바른']
# 지지도: 238, 패턴: ['시', '대책과']
# 지지도: 238, 패턴: ['방지', '포함한', '조치']
# 지지도: 238, 패턴: ['안전교육', '강화를', '방지', '대책']
# 지지도: 238, 패턴: ['통한', '및', '작업']
# 지지도: 238, 패턴: ['및', '실시', '후']
# 지지도: 238, 패턴: ['및', '교육', '통한', '방지', '대책']
# 지지도: 238, 패턴: ['및', '작업자', '통한']
# 지지도: 238, 패턴: ['및', '위험요소']
# 지지도: 238, 패턴: ['위험성', '평가', '실시']
# 지지도: 238, 패턴: ['근로자', '실시를', '방지']
# 지지도: 238, 패턴: ['방지를', '작업']
# 지지도: 238, 패턴: ['작업', '시', '작업', '교육']
# 지지도: 238, 패턴: ['작업', '관리감독']
# 지지도: 238, 패턴: ['작업', '사고사례']
# 지지도: 238, 패턴: ['교육', '및', '통한', '재발', '방지', '대책']
# 지지도: 238, 패턴: ['교육', '및', '통한', '재발', '대책']
# 지지도: 238, 패턴: ['실시와', '재발', '방지', '향후']
# 지지도: 238, 패턴: ['작업자', '재발', '방지', '대책', '향후', '계획']
# 지지도: 238, 패턴: ['작업자', '재발', '대책', '향후', '계획']
# 지지도: 238, 패턴: ['작업자', '방지', '대책', '향후', '계획']
# 지지도: 238, 패턴: ['작업자', '대책', '및', '향후', '계획']
# 지지도: 238, 패턴: ['안전', '교육', '작업']
# 지지도: 238, 패턴: ['확인', '향후']
# 지지도: 238, 패턴: ['TBM', '교육', '실시']
# 지지도: 238, 패턴: ['안전사고', '방지를', '위한']
# 지지도: 238, 패턴: ['산재처리']
# 지지도: 237, 패턴: ['시', '작업', '실시', '및']
# 지지도: 237, 패턴: ['시', '위한', '실시']
# 지지도: 237, 패턴: ['시', '실시를']
# 지지도: 237, 패턴: ['재발', '이행']
# 지지도: 237, 패턴: ['방지', '포함한', '계획']
# 지지도: 237, 패턴: ['안전교육', '실시', '및', '실시']
# 지지도: 237, 패턴: ['안전교육', '대한', '향후']
# 지지도: 237, 패턴: ['안전교육', '철저를', '재발', '방지', '대책']
# 지지도: 237, 패턴: ['안전교육', '철저를', '재발', '대책']
# 지지도: 237, 패턴: ['실시', '여부']
# 지지도: 237, 패턴: ['안전관리', '조치', '계획']
# 지지도: 237, 패턴: ['통한', '대한']
# 지지도: 237, 패턴: ['및', '철저', '통한']
# 지지도: 237, 패턴: ['및', '시', '대책']
# 지지도: 237, 패턴: ['및', '시', '대한']
# 지지도: 237, 패턴: ['및', '시', '후']
# 지지도: 237, 패턴: ['및', '확인', '교육']
# 지지도: 237, 패턴: ['및', '행동']
# 지지도: 237, 패턴: ['근로자', '및', '강화']
# 지지도: 237, 패턴: ['근로자', '통한', '향후', '조치', '계획']
# 지지도: 237, 패턴: ['작업', '작업', '재발', '방지', '대책']
# 지지도: 237, 패턴: ['작업', '재발', '및', '조치']
# 지지도: 237, 패턴: ['작업', '및', '안전교육', '및']
# 지지도: 237, 패턴: ['작업', '안전교육', '계획']
# 지지도: 237, 패턴: ['작업', '안전교육', '현장']
# 지지도: 237, 패턴: ['작업', '전', '및', '근로자']
# 지지도: 237, 패턴: ['교육', '강화를']
# 지지도: 237, 패턴: ['후', '대한']
# 지지도: 237, 패턴: ['후', '근로자']
# 지지도: 237, 패턴: ['사고', '및', '재발', '방지']
# 지지도: 237, 패턴: ['전', '재발', '방지', '향후']
# 지지도: 237, 패턴: ['전', '재발', '향후']
# 지지도: 237, 패턴: ['작업자', '재발', '방지', '대책', '및', '향후', '계획']
# 지지도: 237, 패턴: ['작업자', '재발', '방지', '대책', '조치', '계획']
# 지지도: 237, 패턴: ['작업자', '재발', '대책', '및', '향후', '계획']
# 지지도: 237, 패턴: ['작업자', '재발', '대책', '조치', '계획']
# 지지도: 237, 패턴: ['작업자', '방지', '대책', '및', '향후', '계획']
# 지지도: 237, 패턴: ['작업자', '방지', '대책', '조치', '계획']
# 지지도: 237, 패턴: ['작업자', '대책', '조치', '계획']
# 지지도: 237, 패턴: ['현장', '방지', '향후']
# 지지도: 237, 패턴: ['철저', '및', '작업']
# 지지도: 237, 패턴: ['전파', '조치']
# 지지도: 237, 패턴: ['확인', '및', '시']
# 지지도: 237, 패턴: ['중', '실시']
# 지지도: 237, 패턴: ['전파와']
# 지지도: 236, 패턴: ['시', '및', '작업', '전']
# 지지도: 236, 패턴: ['시', '금지', '및']
# 지지도: 236, 패턴: ['설치', '방지', '대책']
# 지지도: 236, 패턴: ['방지', '교육', '및']
# 지지도: 236, 패턴: ['안전교육', '통한', '방지', '대책과', '계획']
# 지지도: 236, 패턴: ['안전교육', '통한', '대책과', '계획']
# 지지도: 236, 패턴: ['및', '안전교육', '향후']
# 지지도: 236, 패턴: ['및', '재발', '위한']
# 지지도: 236, 패턴: ['근로자', '안전교육', '통한', '대책']
# 지지도: 236, 패턴: ['방지를', '위한', '작업']
# 지지도: 236, 패턴: ['방지를', '안전교육', '및']
# 지지도: 236, 패턴: ['작업', '대한', '조치']
# 지지도: 236, 패턴: ['작업', '재발', '및', '계획']
# 지지도: 236, 패턴: ['작업', '제거']
# 지지도: 236, 패턴: ['교육', '및', '대한']
# 지지도: 236, 패턴: ['교육', '실시를', '통한', '재발', '방지', '대책']
# 지지도: 236, 패턴: ['교육', '실시를', '통한', '재발', '대책']
# 지지도: 236, 패턴: ['실시와', '방지', '향후', '계획']
# 지지도: 236, 패턴: ['전', '재발', '방지', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '재발', '방지', '대책', '및', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '재발', '방지', '대책', '향후', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '재발', '대책', '및', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '재발', '대책', '향후', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '방지', '대책', '및', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '방지', '대책', '향후', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '대책', '및', '조치', '계획']
# 지지도: 236, 패턴: ['작업자', '대책', '향후', '조치', '계획']
# 지지도: 236, 패턴: ['현장', '재발', '조치', '계획']
# 지지도: 236, 패턴: ['사고사례', '통한', '재발']
# 지지도: 236, 패턴: ['확보와']
# 지지도: 236, 패턴: ['안전사고', '재발', '방지']
# 지지도: 236, 패턴: ['특별', '안전교육']
# 지지도: 235, 패턴: ['시', '이동']
# 지지도: 235, 패턴: ['시', '점검', '및']
# 지지도: 235, 패턴: ['시', '후', '실시']
# 지지도: 235, 패턴: ['설치', '재발', '대책']
# 지지도: 235, 패턴: ['방지', '포함한', '향후']
# 지지도: 235, 패턴: ['방지', '포함한', '조치', '계획']
# 지지도: 235, 패턴: ['방지', '관리']
# 지지도: 235, 패턴: ['안전교육', '따른']
# 지지도: 235, 패턴: ['실시', '수립']
# 지지도: 235, 패턴: ['및', '제출']
# 지지도: 235, 패턴: ['및', '지속적인']
# 지지도: 235, 패턴: ['및', '교육', '통한', '재발', '방지', '대책']
# 지지도: 235, 패턴: ['및', '교육', '통한', '재발', '대책']
# 지지도: 235, 패턴: ['및', '현장', '안전교육']
# 지지도: 235, 패턴: ['및', '전', '통한']
# 지지도: 235, 패턴: ['및', '확인', '방지']
# 지지도: 235, 패턴: ['및', '강화를', '재발']
# 지지도: 235, 패턴: ['및', '상태', '및']
# 지지도: 235, 패턴: ['근로자', '교육', '철저']
# 지지도: 235, 패턴: ['방지를', '위한', '안전교육', '및']
# 지지도: 235, 패턴: ['작업', '교육', '및', '교육']
# 지지도: 235, 패턴: ['작업', '교육', '계획']
# 지지도: 235, 패턴: ['작업', '전', '작업', '작업']
# 지지도: 235, 패턴: ['작업', '전', '안전교육', '재발']
# 지지도: 235, 패턴: ['작업', '실시를', '재발', '방지']
# 지지도: 235, 패턴: ['대한', '위한']
# 지지도: 235, 패턴: ['실시와', '재발', '향후', '계획']
# 지지도: 235, 패턴: ['실시와', '방지', '향후', '조치']
# 지지도: 235, 패턴: ['후', '후']
# 지지도: 235, 패턴: ['전', '방지', '향후', '조치']
# 지지도: 235, 패턴: ['작업자', '통한', '방지', '및']
# 지지도: 235, 패턴: ['작업자', '재발', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 235, 패턴: ['작업자', '재발', '대책', '및', '향후', '조치', '계획']
# 지지도: 235, 패턴: ['작업자', '방지', '대책', '및', '향후', '조치', '계획']
# 지지도: 235, 패턴: ['작업자', '대책', '및', '향후', '조치', '계획']
# 지지도: 235, 패턴: ['안전', '및', '재발', '방지']
# 지지도: 235, 패턴: ['안전', '교육', '통한', '방지']
# 지지도: 235, 패턴: ['확인', '통한', '재발']
# 지지도: 235, 패턴: ['확인', '교육', '및']
# 지지도: 235, 패턴: ['사용', '철저']
# 지지도: 234, 패턴: ['시', '교육', '시']
# 지지도: 234, 패턴: ['시', '및', '전파']
# 지지도: 234, 패턴: ['시', '사용', '및']
# 지지도: 234, 패턴: ['재발', '방지를', '교육']
# 지지도: 234, 패턴: ['안전교육', '통한', '재발', '방지', '대책과', '계획']
# 지지도: 234, 패턴: ['안전교육', '통한', '재발', '대책과', '계획']
# 지지도: 234, 패턴: ['실시', '및', '작업', '및']
# 지지도: 234, 패턴: ['및', '작업', '작업', '실시']
# 지지도: 234, 패턴: ['및', '재발', '방지', '교육']
# 지지도: 234, 패턴: ['및', '실시', '관리']
# 지지도: 234, 패턴: ['및', '철저', '지시']
# 지지도: 234, 패턴: ['및', '전', '확인']
# 지지도: 234, 패턴: ['및', '강화를', '재발', '방지']
# 지지도: 234, 패턴: ['및', '점검을']
# 지지도: 234, 패턴: ['근로자', '안전교육', '통한', '방지', '대책']
# 지지도: 234, 패턴: ['근로자', '현장', '및']
# 지지도: 234, 패턴: ['작업', '전', '및', '조치', '계획']
# 지지도: 234, 패턴: ['대한', '점검']
# 지지도: 234, 패턴: ['실시와', '재발', '향후', '조치']
# 지지도: 234, 패턴: ['실시와', '철저를']
# 지지도: 234, 패턴: ['점검', '확인']
# 지지도: 234, 패턴: ['후', '향후']
# 지지도: 234, 패턴: ['현장', '방지', '조치', '계획']
# 지지도: 233, 패턴: ['시', '수립']
# 지지도: 233, 패턴: ['설치', '재발', '방지', '대책']
# 지지도: 233, 패턴: ['재발', '방지를', '위한', '교육']
# 지지도: 233, 패턴: ['재발', '포함한', '조치']
# 지지도: 233, 패턴: ['방지', '이행']
# 지지도: 233, 패턴: ['안전교육', '현장', '철저']
# 지지도: 233, 패턴: ['통한', '포함한', '조치']
# 지지도: 233, 패턴: ['통한', '포함한', '계획']
# 지지도: 233, 패턴: ['및', '통한', '안전사고']
# 지지도: 233, 패턴: ['및', '실시', '대책']
# 지지도: 233, 패턴: ['및', '및', '통한', '방지', '대책']
# 지지도: 233, 패턴: ['작업', '및', '방지', '조치']
# 지지도: 233, 패턴: ['실시와', '재발', '방지', '향후', '조치']
# 지지도: 233, 패턴: ['실시와', '재발', '방지', '향후', '계획']
# 지지도: 233, 패턴: ['실시와', '방지', '향후', '조치', '계획']
# 지지도: 233, 패턴: ['점검', '계획']
# 지지도: 233, 패턴: ['사고', '후']
# 지지도: 233, 패턴: ['전', '교육', '작업']
# 지지도: 233, 패턴: ['작업자', '및', '통한', '재발']
# 지지도: 233, 패턴: ['현장', '재발', '방지', '향후']
# 지지도: 233, 패턴: ['현장', '재발', '향후']
# 지지도: 233, 패턴: ['현장', '마련']
# 지지도: 233, 패턴: ['안전', '교육', '실시', '및']
# 지지도: 233, 패턴: ['안전', '교육', '현장']
# 지지도: 233, 패턴: ['상태', '확인', '및']
# 지지도: 233, 패턴: ['점검과']
# 지지도: 233, 패턴: ['안전수칙', '준수']
# 지지도: 233, 패턴: ['작업순서']
# 지지도: 233, 패턴: ['중량물', '작업']
# 지지도: 232, 패턴: ['시', '실시와', '및']
# 지지도: 232, 패턴: ['재발', '포함한', '계획']
# 지지도: 232, 패턴: ['방지', '포함한', '향후', '조치']
# 지지도: 232, 패턴: ['안전교육', '실시', '및', '및']
# 지지도: 232, 패턴: ['안전교육', '및', '재발', '방지', '조치']
# 지지도: 232, 패턴: ['안전교육', '대한', '향후', '조치']
# 지지도: 232, 패턴: ['안전교육', '강화를', '재발', '방지', '대책']
# 지지도: 232, 패턴: ['안전교육', '강화를', '재발', '대책']
# 지지도: 232, 패턴: ['안전교육', '교육', '실시']
# 지지도: 232, 패턴: ['안전관리', '향후']
# 지지도: 232, 패턴: ['및', '작업', '전', '교육']
# 지지도: 232, 패턴: ['및', '재발', '방지', '실시']
# 지지도: 232, 패턴: ['및', '시', '근로자']
# 지지도: 232, 패턴: ['작업', '전', '및', '작업', '및']
# 지지도: 232, 패턴: ['작업', '전', '상태']
# 지지도: 232, 패턴: ['작업', '전', '방지', '조치']
# 지지도: 232, 패턴: ['작업', '1조']
# 지지도: 232, 패턴: ['작업', '특별안전교육']
# 지지도: 232, 패턴: ['작업', '실시를', '통한', '방지']
# 지지도: 232, 패턴: ['실시와', '및', '통한', '방지']
# 지지도: 232, 패턴: ['실시와', '재발', '향후', '조치', '계획']
# 지지도: 232, 패턴: ['실시와', '전']
# 지지도: 232, 패턴: ['사고', '위한', '실시']
# 지지도: 232, 패턴: ['전', '및', '향후', '계획']
# 지지도: 232, 패턴: ['전', '교육', '철저']
# 지지도: 232, 패턴: ['전', '재발', '방지', '향후', '조치']
# 지지도: 232, 패턴: ['전', '재발', '향후', '조치']
# 지지도: 232, 패턴: ['현장', '재발', '방지', '조치', '계획']
# 지지도: 232, 패턴: ['현장', '방지', '향후', '조치']
# 지지도: 232, 패턴: ['전파', '교육', '및']
# 지지도: 232, 패턴: ['확인', '및', '현장']
# 지지도: 232, 패턴: ['불안전한', '실시']
# 지지도: 232, 패턴: ['제거', '실시']
# 지지도: 232, 패턴: ['관리감독자', '실시']
# 지지도: 231, 패턴: ['안전교육', '현장', '재발']
# 지지도: 231, 패턴: ['안전교육', '대한', '향후', '계획']
# 지지도: 231, 패턴: ['안전교육', '교육', '및']
# 지지도: 231, 패턴: ['안전교육', '통한', '방지', '대책과', '향후']
# 지지도: 231, 패턴: ['안전교육', '통한', '대책과', '향후']
# 지지도: 231, 패턴: ['실시', '수시']
# 지지도: 231, 패턴: ['실시', '배치']
# 지지도: 231, 패턴: ['통한', '포함한', '조치', '계획']
# 지지도: 231, 패턴: ['및', '방지', '대책', '수립']
# 지지도: 231, 패턴: ['및', '확인', '재발']
# 지지도: 231, 패턴: ['근로자', '안전교육', '통한', '재발', '방지', '대책']
# 지지도: 231, 패턴: ['근로자', '안전교육', '통한', '재발', '대책']
# 지지도: 231, 패턴: ['작업', '이동']
# 지지도: 231, 패턴: ['작업', '재발', '방지', '및', '조치']
# 지지도: 231, 패턴: ['작업', '및', '및', '재발', '방지']
# 지지도: 231, 패턴: ['작업', '통한', '방지', '조치', '계획']
# 지지도: 231, 패턴: ['작업', '전', '전']
# 지지도: 231, 패턴: ['실시와', '및', '향후', '조치']
# 지지도: 231, 패턴: ['실시와', '재발', '방지', '향후', '조치', '계획']
# 지지도: 231, 패턴: ['작업자', '실시와', '방지']
# 지지도: 231, 패턴: ['현장', '근로자', '및']
# 지지도: 231, 패턴: ['안전', '향후', '조치', '계획']
# 지지도: 230, 패턴: ['재발', '및', '및']
# 지지도: 230, 패턴: ['재발', '통한']
# 지지도: 230, 패턴: ['재발', '포함한', '조치', '계획']
# 지지도: 230, 패턴: ['방지', '포함한', '향후', '조치', '계획']
# 지지도: 230, 패턴: ['방지', '포함한', '향후', '계획']
# 지지도: 230, 패턴: ['방지', '후']
# 지지도: 230, 패턴: ['안전교육', '실시', '재발', '대책']
# 지지도: 230, 패턴: ['안전교육', '및', '방지', '계획']
# 지지도: 230, 패턴: ['안전교육', '대한', '향후', '조치', '계획']
# 지지도: 230, 패턴: ['안전교육', '철저를', '통한', '방지', '대책']
# 지지도: 230, 패턴: ['안전교육', '철저를', '통한', '대책']
# 지지도: 230, 패턴: ['실시', '안전관리']
# 지지도: 230, 패턴: ['통한', '안전교육', '실시']
# 지지도: 230, 패턴: ['및', '교육', '작업', '및']
# 지지도: 230, 패턴: ['및', '시', '및', '교육']
# 지지도: 230, 패턴: ['및', '지도']
# 지지도: 230, 패턴: ['향후', '및']
# 지지도: 230, 패턴: ['근로자', '설치']
# 지지도: 230, 패턴: ['위한', '안전교육', '철저']
# 지지도: 230, 패턴: ['작업', '시', '및', '안전교육']
# 지지도: 230, 패턴: ['작업', '및', '확인', '및']
# 지지도: 230, 패턴: ['작업', '및', '재발', '조치']
# 지지도: 230, 패턴: ['작업', '통한', '재발', '향후']
# 지지도: 230, 패턴: ['작업', '통한', '방지', '향후']
# 지지도: 230, 패턴: ['작업', '전', '및', '통한', '방지']
# 지지도: 230, 패턴: ['작업', '전', '안전교육', '철저']
# 지지도: 230, 패턴: ['작업', '2인', '1조']
# 지지도: 230, 패턴: ['작업', '확인', '방지']
# 지지도: 230, 패턴: ['교육', '실시와', '교육']
# 지지도: 230, 패턴: ['교육', '실시', '확인']
# 지지도: 230, 패턴: ['실시와', '및', '철저']
# 지지도: 230, 패턴: ['실시와', '및', '향후', '계획']
# 지지도: 230, 패턴: ['사고', '재발', '및']
# 지지도: 230, 패턴: ['사고', '사례', '및']
# 지지도: 230, 패턴: ['작업자', '통한', '재발', '및']
# 지지도: 230, 패턴: ['현장', '재발', '방지', '향후', '조치']
# 지지도: 230, 패턴: ['현장', '재발', '향후', '조치']
# 지지도: 230, 패턴: ['현장', '방지', '향후', '계획']
# 지지도: 230, 패턴: ['확인', '통한', '재발', '방지']
# 지지도: 230, 패턴: ['사례', '통한']
# 지지도: 230, 패턴: ['강화를', '향후', '계획']
# 지지도: 230, 패턴: ['수시', '재발']
# 지지도: 230, 패턴: ['해당', '대한']
